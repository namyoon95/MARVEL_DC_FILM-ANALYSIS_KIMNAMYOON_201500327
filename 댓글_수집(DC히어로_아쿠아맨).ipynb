# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(DC%ED%9E%88%EC%96%B4%EB%A1%9C_%EC%95%84%EC%BF%A0%EC%95%84%EB%A7%A8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=151153
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 151153
total_count = 595  ## 전체 크기= 595

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=151153&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 151153
total_count = 595  ## 전체 크기= 595

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['기차순무(heec****)',
#   '재밌으면 추천 재미없으면 비추 눌러주세요',
#   '10',
#   '11564',
#   '4433',
#   datetime.datetime(2018, 12, 19, 9, 55),
#   0],
#  ['fill****',
#   '엠버허드 졀라 이쁨ㅋㅋ',
#   '10',
#   '5443',
#   '243',
#   datetime.datetime(2018, 12, 19, 11, 25),
#   0],
#  ['소원열차(alst****)',
#   'DC 작품은 제임스완에게 맡기는걸로..',
#   '10',
#   '4864',
#   '535',
#   datetime.datetime(2018, 12, 19, 9, 19),
#   0],
#  ['촌철활인(sian****)',
#   '이 따위로 평점 받을 영화는 아닌데...스토리는 뻔하지만,그래도 눈요기 재대로 했다. 대형 수족관에 2시간 동안 다녀온 기분이다.',
#   '10',
#   '4660',
#   '516',
#   datetime.datetime(2018, 12, 19, 9, 27),
#   0],
#  ['스폰지밥(kuf4****)',
#   '제임스완이 DC를 살리는군요 공포만 잘하는게 아니라 히어로물도 스타일 잘살리네요평론가 평도 5점넘는 영화 오랜만이고 잘 다듬은것 같습니다 돈은 안아까운 영화',
#   '10',
#   '3583',
#   '394',
#   datetime.datetime(2018, 12, 19, 9, 41),
#   0],
#  ['달떵이(qkrg****)',
#   '엠버허드때문에 2번이상은 볼듯',
#   '10',
#   '3217',
#   '261',
#   datetime.datetime(2018, 12, 19, 10, 11),
#   0],
#  ['자유기사(gund****)',
#   'DC는 제임스완에게 큰절 한번 해야 한다. 스토리야 토르의 해양버전이라고 할만큼 전형적 영웅 판타지지만 영화 연출이 가히 역대급이다. 특히 통통배에서 바다좀비(?)를 만나 지구중심(?)으로 가기까지의 시퀀스는 보면서...',
#   '9',
#   '2650',
#   '240',
#   datetime.datetime(2018, 12, 19, 12, 53),
#   0],
#  ['빠냐냐(lepa****)',
#   '진짜 존잼 ㅋㅋㅋ 와 이거 씨쥐처리 대체 어케한거지?? 제작진 영혼 갈아넣은게 느껴진다',
#   '10',
#   '2544',
#   '200',
#   datetime.datetime(2018, 12, 19, 10, 8),
#   0],
#  ['genius(alex****)',
#   '평점 단 애들 dc 안티팬들인가.... 이정도면 히어로영화가 갖춰야할건 다 갖췄다고 본다. 특히 영상미는 10점줘도 안아까움!',
#   '9',
#   '2549',
#   '354',
#   datetime.datetime(2018, 12, 19, 9, 23),
#   0],
#  ['칸타타(viry****)',
#   '오글거리지만 끝내준다. 놀이기구탄 느낌?',
#   '10',
#   '2169',
#   '228',
#   datetime.datetime(2018, 12, 19, 9, 31),
#   0],
#  ['노량진공시충(ehdr****)',
#   '기승전메라 메라 진짜 와.. 너무 예쁘다..',
#   '10',
#   '2003',
#   '129',
#   datetime.datetime(2018, 12, 19, 12, 7),
#   0],
#  ['천년별(ghkd****)',
#   'DC의 반격!  드디어 마블에 대적할 대항마가 나타났다',
#   '9',
#   '1860',
#   '387',
#   datetime.datetime(2018, 12, 19, 9, 45),
#   0],
#  ['han9****',
#   '메라... 수많은 비주얼 속에서 압도적인..',
#   '10',
#   '1485',
#   '95',
#   datetime.datetime(2018, 12, 19, 14, 56),
#   0],
#  ['박성주(psj9****)',
#   '4대 맨 아이언맨, 휴잭맨, 배트맨, 아쿠아맨',
#   '10',
#   '1542',
#   '302',
#   datetime.datetime(2018, 12, 19, 9, 2),
#   0],
#  ['인간(tkek****)',
#   '스토리는 여전히dc답게평범한데 영상미 분위기가 ㄹㅇ지림 그나저나 이번에도 엄마는 못벗어났네 ㅋㅋ',
#   '9',
#   '1162',
#   '107',
#   datetime.datetime(2018, 12, 19, 9, 19),
#   0],
#  ['뱀파이어(sozi****)',
#   '개재밌다 아맥 황홀경~',
#   '10',
#   '1088',
#   '154',
#   datetime.datetime(2018, 12, 19, 9, 33),
#   0],
#  ['드래곤큐(bizk****)',
#   '파워레인저 + 인디아나존스 + 어비스 + 아바타 + 클로버필드 + 쥬라기공원 + 고질라',
#   '8',
#   '877',
#   '83',
#   datetime.datetime(2018, 12, 19, 18, 42),
#   0],
#  ['재이(oran****)',
#   'dc영화 개봉은 믿고거르던 마블빠인데 아쿠아맨 괜찮습니다! 근데 왠지모르게 자꾸 토르생각남..스토리전개나 주인공헤어스타일때문에그런지.. 어쨋든 긴시간치고 지루함도없어요! dc 딱 이대로만 가다오~~',
#   '9',
#   '870',
#   '104',
#   datetime.datetime(2018, 12, 19, 12, 53),
#   0],
#  ['무궁화꽃이(tmdw****)',
#   '물맨붐은....온다가 아니라 이미 왔다....',
#   '10',
#   '860',
#   '134',
#   datetime.datetime(2018, 12, 19, 9, 14),
#   0],
#  ['TAE(yuri****)',
#   '이건만 갑이에요 영상미가 대박',
#   '10',
#   '758',
#   '98',
#   datetime.datetime(2018, 12, 19, 9, 45),
#   0],
#  ['advkfj5454(zxcv****)',
#   '진심 지금까지 모든 히어로 영화중에선 가장 최고의 비주얼들을 보여준다.. 가히 아바타급의 영상미와 새로운 세계를보여주는 영화 아쉬운부분도 있으나 히어로오락영화로썬 최고인듯',
#   '10',
#   '645',
#   '54',
#   datetime.datetime(2018, 12, 19, 13, 35),
#   0],
#  ['장보근(bogl****)',
#   '경쾌하고 아름다웠다아쿠아맨 다웠던 영화',
#   '10',
#   '611',
#   '80',
#   datetime.datetime(2018, 12, 19, 9, 24),
#   0],
#  ['con1****',
#   '아쿠아맨 붐은 왔다!! 이제 DC 세상이 온다!!',
#   '10',
#   '654',
#   '126',
#   datetime.datetime(2018, 12, 19, 9, 49),
#   0],
#  ['메이(koin****)',
#   'DC가 드디어 해냈다!! 액션이 얼마나 박진감넘치던지..대박적..',
#   '10',
#   '590',
#   '79',
#   datetime.datetime(2018, 12, 19, 11, 24),
#   0],
#  ['까마귀(cq20****)',
#   'DC 코믹스 영화를 챙겨보게 만들 첫번째 이유',
#   '10',
#   '446',
#   '72',
#   datetime.datetime(2018, 12, 19, 9, 3),
#   0],
#  ['사람이라네(kgl0****)',
#   '재밌었어요 여주인공 너무 아름다워ㅛ',
#   '10',
#   '407',
#   '40',
#   datetime.datetime(2018, 12, 19, 18, 52),
#   '관람객'],
#  ['JUY00N(dao0****)',
#   '원더우먼부터 dc가 가야할 길을 정확히 보여준 것 같다. 마블이 현실적인 영웅을 그린다면, dc는 신화의 인물같은 영웅을 그린다. 그렇기에 누군가에겐 다소 유치하거나, 오그라들 수 있지만, 그것들이 내가 dc를 좋아...',
#   '10',
#   '397',
#   '42',
#   datetime.datetime(2018, 12, 19, 18, 58),
#   0],
#  ['보는건다조아(iles****)',
#   '와!! 어제 시사회로 봣는데...완전 짱이었어요.. 완전 쵝오였어요.ㅜ',
#   '10',
#   '410',
#   '73',
#   datetime.datetime(2018, 12, 19, 9, 40),
#   0],
#  ['Dio(savu****)',
#   '롯D왈드... 아쿠아x움, DC 해도 이것보다 싸게 입장할 수 없다.... 예매했는데 빨리보고싶어요.. 일단 기대점수로 올려요...후후...훗~~@',
#   '10',
#   '422',
#   '88',
#   datetime.datetime(2018, 12, 19, 9, 8),
#   0],
#  ['jiy7****',
#   '니콜키드먼 싸울 때 전율 일었다 존멋터져',
#   '10',
#   '358',
#   '37',
#   datetime.datetime(2018, 12, 19, 17, 5),
#   0],
#  ['왕눈이(deep****)',
#   '부족한점이 있기는 하지만 1점주는건 아닌겄같다',
#   '9',
#   '403',
#   '87',
#   datetime.datetime(2018, 12, 19, 10, 10),
#   0],
#  ['high****',
#   '어제 용아맥 시사로 봤는데 존잼! 꼭 아맥에서 보시길',
#   '10',
#   '390',
#   '95',
#   datetime.datetime(2018, 12, 19, 9, 2),
#   0],
#  ['똥꼬(ikar****)',
#   'IMAX로 첨 본 영화가 하필 이 영화라 익사하는줄',
#   '10',
#   '314',
#   '41',
#   datetime.datetime(2018, 12, 19, 17, 44),
#   0],
#  ['앙건빵(geun****)',
#   '재미는 있는데 뭔가 오글거리는 느낌이 계속 난다 ㅋㅋㅋㅋ',
#   '8',
#   '299',
#   '45',
#   datetime.datetime(2018, 12, 19, 11, 2),
#   0],
#  ['가을하늘(scjj****)',
#   '아바타 이후 눈호강 했다',
#   '10',
#   '285',
#   '34',
#   datetime.datetime(2018, 12, 19, 18, 6),
#   0],
#  ['아프로(xaxa****)',
#   '스토리와 클리셰는 뻔했지만, 볼거리와 연출이 이제껏 DC보다 훨 나음, 일단 그냥  CG떡칠로 일관했던 다른 DC영화보단 훨 CG 이용 잘 함. 감독이 이렇게 중요합니다 여러분',
#   '9',
#   '285',
#   '40',
#   datetime.datetime(2018, 12, 19, 14, 50),
#   0],
#  ['dlw(zion****)',
#   '지극히 평범한 스토리, 그러나 그걸 커버하는 엄청난 액션 장면들과 후반부의 거대한 스케일의 전투 장면이 단점을 커버한다. 확실히 재미는 있었다.',
#   '10',
#   '257',
#   '31',
#   datetime.datetime(2018, 12, 19, 12, 52),
#   0],
#  ['맨우진(tkeh****)',
#   '대체 1점을 왜준단 말이여,  비록 이 영화 하나로 마블에 맞서긴 힘들어도 화려한 액션과 훌륭한 연출은 보여주었다고 생각한다. CG처리는 말그대로 역대급이었고 시나리오도 훌륭하다 생각했다.  한국 영화 알바들이 지금...',
#   '10',
#   '267',
#   '51',
#   datetime.datetime(2018, 12, 19, 18, 30),
#   0],
#  ['오라클(zobo****)',
#   '저만 보기 아까울 정도로 오랜만에 정말로 재밌다고 생각한 영화입니다. 아바타를 처음 봤을때의 감동이 느껴졌네요. 너무 재밌습니다',
#   '10',
#   '238',
#   '34',
#   datetime.datetime(2018, 12, 19, 18, 26),
#   0],
#  ['손 채은(codm****)',
#   '아쿠아맨도 아쿠아맨이지만 메라가 대박',
#   '10',
#   '210',
#   '16',
#   datetime.datetime(2018, 12, 20, 14, 7),
#   '관람객'],
#  ['권녕우(rnjs****)',
#   'Dc는 항상 뭔가 부족한감이 잇었는데 아쿠아맨은 상상을 뛰어넘는 고퀄이었음...',
#   '10',
#   '217',
#   '27',
#   datetime.datetime(2018, 12, 19, 19, 21),
#   0],
#  ['ubola(ubol****)',
#   '아쿠아리움 보다는 아쿠아맨',
#   '10',
#   '236',
#   '48',
#   datetime.datetime(2018, 12, 19, 9, 40),
#   0],
#  ['공퉁이(just****)',
#   'Dc는 마더를 참 좋아하는듯 ㄷㄷ',
#   '10',
#   '207',
#   '25',
#   datetime.datetime(2018, 12, 19, 16, 14),
#   0],
#  ['boss****',
#   '아바타가 해저를 배경으로 한다면  이런 느낌이 아닐런지 ... 제임스완과 제이슨 모모아가 DC를 살려낸 공신. 감독의 역량과 배우들 간의 케미,, 마지막으로 잭스나이더가 유일하게 잘 한거라면 제이슨 모모아를 캐스팅한...',
#   '10',
#   '202',
#   '25',
#   datetime.datetime(2018, 12, 19, 14, 56),
#   0],
#  ['유감독(unh0****)',
#   '소통하는 지도자의 미덕을 볼 수 있다  아넘 재밌어 ㅋㅋㅋ 드럼 치던 오징어가 기억나네',
#   '10',
#   '193',
#   '17',
#   datetime.datetime(2018, 12, 19, 20, 11),
#   0],
#  ['DHR(ruyd****)',
#   '관객수 500만 넘길듯..',
#   '10',
#   '173',
#   '24',
#   datetime.datetime(2018, 12, 19, 19, 26),
#   0],
#  ['broh****',
#   '영화보고 집으로 돌아가는 길에 수족관에 들러 어항을 사가고 싶게끔 만드는 영화. 오전에 마약왕보고 오후에 아쿠아맨 봤는데 아쿠아맨이 압승',
#   '10',
#   '162',
#   '22',
#   datetime.datetime(2018, 12, 19, 17, 22),
#   0],
#  ['전세준(seju****)',
#   '제임스완은 넘사벽이다 진짜',
#   '10',
#   '157',
#   '23',
#   datetime.datetime(2018, 12, 19, 19, 2),
#   0],
#  ['한경호(hang****)',
#   '영상미 개쩐다 생각보다 좋았다',
#   '10',
#   '149',
#   '21',
#   datetime.datetime(2018, 12, 19, 20, 6),
#   0],
#  ['산신령(rink****)',
#   '최고네요! 어마어마한 그래픽만으로도 만점입니다. 올해 본 영화 중 최고였습니다.',
#   '10',
#   '134',
#   '13',
#   datetime.datetime(2018, 12, 20, 14, 39),
#   '관람객'],
#  ['듀로탄(bapj****)',
#   '조선똥알바충들 마약왕 보라고 비추에 점수주는거봐라',
#   '10',
#   '165',
#   '45',
#   datetime.datetime(2018, 12, 19, 12, 6),
#   0],
#  ['skd0****',
#   '아이맥스 3D로 봤는데 환상적인 그래픽과 비쥬얼,스케일에 압도되었다 스토리는 약간 뻔하지만 앰버허드도 너무 예쁘고 하여간 눈이 즐거운 영화다 돈안아깝다',
#   '10',
#   '131',
#   '17',
#   datetime.datetime(2018, 12, 19, 18, 8),
#   0],
#  ['이동훈(nexz****)',
#   '제임스완이 단디 이를 갈았구나 ㅋㅋ',
#   '10',
#   '127',
#   '15',
#   datetime.datetime(2018, 12, 20, 14, 7),
#   '관람객'],
#  ['silv****',
#   '드뎌 마블도 긴장할 때가 됐군요',
#   '10',
#   '149',
#   '37',
#   datetime.datetime(2018, 12, 19, 20, 35),
#   0],
#  ['극장마드리드(shin****)',
#   '어우 너무 재밌네요  우리 애가 좋아해요',
#   '10',
#   '157',
#   '54',
#   datetime.datetime(2018, 12, 19, 9, 55),
#   0],
#  ['기블리(skup****)',
#   '지금껏 본 히어로 무비중에서 유일하게 최고점을 줍니다 각복, 배우들의 연기, 액션, 판타지, 여정, 드라마, 환상 ㅇ어느것 하나 빠질게 없고 감독의 능력이 정말 대단하다고 할수밖에 없겠네요!!꼭 보시길!!',
#   '10',
#   '129',
#   '29',
#   datetime.datetime(2018, 12, 19, 19, 26),
#   0],
#  ['마리카(hjhc****)',
#   '여러분 이것이 DC의  클라스입니다.',
#   '10',
#   '123',
#   '26',
#   datetime.datetime(2018, 12, 19, 20, 11),
#   0],
#  ['이길도(dlrl****)',
#   '진짜 이건 마블도 ㅇ렇게 못만듬',
#   '10',
#   '129',
#   '32',
#   datetime.datetime(2018, 12, 19, 17, 17),
#   0],
#  ['레오(flux****)',
#   '2018 대미를 장식하는 최고의 오락영화 DC사라있눼~!',
#   '10',
#   '118',
#   '22',
#   datetime.datetime(2018, 12, 19, 17, 43),
#   0],
#  ['주공(ilsa****)',
#   '우주만큼 신비한 바다를 볼수있어서 재밌음',
#   '10',
#   '107',
#   '14',
#   datetime.datetime(2018, 12, 19, 19, 59),
#   0],
#  ['강정호(eins****)',
#   '넵튠의 삼지창 가지러 갈때 괴물들 개떼로 달려그는거 좀비 떼같이 잘 표현했던데 ㅋㅋㅋ 쏘우 애나벨 직쏘같은 공포영화 만든 제임스완이라 그컷은 최고였음... 분노의 질주에서 입증된 액션은 말할 필요도없음... 게임속 ...',
#   '9',
#   '98',
#   '8',
#   datetime.datetime(2018, 12, 19, 19, 14),
#   0],
#  ['왼발의베컴(smpu****)',
#   '시사회로 봤는데 영상미 진짜 개이쁘고 개재밌었다 진짜',
#   '10',
#   '108',
#   '19',
#   datetime.datetime(2018, 12, 19, 19, 23),
#   0],
#  ['핑구(vldr****)',
#   '재밌어요 스토리 지루하지도않고 오늘하루 잘즐겻어요',
#   '10',
#   '100',
#   '17',
#   datetime.datetime(2018, 12, 19, 23, 4),
#   '관람객'],
#  ['beautiful 갤럭시(lafa****)',
#   '히어로 영화의 반환점 !!!',
#   '10',
#   '118',
#   '36',
#   datetime.datetime(2018, 12, 19, 9, 2),
#   0],
#  ['RN(kiri****)',
#   '스토리를 떠나서 시각효과가 미침;;  상상속의 아틀란티스를 제대로 보여줌',
#   '10',
#   '85',
#   '8',
#   datetime.datetime(2018, 12, 19, 20, 30),
#   0],
#  ['에리(thee****)',
#   '이번년도 그 어떤 마블영화보다 재밌고 화려했다',
#   '10',
#   '134',
#   '58',
#   datetime.datetime(2018, 12, 19, 18, 4),
#   0],
#  ['반도젠(dlck****)',
#   '클리쉐가 너무 뻔해서 5초 후에 무슨일이 일어날지 뻔히 예상됨. 게다가 여주랑 로맨스 부분 개연성도 하나도 없고등장인물 한명 한명이 죄다 설명충임. 원래 히어로장르 영화가 조금은 유치한감이 조금씩 있는거야 당연하지만...',
#   '4',
#   '156',
#   '80',
#   datetime.datetime(2018, 12, 21, 8, 52),
#   0],
#  ['silk****',
#   '잼나요 연속으로 아쿠아맨보고 마약왕봤는데 아쿠아맨만 생각남 잘만들었다 마약왕보다가 졸았음 내부자들생각했다가 급실망',
#   '10',
#   '98',
#   '25',
#   datetime.datetime(2018, 12, 19, 18, 43),
#   0],
#  ['NEDVED와VERON(fkdl****)',
#   '완전 취향저격입니다  너무재밋게 봤습니다^^',
#   '10',
#   '83',
#   '11',
#   datetime.datetime(2018, 12, 19, 18, 2),
#   '관람객'],
#  ['Brenden(hoo3****)',
#   '개그는 약하지만 지금까지의 DC와는 다른 볼거리와 내용이 충실한 영화!',
#   '10',
#   '79',
#   '12',
#   datetime.datetime(2018, 12, 20, 14, 19),
#   '관람객'],
#  ['모찌(gilf****)',
#   '그냥 DC미역닦이 생선맨인줄 알았는데, 저스티스 리그, 어벤져스 다 합쳐도 진심 이 영화만 못하다. 올해 가장 눈이 즐거웠던 레디 플레이어 원보다도 눈이 즐거웠다.',
#   '10',
#   '81',
#   '15',
#   datetime.datetime(2018, 12, 19, 14, 48),
#   0],
#  ['Hoon(qw32****)',
#   '다른데는 첫 영화가 9시 전이였나보네 죄다 9시에 올라와있네..일단 본 사람 입장으로서는 진짜 재미있었어요. 진짜 바다 세상에 대한 로망을 품고 있는 제 입장에서는 와... 감탄이 절로 나오고 전율이 일더라구요 ㅋㅋ...',
#   '10',
#   '81',
#   '17',
#   datetime.datetime(2018, 12, 19, 20, 39),
#   0],
#  ['hy81****',
#   '유치하면서도 (처음으로) 시간가는 줄 모르고 본 DC 영화!',
#   '9',
#   '86',
#   '22',
#   datetime.datetime(2018, 12, 19, 19, 32),
#   '관람객'],
#  ['ㅇ사(kota****)',
#   '마약왕보고 상처받은 마음아쿠아맨보고 치유하고 갑니다',
#   '10',
#   '80',
#   '18',
#   datetime.datetime(2018, 12, 20, 12, 13),
#   0],
#  ['ionic(zzqn****)',
#   '확실히 아름다운 바닷속을 티비나 폰이 아닌 대형 스크린으로 봐서 되게 만족하구요 영화 스토리나 전개는 탄탄하고 미약하지만 감동도 있었음. 그리고 어릴적 동심을 불러일으키기도 했고ㅋ 대체적으로 재밌었음. 여주인공 메라...',
#   '10',
#   '65',
#   '9',
#   datetime.datetime(2018, 12, 19, 19, 42),
#   0],
#  ['유(na_j****)',
#   '이대로만 만들어줘~ 액션씬은 정말 잘 만들었다',
#   '7',
#   '80',
#   '24',
#   datetime.datetime(2018, 12, 19, 20, 7),
#   '관람객'],
#  ['새우(saew****)',
#   '오랜만에 영화관에서 눈호강 제대로 했다 . 속편 빨리 보고싶어요',
#   '10',
#   '65',
#   '10',
#   datetime.datetime(2018, 12, 19, 19, 29),
#   0],
#  ['여름날의 미풍(ssss****)',
#   '근래 보기 드문 그래픽!!!',
#   '10',
#   '68',
#   '13',
#   datetime.datetime(2018, 12, 19, 18, 54),
#   0],
#  ['tprem(dkfl****)',
#   'DC도 드디어 희망이 보이기 시작했다',
#   '10',
#   '67',
#   '13',
#   datetime.datetime(2018, 12, 19, 20, 51),
#   '관람객'],
#  ['wmfe****',
#   '어벤져스 처럼 피식거리게 되는 개그코드는 안맞지만 보고나오면 물속에 있다나온 기분임ㅋㅋㅋ아쿠아리움보다 백배나은 눈호강기분',
#   '10',
#   '65',
#   '12',
#   datetime.datetime(2018, 12, 19, 19, 49),
#   0],
#  ['jensen ackles(jens****)',
#   '스토리가 너무 유치해서 중간에 나오고 싶었어요',
#   '1',
#   '150',
#   '98',
#   datetime.datetime(2018, 12, 26, 3, 49),
#   0],
#  ['YSN(usl2****)',
#   '넘넘잼있음~~ 마블 못지 않음ㅎㅎ 이번영화는 아주 잘 만들었음!!!',
#   '10',
#   '63',
#   '13',
#   datetime.datetime(2018, 12, 19, 17, 43),
#   0],
#  ['wnrh****',
#   'DC영화중 최고고 영상미도 최고다',
#   '10',
#   '58',
#   '10',
#   datetime.datetime(2018, 12, 19, 18, 30),
#   0],
#  ['지원(qkrw****)',
#   '최고의 영상미. 들어갈때 돈내고 나올 때  또 걷어가도 바로 지갑열듯.',
#   '10',
#   '56',
#   '10',
#   datetime.datetime(2018, 12, 19, 19, 24),
#   0],
#  ['뿌꾸(lee6****)',
#   '아바타 를 보는듯 화려한 영상과 스토리 굿',
#   '10',
#   '54',
#   '9',
#   datetime.datetime(2018, 12, 19, 20, 2),
#   0],
#  ['폭풍속의 매(free****)',
#   '아이맥스 천호점에서 방금 보고나왔는데 저는 끝내주던데요',
#   '10',
#   '56',
#   '11',
#   datetime.datetime(2018, 12, 19, 19, 16),
#   0],
#  ['겸둥이(mong****)',
#   '진짜 잼났음. 바다에서 펼쳐지는거 신선하고 마블 진짜 좋아하는데 인피니티워 볼때는 좀 지루하기두 해서 몸 꼬였는데 개인적으론 이게 훨 눈요기 많고 잼났음. 한번 더 보고플정도 ...강추',
#   '10',
#   '60',
#   '16',
#   datetime.datetime(2018, 12, 19, 20, 21),
#   0],
#  ['joyo****',
#   '엠버 허드 존예 언니 사랑해요',
#   '10',
#   '51',
#   '8',
#   datetime.datetime(2018, 12, 21, 16, 17),
#   0],
#  ['하트머리(dais****)',
#   '보는내내..이건 뭐지 함.엄청 산만하고 쓸데없이 길어서 지루하고Ost도 영화도 막 5~6개 영화 섞어놓은 느낌..오글거리는 장면이 막 갑툭튀..몇몇 무기며 캐릭터는 너무 유치하고 비주얼도 어글리.. 그 해파리랑 파리...',
#   '1',
#   '154',
#   '111',
#   datetime.datetime(2018, 12, 25, 23, 7),
#   0],
#  ['코볼(scif****)',
#   '히어로물 역사상 끝판왕급  비주얼+ 히어로 판타지 크리처물 종합 선물세트',
#   '9',
#   '55',
#   '13',
#   datetime.datetime(2018, 12, 19, 17, 26),
#   0],
#  ['77kkkjs(1509****)',
#   '정말 재밌는 영화지만 , DC라는 걸 감안했을때 기대는 하지말고 제임스 완 이라는 걸 생각했을땐 꼭 보러가자 = 기대는 하지말고 꼭 보러가자',
#   '10',
#   '59',
#   '20',
#   datetime.datetime(2018, 12, 19, 18, 34),
#   0],
#  ['rrrt****',
#   '화려하다. DC 부활의 신호탄 이다',
#   '10',
#   '50',
#   '12',
#   datetime.datetime(2018, 12, 19, 20, 8),
#   0],
#  ['ksy0****',
#   '진짜 오랜만에 영화보다 잠들었다 물속에서 자는 느낌? 잘잤다',
#   '1',
#   '95',
#   '57',
#   datetime.datetime(2018, 12, 26, 1, 25),
#   0],
#  ['Jeong(jung****)',
#   '아이맥스 3d로 봤는데 정말정말 재밌었어요 !!!',
#   '10',
#   '48',
#   '12',
#   datetime.datetime(2018, 12, 19, 19, 5),
#   0],
#  ['youm****',
#   '진짜 히어로중  가장 멋지고 영상미  아쿠아맨보다  멋지고 아름다운 영화는  여지것 없었다  완전감동금빛갑옷  완전  멋짐  여주 캡이쁨',
#   '10',
#   '49',
#   '14',
#   datetime.datetime(2018, 12, 19, 17, 29),
#   0],
#  ['쌀양(sdas****)',
#   '액션 장난아니고 그래픽도 멋짐 스케일 환상적임ㅋㅋ DC영화 다봤지만 역대급인듯',
#   '9',
#   '43',
#   '9',
#   datetime.datetime(2018, 12, 19, 18, 28),
#   0],
#  ['컬이(duni****)',
#   '혹시나 해서  기대 안하고 봤는데 진짜진짜 역대 최고네!!!   기대이상 완전 잼남!!! 액션 그래픽 스케일 싸운드 ..눈이 쉴틈이 없이 볼거리가 한가위 같았심   2D 보는데 4D처럼 의자가 계속 움찔 들썩거려짐...',
#   '10',
#   '46',
#   '12',
#   datetime.datetime(2018, 12, 19, 18, 19),
#   0],
#  ['Ten(2692****)',
#   '똥고집을 버리고 오락에 집중한 DC코믹스의 화려한 반등',
#   '8',
#   '45',
#   '12',
#   datetime.datetime(2018, 12, 19, 20, 14),
#   0],
#  ['einl****',
#   'DC의 약점은 빌런들이 개연성이 없다는거다.',
#   '7',
#   '54',
#   '21',
#   datetime.datetime(2018, 12, 19, 16, 56),
#   0],
#  ['Style(myjj****)',
#   "좀전까지 '얘들 누구야?' 그래놓고 얘네들이 빛을 무서워한다는건 어디서 들은건지... 이런식으르 내용의 연계성이 없어 보는 내내 불편했다.관객들을 웃겨줄려면 확실하게 웃겨 주던지 그게 아니라면 완전 진...",
#   '1',
#   '127',
#   '94',
#   datetime.datetime(2018, 12, 26, 7, 2),
#   0],
#  ['배서희(seoh****)',
#   '엠버허드가 엄청이쁘다',
#   '10',
#   '42',
#   '10',
#   datetime.datetime(2018, 12, 19, 20, 3),
#   0],
#  ['김미르(acea****)',
#   '아빠때매 눈물흘림 ㅜㅜ 참 재밌게 봤어요 니콜키드먼 늙지도 않아 ㅜㅜ 여주 겁나이쁨 롤에 나오는 빨간머리 캐릭터닮음 ㅎㅎ아쉬운점은  흑인 악당 위협적이지않고 발연기같음 ㅋㅋ',
#   '10',
#   '39',
#   '8',
#   datetime.datetime(2018, 12, 21, 10, 3),
#   0],
#  ['Global(prol****)',
#   '난 마블 히어로들을 2시간 20분간 완전히 잊었었다.- IMAX 3D로 보시길 강력추천',
#   '10',
#   '42',
#   '11',
#   datetime.datetime(2018, 12, 20, 15, 4),
#   0],
#  ['oskk****',
#   '안본사람들은 모름....직접가서보시면..후덜덜',
#   '10',
#   '43',
#   '12',
#   datetime.datetime(2018, 12, 20, 14, 22),
#   0],
#  ['MIN_(i_do****)',
#   '최애 캐릭터 등극!!! 아이맥스보다 포디엑스 완전 추천 입니다ㅎㅎㅎ',
#   '10',
#   '45',
#   '14',
#   datetime.datetime(2018, 12, 19, 20, 2),
#   0],
#  ['김깔라(kimh****)',
#   '개꿀잼 꼭 보세요 ㅎㅎㅎ',
#   '10',
#   '46',
#   '15',
#   datetime.datetime(2018, 12, 19, 19, 26),
#   0],
#  ['KuMo(kumo****)',
#   '완님 제작 맡아줘서 고마워요 ㅠ오리지널 슈트도 멋지게 살려줘서 심장터져ㅠ완벽한 스토리라고 보긴 힘들겠지만 영혼갈아넣은cg와 액션,영상미,ost까지 멋지게 뽑아낸듯.저리때 떨어진 호흡기 갓동님이 다시 달아줌(모모아등근...',
#   '10',
#   '43',
#   '13',
#   datetime.datetime(2018, 12, 19, 20, 22),
#   0],
#  ['할수있다7(shck****)',
#   '그냥말이 필요없습니다 그냥보세요^^',
#   '10',
#   '45',
#   '15',
#   datetime.datetime(2018, 12, 19, 19, 30),
#   0],
#  ['코발트블랙(pnbw****)',
#   '영상미+엠버허드가 8점 다함.그리고 평점 알바가 있다는것도 알게됨..',
#   '8',
#   '36',
#   '7',
#   datetime.datetime(2018, 12, 19, 21, 40),
#   0],
#  ['hjsr****',
#   '볼거리 풍족하고 재밌었음아쿠아맨 멋지고 메라 비현적인 미모 실화? 나 여잔데 엠버허드한테 반함',
#   '10',
#   '38',
#   '10',
#   datetime.datetime(2018, 12, 19, 12, 49),
#   0],
#  ['rokettt(aktn****)',
#   '제임스완이 모든걸 넣었다 자신만의 공포색깔이랑 액션이랑 모두 즐겼다... 고맙다 너가 해냈다...',
#   '9',
#   '39',
#   '11',
#   datetime.datetime(2018, 12, 19, 12, 53),
#   0],
#  ['zoom****',
#   '한국 사람들 진짜  못된사람 많구나  , 마약왕 보게하려고 평점 ㅌ러알바가 있다니 ..;;;해외영화라고 까고보는 아ㄹ바 들 소름돋았습니다 ㅁ ㅏ야 ㄱ 와 ㅇ 보고왔지만 진짜 시간낭비 돈낭비 이건 10번도 볼수있음 가...',
#   '10',
#   '48',
#   '20',
#   datetime.datetime(2018, 12, 20, 13, 14),
#   0],
#  ['뽀잉이(glgl****)',
#   '이런 배우들로 어떻게 파워레인저를 찍을수가있음? 사막에서 인디아나존스 흉내도 내야되고 해리포터 인어도 나와야되고 대게군단도 나와야되고 블랙만타(헬멧꼭검색하셈) 개뜬금없이 나와서 줄거리 읊어주고 이태리 관광도 해야되고...',
#   '2',
#   '51',
#   '23',
#   datetime.datetime(2019, 1, 3, 21, 27),
#   0],
#  ['submarine(vela****)',
#   '내용없고 유치합니다 스토리 이런거 안보고 단순히 눈뽕에 취하고 싶으면 보세요..솔직히 유아용입니다',
#   '3',
#   '52',
#   '24',
#   datetime.datetime(2018, 12, 31, 8, 46),
#   0],
#  ['김민재(pon8****)',
#   '스토리 ㅈㄴ뻔하고 유치해도 비주얼이 모든걸 해결하네 ㅋㅋㅋㅋ 배대슈는 비쥬얼 좋아도 용서가 안됐는데 이건 눈뽕이 너무 차올라서 용서가됨 ㅋㅋ 워너는 완감독한테 큰절해라 디시 영화중 역대급으로 뽑아내셨다',
#   '10',
#   '35',
#   '8',
#   datetime.datetime(2018, 12, 19, 19, 9),
#   0],
#  ['포이즌쨈(joyj****)',
#   '물맨붐은 온다....',
#   '10',
#   '37',
#   '10',
#   datetime.datetime(2018, 12, 19, 20, 4),
#   0],
#  ['유현성(hyun****)',
#   '해냇다 드디어 디씨의부활',
#   '10',
#   '37',
#   '10',
#   datetime.datetime(2018, 12, 19, 17, 10),
#   0],
#  ['HOTEL(kisu****)',
#   'DC의 희망이다 존나 재밌다',
#   '10',
#   '38',
#   '11',
#   datetime.datetime(2018, 12, 19, 20, 39),
#   0],
#  ['어쩌라고뭐(wlsd****)',
#   '재밌었어요~~~~ 물속을 자유자재로 다니는거 넘 부럽 ㅋㅋㅋ쿠키영상으로 2가 나올거라는 느낌 퐉~!!아서 멋짐 멋짐~~',
#   '10',
#   '41',
#   '14',
#   datetime.datetime(2018, 12, 19, 13, 32),
#   0],
#  ['조효웅(gydn****)',
#   '마지막 전투 역대급!!!!',
#   '9',
#   '44',
#   '17',
#   datetime.datetime(2018, 12, 19, 19, 38),
#   0],
#  ['마법사(mung****)',
#   '이번꺼는 괜찮네요 안그래도 영화볼꺼 없었는데 !',
#   '10',
#   '33',
#   '7',
#   datetime.datetime(2018, 12, 19, 18, 34),
#   0],
#  ['egga(gagu****)',
#   '개꿀잼임 물고기 파닥파닥',
#   '10',
#   '35',
#   '9',
#   datetime.datetime(2018, 12, 20, 15, 26),
#   0],
#  ['이규웅(cine****)',
#   'DC 드디어 정신차리다.  역대 DC 영화중  최고작품 확실!',
#   '9',
#   '35',
#   '9',
#   datetime.datetime(2018, 12, 19, 18, 58),
#   0],
#  ['JH(zizi****)',
#   '이야... 보길 잘했다',
#   '10',
#   '35',
#   '9',
#   datetime.datetime(2018, 12, 19, 18, 2),
#   0],
#  ['원민기기(mink****)',
#   'DC가 드디어 정신을 차렸다! 라고 생각하시는 분은 추천!DC가 아직도 정신 못차렸다! 라고 생각하시는 분은 비추! 눌러주십시요.',
#   '10',
#   '36',
#   '10',
#   datetime.datetime(2018, 12, 22, 17, 22),
#   0],
#  ['아이즈원(jeon****)',
#   '내 기준으로는 재미있게 본듯, 근데 1점 준 사람은 도대체 어떻게 보는거야;;',
#   '10',
#   '39',
#   '13',
#   datetime.datetime(2018, 12, 19, 12, 10),
#   0],
#  ['valis(rnsw****)',
#   '오랜만에 DC에서 영화 제대로 만들었네유머코드도 억지스럽지 않고 잘 녹아들었고이게 기대치 최저에서 봐서 그런진 몰라도 잘만든거 같다',
#   '9',
#   '31',
#   '6',
#   datetime.datetime(2018, 12, 19, 18, 48),
#   '관람객'],
#  ['김정욱(wjdd****)',
#   '액션신 나올때마다 몸이 찌릿찌릿했음~ ㅎㅎ액션이랑 볼거리는 최고인듯 가끔 cg어색한것도 좀 있는데 못볼수준은 아님',
#   '8',
#   '34',
#   '9',
#   datetime.datetime(2018, 12, 19, 20, 1),
#   0],
#  ['캐릭터바이러스(jbra****)',
#   'DC는 엄마를 왜이렇게 좋아하냐?',
#   '5',
#   '66',
#   '41',
#   datetime.datetime(2018, 12, 20, 0, 12),
#   0],
#  ['응가똥(wown****)',
#   '남자 섹시하고 여자 개이쁩니다',
#   '10',
#   '28',
#   '4',
#   datetime.datetime(2018, 12, 23, 10, 51),
#   0],
#  ['낙찰(fodl****)',
#   '다시 보고 싶을 정도로 재밌었다',
#   '10',
#   '31',
#   '7',
#   datetime.datetime(2018, 12, 20, 15, 12),
#   0],
#  ['Jh River(pair****)',
#   '갑분싸 장면만 좀 수정하면 DC도 떡상 각 보이는데.. DC 버젼 토르 느낌 많이 들었음. 특히 다리 장면에서',
#   '7',
#   '31',
#   '7',
#   datetime.datetime(2018, 12, 19, 21, 50),
#   0],
#  ['은재형(skyh****)',
#   '히어로물중에 난 가장 재밌었음',
#   '10',
#   '33',
#   '9',
#   datetime.datetime(2018, 12, 19, 19, 12),
#   0],
#  ['ㅇㅇ(yous****)',
#   '미친 졸라 재밌는거 실화냐',
#   '10',
#   '34',
#   '10',
#   datetime.datetime(2018, 12, 19, 23, 8),
#   0],
#  ['신조아(joas****)',
#   '오랜만에 보는 SF인가 ㅠㅠ 목말랏는데 시원하게 적셔주네',
#   '10',
#   '34',
#   '10',
#   datetime.datetime(2018, 12, 19, 20, 0),
#   0],
#  ['아자아자아자(moku****)',
#   '대에박....아바타를 처음봤을때 감동임... 후덜덜',
#   '10',
#   '35',
#   '11',
#   datetime.datetime(2018, 12, 19, 17, 27),
#   0],
#  ['블랙펄(xodn****)',
#   '댓글알바에 쓴 비용이 cg처리에 쓴 비용보다 높을수도',
#   '2',
#   '40',
#   '16',
#   datetime.datetime(2019, 1, 3, 20, 44),
#   0],
#  ['사류작가(kkl0****)',
#   '니콜키드만 아들이 수협회장(오션 마스터) 되는 이야기',
#   '8',
#   '30',
#   '7',
#   datetime.datetime(2018, 12, 19, 20, 36),
#   0],
#  ['감이(y2k4****)',
#   '좀 유치하지만.   멋진스케일 ...끝나고 계속 앉아있으세요 더나옵니다',
#   '8',
#   '31',
#   '8',
#   datetime.datetime(2018, 12, 19, 19, 25),
#   0],
#  ['ghkd****',
#   '재밌다 메라 개이쁘다ㅎㅎ',
#   '8',
#   '23',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 17),
#   '관람객'],
#  ['이우석(dldn****)',
#   '마블은 좀 더 인간적인 모습의 영웅을 그렸다면, 이번 아쿠아맨 영화에서는 영웅이 존재한다면 이런 모습이 아닐까라는 상상을 화려하게 색칠한것 같다.',
#   '10',
#   '29',
#   '7',
#   datetime.datetime(2018, 12, 20, 0, 30),
#   '관람객'],
#  ['MIJIN(dlal****)',
#   '아믿고보는 제임스완 진짜 공포도 딱 내취향인데 히로영화도 내취향으로 ㅠㅠ꼭보세요 진짜 또보러가야할듯 그나저나 옴아저씨가 인시디어스 아부지라니...ㅋㅋㅋ상상도못한정체다',
#   '10',
#   '29',
#   '7',
#   datetime.datetime(2018, 12, 19, 19, 25),
#   0],
#  ['냐옹선생(chic****)',
#   'cg 장난아니고 액션씬 볼만하고 여주인공 매력적이고 게다가 음악도 좋다 그런데 스토리가 유치 ;; 그리고 주인공은 프로레슬러 같음. 아깝다 저런 기술력으로 저런 이야기밖에 못만들다니....',
#   '7',
#   '30',
#   '8',
#   datetime.datetime(2018, 12, 20, 0, 1),
#   0],
#  ['wjdt****',
#   '하..여러분..진심안보면 2018 년도후회하십니다저평점처음 남겨보는데 진심 진심 꼭보세요 진짜 최고다..와ㅋㅋ이거보고후회하는사람없습니다 최고',
#   '10',
#   '31',
#   '9',
#   datetime.datetime(2018, 12, 20, 12, 13),
#   0],
#  ['영맨(joon****)',
#   '그냥 겁나 재밌음. 꼭 보셈',
#   '10',
#   '32',
#   '10',
#   datetime.datetime(2018, 12, 19, 16, 2),
#   0],
#  ['포스(joon****)',
#   '엄청난 스케일의 볼거리. 어쩌면 이건 통할 것 같다는 생각이 든다.',
#   '10',
#   '36',
#   '14',
#   datetime.datetime(2018, 12, 19, 11, 23),
#   '관람객'],
#  ['쭈니별(zing****)',
#   '올해 최고영화!!!   스트레스 확 풀림',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2018, 12, 23, 2, 38),
#   0],
#  ['필립(peac****)',
#   '빨간머리 이렇게 잘 어울리는 배우는 처음봄...ㅋㅋ',
#   '8',
#   '25',
#   '4',
#   datetime.datetime(2018, 12, 23, 10, 51),
#   0],
#  ['꾸우(kimd****)',
#   '비주얼 끝판급 진짜 재밌게 봤음 그리고 메라갓',
#   '10',
#   '27',
#   '6',
#   datetime.datetime(2018, 12, 19, 20, 17),
#   0],
#  ['재(jin5****)',
#   '제임스완이 살리긴 뭘 살려. 제임스완 영화들 전개 뜬금 없어서 감안하고 봤는데 이건 심각하지 않냐? 정신 연령 12세 이하들이나 좋아할 듯. 영상은 게임이냐? 바닷속 인물들 모션 캡쳐 안했는지 무브도 어색하고 형광펜...',
#   '1',
#   '31',
#   '10',
#   datetime.datetime(2019, 1, 11, 13, 2),
#   0],
#  ['형은(ggud****)',
#   'DC치고 나쁘지 않은..',
#   '7',
#   '37',
#   '16',
#   datetime.datetime(2018, 12, 19, 19, 23),
#   0],
#  ['lime****',
#   '재밌게 잘봤습니다. 마블이랑  다른느낌',
#   '10',
#   '26',
#   '6',
#   datetime.datetime(2018, 12, 19, 18, 19),
#   0],
#  ['제브(vydf****)',
#   '아쿠아맨 생각만큼 재미있게봤어요.그래픽도 화려하고 진짜 시간 가는줄 모르고 봤어요',
#   '10',
#   '28',
#   '8',
#   datetime.datetime(2018, 12, 20, 1, 13),
#   '관람객'],
#  ['선생(yys4****)',
#   '역대급. 초절정 미녀 여주인공 두명 간지나는 히어로 엄청난 영상미. 배트맨 슈퍼맨처럼 진지빠는 것도 아니고 적당한 유쾌함도 있으며 화려한 괴수들과 적당한 능력치의 히어로. 실제 그리스로마 신화와 바다로 가라앉은틸란티...',
#   '10',
#   '28',
#   '8',
#   datetime.datetime(2018, 12, 19, 20, 15),
#   0],
#  ['안녕(rody****)',
#   '난 졸잼이었다. 다른 DC영화는 몰라도 아쿠아맨은 마블과 비교해도 꿀리지 않는다. 그리고 전투신 만큼은 리얼 최고;;; DC영웅 하나면 타노스랑 혼자 1:1 가능할듯;;',
#   '10',
#   '29',
#   '9',
#   datetime.datetime(2018, 12, 20, 1, 22),
#   0],
#  ['슈퍼에디(envy****)',
#   '말이 필요없다 다 재밌슴',
#   '10',
#   '31',
#   '11',
#   datetime.datetime(2018, 12, 19, 16, 6),
#   0],
#  ['지나종민(jiji****)',
#   '요 몇달 새에 본 영화중 가장 볼거리 많고 재미있었습니다. 강추 합니다.',
#   '10',
#   '23',
#   '4',
#   datetime.datetime(2018, 12, 21, 15, 7),
#   0],
#  ['지난(aldu****)',
#   '상남자  짱, 메라의 재발견. 스토리는 고전적인 뻔한 전개지만 히어로물 중에서 수중물은 없었고,  큰 영화관 스크린으로 즐기기에는 충분했다.',
#   '10',
#   '23',
#   '4',
#   datetime.datetime(2018, 12, 20, 14, 24),
#   0],
#  ['멤피(mes5****)',
#   '어벤져스 2보단 좋았음',
#   '10',
#   '24',
#   '5',
#   datetime.datetime(2018, 12, 23, 22, 6),
#   0],
#  ['써치라이트(anag****)',
#   '아이맥스 3D로 보세요, 정말 새로운 세상을 구현했네요. 스토리는  일부 설정이 엉성하지만, 다른 영화도 그 정도 설정 오류는 있는 듯 싶어요. 전 정말 재밌게 봤습니다.',
#   '9',
#   '24',
#   '5',
#   datetime.datetime(2018, 12, 21, 14, 53),
#   0],
#  ['qqq(clxh****)',
#   '내용이 너무 유치해서 그저 그랬다..',
#   '6',
#   '25',
#   '6',
#   datetime.datetime(2019, 1, 3, 22, 5),
#   '관람객'],
#  ['hyun0420(ru_d****)',
#   '판타지 보다가 울었음 ㅠㅜ',
#   '10',
#   '26',
#   '7',
#   datetime.datetime(2018, 12, 21, 14, 57),
#   0],
#  ['cherry blossoms(whgo****)',
#   '크리미갈릭핫도그소스 흘리고 있는줄 모르고 먹으면서 봤어요 ...재밌습니다!',
#   '10',
#   '26',
#   '7',
#   datetime.datetime(2018, 12, 19, 19, 24),
#   0],
#  ['허브유(herb****)',
#   '진짜 재밌어요 솔직히 원더우먼은 기대 이하였는데 아쿠아맨 진짜 최곱니다 안 보고 함부로 판단하지 마세요',
#   '10',
#   '27',
#   '8',
#   datetime.datetime(2018, 12, 19, 20, 17),
#   0],
#  ['인간(alst****)',
#   '아바타 이후로 눈정화 는 오랜만이다.',
#   '10',
#   '28',
#   '9',
#   datetime.datetime(2018, 12, 19, 18, 41),
#   0],
#  ['마카로니(wsn5****)',
#   '진짜 기대 안하고 봤는데 여주도 이쁘고 음악도 지리고 스케일은 또 얼마나 큰지 ...ㄷㄷ 액션씬도 대박임 말그대로 꿀잼 ㅎㅎ',
#   '10',
#   '29',
#   '10',
#   datetime.datetime(2018, 12, 20, 0, 27),
#   '관람객'],
#  ['다우림(zndk****)',
#   '뛰어난 영상미와 볼거리!! 액션도 굳!!작정하고 감독의 창의력을 팍팍 밀어준 DC수뇌부에 심심한 감사를..',
#   '10',
#   '21',
#   '3',
#   datetime.datetime(2018, 12, 21, 10, 37),
#   0],
#  ['그리다(ehyu****)',
#   '시간이 안 느껴질 정도!!',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 51),
#   0],
#  ['우디(woul****)',
#   '내용은 솔직히 그냥 전형적인 히어로물영상미 CG가 매우 좋음DC 영화 통틀어 그냥 가장 볼만함이딴거 제쳐두고서라도 엠버허드 보러가는건만해도 10점임',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 12, 20, 15, 20),
#   0],
#  ['Flawlex(flaw****)',
#   '예산 많이 든 백터맨 보는 느낌',
#   '1',
#   '23',
#   '5',
#   datetime.datetime(2019, 1, 3, 21, 55),
#   0],
#  ['달려보자(kimd****)',
#   '재밌네요 ㅋ 지루하지 않게 잘봤습니다.중간중간 재밌는요소도 많고 볼거리가 많네요',
#   '10',
#   '23',
#   '5',
#   datetime.datetime(2018, 12, 19, 18, 47),
#   0],
#  ['사바하(june****)',
#   '무슨 마약왕과 비교를 하냐~존나 재밌게 봤다!! 아쿠아맨 코스튬과 삼지창을 얻게되는 과정을 잘 보여준것같다..그리고!!!!. 마지막 스틸샷 존나 멋짐!!',
#   '10',
#   '24',
#   '6',
#   datetime.datetime(2018, 12, 20, 12, 9),
#   0],
#  ['jbg2****',
#   '와 영상미 아바타이후 역대급이였다 알바새기들넘쳐나는 마약왕안본것이  신의한수였다  평점 9점대로올리자  dc판 토르보는줄알았다 아주깔끔한 히어로물이였다',
#   '10',
#   '28',
#   '10',
#   datetime.datetime(2018, 12, 19, 23, 53),
#   0],
#  ['Mr 몽블랑(dooo****)',
#   '이번에도 어머니로 대동 단결하는 DC 영화다.다만, 액션씬과 대규모 전투씬 등 볼거리가 풍성하기 때문에아이맥스 3D 로 보는 것을 권장.앰버 허드는 존예보스,제이슨 모모아 눈빛 지림 주의 (특히 삼지창 획득하고 폭포...',
#   '8',
#   '18',
#   '1',
#   datetime.datetime(2018, 12, 21, 17, 57),
#   0],
#  ['모사모사모사(hors****)',
#   '영화티켓값이 아깝지 않은 영화였습니다!',
#   '10',
#   '20',
#   '3',
#   datetime.datetime(2018, 12, 23, 2, 26),
#   '관람객'],
#  ['별명(flye****)',
#   '눈한번 깜짝였는데 영화끝났네요 짱재밌음',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 37),
#   0],
#  ['hanm****',
#   'DC 시리즈중 역대급 인듯.2시간 20분이 어찌 지나가는지 몰랐음.볼것이 너무 풍성했고 남여 주인공 간에 코믹대화도 괜찮았고 특히 장면마다 효과음을 굉장히 잘 나타낸듯. 꼭 보세요. 후회 없을듯.4DX로 봐도 재미있...',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 22),
#   0],
#  ['ojl2****',
#   '이런 cg는진짜 역대급이다처음에아쿠아맨이라구해서진짜유치할줄알았는데 진짜아쿠아리움실제가서보는것보다훨씬났다 그리고여주인공은가히 너무이쁘다 아쿠아맨몸도엄청좋고 카리스마가느껴진다 그리고환경과 인간의무자비한 잔인성도느껴진다교...',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 1),
#   0],
#  ['정지은(ccmj****)',
#   '딱 초등학교 남자아이들 수준 영화',
#   '1',
#   '22',
#   '5',
#   datetime.datetime(2019, 1, 1, 22, 16),
#   0],
#  ['이재이씨(i_ej****)',
#   '마블에 넘 눈이 높아졌나캐릭터의 깊이도 줄거리의 개연성도 부족한데정신없는 액션만 과한 영화2편은 안본다 ㅠ',
#   '4',
#   '25',
#   '8',
#   datetime.datetime(2018, 12, 31, 8, 37),
#   0],
#  ['난천재(akzk****)',
#   '완동님 사랑합니다 ㅠㅠ',
#   '10',
#   '25',
#   '8',
#   datetime.datetime(2018, 12, 19, 19, 26),
#   0],
#  ['lees****',
#   'DC가 CG했다 쿠키영상있대요 꼭 보고오세요',
#   '10',
#   '25',
#   '8',
#   datetime.datetime(2018, 12, 19, 10, 3),
#   0],
#  ['주희(rlaw****)',
#   '재밌었어요 문어가 북치는게 제일 웃김ㅋㅋㅋ',
#   '10',
#   '17',
#   '1',
#   datetime.datetime(2018, 12, 30, 13, 4),
#   0],
#  ['geen****',
#   '아이들과 봤는데 어른인저도 재미있게 봤어요',
#   '10',
#   '17',
#   '1',
#   datetime.datetime(2018, 12, 23, 21, 55),
#   '관람객'],
#  ['임수빈(ppp1****)',
#   '퀄리티 오지고요 두시간 넘게 하는줄모르고 봤는데 두시간 넘게 걸린줄 모르고 끝났습니다. 제발 봐주세요! 너무뻔하지도 않고 액션 위주로 나와서 정말 재밌습니다. 개인적으로 주인공 캐릭터가 적당히 코미디도 있어서 지루할...',
#   '10',
#   '18',
#   '2',
#   datetime.datetime(2018, 12, 26, 14, 52),
#   '관람객'],
#  ['gusd****',
#   '너무 재밌게 잘봤습니다 아이들과 또 보고싶네요 강추합니다 최고에요',
#   '10',
#   '19',
#   '3',
#   datetime.datetime(2018, 12, 24, 13, 14),
#   '관람객'],
#  ['한결(kook****)',
#   '와... 디씨 영화맞아? 황홀했다...',
#   '10',
#   '21',
#   '5',
#   datetime.datetime(2018, 12, 23, 1, 41),
#   '관람객'],
#  ['다알(taey****)',
#   '진짜 너무 재밌고 아쿠아리움 갈 바에 이 영화 보는 것을 추천할 정도로 영상미 오지고 메라 엄청 이쁘고.. 암튼 추천입니다ㅋㅋ 개인적으로 올해 가기 전에 꼭 봐야할 작품',
#   '10',
#   '21',
#   '5',
#   datetime.datetime(2018, 12, 20, 12, 14),
#   0],
#  ['주니(gusw****)',
#   '원더우먼과 아쿠아맨은 dc의 구세주가 됐다.',
#   '8',
#   '22',
#   '6',
#   datetime.datetime(2018, 12, 23, 10, 47),
#   0],
#  ['gksx****',
#   '퍼시픽림 잼있게 보셨던 분들은 보셔도 좋은듯스케일크고 전투신 화려한데 유치오글ㅋㅋ 그래도 액션신만큼은 제작진의 노력이 보인다는',
#   '7',
#   '22',
#   '6',
#   datetime.datetime(2018, 12, 21, 7, 50),
#   0],
#  ['또진(thwl****)',
#   '헐~♡ 너무재밋엇어요!!♡',
#   '10',
#   '22',
#   '6',
#   datetime.datetime(2018, 12, 19, 20, 39),
#   0],
#  ['난나야(sold****)',
#   '재밌어요. 스토리는 뻔하지만, 영상미 몰입감 좋습니다.',
#   '10',
#   '23',
#   '7',
#   datetime.datetime(2018, 12, 19, 19, 32),
#   0],
#  ['스말맨(smil****)',
#   '스토리보다 볼꺼리가 많은 영화네요~기대보다 잼나는 영화',
#   '9',
#   '16',
#   '1',
#   datetime.datetime(2018, 12, 26, 19, 56),
#   '관람객'],
#  ['황은지(eunj****)',
#   '진짜 사운드도 너무 좋고 배경도 수족관온듯 신기하고 예쁘고 재밌고 깜짝놀라게하는 장면도 재밋고  놀이기구타는것처럼 재밌었음',
#   '10',
#   '16',
#   '1',
#   datetime.datetime(2018, 12, 26, 19, 56),
#   0],
#  ['맛있는쓰레기(ph22****)',
#   '눈깔 괴물말곤 다 궨찮았는데... 솔직히 소름돋으면서 봄 개꿀잼이었는데 특히 메라가 이뻤음',
#   '10',
#   '16',
#   '1',
#   datetime.datetime(2018, 12, 25, 21, 30),
#   0],
#  ['강선모(asdn****)',
#   '10점 잘안주는데 이거 10점짜리입니다.4D로봤는데 더 재밌어요',
#   '10',
#   '17',
#   '2',
#   datetime.datetime(2018, 12, 23, 2, 59),
#   0],
#  ['다호선(qwq1****)',
#   '엠버허드  존나 예쁘다  나는 오늘부터 내 머리속 생각하는서양인중에서 졸라이쁘고 매혹적인 배우로 엠버허드를  뽑을꺼다',
#   '10',
#   '18',
#   '3',
#   datetime.datetime(2018, 12, 28, 1, 55),
#   '관람객'],
#  ['area(rang****)',
#   '연출도 멋있고 전체적으로 비쥬얼폭발. 눈요기 너무 좋았음..그리고 엠버허드 너무 예쁘고 멋있게 나옴',
#   '9',
#   '18',
#   '3',
#   datetime.datetime(2018, 12, 25, 5, 54),
#   0],
#  ['Johee(qkr3****)',
#   '솔직히 진심 핵잼이다 최소 500만간다',
#   '10',
#   '18',
#   '3',
#   datetime.datetime(2018, 12, 23, 21, 59),
#   0],
#  ['YNWA 96 Liverpool(nice****)',
#   '스크린X로보고왔습니다  한국영화의 고질병 스크린독점 너무하더군요  마약왕 -_- OOO기영화입니다 그리고 아쿠아맨 영상부터 스토리 부족한점 하나도없네요',
#   '10',
#   '18',
#   '3',
#   datetime.datetime(2018, 12, 19, 18, 26),
#   0],
#  ['컴트루(perk****)',
#   '볼거리 스토리 모두 좋습니다DC 걸작',
#   '10',
#   '19',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 51),
#   0],
#  ['복캣(iceb****)',
#   'IMAX 3D 관람 필수! 아바타이후 이런 압도적인 3D 체험은 실로 오랫만!',
#   '9',
#   '19',
#   '4',
#   datetime.datetime(2018, 12, 19, 20, 4),
#   0],
#  ['inhi****',
#   '솔직하게 최근에 본 오락영화 중 최고였다',
#   '10',
#   '20',
#   '5',
#   datetime.datetime(2018, 12, 21, 14, 40),
#   0],
#  ['쎈(good****)',
#   '오랜만에 히어로물 잼나게 봤네요',
#   '10',
#   '20',
#   '5',
#   datetime.datetime(2018, 12, 19, 18, 12),
#   0],
#  ['바퀴님(bloo****)',
#   '드디어 DC가 해냈습니다 ! ㅠㅠ',
#   '10',
#   '21',
#   '6',
#   datetime.datetime(2018, 12, 19, 20, 24),
#   0],
#  ['hughnew(hwct****)',
#   '나는 잘 모르겠다..CG떡칠하면 영상미 좋은건가..배경이 바다속이라기 보다 우주공간에 물고기 풀어놓은 느낌..전투씬은 모바일게임 광고 보는 느낌이었어..물속에서 헤엄도 안치는데 이동이 가능하고..그리고 DC는 왜 항...',
#   '3',
#   '22',
#   '7',
#   datetime.datetime(2019, 1, 8, 20, 5),
#   0],
#  ['김치만(tech****)',
#   "시각효과 액션은 볼만하나 뭔가 '그이상의 어떤것'을 만들어내진 못했음. 다크나이트? 풉‥엠버허드 매력은 인정~",
#   '7',
#   '22',
#   '7',
#   datetime.datetime(2018, 12, 19, 20, 21),
#   0],
#  ['Jonny(cjdg****)',
#   'DC도 영화재미있게 만들수있잔아요!! 화이팅~~',
#   '10',
#   '22',
#   '7',
#   datetime.datetime(2018, 12, 19, 18, 43),
#   '관람객'],
#  ['라벤더퍼플(daum****)',
#   '나쁘진 않았지만 그렇다고 그렇게 좋지도...',
#   '7',
#   '28',
#   '13',
#   datetime.datetime(2018, 12, 19, 21, 34),
#   0],
#  ['젊은순수(nam1****)',
#   '평점테러 있어서 10점 주고 간다...볼만한 히어로물...최근 개봉작중에 스파이더맨 다음으로 좋았다',
#   '10',
#   '14',
#   '0',
#   datetime.datetime(2018, 12, 26, 14, 53),
#   0],
#  ['김다희(qkdt****)',
#   '진짜 그냥 넋 놓고 봤다..',
#   '10',
#   '15',
#   '1',
#   datetime.datetime(2018, 12, 26, 20, 23),
#   0],
#  ['lkjh****',
#   '대박대박 돈이 안아까워요',
#   '10',
#   '15',
#   '1',
#   datetime.datetime(2018, 12, 25, 21, 35),
#   0],
#  ['데느님(z2in****)',
#   '어쩌다 DC의 가장이 되버린 아쿠아맨, 아쿠아맨의 진정한 주인공은 메라였다.',
#   '8',
#   '15',
#   '1',
#   datetime.datetime(2018, 12, 24, 15, 43),
#   0],
#  ['히비(dxka****)',
#   '영상이랑 액션은 괜찮은데 스토리가..',
#   '8',
#   '15',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 24),
#   0],
#  ['pjw5****',
#   '진심 아이언맨보다 재밋다',
#   '10',
#   '17',
#   '3',
#   datetime.datetime(2018, 12, 23, 1, 1),
#   0],
#  ['lche****',
#   '원더우먼이 최고였는데 아쿠아맨으로 갈아탔다 메라존예....',
#   '10',
#   '18',
#   '4',
#   datetime.datetime(2018, 12, 20, 15, 47),
#   0],
#  ['내가그린기린그림은(yakh****)',
#   '눈이 황홀한 영화ㅠㅠ보는 내내 입벌리게됨 ㅋㅋ',
#   '10',
#   '20',
#   '6',
#   datetime.datetime(2018, 12, 20, 11, 56),
#   '관람객'],
#  ['장지민(pink****)',
#   '영화 막바지에 노래부분 나오는데, 사람들 끝난줄 알고, 나감 ㅜㅜ노래끝나고, 2편 암시하는 주인공 저격하는 놈들 대화부분있는데영화관관리하는사람도 사람들 노래중에 , 나가니깐 끝난줄 알고,문 활짝 열던데, 영화 수준좀...',
#   '10',
#   '29',
#   '15',
#   datetime.datetime(2018, 12, 19, 12, 50),
#   '관람객'],
#  ['김민지(kimm****)',
#   '올해 본 영화 싹 다 합쳐서 제일 재밌다',
#   '10',
#   '13',
#   '0',
#   datetime.datetime(2018, 12, 23, 2, 25),
#   0],
#  ['smw2****',
#   '영화 개꿀잼 ㅇㅈ따리?',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2018, 12, 28, 4, 22),
#   '관람객'],
#  ['bm90****',
#   '좀 길어요 ㅋ마치 게임하는 기분',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2018, 12, 25, 13, 34),
#   '관람객'],
#  ['cwal****',
#   '영상미 액션 등등 나쁘지않았어요',
#   '10',
#   '15',
#   '2',
#   datetime.datetime(2018, 12, 24, 13, 15),
#   0],
#  ['도라지무침(tjrg****)',
#   '개인적으로 히어로물 좋아하는데 DC가 앞으로도 이정도로 뽑아주면 마블과 좋은 경쟁이 될거 같아요. 추천합니다^^',
#   '10',
#   '16',
#   '3',
#   datetime.datetime(2018, 12, 21, 14, 20),
#   0],
#  ['케이스(my53****)',
#   '제대로 물 만난 DC, 이번엔 제발...!',
#   '7',
#   '16',
#   '3',
#   datetime.datetime(2018, 12, 19, 19, 50),
#   0],
#  ['잉글리스(expe****)',
#   '드뎌 dc에서도 볼만한 영화가 나왔네',
#   '10',
#   '18',
#   '5',
#   datetime.datetime(2018, 12, 19, 18, 40),
#   0],
#  ['소개킹(lssk****)',
#   '인간의 상상력은 어디까지...',
#   '10',
#   '21',
#   '8',
#   datetime.datetime(2018, 12, 19, 11, 10),
#   0],
#  ['두리뭉(tj05****)',
#   '한줄평: 고퀄리티 파워레인져...진심 유치한데 여배우가 이뻤다... 악당 디자인 진심 어릴때보던 파워레인저수준...',
#   '6',
#   '12',
#   '0',
#   datetime.datetime(2019, 1, 7, 22, 35),
#   0],
#  ['jacobs2(tjdw****)',
#   '아쿠아맨.기존 DC  영화들보단 확실히 낫다.근데 기존 DC 영화의 유치함은 그대로 .,,세련됨을 표현하려 노력했지만 .. 역시나 옛날 느낌은 벗을 수가 없었다.아쿠아맨의 최고 수혜자는 앰버허드. 진짜 영화내내 앰버...',
#   '7',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 31, 17, 12),
#   '관람객'],
#  ['LJH(lalg****)',
#   '3d imax로 봤는데 영상미 진짜 최고에요 재밌게 봤습니다',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 26, 19, 56),
#   0],
#  ['용팔이(yyon****)',
#   '나는 기대안하고봤는데 소름돋게 재밋던데 지루할 틈이 없었음',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 25, 1, 12),
#   0],
#  ['준범맘(graz****)',
#   '미친 비주얼. 색감이 진짜 오색찬란하다.',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 23, 22, 4),
#   0],
#  ['이름없음(brsu****)',
#   '여태 본 히어로물 중에 제일 좋았음 바다 배경이라 그런지 영상미가 쩜ㅇㅇ',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 23, 21, 48),
#   0],
#  ['로보트(ysch****)',
#   '보는 내내 눈이 즐거웠음..',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 58),
#   0],
#  ['송신(tlad****)',
#   '제임스완 입김이 쎘나봄 갑툭튀 꽤 많음 호러무비인줄액션이나 개그가 굉장히 구렸었는데 상당히 나아졌음영상미가 아주 죽임 앰버허드 아주 죽임',
#   '7',
#   '13',
#   '1',
#   datetime.datetime(2018, 12, 22, 9, 51),
#   0],
#  ['Min진(wxzv****)',
#   '히어로물의 정석입니다.',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2018, 12, 26, 10, 5),
#   '관람객'],
#  ['럭키두(luck****)',
#   'DC가 정말 죽을 힘을 다해 만든거 같다. 박수 쳐주고 싶음.',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2018, 12, 21, 10, 12),
#   0],
#  ['리프레(dldy****)',
#   '메ㅡ멘 너무 이쁘다 진짜 엠버허드 존예다연출 갈린게 눈에 보인다 스토리는 모자라도 나머지가 채워주니',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2018, 12, 20, 15, 34),
#   0],
#  ['달콤버터(sesl****)',
#   'DC  해냈다! ! ! 감독이 중요하네',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 25, 6, 38),
#   0],
#  ['dudg****',
#   '이 영화보고 뻔한 스토리에 재미없다고 하는 사람은 도대체 어떤 영화를 봐야 감동을 느끼는지 의문 스럽다.빼어난 영상미에 화려한 액션신까지 근래 본 영화중에최고였음. 물론 취향따라  틀리겠지만 2시간 20분 동안속시원...',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 24, 16, 19),
#   0],
#  ['짜파구리(poro****)',
#   '여주인공이 이쁜진 어떻게 알고 연출이 여신급이냐..특히 폭풍우 치는 배씬에서 조명탄 들고 계속 들어갈때 씬 박수친다. 히어로 영화에서 심해 공포가 느껴짐.. 그리고 하이라이트 전쟁씬은 경이롭다. 사이보그맨, 그린랜턴...',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 23, 21, 55),
#   0],
#  ['이호경(ghru****)',
#   '아니 앰버허드..  극장에서 봤지만 누군가 다시보러가자 하면 앰버허드 또 보러간다.. 미쳤다',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 23, 13, 31),
#   0],
#  ['크루니(ksj_****)',
#   '넘 이쁜 바다와 남,여주인공의 매력에 흠뻑 젖다 나왔네요?  아이와 다시보고 싶을 정도로 화려하게 잘 만들었어요? 연말 극장 가족영화로 쵝오!!',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 33),
#   0],
#  ['omcd****',
#   '이걸 할인 받아서 4천원에 본게 너무 미안해지네. 진짜 재밌음',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 12),
#   0],
#  ['십리도화림(lexp****)',
#   '화려한 그래픽으로 재현된 광활한 가상의 해저 세계가 눈을 즐겁게 하네요. 육지와 바다의 선명한 컬러 대비를 통한 시원한 영상미도 좋습니다. 스펙터클한 전투, 결투, 체이싱(chasing) 장면들도 박진감 넘치네요. ...',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 21, 14, 51),
#   0],
#  ['정은비(eunv****)',
#   '2시간 동안 게임하는 느낌 . 시간 가는 줄 몰랐다',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2018, 12, 19, 19, 9),
#   0],
#  ['사과나무53(tkrh****)',
#   '새로운 슈퍼히어로의 탄생 속시원한 영화',
#   '10',
#   '16',
#   '4',
#   datetime.datetime(2018, 12, 20, 14, 9),
#   0],
#  ['kkj0****',
#   '유치하지만 시간가는줄 모르고 볼 정도로 재미있다.',
#   '10',
#   '17',
#   '5',
#   datetime.datetime(2018, 12, 19, 19, 30),
#   0],
#  ['문현빈(lego****)',
#   '마블충들아 별점테러하지말고 그냥가라',
#   '10',
#   '18',
#   '6',
#   datetime.datetime(2018, 12, 20, 21, 32),
#   0],
#  ['thec****',
#   '감독하나에 영화가 이렇게 달라지나. 뭘 더하고 빼야하는지 정확하게 알고 상업영화의 완성본을 만들었다.',
#   '10',
#   '18',
#   '6',
#   datetime.datetime(2018, 12, 20, 16, 5),
#   0],
#  ['pss(eorn****)',
#   '볼거리가 많고 개연성도 나쁘지않음',
#   '10',
#   '20',
#   '8',
#   datetime.datetime(2018, 12, 19, 18, 8),
#   0],
#  ['코피칠갑(copy****)',
#   '이제가 DC가 그럴듯한 작품하나 만든듯. 아쿠아맨은 디시 마블 다합쳐도 상당히 상위권에 들어갈만한 작품인듯',
#   '9',
#   '11',
#   '0',
#   datetime.datetime(2018, 12, 24, 14, 46),
#   0],
#  ['김강욱(kku8****)',
#   '난 진심으로 디씨를 포기한 적이 없었고 아쿠아맨을 보고 그 맘이 더 굳어졌다 배경보는 재미도있고 전투도 볼만하고 스토리도 ㄹㅇ오진다 디씨가 작정하고 만든것같다',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 25, 21, 28),
#   0],
#  ['횬이(gydm****)',
#   '십점 주고 싶은데 의심할까봐 9점이다..캐스팅 너무 잘했고 너무 잼나게 봤음!!',
#   '9',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 25, 9, 36),
#   0],
#  ['나이스가이(mnis****)',
#   '기대안했는데 DC거 중에 제일 재밌음',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 25, 1, 13),
#   0],
#  ['dudw****',
#   '역대급 액션신어마무시한 CG마블긴장 해야할듯아임 아쿠아맨!!!2편 커밍ㅋㅋ',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 24, 12, 33),
#   0],
#  ['쿨개미(ever****)',
#   '뭔가 우뢰매 같기도 후뢰쉬매누같기더 할때가있다ㅠ',
#   '7',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 24, 9, 52),
#   0],
#  ['크리스탈(piss****)',
#   '다음편을 기다려요재미가 넘쳤음 해요',
#   '8',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 23, 21, 57),
#   '관람객'],
#  ['두부군(temp****)',
#   '캬 맨오브스틸이후로 드디어 괜춘하다',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 33),
#   0],
#  ['JARSofCLAY(jule****)',
#   '아이언맨이 그랬듯 DC는 앞으로 아쿠아맨 중심으로 펼쳐질것 같다. 앰버허드 존예!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 25, 21, 36),
#   0],
#  ['Jade lounge(mix2****)',
#   '개쩜 정말 아서랑메라 둘이캐미 터짐 몸매는 둘다 코피터짐 볼거리가잔뜩임ㅋㅋ2탄기다려짐',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 25, 13, 35),
#   0],
#  ['llqq****',
#   'ㅜㅜㅜㅜ재미있어요 짱짱',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 25, 4, 52),
#   0],
#  ['sisi****',
#   '마약왕보고 아쿠아맨봐서그런지 우주최강꿀잼',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 23, 2, 43),
#   0],
#  ['ajtwoddl(tndb****)',
#   '이거재밌어요진심 여주 존예에요',
#   '10',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 25, 5, 34),
#   0],
#  ['쥘(sgre****)',
#   '이것은 DC의 승리가 아니다. 끝까지 믿고 기다린 우리 모두의 승리다.',
#   '8',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 48),
#   0],
#  ['쪼아(aarr****)',
#   '이건 꼭 봐야할 영화 핵잼',
#   '10',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 4),
#   0],
#  ['경원(tlsd****)',
#   '엄마가 아바타 이래로 너무 재미있게 봤대요^^',
#   '10',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 21, 10, 34),
#   0],
#  ['쫀쫀(husk****)',
#   '볼거리가 많네요 재미 있네요',
#   '9',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 19, 17, 26),
#   '관람객'],
#  ['아게하(ynyh****)',
#   '기대 안 하고 봤는데 DC의 역습',
#   '10',
#   '14',
#   '3',
#   datetime.datetime(2018, 12, 19, 16, 23),
#   0],
#  ['Wade(casi****)',
#   '솔직히 블랙팬서 보다는 훨 재미있었다',
#   '10',
#   '15',
#   '4',
#   datetime.datetime(2018, 12, 26, 20, 26),
#   0],
#  ['milg****',
#   '재미있었다. 영상미좋고...톰크루즈 전부인인 니콜키드먼 나이들어도 예쁜건 여전함.',
#   '10',
#   '15',
#   '4',
#   datetime.datetime(2018, 12, 19, 18, 1),
#   0],
#  ['cscp****',
#   '메라 존나이쁜걸로 별5갤가돗보다이쁨;;',
#   '10',
#   '16',
#   '5',
#   datetime.datetime(2018, 12, 20, 10, 5),
#   0],
#  ['theo****',
#   '감동적이면서 판타지적인 명작 영화',
#   '10',
#   '16',
#   '5',
#   datetime.datetime(2018, 12, 19, 16, 39),
#   0],
#  ['미크(mikb****)',
#   'DC무비를 제임스완이 시작했더라면 인피니티워는 없었을지 모른다',
#   '10',
#   '17',
#   '6',
#   datetime.datetime(2018, 12, 19, 20, 9),
#   0],
#  ['TeaTime(kfen****)',
#   '뭉치면 살고 흩어지면 죽는다?? 그 모든 공식을 DC는 깬다. 흩어졌을때 더욱 강한 DC의 메타휴먼들...',
#   '10',
#   '17',
#   '6',
#   datetime.datetime(2018, 12, 19, 18, 38),
#   0],
#  ['JYJ(pink****)',
#   '예상보다 훨씬 재밌었음',
#   '10',
#   '18',
#   '7',
#   datetime.datetime(2018, 12, 20, 15, 35),
#   0],
#  ['헬로키티(pcw8****)',
#   '한줄 요약  -  역시 아이템빨이 최고여~~~',
#   '8',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 26, 19, 31),
#   0],
#  ['아이신스(arom****)',
#   '진짜 두번보세요!!저는 여자고 이런 히어로 물을 크게 좋아하진 않지만 꿀잼이고 액션이 넘 시원해요. 앰버허드는 눈을 못 뗄 정도로 예쁘고 니콜 키드먼도 나이에 비해 엄청난듯...덕분에 크리스마스에 여행 한 듯 행복했...',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 26, 2, 22),
#   0],
#  ['lovegoch(toge****)',
#   '마블 턱 밑까지 따라왔네영.. 강추드려용~~',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 25, 21, 37),
#   0],
#  ['레몬(oran****)',
#   '개꿀잼 진짜 늘어지는 부분 하나도 없고 눈을 못뗌 잠 얼마 못자고 갔는데 하나도 안졸렸음 스토리가 스피디하게 전개 그리고 cg영상미 짱 쿠키영상전에 나오는 엔딩크레딧 cg까지 겁나 세심했음 아쉬운거 굳이 뽑자면 조금...',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 25, 12, 12),
#   0],
#  ['혀니(sony****)',
#   '메라 와꾸때문에 세번은 볼듯',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 25, 0, 34),
#   0],
#  ['샴푸요정(sham****)',
#   'ㅜㅜ오늘 남친이랑 보러가기로했는데 영화관 착각해서 돈만 날리고 못봄 ㅠㅠ 제가 좋아하는 스탈이라 재밌을거 같아요 다시 보러 가야 할 것 같아요',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 23, 22, 2),
#   '관람객'],
#  ['초전박살(zipp****)',
#   '초등학생 아들이 너무 좋아합니다. IMAX에서 보시기를 추천',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 23, 21, 57),
#   0],
#  ['울산토이(jiro****)',
#   '엠바허드~♡♡♡♡     아쿠아맨2  어서 나와라',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2018, 12, 23, 21, 56),
#   0],
#  ['콜라쏘다(byh6****)',
#   '영상미 진짜 최고 내용이나 연출은 오글..',
#   '6',
#   '11',
#   '1',
#   datetime.datetime(2019, 1, 13, 22, 1),
#   '관람객'],
#  ['방한나(hann****)',
#   '가족들이랑 같이 봤는데 너무 띵곡들이랑 띵작인 영화인거 같았다. 외국 영화중 젤 재미있게 봤다  참고로 우리 아버지가 등대지기가 되고싶다고 했다 하하',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2018, 12, 26, 20, 3),
#   0],
#  ['sktj****',
#   '재미나게 잘봤어요~~',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2018, 12, 25, 4, 34),
#   0],
#  ['메소드(bliz****)',
#   '진짜 이번 DC는 다릅니다.',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2018, 12, 24, 14, 50),
#   0],
#  ['bglo****',
#   '정말 눈 호강 제대로 했네요..잠시도 딴 생각할 틈이 없어요..최고입니다',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2018, 12, 23, 22, 7),
#   0],
#  ['태구(thgu****)',
#   '영상미 대박 남주 여주 존잘 존예',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 53),
#   0],
#  ['봉봉이(blac****)',
#   '제임스완이 디씨영화에 심폐소생술을 실행했다.. 모든면에서 마블에 뒤쳐지지 않는 영화! 영상미는 아바타 이후 최고였다 심해에 많은 볼거리를 제공한 아쿠아맨.. 마블도 긴장할만한 영화다',
#   '9',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 23, 2, 8),
#   0],
#  ['young(dptm****)',
#   '앰버허드 사랑해요. 기본적으로 영화 자체를 잘 만듦. 좋은 영상미랑 수족관에 놀러온 기분이랄까?',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 21, 10, 56),
#   0],
#  ['likelesure0203(0185****)',
#   '잼나용 ㅋ잘만들었음..',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 21, 8, 3),
#   0],
#  ['ch65****',
#   '진짜재밌다꼭봐라 (여수관람객)',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 21, 7, 49),
#   0],
#  ['박천일(dld1****)',
#   '생전 처음보는 히어로 인데 뭔가 친숙하기고 하고그냥 유잼 대잼 꿀잼임 아마 속편도 제작하는거같으니 아쿠아맨 2도 재밌게 보려면 관람하자~',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 21, 6, 30),
#   0],
#  ['iueg****',
#   '완전 꿀잼이었어요 강추합니다',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2018, 12, 21, 5, 23),
#   0],
#  ['성빈mom(babo****)',
#   '화려한장면과 연출은 최고나 뻔한스토리에 조금 지루함',
#   '8',
#   '13',
#   '3',
#   datetime.datetime(2019, 6, 25, 17, 51),
#   '관람객'],
#  ['신소연(dty1****)',
#   '얼마전에 신비한동물사전 2 보면서는 꿀잠잤지만 이영화는 영상미도좋고 걍 재밌었음 특히 나는 판타지 이런거 좋아해서 더더욱 좋았고 +더 좋았던건 영화에 나오는 모든 노래들이  너무너무좋아서 다찾아서 듣고있음ㅠ특히eve...',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2018, 12, 25, 6, 27),
#   0],
#  ['해적왕(iand****)',
#   '머리카락 한올한올 물방울 하나하나 심혈을 기울여만든 수작!!! 스토리도 굉장히 풍부하고 집중을 떨어뜨릴수 없었음!!!',
#   '10',
#   '14',
#   '4',
#   datetime.datetime(2018, 12, 23, 13, 23),
#   0],
#  ['서비(jupi****)',
#   '디씨에서  이런걸 다~~ㅋ잘봤슾되',
#   '10',
#   '14',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 22),
#   '관람객'],
#  ['환이(ash3****)',
#   '죽기전에 꼭 봐야하는영화',
#   '10',
#   '14',
#   '4',
#   datetime.datetime(2018, 12, 19, 19, 26),
#   0],
#  ['김슬기(tmfr****)',
#   '진짜 재밌어요 감동 .. 꼭 보세요 ㅠㅠㅠ',
#   '10',
#   '14',
#   '4',
#   datetime.datetime(2018, 12, 19, 19, 19),
#   0],
#  ['Lee6179(lhw6****)',
#   '재밌겠지(사실 안봄)',
#   '10',
#   '15',
#   '5',
#   datetime.datetime(2018, 12, 19, 18, 32),
#   0],
#  ['불출마(lsk2****)',
#   '영상미가 좋네요 재밌습니다',
#   '8',
#   '16',
#   '6',
#   datetime.datetime(2018, 12, 20, 10, 21),
#   '관람객'],
#  ['tree****',
#   '마블영화다봤는데 평점안썼는데..이건써야겠다아바타신비로움+마블액션+살짝 다빈치코드에 추리(?) ㅋㅋ 강추다!!형믿고 봐봐',
#   '10',
#   '17',
#   '7',
#   datetime.datetime(2018, 12, 20, 1, 29),
#   0],
#  ['1부에 12팀 실화냐(chum****)',
#   '어벤져스보다 200만배 재밌었음. 마블이고 DC고 난 잘 모르겠고 그냥 내가 살면서 본 영화 중에 제일 화려하고 쩔었음. 보면서 와 사람이 어떻게 이런걸 만들어내지? 라는 생각 밖에 안듬. 100점 만점에 120점짜...',
#   '10',
#   '18',
#   '8',
#   datetime.datetime(2018, 12, 23, 10, 49),
#   0],
#  ['이상화(guma****)',
#   'DC가 제대로 하나 만든것같다?',
#   '10',
#   '18',
#   '8',
#   datetime.datetime(2018, 12, 20, 1, 29),
#   0],
#  ['민중의빠따(gkst****)',
#   '이정도면 개꿀잼임 진심 이거재미없다는 색기들은 다큐멘타리나 처보러가라^^ㅗ',
#   '10',
#   '24',
#   '14',
#   datetime.datetime(2018, 12, 23, 4, 10),
#   '관람객'],
#  ['향댁잉(wlsg****)',
#   'DC영화중 젤재밌게봄',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2020, 7, 21, 17, 0),
#   '관람객'],
#  ['donell(bboy****)',
#   '엠버허드 심하게 이쁘다',
#   '8',
#   '9',
#   '0',
#   datetime.datetime(2018, 12, 31, 9, 40),
#   '관람객'],
#  ['choc****',
#   '괜찮게 봤습니다 영웅물이니 다 비슷비슷합니다',
#   '9',
#   '9',
#   '0',
#   datetime.datetime(2018, 12, 29, 22, 52),
#   '관람객'],
#  ['쌘구(khd7****)',
#   '기대이상 재밌게 봤네요 기대하고 기대하다 마약왕vs아쿠아맨 뭐볼지 고민하다 저스티스리그때부터 궁굼하기도하고 영화나오면 꼭 보고싶었는데 존잼 추천추천',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2018, 12, 23, 2, 24),
#   0],
#  ['조성민(mi41****)',
#   '상영시간이 꽤 길었는데도 지루함없이 넘 잼있게보고왔어요 보고나서 또보고싶단생각이들었어용',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2019, 1, 22, 23, 32),
#   '관람객'],
#  ['김창후(rlac****)',
#   '너무 마초스러워서 멋져부령~',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2019, 1, 1, 3, 29),
#   '관람객'],
#  ['쏭박(niki****)',
#   '생각보다 훨신 잼있었음',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2018, 12, 30, 12, 38),
#   '관람객'],
#  ['djfw****',
#   '한동안 어벤져스까지 해서 마블이 치고 나가니까 디씨가 씨발 야 우리도 질수없다  해서 아주그냥 작정하고 만든것같다 제작기술 과 컴그래픽 등이 그냥 개소름 돋는다',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2018, 12, 24, 15, 34),
#   '관람객'],
#  ['ylyukfj(sjki****)',
#   '진짜 역대급 영화...마블도 발라버릴 내용과 영상미임 제임스완 제대로 일낸듯 배우들 비주얼도 열일하고 하나도 빠질게 없음 최고의 영화임 안본 사람 없게해주세요ㅠㅠ',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 45),
#   0],
#  ['은지(9431****)',
#   '난 너무 재밌었어요..레알 진지해요..',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 43),
#   0],
#  ['릴리(esln****)',
#   '유치하다 파워레인져 울트라맨 보는줄',
#   '7',
#   '11',
#   '2',
#   datetime.datetime(2019, 1, 16, 20, 25),
#   '관람객'],
#  ['바트의힘(9961****)',
#   '제 인생 역대급 영화이네요.',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2018, 12, 30, 8, 43),
#   '관람객'],
#  ['금륜법왕(sonr****)',
#   'DC가 제임스완을 영입한건  맨유가 퍼거슨을 영입한 격.',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2018, 12, 21, 11, 18),
#   0],
#  ['mrbundesteam(namk****)',
#   '스토리는 뭐 히어로물인데  영상미가 있어 보기좋네요',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2018, 12, 23, 10, 50),
#   0],
#  ['바리(joun****)',
#   '여름 블럭버스터로 찾아왔다면 더욱 좋았을 영화.개연성 따지는 분들 많은데 원작과 유사하게 진행하다보니 어쩔수없이 발생하는 문제인듯하고, 제임스완감독이 DC유니버스에 제세동기로 심장뛰게 만들었으니 웨던형제가 이제 온몸...',
#   '9',
#   '12',
#   '3',
#   datetime.datetime(2018, 12, 20, 14, 58),
#   0],
#  ['nhk9****',
#   'Very entertaining! Better than the last few DC movies^^',
#   '9',
#   '12',
#   '3',
#   datetime.datetime(2018, 12, 19, 18, 47),
#   '관람객'],
#  ['hopetoachieve(lind****)',
#   '역쉬 제임스완~~!!! DC를 살리다~~!!!',
#   '8',
#   '12',
#   '3',
#   datetime.datetime(2018, 12, 19, 18, 34),
#   0],
#  ['연유맛핫바(ggar****)',
#   '제임스완이 DC에 인공호흡기 갖다댔네',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 23, 4, 35),
#   0],
#  ['SamPark(love****)',
#   '최고다 정말 재밌었음 !!!',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 23, 2, 40),
#   0],
#  ['tlaw****',
#   '뭐 영웅 스토리인데 대단한 스토리 기대하고 볼거면 보지말고 제작비 비례하는 죽이는영상미 보면서 눈호강 할 분들은 보시고 나는 300%만족 안봤음 어쩔뻔??',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 23, 2, 35),
#   0],
#  ['뚜벅뚜버기(regr****)',
#   '작정하고 재밌게 만들었네. 강추 ㅋㅋㅋ 쿠키영상 한 개 있음',
#   '9',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 21, 14, 43),
#   0],
#  ['fait****',
#   '마불이나 dc나 구분짓고 싶지 않다!! 아쿠아맨은 봐야할 영화!!!',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 21, 7, 20),
#   0],
#  ['솔직그대로(kyw8****)',
#   '배트맨v슈퍼맨의 후폭풍을 원더우먼이 만회하였다면, 아쿠아맨은 저스티스 리그의 후폭풍을 만회하였다.',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 20, 15, 53),
#   0],
#  ['별똥(meky****)',
#   '솔직히 한번 더 보고 싶은ㅋㅋ지겹지가 않음',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 20, 15, 43),
#   0],
#  ['흠흠흠(eys1****)',
#   '올해 액션중 가장 지루할 틈이 없음.!!주인공 하나하나 조합이 좋다. 강추합니다',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 20, 15, 40),
#   0],
#  ['larc****',
#   '세상을 구한 새로운 왕 아쿠아맨',
#   '9',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 19, 19, 33),
#   0],
#  ['Happiness(gkaq****)',
#   '아바타가 생각난다.그리고 엠버허드.. !!',
#   '8',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 19, 19, 12),
#   0],
#  ['최성민(maro****)',
#   '최고라고 밖에 말 할 수 없는 영화',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 19, 18, 31),
#   0],
#  ['dudc****',
#   'DC영화중 최곤데??ㅋㅋㅋ',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 19, 17, 28),
#   0],
#  ['자수정(hh00****)',
#   '좀 오글거리고 그동안 듣고 봐왔던 이야기들의 총합 같기는 했지만 비쥬얼이 장난 아니네요.. 정말 처음부터 끝까지 화려합니다.',
#   '9',
#   '13',
#   '4',
#   datetime.datetime(2018, 12, 19, 13, 21),
#   '관람객'],
#  ['풀잎(dudw****)',
# ...
#   '스토리는 뻔하지만 cg나 액션은 좋아요.',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 25, 5, 9),
#   '관람객'],
#  ['파아슬리(ioni****)',
#   '최고였습니다. 아틸란티스 해저도시 모습은 쵝오의 황홀경임. 아쿠아맨도 섹시하심.ㅋㅋㅋㅋ',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 25, 4, 44),
#   0],
#  ['STITCH LIFE(baek****)',
#   '세상에서 가장 크고 아름다운 아쿠아리움을 다녀온듯한 느낌',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 25, 2, 40),
#   0],
#  ['ginger(hsle****)',
#   'DC라서 기대안하고 보았는데, 잼나게 보았어요. 적당한 유머, 공포, 환상적인 광경등 다시 보고싶네요. 아쿠아맨 모모아도 덩치는 크지만 귀여웠어요. ㅋ ㅋ 2편 나오면 볼거예요.',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 24, 13, 21),
#   0],
#  ['벌자(clsr****)',
#   'dc가 배대슈 .. 저스티스를 말아먹어서 그렇지.. 그럭저럭 괜찮았던 맨오브스틸이나 원더우먼 보다 훨씬 역대급임.. 바다속 cg는 환상 그자체고 엠버허드의 미모는 리즈갱신함',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 24, 3, 49),
#   0],
#  ['clzl****',
#   '진짜 볼거리가 계속있어서 지루할틈없이 넘 잼께봤어요 ㅠㅠㅠ',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 24, 1, 22),
#   0],
#  ['사과주스(tjda****)',
#   '손발이 오그라드는걸 20번 이상 경험 할수있다....',
#   '7',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 24, 0, 49),
#   0],
#  ['ASDF(ange****)',
#   '최근 DC중에 그나마 마음에 드는영화였습니다.',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 24, 0, 13),
#   '관람객'],
#  ['권담(mask****)',
#   '액션, 모험,환타지,공포 종합선물세트같은 영화',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 22, 25),
#   '관람객'],
#  ['levi****',
#   '개인적으로 마블보다 이번건 더 재밌었던것같음',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 22, 17),
#   0],
#  ['이경규(gabr****)',
#   '엠버 허드 겁나 예뻐서 두 번 봐야징',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 11, 43),
#   0],
#  ['진통제(robf****)',
#   '화려한 눈요기.. 그리고. 내용은 뻔함 .. .. 마지막 해피엔딩..',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 10, 27),
#   0],
#  ['끼오기(knot****)',
#   '2시간 내내 눈호강~~~극장서 안보면 후회할뻔. 영상 최고입니다',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 8, 53),
#   0],
#  ['냐옹(mylo****)',
#   '핵재밋다완전재밋다ㅡ굳굳',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 57),
#   0],
#  ['secheon123213(ttss****)',
#   '개인적으로 베트맨 이후로 DC영화에 매력을 못느꼈는데심야시간에 봤지만,졸지않고 볼거리가 많아서 정말 재밌게 봄.추천합니다.',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 43),
#   0],
#  ['사과링고(daye****)',
#   '걱정했지만 제법!! 도시 스케일에 압도되고 너무 역동감 넘쳐요.바다속을 이리 멋지고 스피디 하게 표현 하다니 DC 영화라곤 생각 못할 만큼 굉장 하네요.근데 CG가 어설픈게 가끔 나오고 왕의 무기가 장황한 설명에 비...',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 2, 39),
#   0],
#  ['주변사람챙기기(neve****)',
#   '왠만하면 후기 안쓰는데...너무 저평가된듯해서....아이언맨급 dc히어로 탄생....감독 대박...앰버허드 대박....또 보고 싶음',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 1, 13),
#   0],
#  ['suzyn(suji****)',
#   '엠버허드이쁘다..근데니콜키드먼더이쁘다....제이슨모모아몸너무좋다....스토리는예상가능잼인데 씨지넘이뻤다잼잼',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 23, 1, 12),
#   '관람객'],
#  ['나지수(yoou****)',
#   '143분동안 눈호강 제대로 했습니다',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 22, 22, 44),
#   0],
#  ['토실도치(sej2****)',
#   '아이언맨 시리즈나 어벤저스보다 더 재미잇어요!!!',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 22, 22, 42),
#   0],
#  ['박치기소녀(bakc****)',
#   '월렝데포아저씨는 디씨에도나오고 마블에도나오네요',
#   '8',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 21, 22, 58),
#   '관람객'],
#  ['성훈찡(shwo****)',
#   '너무멋있잖아 화장실가는 시간마저 아까워 DC영화같지 않았지만 다시봤다 DC',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 21, 15, 7),
#   '관람객'],
#  ['퀸타이(jdhy****)',
#   '와 기대없이 영화보다가 몰입 짱',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 21, 11, 17),
#   0],
#  ['감용(qaze****)',
#   'DC 붐은 왔다....!',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 21, 11, 1),
#   0],
#  ['MELO(ires****)',
#   '영상만으로 10점  저티스리그 2 까지 달려보자',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 12, 21, 10, 32),
#   0],
#  ['JEi(ss0n****)',
#   '유치한 전개의 히어로물. 그리고 뭔놈의 해적놈은 IQ가 200을 넘는건가? 인간의 기술로 구현되지 않은 물건을 지 입맛에 맞게 개조를 다 하냐..',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 25, 12, 46),
#   0],
#  ['블루돌핀(cal8****)',
#   '후반에 너무 지루해서 영화관에서 난생처음으로 졸았음',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 16, 9, 36),
#   0],
#  ['시간의끝에서(cls1****)',
#   '노잼이에요 스토리나 연기나 대사마저도 별루였어요',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 7, 21, 16),
#   0],
#  ['룰루랄라(yeji****)',
#   '정말 유치하고  10년전에 나왔으면 완벽했을 영화. 보는 재미는 있었지만 (영상미) 그외 스토리, 대사, CG, 코디, 배경음악까지 전부 읭????이게뭐지 ??? 하면서 봄 ㅋㅋ 어린친구들은 좋아할듯 파워레인저 같아...',
#   '3',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 6, 15, 41),
#   0],
#  ['정발(king****)',
#   '기대가 커서 그런가.... 그저 그럼....',
#   '6',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 4, 10, 46),
#   '관람객'],
#  ['양보연(didq****)',
#   '진짜 오글아들어 미쳐버리는줄',
#   '4',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 4, 0, 28),
#   0],
#  ['zldz****',
#   '아쿠아맨 이 로보트 불러오고  블랙만타 거대화 되는줄 고고 파워레인저 !!',
#   '2',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 3, 22, 13),
#   0],
#  ['충원(song****)',
#   '그냥 그렇것 같은데 평점은 높네',
#   '2',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 3, 20, 22),
#   0],
#  ['kdekkk(ehde****)',
#   '저만 재미없었나요...',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 3, 13, 56),
#   0],
#  ['f200****',
#   '볼거리도 많고 여주, 남주 비주얼이 아주 ㄷㄷㄷ',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2019, 1, 1, 0, 31),
#   '관람객'],
#  ['읍스(bada****)',
#   'DC 든  Marvel 시리즈 든 그닥 좋아하는 편은 아니었는데, 아들이 좋아해서 같이 봤는데, 그간 본 시르즈중 최고였습니다.',
#   '8',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 30, 12, 12),
#   '관람객'],
#  ['마탄의사수(kimh****)',
#   '2시간 20분동안 엄청난 비쥬얼과 주인공들의 매력만으로도 돈이 안아깝다. . .제이슨모모아만큼 카리스마 넘치는 히어로물은 없었던듯. . .앰버허드만큼 매력넘치는 여자히어로도 없었던듯. . .내용도 볼만하지만 비쥬얼때...',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 30, 10, 38),
#   0],
#  ['김태훈(taeh****)',
#   '유치한 복장에 유치한 능력 솔직히 봐보면 피식하게 되는데 근데 그런 유치한것도 매력으로 느껴졌고 액션도 너무 마음에 들었고 이걸 보고난 순간 돈이 아깝다는 생각이 전혀 안들었습니다 진짜 재미나게 잘 봤어용',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 30, 3, 7),
#   '관람객'],
#  ['손연실(yurr****)',
#   '눈뽕 최고입니다 감사합니다',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 29, 14, 24),
#   '관람객'],
#  ['hr52(jiim****)',
#   '진짜  스케일이  다르고 정말 잘 봤습니다.',
#   '9',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 29, 11, 57),
#   '관람객'],
#  ['성열훈(dufg****)',
#   '앞으로 바다에가면 첫번째로 생각날 영화 (물고기와 이야기할수있을듯)',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 29, 5, 35),
#   '관람객'],
#  ['카세트라디오(ting****)',
#   '4D로 보면 정신가출했을듯',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 29, 0, 41),
#   '관람객'],
#  ['spad****',
#   '토르배우 보다 아쿠아맨배우가 사모아인 느낌도 나면서 엄청강해보임 둘다 비슷한 캐릭터인데 매우 서글서글하고 정감이 있네 액션은 끝장난다 음악도 좋고',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 28, 0, 31),
#   '관람객'],
#  ['지여니9453(paul****)',
#   '장난아니라 진심개꿀잼 추천!',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 27, 20, 30),
#   0],
#  ['딸만셋(sens****)',
#   '2시간이 지루하지는 않습니다.',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 26, 19, 12),
#   '관람객'],
#  ['iws1****',
#   '이 세상 cg가 아니다. 영상미가 스토리고 뭐고 다 씹어먹어버리네',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 26, 12, 29),
#   0],
#  ['eversanta(io-t****)',
#   '재미없다는 알바들때문에 못볼뻔했다. 아쿠아맨 최고에요.',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 25, 7, 9),
#   '관람객'],
#  ['캐시언니(lhs9****)',
#   '진짜 너무너무 재밋음 원래 평점 리뷰 이런거안하는데 개꿀잼이라서 함 써봄 꼭보세여 이십번봐도 재밋을듯',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 25, 5, 59),
#   0],
#  ['둘리뇨니(nsed****)',
#   '진심 원더우먼에서 디씨가해냈단사람 나와 !!! 원더우먼 평타라면 진심 아쿠아맨 개상타임 솔직히 어벤저스1 본감동이었음 그 만큼신선하고 너무재밌고 그래픽이 쩔었음 나 평점한번남겨본적없는데 이건진짜 꼭봐야함',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 24, 13, 12),
#   0],
#  ['E9(dose****)',
#   '메라가 캡틴마블 했으면 더 잘 어울렸을 듯..ㅠ',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 24, 3, 10),
#   0],
#  ['SOLSOW(tjrl****)',
#   '꿀잼했습니다 ㅋㅋ생각보다 안유치함',
#   '8',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 24, 0, 18),
#   '관람객'],
#  ['김지영(qwer****)',
#   '꿀잼어벤저스보다 훨신잼있음.',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 23, 22, 19),
#   '관람객'],
#  ['스크루지(cawo****)',
#   'DC영화중에 제일재밌는거 같네요엠버허드 스칼렛 요한슨보다 훨이쁜듯~~~',
#   '8',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 23, 2, 40),
#   0],
#  ['서노(azds****)',
#   'CG가 상당히 좋앗습니닺',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 21, 5, 59),
#   '관람객'],
#  ['세훈(rlat****)',
#   '이렇게 감독의 중요성이 크구나 라는 생각이 많이 들었으며 영상미나 특히 여태것 나왓던 cg가 dc 영화중 가장 마음에 든 영화였던것같아요 아이맥스로 한번더 보고싶습니다 정말 제임스 완했네요 ㅋㅋ',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 20, 18, 5),
#   0],
#  ['sang****',
#   '쩌리히어로중 하나로 낙인됐던 아쿠아맨을 이정도로 끌어낸건 진짜 대단하다고본다. Dc는 제임스완에게 삼천배 절은 해야할듯. 긴 러닝타임이라 살짝 지루하지만 이정도면 dc에서 선방한듯. 이제 플래시도 내놔라. 슈퍼맨, ...',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 20, 17, 16),
#   0],
#  ['앨리콜럼버스(hahu****)',
#   '우와 영화미쳤다 올햬영화는 아쿠아맨이다~',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 20, 16, 15),
#   0],
#  ['최연우(coun****)',
#   '디씨의 새로운 영화 그 전까지는 망 이제부터 시작하자',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 12, 19, 20, 18),
#   '관람객'],
#  ['pam(pam4****)',
#   '너무 지루했다... 영상미가 좋은것은 알겠다! 하지만 질질 끄는 내용과 영화가 너무 길다는 점... 중간에 나가고 싶을정도였다... ㅠㅠ',
#   '2',
#   '9',
#   '3',
#   datetime.datetime(2019, 1, 11, 19, 59),
#   '관람객'],
#  ['너의이름은(khy8****)',
#   '뻔한스토리였지만...돈은아깝지않음.',
#   '8',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 30, 4, 52),
#   '관람객'],
#  ['백플(alvm****)',
#   '영상미도 좋고 노래가 크~~',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 29, 6, 40),
#   '관람객'],
#  ['sano****',
#   '진짜 대박 영화입니다~',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 29, 4, 57),
#   '관람객'],
#  ['나즈(yuka****)',
#   '평점 왜 이러냐 겁나 재밌더만',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 23, 11, 19),
#   0],
#  ['fpsl****',
#   '재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!재밌다!...',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 41),
#   0],
#  ['혀니 앓이(kdkd****)',
#   '정신없이 몰아치네요 이정도면 성공적인 시리즈로의출발치곤 중박이상 입니다 개인적으론 좀더분발해주길바래봅니다 dc 화이팅',
#   '8',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 21, 15, 35),
#   '관람객'],
#  ['가월십야(i1de****)',
#   '이 정도면 DC살아난다',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 20, 14, 12),
#   0],
#  ['minini(nura****)',
#   '액션이 진짜 화려해서 눈을 뗄수가 없었어요 너무 재밋음',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2018, 12, 20, 11, 59),
#   '관람객'],
#  ['파랑감자(lemh****)',
#   '오글거려서 죽을뻔 손발 오그라드니까 다리미 하나 챙겨서 보세요',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 14, 1, 3),
#   0],
#  ['shdu****',
#   '아 DC한테 또속았네 펑점알바들에게도 속았네..우뢰매보는줄',
#   '2',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 7, 19, 11),
#   0],
#  ['조깨비(jms1****)',
#   '이거 평점높게주는 사람들 미쳤냐 바다용사 벡터맨이다',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 6, 20, 41),
#   0],
#  ['back****',
#   '와 다 진짜 알바들 아니냐???  스으레에기 영화다 영상미만 좋다는 말은 보긴했는데 진짜 영상미만 좋다대사 하나하나가 주옥 같이 스으레에기 같고 스토리는 보나마나 뻔하지 다시는 DC 영화 안본다 진짜로 개빡치네',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 5, 23, 2),
#   0],
#  ['찬스틴(chan****)',
#   '이 영화가 DC 작품 중 제일 나은 것이라구요? ....예 잘 봤습니다',
#   '4',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 3, 20, 28),
#   0],
#  ['정윤지(tree****)',
#   '솔직히 너무 유치하고 애들이랑같이볼만은 한 영화임. 왜 이렇게 평점 높은지 이해가 안감 하도 재밋다길래 결국 봣는데진짜유치해.. 팝콘먹는데만집중함. 아쿠아맨 날라가서 종에 머리 처박을땐 킬링파트아닌데 어이없어서웃김....',
#   '2',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 2, 0, 40),
#   0],
#  ['프로필(dltm****)',
#   '평점이 생각보다 너무 높아서 내려야할 듯.. 중간중간 지루하고 스토리가 너무 오글거림 영상미만 볼만한듯',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 1, 23, 12),
#   0],
#  ['mome****',
#   '왜 왕이 되어야 하는 지까지는 이해.. 아쿠아리움 온것 같은 느낌이 나서 좋았다, 여주가 이제 리즈가 온것 같다. 니콜키드먼 살려준 주인공 아버지 개이득.',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2019, 1, 1, 7, 47),
#   0],
#  ['dsadsa(rkej****)',
#   '영상미는 마블을 씹어먹음. 그런데 스토리 흐름이  너무 끊기는 듯한 느낌을 많이 받음.',
#   '7',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 23, 11, 2),
#   0],
#  ['이걸봐(kws3****)',
#   '영화가 끝나고 박수가 나오다니..',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 21, 8, 4),
#   0],
#  ['안식을그대에게(stse****)',
#   'DC의 완벽한 부활의 신호탄이 될 영화다.저스티스 리그 5점, 원더우먼 7점이라면아쿠아맨은 9점이다.후반부로 갈 수록 스토리 진행이 빨라지면서액션 요소가 살짝 아쉽지만 그럼에도 불구하고 정말 훌륭한 영화다.배우들의 ...',
#   '9',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 20, 12, 9),
#   0],
#  ['선향(pthw****)',
#   'CG대박이다.. 진짜 리얼했어!',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 20, 11, 56),
#   '관람객'],
#  ['llii****',
#   '엄청재밌진 않았지만 기대 크게 안하고 보면 잼밌게 볼수있음.. 다만.. 러닝타임이 긴편인데 그이유가 삼지창찾는다고 너무 유적지만 몇군대를 가는거야.. 난 인디아나존스 보는줄 알았음..',
#   '7',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 20, 1, 25),
#   0],
#  ['김진섭(wlst****)',
#   '제임스 갓님이 dc를 살리셨다',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 19, 19, 54),
#   0],
#  ['luci****',
#   'DC의 새로운 희망 ....그리고 이런걸 극장에서 봐야지... 특수효과없는 영화를 머하러 극장에서 보냐 걍 스마트폰으로 보면 되지..',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2018, 12, 19, 18, 1),
#   '관람객'],
#  ['AlinexSuccubus(amdz****)',
#   '물고기 버전의 블랙팬서',
#   '1',
#   '11',
#   '5',
#   datetime.datetime(2019, 1, 14, 18, 41),
#   0],
#  ['이름없음(leeu****)',
#   '정성들여 요리 한 음식인것 같은데  맛은 없네요',
#   '1',
#   '11',
#   '5',
#   datetime.datetime(2019, 1, 8, 22, 41),
#   0],
#  ['vbak****',
#   '옛날바이x맨 후레x맨 보는것같은유치한느낌이...스토리전개도너무흠...에피소드여러개를급하게짜집기해서마무리한느낌..간간히영상이그나마굿~',
#   '3',
#   '11',
#   '5',
#   datetime.datetime(2018, 12, 31, 8, 31),
#   0],
#  ['IC은인(rork****)',
#   '무슨 유치원생 영화인줄',
#   '2',
#   '11',
#   '5',
#   datetime.datetime(2018, 12, 30, 13, 24),
#   '관람객'],
#  ['히야(wos3****)',
#   '엠버허드 존예 개이뻨ㅋㅋㄱ',
#   '8',
#   '11',
#   '5',
#   datetime.datetime(2018, 12, 20, 10, 51),
#   '관람객'],
#  ['lucia2333(dlsk****)',
#   '이게 정말 재밌다고...??? 영상미는 무슨 ㅋㅋㅋㅋ 보다가 실소가 터지던데.',
#   '1',
#   '12',
#   '6',
#   datetime.datetime(2019, 1, 12, 21, 16),
#   0],
#  ['너와함께라면(good****)',
#   '역대 최악의 영화 너무 유치하고 현실성이 없어 스파이더맨이 한 10배는 재밌다',
#   '1',
#   '12',
#   '6',
#   datetime.datetime(2019, 1, 9, 1, 31),
#   0],
#  ['김준수(kbs0****)',
#   'ㅋㅋ진짜평점처음남기는데 댓글알바들다 죽여야된다',
#   '1',
#   '12',
#   '6',
#   datetime.datetime(2019, 1, 2, 23, 41),
#   0],
#  ['생맥주가조아(raul****)',
#   '와 SF영화보다가 존건 또 첨이네 진심 초딩 졸업작품용 망작 절대 보지마삼',
#   '1',
#   '12',
#   '6',
#   datetime.datetime(2018, 12, 28, 17, 20),
#   0],
#  ['도망자T라(meta****)',
#   '아쿠아맨///마약왕 둘중 아쿠아 맨에 더 잼있다에 추천 꾸~욱',
#   '6',
#   '12',
#   '6',
#   datetime.datetime(2018, 12, 21, 10, 13),
#   0],
#  ['Murphy Lee(pink****)',
#   "평점이 높아서 친구랑 약속잡고 예매해서 봤는데...,,,,.. 엌..ㅋ...ㅋㅣㅣㅋ이렇게 유치할수갘ㅋ,ㅋ'ㅋ.ㅋ;ㅋ 수준 이하다. 평점 알바는 안썼으면 좋겠다.",
#   '1',
#   '13',
#   '7',
#   datetime.datetime(2018, 12, 30, 22, 8),
#   '관람객'],
#  ['baec****',
#   '문어가 드럼10개 한번에 치는 장면이 제일 웃겼습니다.',
#   '1',
#   '14',
#   '8',
#   datetime.datetime(2019, 1, 6, 8, 50),
#   '관람객'],
#  ['쿠르노(tric****)',
#   '돈날렷다.그냥 때려밖은 cg, 이상한 스토리와 개연성 그냥 DC가 DC햇다.',
#   '1',
#   '14',
#   '8',
#   datetime.datetime(2018, 12, 24, 9, 24),
#   0],
#  ['사랑하는 천사들(rive****)',
#   '와~ 아이들이 좋아할만한 10세~12세 영화입니다.근데 아이들도 좀 유치하다고 ㅋㅋ어른들은 비추!',
#   '1',
#   '16',
#   '10',
#   datetime.datetime(2018, 12, 31, 23, 2),
#   '관람객'],
#  ['pppp(cycl****)',
#   '황금똥을 싸질러놨다고 생각합니다 원작이 뭔진 관심없고 CG팀 고생한거 알겠는데 감독 작가 연출 다 B급 전대물영화 찍던 사람들인가봅니다. 정신고문 당하고 나온느낌이에요 연기자들한테 미안해해야 할 작품',
#   '1',
#   '24',
#   '18',
#   datetime.datetime(2019, 1, 6, 21, 14),
#   '관람객'],
#  ['미용사(rede****)',
#   '진심 파워레인저 cg 업그레이드 버젼ㅋㅋㅋㅋ DC 이렇게 계속 졸작 만드는것도 능력임ㅋㅋㅋㅋ',
#   '2',
#   '5',
#   '0',
#   datetime.datetime(2019, 2, 16, 13, 49),
#   0],
#  ['mira****',
#   '내 취향은 아닌 갑다. 보는데 잠와 죽을뻔 했네.',
#   '2',
#   '5',
#   '0',
#   datetime.datetime(2019, 2, 13, 17, 13),
#   0],
#  ['zoon****',
#   '화려하지만 지루한 느낌',
#   '6',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 30, 0, 54),
#   '관람객'],
#  ['낄낄낄(char****)',
#   '솔직히 영상미는 좋았지만..스토리의 개연성이 너무 떨어져서 씁쓸하더라 ㅋㅋ ..',
#   '6',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 26, 21, 51),
#   0],
#  ['쮜뇽이(jwoo****)',
#   'Cg 좋다고해서 봤는데 걍 그렇구만 뭘ㅋㅋ DC 마블 매니아아니면 걍노잼',
#   '4',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 15, 1, 51),
#   '관람객'],
#  ['astrodory508(tjdc****)',
#   '액션, 컴터그래픽은 좋았지만 스토리가 너무 뻔하고 유치해',
#   '6',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 14, 13, 17),
#   '관람객'],
#  ['쾌도(ambe****)',
#   '눈이 즐거울 정도의 화려한 영상미. 손발이 오글거리는 스토리',
#   '7',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 13, 3, 54),
#   0],
#  ['김봉주(qhdw****)',
#   '구냥 영웅영화 줄거리가그렇듯 별로....',
#   '6',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 6, 12, 26),
#   '관람객'],
#  ['insu****',
#   '진짜 쵝오다 ㅋㅋ 아쿠아맨이 디씨를 살렸구나',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 5, 23, 53),
#   0],
#  ['sims****',
#   '수족관을 좋아해서 볼거린많지만 뻔한스토리에 빌런 파워레인저형은ㅋㅋ엠버허드 얼굴보면서 참았네여',
#   '6',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 3, 22, 8),
#   0],
#  ['yjso****',
#   '어디선가 본듯한 뻔한내용이지만 영상미가 화려하고 볼만했습니다',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 2, 18, 19),
#   0],
#  ['다인(wp2d****)',
#   '볼게 진짜 많고 엄청 화려한데 내가 지쳤다',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 2, 17, 51),
#   '관람객'],
#  ['딸셋맘(smil****)',
#   '시간이 언제 다 지나간줄도 몰랐네요~~재미 있었어요~액션과 배우들 다 멋있었네요 ~~^^',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 2, 2, 41),
#   '관람객'],
#  ['노환성(conn****)',
#   '정말정말 디티일이 개멋짐',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 1, 0, 46),
#   '관람객'],
#  ['휘날리는바람(blac****)',
#   '지루하지 않은 화려한 액션신이 많아서 좋았어요',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 1, 0, 46),
#   '관람객'],
#  ['토바(toba****)',
#   'DC 라서 기대 안하고 갔는데 화려한 영상미와 지루하지 않은 스토리로 재밌게 봤습니다^^',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 1, 0, 36),
#   '관람객'],
#  ['리퍼(dhfb****)',
#   '나름 재밌게 봤습니다. 일단 돈은 아깝지 않음',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 1, 1, 0, 26),
#   0]]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                     0  ...    6
# 0      기차순무(heec****)  ...    0
# 1            fill****  ...    0
# 2      소원열차(alst****)  ...    0
# 3      촌철활인(sian****)  ...    0
# 4      스폰지밥(kuf4****)  ...    0
# ..                ...  ...  ...
# 585     딸셋맘(smil****)  ...  관람객
# 586     노환성(conn****)  ...  관람객
# 587  휘날리는바람(blac****)  ...  관람객
# 588      토바(toba****)  ...  관람객
# 589      리퍼(dhfb****)  ...    0
#
# [590 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#              nickname  ... watch_movie
# 0      기차순무(heec****)  ...           0
# 1            fill****  ...           0
# 2      소원열차(alst****)  ...           0
# 3      촌철활인(sian****)  ...           0
# 4      스폰지밥(kuf4****)  ...           0
# ..                ...  ...         ...
# 585     딸셋맘(smil****)  ...         관람객
# 586     노환성(conn****)  ...         관람객
# 587  휘날리는바람(blac****)  ...         관람객
# 588      토바(toba****)  ...         관람객
# 589      리퍼(dhfb****)  ...           0
#
# [590 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
