# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(DC%ED%9E%88%EC%96%B4%EB%A1%9C_%EC%A0%80%EC%8A%A4%ED%8B%B0%EC%8A%A4%EB%A6%AC%EA%B7%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=116866
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 116866
total_count = 673  ## 전체 크기=673

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=116866&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 116866
total_count = 673  ## 전체 크기=673

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['야후예스(eocj****)',
#   '블랙핑크ㅋㅋㅋ그 순간부터 대사 집중 안되고 노래만 귀에 맴돔',
#   '10',
#   '2336',
#   '419',
#   datetime.datetime(2017, 11, 15, 17, 6),
#   '관람객'],
#  ['Mu(prau****)',
#   '슈퍼맨 혼자만 너무 쎄서 밸런스가 무너졌다. 나머지 멤버 없어도 이길 수준? 배댓슈에선 슈퍼맨 뺨치게 강하고 본인 영화에선 신과 맞짱 뜨던 원더우먼이 왜 이렇게 약해진거냐..',
#   '6',
#   '1963',
#   '292',
#   datetime.datetime(2017, 11, 15, 19, 47),
#   0],
#  ['yks0****',
#   '배트맨 능력은 돈이래ㅋㅋㅋ제일부럽냉',
#   '10',
#   '1277',
#   '182',
#   datetime.datetime(2017, 11, 15, 7, 54),
#   0],
#  ['jinj****',
#   '혼자선 세상을 구할수 없다고???틀렸어 슈퍼맨은 혼자서 세상을 구할 수 있어ㅋㅋㅋ',
#   '6',
#   '1143',
#   '111',
#   datetime.datetime(2017, 11, 16, 4, 8),
#   0],
#  ['블랙님(jgki****)',
#   '예전 DC영화처럼 무겁지도않고 재밌게 봤음원더우먼은 봐도봐도 예쁘네',
#   '10',
#   '1331',
#   '412',
#   datetime.datetime(2017, 11, 15, 14, 46),
#   '관람객'],
#  ['JM(wjda****)',
#   '마지막처럼~ 마지막처럼~~',
#   '10',
#   '1105',
#   '260',
#   datetime.datetime(2017, 11, 15, 7, 24),
#   0],
#  ['alsw****',
#   '플래시 : 그래서 초능력이 뭐에요?배트맨 : 난 부자야',
#   '10',
#   '649',
#   '102',
#   datetime.datetime(2017, 11, 15, 17, 28),
#   '관람객'],
#  ['advkfj5454(zxcv****)',
#   '볼만은하다... 그래서 더 아쉽다. 각 캐릭터 솔로영화 이후 나왔다면 지루할수 있는 부분들이 풍성한 액션 스토리에대한 이해들로 다 채워졌겠지만 아쉽다... 그래도 분명 배댓슈이후로 정신은 차린건같다',
#   '10',
#   '719',
#   '208',
#   datetime.datetime(2017, 11, 15, 17, 43),
#   '관람객'],
#  ['이영국(lyk3****)',
#   '15시에 개봉인데 아침부터 테러하는놈들 뭐야?',
#   '10',
#   '725',
#   '294',
#   datetime.datetime(2017, 11, 15, 7, 31),
#   0],
#  ['애교만점(kanp****)',
#   '전반부는 조금 지루하내요. 후반부 액션신은 볼 만하나 슈퍼맨이 오버파워라 캐릭터간 밸런스가 너무 맞지않는것같음 슈퍼맨만 있으면 다 나머지 멤버가 머가 필요하지 생각이 듬',
#   '5',
#   '607',
#   '190',
#   datetime.datetime(2017, 11, 15, 22, 24),
#   '관람객'],
#  ['이한이유하(blue****)',
#   '무식한 것들이 시리즈로 제작된 걸 전 편을 안 보고 와서는 슈퍼맨이 왜 죽었는지, 왜 안 나오는지 이해 안된다고 씨부리네. 반지의제왕 1~3편 중 2(두 개의 탑)만 보고 왜 쟤들이 싸우는지 모르겠으니 영화 못 만들...',
#   '10',
#   '1054',
#   '637',
#   datetime.datetime(2017, 11, 15, 14, 13),
#   0],
#  ['찬엔드라이브(kych****)',
#   '배트맨은 그냥 스폰서일뿐',
#   '6',
#   '481',
#   '92',
#   datetime.datetime(2017, 11, 16, 3, 57),
#   '관람객'],
#  ['장보근(bogl****)',
#   '마블과는 다른 색깔의 느낌영웅들의 캐미또한 최고였다(시사회가서 봄)',
#   '10',
#   '684',
#   '301',
#   datetime.datetime(2017, 11, 15, 0, 0),
#   0],
#  ['땡준(yssj****)',
#   '제발 이번에는 싸우다가 힘들어도 마사 부르지말자',
#   '10',
#   '562',
#   '196',
#   datetime.datetime(2017, 11, 15, 7, 15),
#   0],
#  ['글쎄내가(rnrf****)',
#   '러닝타임이 좀더 길었으면 하는 아쉬움이 있네요...장면장면이 짧고 휙휙 지나가는 느낌이 나요. 살짝 유치한 느낌도 좀 낫지만 그래도 액션은 시원시원합니다. 쿠키영상은 2개입니다',
#   '8',
#   '439',
#   '109',
#   datetime.datetime(2017, 11, 15, 17, 9),
#   '관람객'],
#  ['황재연(deu9****)',
#   'dc가 조낸 급하긴 급했나봄',
#   '8',
#   '381',
#   '66',
#   datetime.datetime(2017, 11, 15, 11, 46),
#   0],
#  ['쿠쿠(djhl****)',
#   '원더우먼 존멋!!!!',
#   '7',
#   '395',
#   '85',
#   datetime.datetime(2017, 11, 15, 17, 23),
#   '관람객'],
#  ['comt****',
#   '결국엔 슈퍼맨? 애들너무 약하다 ...',
#   '1',
#   '410',
#   '131',
#   datetime.datetime(2017, 11, 16, 19, 9),
#   '관람객'],
#  ['유리엘(war1****)',
#   '디씨 영화평은 늘 이런식 ㅋㅋㅋ 거의 자포자기 수준으로 그래 이정도면 선방, 괜찮다, 다음을 기대하자, 얼마나 그동안 재미가 없었으면 이정도는 봐주자는 식의 리뷰냐',
#   '1',
#   '400',
#   '134',
#   datetime.datetime(2017, 11, 15, 22, 6),
#   0],
#  ['김현균(hyeo****)',
#   '나쁘지는 않았는데 개연성이 좀.... 솔직히 10점짜리 영화는 아님',
#   '7',
#   '379',
#   '122',
#   datetime.datetime(2017, 11, 15, 17, 15),
#   0],
#  ['도용좀하지마(a200****)',
#   '자막 누가했냐? 웃기는장면인데 안웃겨어쩔거냐 자막 만든놈아',
#   '7',
#   '305',
#   '58',
#   datetime.datetime(2017, 11, 16, 0, 38),
#   '관람객'],
#  ['kdlz****',
#   '저스티스 리그라기보단 그냥 슈퍼맨 인거같은데',
#   '5',
#   '304',
#   '62',
#   datetime.datetime(2017, 11, 15, 17, 15),
#   0],
#  ['낚시왕김삿갓(doub****)',
#   '아....난 힘들드라..초반은 괜찮았는데...마지막은....아쿠아맨의 능력은 뭔지 잘몰겠고..포크들고다니고...플래시를 ㅂ ㅅ 만들어놨네....스피드느낌은 TV가 훨나음....슈퍼맨은졸쌔네...슈퍼맨이플래시를스피드로...',
#   '7',
#   '324',
#   '82',
#   datetime.datetime(2017, 11, 16, 3, 26),
#   0],
#  ['서어새앵(sonc****)',
#   '히어로 영화에도 개연성은 필요하다.',
#   '5',
#   '301',
#   '83',
#   datetime.datetime(2017, 11, 15, 17, 13),
#   0],
#  ['하드랜딩(woon****)',
#   '마음을 비우고 봐라. 마블과는 비교하진 말고',
#   '7',
#   '256',
#   '53',
#   datetime.datetime(2017, 11, 16, 16, 44),
#   '관람객'],
#  ['glac****',
#   '아직도 많이 부족하다!!!',
#   '4',
#   '325',
#   '129',
#   datetime.datetime(2017, 11, 15, 21, 24),
#   '관람객'],
#  ['지진(eart****)',
#   'DC의 다채로움에 박수를  feat.  블랙핑크',
#   '8',
#   '277',
#   '85',
#   datetime.datetime(2017, 11, 15, 17, 42),
#   '관람객'],
#  ['난다손(minh****)',
#   '슈퍼맨 혼자만 있어도 인류를 구할 수 있다는 걸 보여주는 영화 ㅋ',
#   '8',
#   '223',
#   '34',
#   datetime.datetime(2017, 11, 15, 19, 19),
#   '관람객'],
#  ['님(empe****)',
#   '재밌음ㅋㅋ쿠키영상2번째까지 보셈ㅋ',
#   '9',
#   '260',
#   '95',
#   datetime.datetime(2017, 11, 15, 17, 12),
#   '관람객'],
#  ['바둥바둥(bato****)',
#   '플래쉬 달리는 폼  왜 그러니',
#   '7',
#   '235',
#   '72',
#   datetime.datetime(2017, 11, 15, 17, 52),
#   '관람객'],
#  ['이도련(ejmw****)',
#   '슈퍼맨이 너무 완벽해서 굳이 살려야했나...슈퍼맨이 등장하고 정신차리고난 이후부터 긴장감이라곤 1도 없어진다...플래시보다도 빠를수 있고 원더우먼보다 쌔고 사이보그 같은 눈뽕빔 (?)도...다만 돈이없다....그래서...',
#   '6',
#   '180',
#   '33',
#   datetime.datetime(2017, 11, 16, 1, 11),
#   0],
#  ['pcy8****',
#   '결국 세상을 구한건 수퍼맨 여친이네',
#   '3',
#   '150',
#   '20',
#   datetime.datetime(2017, 11, 15, 17, 11),
#   0],
#  ['파워맨(dhfo****)',
#   '원더우먼이 멋있게 나온다 제일 좋은듯',
#   '10',
#   '172',
#   '44',
#   datetime.datetime(2017, 11, 15, 21, 8),
#   '관람객'],
#  ['길우(lgw0****)',
#   '시원시원한 맛에 보는건 좋다. 하지만 캐릭터들을 엮어내는 방법?은 확실히 마블영화가 잘하는구나.. 라는 생각이 들게 만든다.',
#   '6',
#   '178',
#   '51',
#   datetime.datetime(2017, 11, 16, 3, 22),
#   '관람객'],
#  ['루차(dgju****)',
#   '작가를 초딩들로 기용해서 썼나? 빌런도 30년 전에나 볼법한 조온나 1차원적인 악당이고, 1%라도 악당이 될 가능성이 있으면 슈퍼맨을 죽여야한다던 배트맨이 1화만에 지구의 운명을 로또에 거네 ㅋㅋ',
#   '1',
#   '143',
#   '21',
#   datetime.datetime(2017, 11, 16, 14, 55),
#   0],
#  ['레옹(dosa****)',
#   '시작하고 나서 ... 원더우먼 이쁘네 ... 중간에 우리나라 K팝이 나오네 ... 근데 원더우먼 이쁘네 ... 끝나고 원더우먼은 겨드랑이도 이쁘네 ...',
#   '10',
#   '153',
#   '32',
#   datetime.datetime(2017, 11, 16, 10, 54),
#   '관람객'],
#  ['Vai Cavalo(dand****)',
#   '큰 기대는 안 하고 보는게 좋음',
#   '6',
#   '202',
#   '87',
#   datetime.datetime(2017, 11, 15, 17, 1),
#   0],
#  ['kjpg****',
#   '왜 항상 서로 죽일듯이 싸울려다가 뜬금없이 화해하냐....ㄷㄷ',
#   '4',
#   '162',
#   '51',
#   datetime.datetime(2017, 11, 16, 2, 59),
#   '관람객'],
#  ['박범진(pj12****)',
#   'DC가 드디어 부활했다',
#   '10',
#   '493',
#   '394',
#   datetime.datetime(2017, 11, 15, 7, 9),
#   0],
#  ['hsgg****',
#   '오늘 아이맥스에서 보고와서 분노의 평을 남깁니다. 이 영화의 가장 큰 문제 3가지는 영화 전체를 망치는 빌런(약하고매력없고긴장감조차없음), 구멍투성이각본(실소가나옴), 그리고 가장중요할때 액션의부재... 폭망작이라고...',
#   '1',
#   '134',
#   '38',
#   datetime.datetime(2017, 11, 16, 1, 25),
#   0],
#  ['정성욱24세(waw5****)',
#   '불친절해도 너무 불친절하다 빌런인 스테판울프는 지구에 왜 왔는지 어디서 왔는지 영화가 끝나도 알수가 없고 지구를 공격하는 이유조차 없는 세상불친절한 영화 (엄마가 불러서 왔다는데...)베트맨 찐따 팝콘맨으로 만들고 ...',
#   '1',
#   '136',
#   '41',
#   datetime.datetime(2017, 11, 17, 18, 17),
#   0],
#  ['srxj****',
#   '의리로봤다DC이놈들아',
#   '10',
#   '126',
#   '33',
#   datetime.datetime(2017, 11, 15, 19, 34),
#   '관람객'],
#  ['맨우진(tkeh****)',
#   '솔직히 감동이나 교훈따윈 저편에 두고 스토리나 액션만 보는 나에게는 명작이였다.',
#   '10',
#   '170',
#   '78',
#   datetime.datetime(2017, 11, 15, 7, 23),
#   0],
#  ['chll****',
#   '역동성은 마블보다 더 좋다 하지만 여전히 디씨스러운 전개 조금 아쉬운 부분 ..',
#   '8',
#   '145',
#   '54',
#   datetime.datetime(2017, 11, 15, 17, 50),
#   '관람객'],
#  ['테일러(tail****)',
#   '기대엪100퍼센트는 미치지못했으니 90퍼센트 이상은 능히 해주었다고 생각함. 다음에 나올 dc유니버스가 기대됨!',
#   '10',
#   '201',
#   '110',
#   datetime.datetime(2017, 11, 15, 7, 42),
#   0],
#  ['락사마(ckr3****)',
#   '슈퍼맨 혼자면 되는데 뭐하러 뭉치냐',
#   '4',
#   '96',
#   '6',
#   datetime.datetime(2017, 11, 16, 18, 46),
#   0],
#  ['hht2****',
#   '마치 ‘슈퍼맨 곧 부활하니까 너흰 너무 강하면 안돼’라고 하는듯 다들 왜이리 약한지... 굳이 리그 안만들어도 슈퍼맨 혼자서 지구 구해도 될듯',
#   '5',
#   '108',
#   '18',
#   datetime.datetime(2017, 11, 18, 0, 39),
#   '관람객'],
#  ['limg****',
#   '배트맨은크리스퍼놀란감독의배트맨으로만끝냈어야했다인간적이고뇌에가득했던배트맨은 총만찌질하게쏘는부동산중개업자로만영화에등장할뿐이다',
#   '1',
#   '116',
#   '30',
#   datetime.datetime(2017, 11, 15, 22, 8),
#   0],
#  ['앙기뮤띠(dltj****)',
#   '네 아쉬워요 cg 아쉽고, 후반부 긴장감 없어지고, 빌런 아쉽습니다. 그래도 원더우먼은 이쁘고, 아쿠아맨 섹시하고, 플래쉬 유쾌하고, 배트맨 멋있고, 슈퍼맨 OO고, 블랙핑크는 사랑입니다. 펔 마블!! 까진 아니라도...',
#   '8',
#   '153',
#   '68',
#   datetime.datetime(2017, 11, 15, 21, 54),
#   '관람객'],
#  ['slim****',
#   '간신히 평타만 쳐줬는데도 눈물이 다 나올 거 같네',
#   '8',
#   '91',
#   '15',
#   datetime.datetime(2017, 11, 16, 5, 34),
#   '관람객'],
#  ['Theodore(pste****)',
#   '12세 관람가인 건 좋은데, 딱 12살짜리들만 만족할만한 수준으로 만들었음. 마블이 성공한 건 42살짜리 덕후도 즐길만한 암시와 함축, 깨알 드립, 딴만, 짠맛, 쓴맛, 신맛으로 맛깔나게 요리를 해주기 때문인데......',
#   '6',
#   '97',
#   '26',
#   datetime.datetime(2017, 11, 16, 1, 22),
#   0],
#  ['우르드(kimd****)',
#   '반쪽짜리 부활, 왜  dc가 망하고 마블이 떳는지 명확하다',
#   '5',
#   '77',
#   '13',
#   datetime.datetime(2017, 11, 16, 1, 21),
#   0],
#  ['jhy4****',
#   '후반에 너무 전투같지 않은 전투하다 끝.',
#   '7',
#   '106',
#   '44',
#   datetime.datetime(2017, 11, 15, 20, 45),
#   '관람객'],
#  ['느림보(ooxx****)',
#   '너무 기대가 컸네요이도저도 아니었음',
#   '5',
#   '128',
#   '66',
#   datetime.datetime(2017, 11, 15, 17, 32),
#   '관람객'],
#  ['무빙장인(whda****)',
#   '확실히 저번 작품보다는 월등히났다.과연 이 영화로 DC의 반격이 시작될지.. 그것이 의문임',
#   '9',
#   '121',
#   '60',
#   datetime.datetime(2017, 11, 15, 0, 30),
#   0],
#  ['라이언(joyj****)',
#   '혼자서는 세상을 구할 수 없다(X) 있다(O) 진짜 혼자 구함',
#   '10',
#   '71',
#   '13',
#   datetime.datetime(2017, 11, 16, 9, 56),
#   '관람객'],
#  ['Uiiu(drag****)',
#   '슈퍼맨을 부활시키기위한 팀...',
#   '6',
#   '60',
#   '4',
#   datetime.datetime(2017, 11, 15, 17, 28),
#   0],
#  ['yyym****',
#   '잘 모르겠음 그냥 그냥 본거 같음',
#   '6',
#   '72',
#   '17',
#   datetime.datetime(2017, 11, 15, 22, 31),
#   '관람객'],
#  ['RootKim(jwki****)',
#   '토르2보다 재미없었다  절대 8점대 영화가아니다',
#   '1',
#   '69',
#   '15',
#   datetime.datetime(2017, 11, 17, 0, 49),
#   0],
#  ['LOVE Seeker(gksa****)',
#   '슈퍼맨 >>>> 악당 > 배트맨 + 원더우먼 + 아쿠아맨 + 사이보그 + 플래쉬탈탈 털리던 저스티스리그가 슈퍼맨 부활 시키고 그냥 상황역전 ㅉㅉ',
#   '5',
#   '87',
#   '34',
#   datetime.datetime(2017, 11, 15, 17, 36),
#   '관람객'],
#  ['준이(asic****)',
#   '한창 재밌게보고 있는데 지진때문에 쫒겨남.',
#   '1',
#   '192',
#   '139',
#   datetime.datetime(2017, 11, 15, 17, 34),
#   0],
#  ['jini****',
#   '폼만 잡다 끝난듯..지루함',
#   '4',
#   '71',
#   '20',
#   datetime.datetime(2017, 11, 16, 17, 58),
#   '관람객'],
#  ['박종문(bbi-****)',
#   '잭 스나이더 제발 각본 좀 못 쓰게 해라.',
#   '5',
#   '58',
#   '8',
#   datetime.datetime(2017, 11, 15, 21, 31),
#   0],
#  ['박준석(juns****)',
#   '한 줄 정리 : 슈퍼맨 죽어서 난리칠라했는데 다시 살아돌아와서 실패함. 끝. 기승전슈퍼맨;;',
#   '6',
#   '66',
#   '16',
#   datetime.datetime(2017, 11, 16, 3, 27),
#   0],
#  ['권승리(tmdf****)',
#   '맨오브스틸 배댓슈 수어사이드 앞 영화에서 못느낀 알수없는 유치함과 답없는 배트맨 전편에 이은 엄마타령 후반부 갈수록 이게 갤가돗 화보영상인지 영화인지 구분이 안됬다. 오징어 처럼 흐느적대는 플래시는 덤',
#   '2',
#   '62',
#   '15',
#   datetime.datetime(2017, 11, 17, 9, 59),
#   '관람객'],
#  ['JGH(paga****)',
#   '믿고 거르는 dc 시네마~',
#   '1',
#   '70',
#   '27',
#   datetime.datetime(2017, 11, 16, 13, 46),
#   0],
#  ['best****',
#   '다크나이트야 말할 필요없는  명작이고 맨오브스틸의 액션은 신기원수준으로 흥미진진했는데  배대슈,수어사이드스쿼드에서 너무 망했음, 그 중간쯤 위치할 만한 영화인데  너무 많은걸 한번에 담으려하니 영화완성도가 부족한편,...',
#   '7',
#   '45',
#   '3',
#   datetime.datetime(2017, 11, 16, 16, 45),
#   0],
#  ['노블레스(blue****)',
#   '전에 비해 볼꺼리는 많았다 근데 너무 삭제 장면이 많아서 배트맨 v 슈퍼맨 처럼 노컷감독판을 봐야 더 재밌을꺼 같다.. 그리고 배트맨을 너무 호구 처럼 만들어놔서 배트맨 불쌍하게 느껴질 정도다.. 역시 실질적 주인공...',
#   '8',
#   '45',
#   '7',
#   datetime.datetime(2017, 11, 15, 21, 20),
#   0],
#  ['브리(bb33****)',
#   '아주 재미없는것은 아니지만....이미 더 재밌는 것을 보았는데 그보다 못한 것을 본 느낌. 이미 답을 알아서 식상한 느낌.ㅠㅠㅠ비추입니다',
#   '5',
#   '51',
#   '13',
#   datetime.datetime(2017, 11, 15, 17, 33),
#   0],
#  ['초류향(tnsd****)',
#   '마블에 어벤져스 있다면 DC는 저스티스리그 있다.',
#   '10',
#   '234',
#   '198',
#   datetime.datetime(2017, 11, 15, 0, 4),
#   0],
#  ['짱똘(dlsu****)',
#   '진심 너무 노잼이다 나 영웅이야 멋져?하는 씬이 너무많아 디씨는 한참 멀었다',
#   '5',
#   '41',
#   '6',
#   datetime.datetime(2017, 11, 16, 19, 14),
#   0],
#  ['맨시티no 20베실바(hjk0****)',
#   'Dc가 이 정도 반격을 해줘야 마블과의 경쟁이 재밌지.',
#   '8',
#   '162',
#   '127',
#   datetime.datetime(2017, 11, 15, 0, 23),
#   0],
#  ['진진(aaai****)',
#   '관람객 평점이 네티즌 평점보다 더 낮은데 그럼 평점 테러를 하는게 아니라 알바들이 10점 찍는다고 보는게 더 정상 아님?',
#   '5',
#   '38',
#   '4',
#   datetime.datetime(2017, 11, 15, 13, 24),
#   0],
#  ['yoon6427(vicb****)',
#   '진짜 예고편이 전부다 악당들도 보스빼곤 종류도없고 민간인도안나옴  무슨 컴퓨터게임 CG인줄',
#   '1',
#   '40',
#   '7',
#   datetime.datetime(2017, 11, 18, 12, 5),
#   '관람객'],
#  ['아콘(brai****)',
#   '잡탕 찌개 끓이다가 라면수프 넣었는데 그저그래....',
#   '6',
#   '41',
#   '8',
#   datetime.datetime(2017, 11, 16, 3, 34),
#   0],
#  ['Zenophy(phan****)',
#   'DC는 아직 갈 길이 멀구나... ㅠ_ㅜ 그래도 응원한다.. 전작인 원더우먼이 더 나았던 거 같아.',
#   '6',
#   '36',
#   '4',
#   datetime.datetime(2017, 11, 15, 21, 26),
#   0],
#  ['기타맨(pilm****)',
#   '아 후반부 연출 진짜....',
#   '5',
#   '38',
#   '6',
#   datetime.datetime(2017, 11, 16, 1, 16),
#   0],
#  ['papa****',
#   '슈퍼맨 vs 베트맨을 재밋게 본사람입니다..너무 하네.. DC가 돈이없나 감독이 문젠가..해도해도 너무 유치하자나..어설프게 어벤저스빼낀 느낌(특히 번개맨인가 웃기지도 않고~ 아쿠아맨인가는 토르따라할라는거같은데 짝퉁...',
#   '5',
#   '50',
#   '18',
#   datetime.datetime(2017, 11, 16, 3, 22),
#   0],
#  ['fldz****',
#   '다 모였다 초딩 꿈동산..',
#   '1',
#   '34',
#   '3',
#   datetime.datetime(2017, 11, 17, 13, 20),
#   0],
#  ['cown****',
#   '유쾌하지도 않고 진지하지도 않고.. 제목을 원더우먼 리그로 바꾸는게 나을듯 원더우먼 빼면 볼거없는 영화',
#   '4',
#   '35',
#   '4',
#   datetime.datetime(2017, 11, 15, 23, 8),
#   0],
#  ['유니콘(mj10****)',
#   '매끄럽지 못한 스토리 너무나도 싱거운 악당 캐릭터의 밸런스 붕괘 그리고 배대슈보다 못한 음악까지 솔직히 기대 이하였다. 그리고 사라진 50분',
#   '4',
#   '36',
#   '5',
#   datetime.datetime(2017, 11, 17, 0, 54),
#   0],
#  ['Lovelifesong(doth****)',
#   '저 포스터 만든 새기 영화도 안처보고 만들었네 혼자서 구하드라 새기야',
#   '1',
#   '39',
#   '8',
#   datetime.datetime(2017, 11, 17, 0, 34),
#   0],
#  ['오렌지(asd7****)',
#   '설명충이 짜증날때도 있지만 필요한순간도 있는 법이다 이 영화에는 설명충이 없다. 너무 생략이 많어..',
#   '5',
#   '40',
#   '9',
#   datetime.datetime(2017, 11, 16, 1, 42),
#   '관람객'],
#  ['에아노르(epql****)',
#   '뉘들은 이런거보지마라. .똥은 나만맛본다 히히',
#   '3',
#   '43',
#   '12',
#   datetime.datetime(2017, 11, 17, 12, 30),
#   '관람객'],
#  ['moungnym(lmd1****)',
#   '글쎄요 아직 저스티스리그를 하기에는 다른 캐릭터 에 대한 홍보가 더 필요하지 않을까요',
#   '7',
#   '34',
#   '4',
#   datetime.datetime(2017, 11, 16, 23, 37),
#   '관람객'],
#  ['양구와끼(ckdw****)',
#   '정말 솔직하게 말합니다.내용 너무 무난해서 재미 없습니다.',
#   '5',
#   '40',
#   '10',
#   datetime.datetime(2017, 11, 15, 21, 22),
#   0],
#  ['넬(rlas****)',
#   '그냥 첨부터 슈퍼맨깨우지그랬냐',
#   '8',
#   '34',
#   '5',
#   datetime.datetime(2017, 11, 17, 19, 18),
#   '관람객'],
#  ['르네상스(imjo****)',
#   '마블 스튜디오가 강세를 이어가고 있는 만큼 DC는 DC만의 길을 걸었으면 좋겠다. DC 특유의 연출과 진지함은 어벤져스를 따라가다가 빛을 바랬다. 조각난 개연성은 덤',
#   '5',
#   '31',
#   '3',
#   datetime.datetime(2017, 11, 16, 14, 35),
#   0],
#  ['28sh****',
#   '예고편+슈퍼맨 하드캐리! 끝! 슈퍼맨 나오는 순간 나머지 캐릭 존재감 떨어짐.어벤져스 캐릭터와 많이 겹침.기대했건만 많이 아쉬움. 스토리 기대안했지만 설명이 너무 모자름 디씨코믹스 팬들은 모르겠지만 일반인이 봤을땜 ...',
#   '5',
#   '27',
#   '1',
#   datetime.datetime(2017, 11, 16, 1, 4),
#   0],
#  ['OULLMOON(il99****)',
#   '저스티스리그 : 혼자선 구할 수 없어! 모두 함께 그를 부르자!!',
#   '1',
#   '29',
#   '3',
#   datetime.datetime(2017, 11, 19, 3, 18),
#   0],
#  ['노아어뭉(cute****)',
#   '적당히 재밌음.배트맨의 수퍼파워는 돈 이었음ㅋ은행을 사버리는 배트앤의 위엄.',
#   '7',
#   '33',
#   '7',
#   datetime.datetime(2017, 11, 16, 0, 40),
#   '관람객'],
#  ['hyob****',
#   '너무나 지루하고 유치하기 짝이 없네',
#   '1',
#   '29',
#   '4',
#   datetime.datetime(2017, 11, 17, 17, 54),
#   0],
#  ['박종석(afga****)',
#   '영화상영시간이 짧았음 3시간정도 해도될거같은데...히어로들이 모여지는 과정이 절반 살짝 지루하기도마지막 결투씬들은 볼만했음',
#   '5',
#   '29',
#   '4',
#   datetime.datetime(2017, 11, 16, 9, 29),
#   '관람객'],
#  ['단비꺼얌(moki****)',
#   '15일 0시 되니까 적는 애들뭐냐ㅋㅋㅋ ㅋ 엠바고냐 작작해라 평점 조작들아',
#   '7',
#   '44',
#   '19',
#   datetime.datetime(2017, 11, 15, 7, 8),
#   0],
#  ['천본앵(jisu****)',
#   '혼자서는 세상을 구할수 없다?슈퍼맨만 있음 구할수있다',
#   '1',
#   '26',
#   '2',
#   datetime.datetime(2017, 11, 18, 14, 32),
#   0],
#  ['채소호빵(ente****)',
#   '슈퍼맨>>>>나쁜놈>>>>나머지',
#   '6',
#   '26',
#   '2',
#   datetime.datetime(2017, 11, 15, 21, 31),
#   0],
#  ['반갑다야(uoul****)',
#   '중간 중간 유머씬을 야구로 비유하면 타율 1할 수준.. 웃는사람도 거의없더라.. 액션신도 뭐 ㅋㅋㅋ 분발혀라',
#   '1',
#   '36',
#   '12',
#   datetime.datetime(2017, 11, 16, 13, 46),
#   0],
#  ['whit****',
#   '블랙핑크 지수 이뻐요오',
#   '6',
#   '46',
#   '22',
#   datetime.datetime(2017, 11, 15, 23, 9),
#   '관람객'],
#  ['vivien(dead****)',
#   '아마존 여전사들만 멋있음... 오글거리는 장면 많구 클리셰 덩어리라 좀 신선도가 떨어짐...그리고 슈퍼맨이 너무 쌔서 다른 애들이 굳이 필요한가? 이런 생각이 듬',
#   '5',
#   '23',
#   '0',
#   datetime.datetime(2017, 11, 17, 0, 57),
#   0],
#  ['baron(zemo****)',
#   '배트맨을 찐따로 만들었어',
#   '1',
#   '25',
#   '2',
#   datetime.datetime(2017, 11, 23, 11, 41),
#   0],
#  ['stor****',
#   '솔직하게 지루했다..평론가들한테 뭔가 평점딜한것같고, 평점알바 미리투입한것같다. 원더우먼은재미있었는데...평식형님말이맞다. 흩어져야산다. 원더우먼 시리즈에 올인이나해라ㅡㅡ',
#   '1',
#   '28',
#   '5',
#   datetime.datetime(2017, 11, 18, 14, 25),
#   0],
#  ['마법대소녀(happ****)',
#   '영화 제목 바꿔라슈퍼맨 리턴즈로슈퍼맨 혼자 다하네...슈퍼맨과 그의 아이들 .',
#   '7',
#   '24',
#   '2',
#   datetime.datetime(2017, 11, 15, 18, 37),
#   0],
#  ['whoa****',
#   '돈아깝다, 진심 ㅜㅜ토르나 다시볼걸...재미도 스토리도 액션도 그닥',
#   '4',
#   '27',
#   '5',
#   datetime.datetime(2017, 11, 16, 0, 48),
#   0],
#  ['동코(wwdd****)',
#   '슈퍼맨과 아이들 같은느낌',
#   '7',
#   '27',
#   '5',
#   datetime.datetime(2017, 11, 15, 17, 14),
#   0],
#  ['윤형인(godz****)',
#   '배대슈에서 그렇게 멋있는 배트맨 만들어놓고선 이제와서 어줍잖게 마블 스타크 흉내낸답시고 다크나이트를 말장난이나 해대는 물주로 전락시켜버린 DC에게 더이상 희망은 없다',
#   '1',
#   '22',
#   '1',
#   datetime.datetime(2017, 11, 19, 22, 7),
#   0],
#  ['scatterbrain(yhki****)',
#   "배트맨은 너무도 나약한 한낱 인간에 불과하다. 파리같은 쫄다구 한 마리에 쩔쩔매는 그가 너무 안쓰러워 콧물이 나올 지경이었다. 그러나, 당신의 능력은 무엇이냐는 플래시의 질문에 당당히 '돈'이라 말할 ...",
#   '7',
#   '22',
#   '1',
#   datetime.datetime(2017, 11, 17, 13, 54),
#   0],
#  ['좌염소우타조(xiao****)',
#   '혼자서는 평점을 구할 수 없다.',
#   '8',
#   '24',
#   '3',
#   datetime.datetime(2017, 11, 16, 23, 16),
#   0],
#  ['토모(tomo****)',
#   '혼자서는 세상 을 구할 수 없다더니 슈퍼맨이 혼자 구할듯',
#   '6',
#   '24',
#   '3',
#   datetime.datetime(2017, 11, 15, 21, 27),
#   0],
#  ['김진호(rlaz****)',
#   '정말로 영화 다보고 나왓는데.뻔한 결말 스토리는 초반부분에 짜집기한마냥 이어지지도않는 편집 여기서 정말 실망햇습니다 그리고 슈퍼맨이 돌아오고나서 정말 안나오더군요 그리고 막타로 슈퍼맨혼자 다해버리고 정말로 궁금한게잇...',
#   '4',
#   '24',
#   '3',
#   datetime.datetime(2017, 11, 15, 18, 39),
#   0],
#  ['씨즈(kims****)',
#   '벤 에플렉의 배트맨도 상당히 괜찮아지기 시작했다',
#   '7',
#   '44',
#   '24',
#   datetime.datetime(2017, 11, 15, 18, 22),
#   '관람객'],
#  ['lees****',
#   '토르 볼껄 그냥ㅜㅜ 하루죙일 입으로 떠들면서 애들 모으다가 아이언맨같은 느낌에 사이보그 나오고 스파이더맨 캐릭터 따라하는거 같은 번개맨.  물 안쓰고 쇠파이프 쓰는 아쿠아맨... 결국 원펀맨 같은 수퍼맨 등장으로 1...',
#   '3',
#   '21',
#   '2',
#   datetime.datetime(2017, 11, 16, 9, 48),
#   0],
#  ['건(emer****)',
#   '원더우먼 시선 강탈. 앞으로 DC에선 필수캐릭이 된 듯',
#   '8',
#   '26',
#   '7',
#   datetime.datetime(2017, 11, 16, 0, 52),
#   '관람객'],
#  ['gram1st(wjdw****)',
#   '그냥그러더라 결말 허무하고 그랳어 그냥',
#   '1',
#   '28',
#   '9',
#   datetime.datetime(2017, 11, 18, 2, 10),
#   '관람객'],
#  ['swze****',
#   '액션은 볼만해요. . 단지 스토리나. . 마지막 영웅들 서있는 장면 좀 유치함 ㅋ',
#   '8',
#   '30',
#   '11',
#   datetime.datetime(2017, 11, 16, 13, 44),
#   '관람객'],
#  ['준팔(tops****)',
#   '디시는 정말 끝난듯 하다.. 원더우먼 보고 잠깐 기대했던 내가 바보지.. 잭스나이더는 정말 극본은 안되겠다. 과도한 cg로 몰입감도 떨어지고, 스토리의 개연성은 정말 최악이다. 건진거라고는 1도 없는 영화',
#   '6',
#   '34',
#   '15',
#   datetime.datetime(2017, 11, 15, 16, 59),
#   0],
#  ['예낑(ko71****)',
#   '그냥저냥 디씨치고 잘만듬',
#   '8',
#   '42',
#   '23',
#   datetime.datetime(2017, 11, 15, 20, 41),
#   '관람객'],
#  ['718(niko****)',
#   "포스터 진짜 개극혐 '지구를 지켜라'급",
#   '1',
#   '18',
#   '0',
#   datetime.datetime(2017, 11, 18, 15, 39),
#   0],
#  ['anim****',
#   '대체 배트맨은 하는게 뭐냐?',
#   '1',
#   '19',
#   '1',
#   datetime.datetime(2017, 11, 28, 4, 27),
#   0],
#  ['박미희(sale****)',
#   '마블처럼 솔로무비를 좀더 진행한후 나왔더라면...',
#   '7',
#   '21',
#   '3',
#   datetime.datetime(2017, 11, 15, 17, 25),
#   0],
#  ['kimc****',
#   '모여라 초딩 꿈동산...',
#   '1',
#   '25',
#   '7',
#   datetime.datetime(2017, 11, 17, 11, 46),
#   0],
#  ['현(kbs1****)',
#   '이게   마블의 대항마라고? 혹시 dc팬분들은 보고 평점 하신거 맞음? dc팬들은 빌런이 약하고 급전개 스토리에 맛들이셨네 이래서 dc가 고쳐지지 않는거에요 (제발 영화 좀 보고 평점하자 dc빠들아. .)',
#   '1',
#   '30',
#   '12',
#   datetime.datetime(2017, 11, 15, 23, 14),
#   0],
#  ['벼리(leej****)',
#   '히어로들 등장씬 지럈다 특히 원더우먼',
#   '8',
#   '19',
#   '2',
#   datetime.datetime(2017, 11, 17, 15, 23),
#   '관람객'],
#  ['Toriko(cjsd****)',
#   '혼자서는 세상을 구할수 없다슈퍼맨  :  되는데요?',
#   '1',
#   '21',
#   '4',
#   datetime.datetime(2017, 11, 17, 18, 35),
#   0],
#  ['대륙간핵탄도탄(sera****)',
#   '여기 나오는 케릭터 스토리 알고 보는데도 좀 그렇네요.. 전작들 보고 보시는걸 추천합니다 이해 안될수도 있어요',
#   '7',
#   '23',
#   '6',
#   datetime.datetime(2017, 11, 15, 22, 20),
#   '관람객'],
#  ['라데(lang****)',
#   '재미는 있는데, 결국 슈퍼맨 없으면 아무것도 안되는 거야? 다음편 부턴 그러지 말길 바래. 여튼 갤가돗은 진짜 이쁘다.',
#   '8',
#   '17',
#   '1',
#   datetime.datetime(2017, 11, 16, 22, 13),
#   0],
#  ['프렌즈(dwa7****)',
#   '시원하고 화려하고 통쾌하다 하지만 내용 너무예상되고 빌런이 너무약함 그냥 스트레스풀이로 보셈',
#   '7',
#   '18',
#   '2',
#   datetime.datetime(2017, 11, 15, 23, 41),
#   '관람객'],
#  ['vs58****',
#   '세상은 혼자서도 구해지던데요',
#   '1',
#   '19',
#   '3',
#   datetime.datetime(2017, 11, 22, 21, 11),
#   0],
#  ['Keepforever(qwer****)',
#   '그렇게 어머니 찾는데 스토리는 어머니 어디 계시냐',
#   '1',
#   '20',
#   '4',
#   datetime.datetime(2017, 11, 17, 17, 59),
#   0],
#  ['GHOST(dude****)',
#   '뭔가 허술한 부분도 있지만 나름 선방한 느낌.. 런닝타임이 다소 짧은 듯하다 DC영화의 희망이 보인다',
#   '8',
#   '22',
#   '6',
#   datetime.datetime(2017, 11, 15, 17, 50),
#   0],
#  ['다이어트(jeh1****)',
#   '영화보다 기억에 남은 장면은 블랙핑크 ㄷㄷ 오졌다 솔직히 dc가 마블에게 밀리는 점이 확실히 있는데..정작 고치는거 하나 없네',
#   '1',
#   '26',
#   '10',
#   datetime.datetime(2017, 11, 16, 9, 11),
#   0],
#  ['백봉현(bomt****)',
#   '마블이던 DC던 뭐가중요하죠? 서로재밌게만들어서 우린 즐기면될뿐인대 왜서로댓글로 까고 못잡아먹어안달이죠',
#   '9',
#   '30',
#   '14',
#   datetime.datetime(2017, 11, 15, 15, 11),
#   0],
#  ['hsm3398(hsmh****)',
#   '마지막이 좀 시시하지만 두시간러닝타임치곤 잘만들었다',
#   '8',
#   '43',
#   '27',
#   datetime.datetime(2017, 11, 15, 18, 21),
#   '관람객'],
#  ['알렌(once****)',
#   '영화 한줄요악. 초딩  5명이 중딩이랑 싸우다 못이기니까 체대생 불러서 정리하는 영화. 끝.',
#   '5',
#   '15',
#   '0',
#   datetime.datetime(2017, 11, 22, 19, 12),
#   0],
#  ['레이아드(top1****)',
#   '케릭터들이 아까워 죽겠다... 배댓슈에 저스티스 리그까지 보고나니 맨 오브 스틸은 우주 명작이었네',
#   '1',
#   '16',
#   '1',
#   datetime.datetime(2017, 11, 22, 15, 45),
#   0],
#  ['한상히짱(hsh4****)',
#   '노잼 보는내내 토르가 생각났다',
#   '1',
#   '16',
#   '1',
#   datetime.datetime(2017, 11, 18, 15, 57),
#   0],
#  ['ghdx****',
#   '망작은 아니에요 망작은 아닌데, 전체적으로는 어벤져스보다 못하지만 액션만큼은 어벤져스에 밀리진 않네요 딱 킬링타임용 영화정도로는 매우 적절합니다',
#   '7',
#   '18',
#   '3',
#   datetime.datetime(2017, 11, 16, 15, 30),
#   0],
#  ['마늘(twob****)',
#   '슈퍼맨 벨붕 영화 ㅎㅎ?',
#   '7',
#   '18',
#   '3',
#   datetime.datetime(2017, 11, 15, 17, 42),
#   0],
#  ['김유정(zhdd****)',
#   '같이 갔던 사람은 졸고ㅋㅋㅋㅋ 나는 오기로봤음말이 필요없음 걍 노잼임 히어로물이 이렇게 재미없을수있구나를 깨달을수있는 시간이었음  히어로물이 진지하니까 오히려 되게 유치하게 느껴짐',
#   '1',
#   '19',
#   '4',
#   datetime.datetime(2017, 11, 18, 15, 43),
#   0],
#  ['하얀바람(nfoo****)',
#   '알바들 ㅋㅋㅋ 8점사수를 위해 총공세구나',
#   '1',
#   '23',
#   '8',
#   datetime.datetime(2017, 11, 17, 12, 35),
#   0],
#  ['good****',
#   '솔직히 마블과 비교될 수 밖에 없는 지금같은 상황에서 이정도 하술한 구성과 전개라면 진짜 디씨는 암울해질 수 밖에 없을거다.',
#   '1',
#   '30',
#   '15',
#   datetime.datetime(2017, 11, 18, 10, 37),
#   '관람객'],
#  ['또또(imqt****)',
#   '제작비 어디다 썼냐??',
#   '1',
#   '14',
#   '0',
#   datetime.datetime(2017, 12, 6, 20, 36),
#   0],
#  ['이은(leee****)',
#   '슈퍼맨 > 저스티스 리그',
#   '7',
#   '15',
#   '1',
#   datetime.datetime(2017, 11, 15, 22, 35),
#   0],
#  ['리얼한개구리(soda****)',
#   '불친절하고 부실한 스토리. 어따 팔아먹은건지 모르겠는 개연성. 시덥잖은 개그. 전작보다 오히려 퇴화한 액션. 무력한 배트맨. 영화에서 완전히 빼도 지장없을 아쿠아맨. 결국 혼자 세상 다 구하는 슈퍼맨.',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 19, 2, 51),
#   0],
#  ['아무말대잔치(rngu****)',
#   '그냥슈퍼맨이 젤 쎈 영화',
#   '1',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 18, 14, 2),
#   0],
#  ['라무네스(juli****)',
#   '슈퍼맨 살리기. 모두 멋있긴 한데 캐릭터의 토대가 부족한 느낌.',
#   '6',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 16, 1, 31),
#   0],
#  ['Immortal King(batt****)',
#   '천 리 길을 한 걸음씩 걸어간 마블과, 한 걸음에 걸어가려는 디씨의 차이인가...',
#   '6',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 15, 23, 9),
#   0],
#  ['kag0****',
#   '확실히 점점 나아지고 있긴 하지만.. 아직은..물에 잠겨도 전혀 흐트러지지 않는 슈퍼맨의 헤어.딱 보니 플래쉬가 개그 치는 역할인 것 같은데, 진심 무표정으로 봄.케릭터들 간에 힘의 밸런스가 너무 차이나서.. 원펀맨...',
#   '5',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 15, 22, 47),
#   0],
#  ['귀찬운데(stdi****)',
#   '빠르면서 늦게 나온듯한 영화아쿠아맨과 플래시등 여러모로 설명을 하기엔 부족한 분량..  이런점을 보면 아쿠아맨과 플래시 실사영화를 먼저 냈었다면 어땠을까 그런점 감안하고도 나름즐기면서 봤다. 마블보다 빠르게 냈다면 ...',
#   '7',
#   '16',
#   '2',
#   datetime.datetime(2017, 11, 15, 22, 30),
#   '관람객'],
#  ['돈까스윙스(jwe0****)',
#   '스토리 전개 진짜 재미없고 중간에 싸울때만 좀 재미있고 어머니만 계속 찾고 토르 한 번 더볼걸 ㅠㅠ진짜 돈이 아깝습니다 뻔한스토리 슈퍼맨이 혼자 다 해먹고 하 내 돈 ..',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 11, 23, 11, 44),
#   0],
#  ['샤를(pwl5****)',
#   '별로였음..실망했음..',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 11, 18, 7, 58),
#   0],
#  ['귀공자(ryu7****)',
#   '슈퍼맨>>넘사벽>>히어로라고하는애들... 이게 영화냐 ?  행복할때보세요 그래야 분노가  덜할테니 ㅋ',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 11, 18, 0, 54),
#   0],
#  ['김지영(dadd****)',
#   '진자 재미없어요..지오스톰이 훨 잼잇네',
#   '1',
#   '19',
#   '5',
#   datetime.datetime(2017, 11, 23, 21, 25),
#   '관람객'],
#  ['클린히트(9ed1****)',
#   '많이 기대 하고 극장 갔는데 좀 아쉽네요처음 원더 우먼 총알막는 부분은 정말 멋져서 엄청 기대 했는데영화시간을 너무 줄여 놔서 여러 영화로 기본스토리를 딴딴히 한 마블에 비해선 좀 아쉬움',
#   '8',
#   '19',
#   '5',
#   datetime.datetime(2017, 11, 15, 17, 10),
#   0],
#  ['vlfr****',
#   '블랙핑크가 가장 재밌었다',
#   '5',
#   '22',
#   '8',
#   datetime.datetime(2017, 11, 15, 16, 59),
#   0],
#  ['당근작가(usp6****)',
#   '아니., 캐릭터벨런스 생각안하고 만드냐?타이틀은 혼자서는 이길수 없다매, 슈퍼맨 혼자 다 하네디씨는 그냥 단독 영화만 만드는게 나을듯싶네',
#   '4',
#   '13',
#   '0',
#   datetime.datetime(2018, 7, 9, 1, 3),
#   0],
#  ['dua lipa(baoz****)',
#   '빡칠만큼 재미없어..',
#   '1',
#   '14',
#   '1',
#   datetime.datetime(2017, 11, 25, 22, 9),
#   0],
#  ['요리왕김머한(kdh0****)',
#   '알바새기들아 양심 ㅈ도없냐 별점조작을 해도 양심있게 좀 조작해라 쓰래기들아',
#   '1',
#   '14',
#   '1',
#   datetime.datetime(2017, 11, 23, 21, 20),
#   0],
#  ['김희진(jkhe****)',
#   '제일 기억남는건 마지막 전투에서 슈퍼맨이 등장하자  밝게  웃는 배트맨의 얼굴... 난 그렇게 밝게 웃는 배트맨을 본적이 없어.',
#   '5',
#   '14',
#   '1',
#   datetime.datetime(2017, 11, 16, 12, 40),
#   0],
#  ['간지초복(um07****)',
#   '해결사를 모집해서 해결안되니 결국 은퇴하고죽은 해결사를 부른다.  즉 의미없다..',
#   '5',
#   '14',
#   '1',
#   datetime.datetime(2017, 11, 16, 0, 43),
#   0],
#  ['조우빈(whdn****)',
#   '무난했지만 디씨가 아직 마블에게는 안 되는 이유를 보여준 것 같음',
#   '6',
#   '15',
#   '2',
#   datetime.datetime(2017, 11, 16, 21, 49),
#   0],
#  ['perse(pers****)',
#   '역시 배트맨은 사람이고 슈퍼맨은 초능력자다',
#   '10',
#   '16',
#   '3',
#   datetime.datetime(2017, 11, 18, 21, 53),
#   '관람객'],
#  ['동네(dwle****)',
#   '좀 시간들여서 제대로 만들어라 마블이 잘나가서 배아프다고 닥달났네 앞으로 이딴식으로 만들려면 디시도 디즈니에 팔아라 그냥',
#   '4',
#   '17',
#   '4',
#   datetime.datetime(2017, 11, 17, 12, 47),
#   0],
#  ['실딱(thom****)',
#   '에즈라 아니였음 뛰쳐나왔다 시작부터 액션신 발로찍는거같더니 러닝타임의 1/5 나오는 액션신을 슬로모션범벅해놔서 더 지루했다 처음 인물소개까진 좋았는데 막판에 악당하고싸워도 졸리드라',
#   '2',
#   '19',
#   '6',
#   datetime.datetime(2017, 11, 16, 1, 12),
#   0],
#  ['oopo****',
#   '마블 디씨 비교하지 말고  둘다봐요.',
#   '10',
#   '19',
#   '6',
#   datetime.datetime(2017, 11, 15, 15, 41),
#   0],
#  ['방다솜(tree****)',
#   '디시 영화가 왜 망하는지 알 수 있는 표본. 유치하고 이것저것 잡스럽게 넣은 망한 영화',
#   '1',
#   '20',
#   '7',
#   datetime.datetime(2017, 11, 19, 19, 35),
#   '관람객'],
#  ['HeadAxe(tis1****)',
#   '이거 츠지하라를 탓이야, 아니면 조스웨던 탓이야?',
#   '6',
#   '21',
#   '8',
#   datetime.datetime(2017, 11, 15, 20, 43),
#   '관람객'],
#  ['ski(boxi****)',
#   '디씨 망테크타능거보니까 싹다 접고 배트맨 리부트 또 해야될판이네. 다크나이트때문에 디씨빠였는데 어느새 마블빠로 변해있는 내 모습. 좀 시빌워 참고라도 하지..',
#   '5',
#   '21',
#   '8',
#   datetime.datetime(2017, 11, 15, 17, 25),
#   0],
#  ['청설모(solm****)',
#   '개망 감독이 갈려야 산다 이정도 배우에 이 스토리로 못살리다니',
#   '1',
#   '30',
#   '17',
#   datetime.datetime(2017, 11, 15, 17, 27),
#   0],
#  ['sonm****',
#   '시사회에서 봤습니다솔직히 지금까지 나온 마블보다는 퀄리티 있고, 눈이 호강 합니다. 캐릭터 존재감은 확실하고요 스케일 차이가 난다는게 확연히 느껴집니다. 이제 까지 본 마블은 아이들을 위한 오락성이 었으면 DC 는 ...',
#   '10',
#   '372',
#   '359',
#   datetime.datetime(2017, 11, 15, 8, 5),
#   0],
#  ['swso****',
#   '영화전체가 어벤져스 예고편보다 재미없다',
#   '1',
#   '12',
#   '0',
#   datetime.datetime(2017, 12, 2, 11, 40),
#   0],
#  ['킴다(ekdu****)',
#   '개인적으로 뻔한스토리 악역도 밋밋하고 흥미진진한 요소도 없고 그냥 뻔한 히어로영화',
#   '6',
#   '13',
#   '1',
#   datetime.datetime(2017, 11, 16, 0, 47),
#   0],
#  ['아몰랑(ddha****)',
#   '배트맨을 돈만 많은 찐따로 만들어버린 잭 스나이더.',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2017, 11, 19, 13, 11),
#   0],
#  ['서동민(sjis****)',
#   'DC 는  왜이렇게  영화를만들까??',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2017, 11, 18, 13, 37),
#   0],
#  ['love****',
#   '액션 좋고 볼거리 괜춘합니다. 스토리 전개가 조금 아쉽네요.',
#   '8',
#   '14',
#   '2',
#   datetime.datetime(2017, 11, 16, 18, 40),
#   '관람객'],
#  ['꼬우면우승하던가(hgjj****)',
#   '인피니티워 예고편보고 들어왔다 디씨 너넨 끝이다',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 11, 30, 4, 4),
#   0],
#  ['밥돌이(nose****)',
#   '진짜 잘잤다~ 하암 일어나보니까 슈퍼맨 살아있내 ㅋㅋ',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 11, 23, 14, 58),
#   0],
#  ['dsfdsdfsdf(yjle****)',
#   '스토리엉성 작가가쓰다가휴가간줄',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 11, 19, 22, 29),
#   '관람객'],
#  ['장웅(jang****)',
#   '애들이 너무약해요ㅎㅎ',
#   '5',
#   '15',
#   '3',
#   datetime.datetime(2017, 11, 18, 1, 21),
#   '관람객'],
#  ['별명따윈없다(dydd****)',
#   '갤가돗 엉덩이 너무 섹시한거 아니니?',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2017, 11, 16, 20, 40),
#   0],
#  ['풍류영(mu65****)',
#   '허접한 잭스나의 부실공사를 곳곳에서 땜빵하느라 뺑이친 조스웨던의 흔적들',
#   '6',
#   '16',
#   '4',
#   datetime.datetime(2017, 11, 17, 11, 37),
#   '관람객'],
#  ['InTheFuture(insi****)',
#   '스토리, 액션, 인물이 모두 어정쩡한 영화임다.',
#   '3',
#   '17',
#   '5',
#   datetime.datetime(2017, 11, 16, 10, 7),
#   0],
#  ['Johnny depp(sksj****)',
#   '이번엔 성공하길...',
#   '10',
#   '23',
#   '11',
#   datetime.datetime(2017, 11, 15, 8, 40),
#   0],
#  ['원영파파(dlaw****)',
#   '더 이상 보고 싶지 않다.',
#   '1',
#   '11',
#   '0',
#   datetime.datetime(2017, 12, 25, 19, 23),
#   0],
#  ['캡틴아메리카노(blue****)',
#   '와 방금 인피니티 워 예고편 보고왔는데, 그 예고편 2분이 저스티스 리그 2시간 보다 더 재밌음ㅋㅋㅋㅋ',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 11, 30, 4, 11),
#   0],
#  ['일루와바(kkbk****)',
#   '졸작.... 특히 중후반에 늘어지는 대화씬은 매우 지루했음.',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 11, 24, 9, 35),
#   0],
#  ['오이시(lant****)',
#   '혼자선 세상을구할수없다더니 슈퍼맨 혼자구함ㅋ',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 11, 19, 3, 43),
#   0],
#  ['shadowpax(breg****)',
#   '기대보다 준수하지만 그래도 눈 높아진 팬들에겐 아직 부족하다',
#   '6',
#   '13',
#   '2',
#   datetime.datetime(2017, 11, 15, 23, 8),
#   0],
#  ['바바(seo1****)',
#   '방금 보고나서 ㅠㅠ망 ㅠㅠ',
#   '6',
#   '14',
#   '3',
#   datetime.datetime(2017, 11, 15, 17, 23),
#   0],
#  ['mgum****',
#   '너무 지루하고  돈낭비/시간낭비...누가본다면  말리고싶다.',
#   '1',
#   '15',
#   '4',
#   datetime.datetime(2017, 11, 22, 20, 55),
#   0],
#  ['도넛(gusd****)',
#   '뱃찐따... 잘가라 재스나이더',
#   '1',
#   '15',
#   '4',
#   datetime.datetime(2017, 11, 22, 13, 14),
#   '관람객'],
#  ['kate(jink****)',
#   '기대했는데 실망했다ㅠㅠ',
#   '4',
#   '15',
#   '4',
#   datetime.datetime(2017, 11, 16, 16, 21),
#   '관람객'],
#  ['4885(jeff****)',
#   '썩은토마토 점수가 말해준다 개 쓰레기 작품이라는 것을 암살닦이보다 조금 나은수준',
#   '1',
#   '17',
#   '6',
#   datetime.datetime(2017, 11, 17, 19, 31),
#   0],
#  ['kims****',
#   '전반적으로 좋았다 완벽할수는 없지만 잘만들어진거 같다. 영화끝나도 끝까지 앉아 있으면 맨마지막에 앤딩 화면 나오니깐 기다렸다가 보시길 ㅎㅎ',
#   '10',
#   '17',
#   '6',
#   datetime.datetime(2017, 11, 17, 16, 5),
#   '관람객'],
#  ['꿈꾸는다락방(euro****)',
#   '처음부터 끝까지 진짜 핵노잼',
#   '1',
#   '17',
#   '6',
#   datetime.datetime(2017, 11, 17, 0, 48),
#   0],
#  ['띤뚱우(shin****)',
#   '마블의 독주를 막을 DC의 히어로들 저스티스리그..',
#   '10',
#   '126',
#   '115',
#   datetime.datetime(2017, 11, 15, 0, 1),
#   0],
#  ['캡슐로봇(kjik****)',
#   '기대를너무했는지.얙션이나스토리에조금실망.팬심으로슈퍼맨이돌아온거는환영~~',
#   '7',
#   '10',
#   '0',
#   datetime.datetime(2017, 11, 18, 8, 35),
#   '관람객'],
#  ['하루하루(park****)',
#   '많은 캐릭터를 담아내기엔 러닝타임이 짧고 내용은 진부한데다 볼거리까지 없음.기대했지만 실망',
#   '4',
#   '11',
#   '1',
#   datetime.datetime(2017, 11, 15, 20, 26),
#   0],
#  ['천국을떠난천사(mira****)',
#   '여윽시 디씨 영화는 다운받아봐야해믿고 거르는 디씨',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 11, 30, 4, 18),
#   0],
#  ['rans****',
#   '하...뱉신하면 세계관에 원탑 탐정이며 메타휴먼이 아니더라도 다른 맴버보다 더욱 존제감있는 캐릭턴데 걍 돈만은 모자란 쩌리 병X으로 만들어 놨다. 만약 2가 나온다면 걍 슈퍼맨 기쁨조나 하면서 크립토나이트만 몸빵해주...',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2017, 11, 18, 3, 56),
#   0],
#  ['이규원(dlrb****)',
#   '어벤져스와 비교 당할수밖에 없는 영화...하지만 어벤져스에 비해 슈퍼맨을 제외하면히어로들이 너무 약하다.',
#   '5',
#   '12',
#   '2',
#   datetime.datetime(2017, 11, 16, 12, 17),
#   '관람객'],
#  ['mase****',
#   '그저그렇다 기승전결이 이상하면 감동은 전혀없당..토르랑비교되네',
#   '6',
#   '12',
#   '2',
#   datetime.datetime(2017, 11, 16, 0, 43),
#   0],
#  ['더프(axel****)',
#   '볼만은 한데 역시 밸런스의 문제가 있음.',
#   '7',
#   '12',
#   '2',
#   datetime.datetime(2017, 11, 15, 23, 12),
#   0],
#  ['원어민(8kjg****)',
#   '평점 정상화를 위해서..너무 식상합니다 꼭 게임 동영상 보는듯했어요.',
#   '1',
#   '17',
#   '7',
#   datetime.datetime(2017, 11, 18, 18, 21),
#   '관람객'],
#  ['소비자유통(gkst****)',
#   '별 기대 안했는데 재미있네요',
#   '10',
#   '21',
#   '11',
#   datetime.datetime(2017, 11, 15, 22, 32),
#   '관람객'],
#  ['이경원(ange****)',
#   '재미있습니다~!!♡',
#   '10',
#   '23',
#   '13',
#   datetime.datetime(2017, 11, 15, 22, 38),
#   '관람객'],
#  ['백야솔(gksw****)',
#   '솔직히 불안했는데 기대이상이네요',
#   '10',
#   '24',
#   '14',
#   datetime.datetime(2017, 11, 16, 1, 31),
#   '관람객'],
#  ['우Sense(bang****)',
#   '어휴.... 어휴....',
#   '1',
#   '9',
#   '0',
#   datetime.datetime(2017, 12, 25, 20, 12),
#   0],
#  ['jaie86(jaie****)',
#   '딱지금 야심한 새벽 하루동안 떨어졌던 평점을 끌어올리기 위해 9~10점 말도 안되는 폭풍 칭찬 평점 알바 글이 쏟아지는 시간임. 개봉일부터 매일 꼬박꼬박 평점 10점 폭탄을 쏟아 부어도 8점을 못넘는 영화가 저스티스...',
#   '1',
#   '9',
#   '0',
#   datetime.datetime(2017, 11, 28, 0, 43),
#   0],
#  ['빵내놔(sdri****)',
#   '대사가 너무 오글거림.. 그렇다고 초딩이 보기도 초반에 너무 루즈함',
#   '1',
#   '9',
#   '0',
#   datetime.datetime(2017, 11, 26, 18, 19),
#   '관람객'],
#  ['cns6****',
#   '시리즈라서 보긴봤지만 역대급  최악의 영화다.',
#   '1',
#   '9',
#   '0',
#   datetime.datetime(2017, 11, 25, 17, 37),
#   '관람객'],
#  ['오늘밤새(inst****)',
#   '슈퍼맨 혼자 해도 될것을 뭐하러 다 모았냐...  ㅋㅋ',
#   '7',
#   '10',
#   '1',
#   datetime.datetime(2018, 2, 18, 11, 9),
#   0],
#  ['향비(m_la****)',
#   '으 노잼이였어요 최악 디씨 실망',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2017, 12, 10, 9, 13),
#   '관람객'],
#  ['최영준(youn****)',
#   '개디루지루디루함함함',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2017, 11, 30, 1, 16),
#   '관람객'],
#  ['crew****',
#   '뭉치긴 했으나 슈퍼맨이 혼자 다함 더이상 마사는 없지만 이래저래 구멍뚫린듯한 스토리 엉뚜한 짓한 거에 대한 설명도 없ㅇㄷㅁ',
#   '8',
#   '11',
#   '2',
#   datetime.datetime(2017, 11, 16, 22, 19),
#   '관람객'],
#  ['윤라영봉(ekfh****)',
#   '마블을 따라잡고 싶었겠지만 아쉽내',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 11, 22, 23, 4),
#   0],
#  ['갱고야(pky7****)',
#   '망하는데는 이유가 있지팀 영화인데 개인혼자 다끝내면 머하러 팀을 이루나?',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 11, 19, 23, 25),
#   0],
#  ['ario****',
#   '앞으로 DC는 원더우먼이 제목으로 나올때만 보기로 결정',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 11, 18, 16, 22),
#   0],
#  ['김한영(akdk****)',
#   '뭐야 이게 .ㅡ.ㅡ.ㅡ.',
#   '6',
#   '12',
#   '3',
#   datetime.datetime(2017, 11, 17, 17, 20),
#   '관람객'],
#  ['isabel(isab****)',
#   '진짜 핵노잼 완전 유치 돈아까움',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2017, 11, 23, 0, 17),
#   0],
#  ['사보텐더(utop****)',
#   '재미없다. 개연성 없는 전개 및 캐릭터들 매력 반도 못살린 연출. 잭 스나이더 바이바이',
#   '4',
#   '13',
#   '4',
#   datetime.datetime(2017, 11, 16, 21, 56),
#   0],
#  ['한철희(hanc****)',
#   '반가운 슈퍼맨의 등장 마지막엔 토끼와 거북이 경주하는줄',
#   '8',
#   '13',
#   '4',
#   datetime.datetime(2017, 11, 15, 23, 12),
#   '관람객'],
#  ['맑은서울(leei****)',
#   '파트2에 제발 반지닦이 살려주시길 기원해요 아미 해머가 그린랜턴 할 조던 캐스팅에 되었으면 좋겠어요 파트2  그린랜턴 나와야지 북미팬들 실망시키지 맙시다 이제 샤잠은 제일 나중에 나와야해요',
#   '10',
#   '17',
#   '8',
#   datetime.datetime(2017, 11, 15, 1, 28),
#   0],
#  ['domo****',
#   '올해 가장 기대했던 영화인데 너무 큰 기대를 한것 같다',
#   '1',
#   '32',
#   '23',
#   datetime.datetime(2017, 11, 15, 22, 32),
#   '관람객'],
#  ['킁킁빠(yoka****)',
#   '경쟁심리 때문인지는 모르겠지만, 마블처럼 안하고 일단 모였다 식으로 이렇게 영화 내놓고 그러면 지들만 개손해지. DC 특유의 어두운 면을 단점으로 취급하지 말고 장점으로 보고서 15세 이상을 좀 겨냥하고 만들던지.',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2019, 7, 23, 19, 22),
#   0],
#  ['채린(cher****)',
#   '하찮은 자존심 좀 이제 그만 버리고 그냥 디즈니한테 판권 넘겨라...워너브라더스 놈들이 어린시절 좋아했던 추억 속 캐릭터들 다 망치고 있네...',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2019, 4, 9, 15, 9),
#   0],
#  ['오성빈(seon****)',
#   '원더우먼을 보고 희망은 조금있었는데 이걸보고 dc는 망했다라고 생각했다',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2018, 5, 13, 21, 30),
#   0],
#  ['운똥(dnst****)',
#   '푹 잘자다가 블랙핑크 노래듣고 깻다',
#   '1',
#   '8',
#   '0',
#   datetime.datetime(2017, 11, 25, 19, 12),
#   0],
#  ['이영주(youn****)',
#   '음.. 그냥 그래요ㅎㅎㅎ',
#   '5',
#   '8',
#   '0',
#   datetime.datetime(2017, 11, 21, 21, 28),
#   '관람객'],
#  ['하늘하늘(sign****)',
#   'DC가 제대로 된 영화를 만들거란 기대를 안하고 보면 재밌다.',
#   '5',
#   '8',
#   '0',
#   datetime.datetime(2017, 11, 21, 18, 37),
#   '관람객'],
#  ['bb819(skel****)',
#   '진심 이 영화가 재밌다면 앞으로 당신이 보는 영화는 다 10점만점에 10점일거다',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2019, 2, 10, 12, 52),
#   0],
#  ['머큐Lee(cfos****)',
#   '이 영화가 재미있다면 무슨 영화를 봐도 재미있을것',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2019, 2, 6, 20, 9),
#   0],
#  ['nowletmetalktoya(newl****)',
#   '망했어 마블 어벤져스와 라이벌리를 형성하고 싶어서 너무 성급하게 만든티가 너무 남 아니 갑자기 어디서 삼지창털보가 나오고 로봇이 갑자기 튀어나오고 플래쉬는 스파이더맨 말장난 따라하려는 어색한 티나고..슈퍼맨은 부활해...',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 12, 30, 19, 49),
#   0],
#  ['럭키연(wkfe****)',
#   '캐릭터가 매력이 너무없다;',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 12, 29, 11, 48),
#   0],
#  ['파와(ssss****)',
#   '배트맨이 쩌리가...',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2017, 11, 21, 23, 5),
#   0],
#  ['강정민(rich****)',
#   '원더우먼 초반에 테러범 잡는거 멋있네요',
#   '8',
#   '9',
#   '1',
#   datetime.datetime(2017, 11, 15, 21, 15),
#   0],
#  ['권기헌(bkte****)',
#   '왜 마블이 최고인지 알수있던 영화..어벤져스 본 이후로 보는 눈이 너무 높아졌다.',
#   '2',
#   '10',
#   '2',
#   datetime.datetime(2019, 4, 12, 10, 57),
#   0],
#  ['김성용(rlat****)',
#   '정말 쓰레기같은 영화네요~ 마블 따라하려는게 ~ 제말이 틀린것 같으면 영화관가서 한번 봐보세요 ㅎㅎ',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 27, 15, 29),
#   0],
#  ['공룡이아빠(jonj****)',
#   '아쿠아맨은 수영만 하고 플래쉬맨은 뛰기만 하고 배트맨은 운전하고 인간로봇은 해킹하고 원더우먼은 난투난투난투 이게 뭐람?',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 21, 21, 46),
#   0],
#  ['시티우승(rkdg****)',
#   '레알 빅찐따들 슈퍼맨빼고 할줄아는게 있니',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 21, 20, 57),
#   0],
#  ['doc0****',
#   '얼마나 더 많은 히어로가 필요한가...어벤저스보다 최악..',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 21, 16, 56),
#   0],
#  ['아라레vs오공(whdl****)',
#   '슈퍼맨한테 이르는 게 팀 계획의 전부네 ㅋㅋ 왜 모였냐',
#   '5',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 20, 1, 42),
#   0],
#  ['아메리카가와(swjs****)',
#   '중구난방한 스토리라인과 허접한 결말. 괜히 봤다는 생각이든다.',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 19, 22, 56),
#   0],
#  ['marb****',
#   '올해 최악의 영화로 꼽습니다. 슈퍼맨 살리기전에 개운하게 잤습니다. 진짜 어떻게 이 캐릭터로 이렇게 재미업게만드는것도 기술입니다.....',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 18, 16, 35),
#   0],
#  ['yoog****',
#   '상영시간이 한 3시간은 되었으면..',
#   '9',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 17, 23, 31),
#   '관람객'],
#  ['이용노(lyn1****)',
#   '재밋게봤어요ㅋ디아로러너널촟',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 17, 15, 41),
#   '관람객'],
#  ['rlat****',
#   '재밌어요 쿠키영상 2개있어여',
#   '8',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 16, 22, 36),
#   '관람객'],
#  ['진(u_u9****)',
#   '노력하는 중인 DC. 여태나온 닦이 영화들보다 나았고, 기대 없이 보기에는 재밌었다.',
#   '8',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 16, 18, 28),
#   '관람객'],
#  ['양원석(yws2****)',
#   '이거 개못만들진 않았는데 솔직히 이걸로 디시 부활이다 우워어어 하기엔 너무 아쉬운 영화아닌가 빌런 아쉽고 스토리도 아직 아쉬운데?수스쿼 배대슈가 진짜 못만든거지 이게 명작은 아니지',
#   '7',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 15, 23, 53),
#   0],
#  ['개싸(koja****)',
#   '볼만했습니다  전작에 비해서',
#   '8',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 15, 22, 28),
#   '관람객'],
#  ['하하뇽(dygk****)',
#   '10점은 오바고 7점이 딱적당한듯',
#   '7',
#   '10',
#   '2',
#   datetime.datetime(2017, 11, 15, 13, 28),
#   0],
#  ['남들처럼평범하게(dcfl****)',
#   '총체적 난국.. 하아... 어중간하게 망하기 보다는 차라리 폭망하고 세계관 리붓하는 게 나을 것 같은데 배우들이 아깝다. 특히 원더우먼.아쿠아맨은 단독영화 잘 뽑으면 괜찮을 것 같음. 플래시도 어울리는 편.. 사이보...',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 11, 24, 7, 34),
#   0],
#  ['이근영(rmsd****)',
#   '..아인간적으로이거 7점이상준건너무하다... 스토리는 히어로물이라그렇다치지만 씨쥐너무하잖아... 보다보다 짜증이나던데..히어로물이제껏봤던것중에서 제일재미없엇음',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 11, 23, 20, 1),
#   0],
#  ['그럭저럭(bdha****)',
#   '개 폭망 노잼 . 밸런스도 없고, 배트맨도 없고',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 11, 22, 23, 20),
#   0],
#  ['찬진이네(jchc****)',
#   '언젠가는 저스티스리그VS어벤져스영화가 나왔으면하는 생각...꼭보세요 잘만들었음!!',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2017, 11, 17, 15, 42),
#   0],
#  ['mett****',
#   '개봉 이틀 째 봤는데 그것도 아이맥스 4D로 봤는데도 지루했음.  오락실에 3000원짜리 라이더가 훨씬 재밌을 정도니.   완전 고가의 좋은 요리재료로 야매요리사가 맛도없는 허접한 요리를 만든 음식을 먹은 느낌이랄까...',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 11, 24, 5, 31),
#   0],
#  ['Narcissist(ante****)',
#   '때로 나와서 더 난잡하기만 함.. 게다가 빌런도 결국...ㅎㅎㅎ 완전 개판임. DC는 거르는게 답',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 11, 17, 11, 38),
#   0],
#  ['바삭바삭(leeg****)',
#   '플래시가 슈퍼맨보다 느리면 왜 존재하는지;; 너무 히어로들의 능력치 비중이 안맞음. 그냥 슈퍼맨만 있으면 이기는거잖아.',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2017, 11, 17, 18, 33),
#   0],
#  ['iost****',
#   '굿 이번에 진짜 잘나왔음',
#   '10',
#   '25',
#   '17',
#   datetime.datetime(2017, 11, 15, 16, 5),
#   0],
#  ['헨도(apin****)',
#   'ㅋㅋ 왜 디씨 영화 호감순으로 정열하면 마블빠 언급하면서 열폭하는 댓글 밖에 없죠? 피해의식 있으신가 ㅋㅋ 그래도 오늘 퇴근하고 바로 예매 해놨으니 재밌을거라는 기대감으로 7점 드립니다',
#   '7',
#   '34',
#   '26',
#   datetime.datetime(2017, 11, 15, 11, 10),
#   0],
#  ['gnfn****',
#   '한번보고 평정달아라 알바들아...',
#   '10',
#   '34',
#   '26',
#   datetime.datetime(2017, 11, 15, 10, 22),
#   0],
#  ['BRUCE WAYNE(kong****)',
#   'DC와 갤 가돗이 2017년 원더우먼에 이어 쏘아올린 연타석 홈런. 이제는 이어지는 다음 타석에서도 또 홈런을 보여주리라 믿게 되었습니다. 원더우먼이 인간들을 믿기에 싸우듯이 저는 이제 원더우먼과 DC를 믿습니다. ...',
#   '10',
#   '35',
#   '27',
#   datetime.datetime(2017, 11, 15, 7, 10),
#   0],
#  ['데프(save****)',
#   '오 예상외로 꿀잼이었습니다',
#   '10',
#   '37',
#   '29',
#   datetime.datetime(2017, 11, 15, 18, 33),
#   '관람객'],
#  ['프로똘끼남2018(kimt****)',
#   '혼자서 세상 못구한다며ㅋㅋㅋ 슈퍼맨이 혼자 다 해결하는구만ㅋㅋㅋㅋ',
#   '5',
#   '7',
#   '0',
#   datetime.datetime(2019, 2, 19, 14, 48),
#   0],
#  ['빙충이(cn30****)',
#   '새벽의 저주, 300, 왓치맨. 잭 스나이더 맞냐?',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2018, 7, 4, 13, 11),
#   0],
#  ['gudw****',
#   '캐릭터들의 너프시켰으면 긴장감이라도 있어야지....슈퍼맨 하나로 모든 캐릭터들을 찌질이로 만듬....',
#   '4',
#   '7',
#   '0',
#   datetime.datetime(2018, 2, 7, 3, 37),
#   0],
#  ['RED(hota****)',
#   '슬프지만 내가 아는 디씬 끝났다..',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2017, 12, 1, 21, 21),
#   '관람객'],
#  ['hans(jeey****)',
#   '슈퍼맨 없으면 지구는 멸망. 다른 히어로들 밸런스 붕괴됐고 악당은 유치하고 캐릭터도 그냥 그렇고..배트맨은 밤의 기사에서 돈많은 스폰서, 죄책감에 쭈글대는 불쌍한 사람이 됐다..배트맨 캐붕 어쩔거임...원더우먼 이뻐...',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2017, 11, 19, 21, 17),
#   0],
#  ['빈이파파(kiss****)',
#   '좋은데 뭔가 1 프로 부족한 듯..슈퍼맨이 너무 강함',
#   '8',
#   '7',
#   '0',
#   datetime.datetime(2017, 11, 19, 2, 37),
#   '관람객'],
#  ['CANES(minj****)',
#   '저는 좀 별로였어요 기대를 많이 한건아니라서 맘편히 봐ㅅ지만 그래도 많이 실망했네요',
#   '1',
#   '7',
#   '0',
#   datetime.datetime(2017, 11, 18, 16, 40),
#   0],
#  ['BBBBBB(jjeo****)',
#   '파워레인저 공감하넼ㅋㅋㅋ 어벤저스를 기대했으나 딱 파워레인저',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2018, 12, 25, 19, 9),
#   0],
#  ['포대화상미륵존여래불(baks****)',
#   '비주얼은 어벤져스급인데 일어나는 일은 디워가 환타지대작으로 보일정도이니,도대체 잭 스나이더에게 무슨 일이 일어난건지 아시는 분',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2018, 1, 16, 3, 4),
#   0],
#  ['나라(lsw3****)',
#   '그냥 시간 아까웠다..',
#   '4',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 25, 23, 55),
#   '관람객'],
#  ['자승자강JS(dntn****)',
#   '디씨는 배트맨시리즈나 만들어라 젠틀맨리그 보다 못한 저스티스리그',
#   '1',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 21, 20, 40),
#   0],
#  ['ques****',
#   '정말 매력적인 캐릭터들인데 이렇게 밖에 사용 못했다는게 너무 아쉽다',
#   '3',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 21, 18, 59),
#   '관람객'],
#  ['황예원(love****)',
#   '평점이안좋아서 걱정했는데 의외로 재밌어요',
#   '6',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 19, 0, 53),
#   '관람객'],
#  ['tttt345(jueu****)',
#   '그냥볼만해요원더우먼예뻐요',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 18, 22, 5),
#   '관람객'],
#  ['hovs****',
#   '재밌어요 슈퍼맨이 짱이네요',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 18, 21, 54),
#   '관람객'],
#  ['미래소년(alfo****)',
#   '방금 봤는데 재미있네요. 갤가돗 진심 인생여자다',
#   '9',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 17, 16, 1),
#   0],
#  ['살바도르(dali****)',
#   '뭔가 아쉬운 부분이 있긴하지만 그래도 이정도면 정말 잘 나왔네요~',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 17, 2, 0),
#   '관람객'],
#  ['nksz****',
#   '저스티스리그 애니랑 만화 다 본 사람이고 매니아인데요. 영화에서는 좀 아쉽네요.. 악당이 너무 허무하게 죽음..ㅜㅜ 끝도 뭔가 짜릿함이 덜 함 ㅇㅇ  스테판울프 보다는 다크사이드 데리고 오삼 ㅜㅜ  스테판울프 너무 ...',
#   '6',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 23, 58),
#   '관람객'],
#  ['pooh****',
#   '좋아요 역시 슈퍼맨  멋집니다',
#   '9',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 22, 45),
#   '관람객'],
#  ['라킴(khr9****)',
#   '일단 밥값은 했네요 저스티스든 어벤져스든 캐릭터가 많으니 각 캐릭터의 특히 처음 등장하는 캐릭터의 특성이 잘 부각되지는 않네요 쨋든 전 마블 디씨 둘다 좋아하니깐요ㅎ',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 14, 44),
#   '관람객'],
#  ['이정훈(pou2****)',
#   '깨알같은 마지막처럼ㅋㅋㅋ',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 10, 56),
#   '관람객'],
#  ['01(para****)',
#   '베트맨 왜이렇게 하는게 없음? 너무 무능력하게 나오는데',
#   '7',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 10, 55),
#   0],
#  ['GB(cjkp****)',
#   '개인적으로 좀 실망함 메인 빌런이 나중에 허무하게 떡발리고 아쿠아맨은 뭥미 하는거 드럽게 없음 ㅋㅋㅋㅋ 배트맨 장비는 드럽게 답답하고 그냥 기대 이하였음 그리고 중간중간 웃길려고 집어넣은게 있는거같이 느껴지다만 웃기...',
#   '7',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 1, 58),
#   0],
#  ['홍차와풀빵(dkff****)',
#   'A급히어로들이 괴수연합이랑 힘들게 싸우고 있는데 마지막에 원펀맨이 와서 다 족침...',
#   '7',
#   '8',
#   '1',
#   datetime.datetime(2017, 11, 16, 1, 9),
#   0],
#  ['짱짱이(rbal****)',
#   '개노젬개실망 왜봣지 내가 어휴',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 25, 20, 53),
#   '관람객'],
#  ['ghkd****',
#   '캐릭터의 색깔이 전혀 드러나지 않는 B급 영화',
#   '5',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 21, 1, 54),
#   '관람객'],
#  ['Nine90(dlrn****)',
#   '잤어요.. 제뒤에모르는애는 끝나고 불이켜져도 저고잇엇어요',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 19, 19, 51),
#   '관람객'],
#  ['심짱(sim_****)',
#   'DC 최고사실 앞에 내용 모르는데 몰라도 재밌어요 ㅋㅋㅋㅋ적극 추천',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 18, 23, 5),
#   '관람객'],
#  ['김창헌(iden****)',
#   '우려보다 훨씬 좋았어요~슈퍼맨은 넘사벽라 다음 작품에 밸런스 조절을 어떻게 할지 궁금하네요~!!',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 16, 22, 38),
#   '관람객'],
#  ['김소연(soyo****)',
#   '아쿠아맨.음향.영상',
#   '8',
#   '9',
#   '2',
#   datetime.datetime(2017, 11, 15, 22, 22),
#   '관람객'],
#  ['도남매맘(llsm****)',
#   '진짜 개노잼 슈퍼맨은 그렇게 강한데 애초에 죽은게 노어이 ㅋㅋ',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 24, 8, 48),
#   0],
#  ['fbi0****',
#   '초등학생이보면 환장하긋네요',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 22, 19, 48),
#   0],
#  ['방구차(n_nj****)',
#   '마블따라가기 급급한듯한 스토리전개',
#   '4',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 20, 2, 24),
#   '관람객'],
#  ['sili****',
#   '보다 잠들어 버려서 잘 기억이 안납니다',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 20, 0, 41),
#   '관람객'],
#  ['어머(kim1****)',
#   '다음 작품이 기대 되네요',
#   '8',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 19, 1, 24),
#   '관람객'],
#  ['asd1****',
#   '보다가 지루해서 졸았네요',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 18, 20, 21),
#   '관람객'],
#  ['99ka****',
#   '원더우먼 너무 멎지다. 간만에 DC가 일냇네',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 17, 15, 37),
#   0],
#  ['인도카레(more****)',
#   '7점에 딱 어울리는 영화 마블 생각이 나지않을수가 없다',
#   '7',
#   '10',
#   '3',
#   datetime.datetime(2017, 11, 17, 13, 30),
#   '관람객'],
#  ['레전드(wogh****)',
#   '무슨 택배 기사도 아니고 엄마 상자 찾으러다니고시작 15분만에 잠들엇다',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2017, 11, 19, 17, 41),
#   '관람객'],
#  ['Harace(mptb****)',
#   '원더우먼까지는 아니지만 그래도 배트맨대슈퍼맨 보다는 확실히 재미있게 봤습니다',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2017, 11, 16, 17, 32),
#   '관람객'],
#  ['이성문(iy73****)',
#   '저스티스 리그를 심야로 지금 막 보고 올립니다.감독이 전투씬에만 중점을 두지 않았던 것 같습니다.  좀 더 정서적인 부분이 잇어서 좋았습니다.',
#   '7',
#   '11',
#   '4',
#   datetime.datetime(2017, 11, 16, 1, 34),
#   '관람객'],
#  ['뼈이빨(powe****)',
#   '재밋엇ㅇ습니다 마블관다른매력이잇습니다',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2017, 11, 15, 22, 28),
#   '관람객'],
#  ['박윤경(jump****)',
#   '감독이 영상미 하나는 제대로 해냈네',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2017, 11, 15, 12, 21),
#   0],
#  ['supe****',
#   '절대 보지마세요 제발 돈 주고 보지마세요',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2017, 11, 18, 22, 42),
#   '관람객'],
#  ['김호웅(howo****)',
#   '마블 따라잡기 실패ㅠㅠ',
#   '6',
#   '16',
#   '9',
#   datetime.datetime(2017, 11, 17, 14, 0),
#   '관람객'],
#  ['FunCom(hhdd****)',
#   '마블의성공을보면서 조급해진 워너의 심각한 간섭으로 영화는 dc고유의정체성을 상실한다.새로등장한 케릭터의 생소함, 부실한 스토리, 뚝뚝끊기는 장면전환..중도하차했다지만 액션장인인 잭감독의 연출이라곤볼수없는 가벼운 액션...',
#   '6',
#   '6',
#   '0',
#   datetime.datetime(2019, 7, 24, 11, 51),
#   0],
#  ['남영식(blem****)',
#   '재밌어요 기대안하고 봤는데 ㅋ',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 12),
#   '관람객'],
#  ['퓨리스(qlal****)',
#   '조금 지루한 부분이 있지만 내용을 이어가기위한 설명일뿐 바로 긴장감을 늦출수없는 장면이이어진다 .원더우먼 이렇게 예뻣었나 감탄하게 되고. 과연 배트맨이 부자일까? 아이언맨이 더부자일까 고민에 잠기게된다 ^^',
#   '9',
#   '6',
#   '0',
#   datetime.datetime(2017, 11, 17, 15, 33),
#   0],
#  ['HJ(gmlw****)',
#   '재밌게는 봤음 너무 일찍 나온게 좀 걸렸음 나머지 새히어로 세명도 솔로영화가 먼저 나왔어야 했는데 그게 좀 아쉬움 ㅋㅋ 다이애나 초반 액션 존멋존예 ㅋㅋ',
#   '7',
#   '6',
#   '0',
#   datetime.datetime(2017, 11, 16, 1, 38),
#   0],
#  ['쭈꿍이(dece****)',
#   '조금 아쉽다.. 뭔가 허전하다..  하지만 원더우먼이 너무 좋다..',
#   '8',
#   '6',
#   '0',
#   datetime.datetime(2017, 11, 15, 20, 27),
#   0],
#  ['에이아이(01sh****)',
#   '슈퍼맨 시체가 얼마나 가치있는데 그냥 동네 무덤에 넣어놨냐.  기계인간은 동네  바보형 비주얼. 아쿠아맨은 산적 마운틴맨이 어울리고 배트맨도 노답, 슈퍼맨이 눈레이저쏘더니 시력이 이상한지 원더우먼 놔두고 왜 저런 여...',
#   '6',
#   '7',
#   '1',
#   datetime.datetime(2019, 2, 18, 2, 39),
#   0],
#  ['천산흑협(alst****)',
#   '포스터 진짜 개 찐따같다',
#   '2',
#   '7',
#   '1',
#   datetime.datetime(2018, 7, 26, 23, 16),
#   0],
#  ['ksd4****',
#   '쟁나게 봤어요또보고 시포요',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2017, 11, 18, 21, 51),
#   '관람객'],
#  ['프리판다(why1****)',
#   '잼써요.돈 많이 들었을 거 같음.',
#   '8',
#   '7',
#   '1',
#   datetime.datetime(2017, 11, 18, 21, 50),
#   '관람객'],
#  ['시훈(djba****)',
#   '진실의 방 이후로 또 나왔네 진실의 밧줄 ㅋㅋㅋ',
#   '9',
#   '7',
#   '1',
#   datetime.datetime(2017, 11, 16, 12, 39),
#   0],
#  ['kjpo****',
#   '솔직히 기대안했는데 재밌눈데? 아쉬운건 마블처럼 영웅들의 스토리가 연결되는게 뷰족하다는점.. 객관적으로 봐도 토르가 더 잼있다. 하지만 보는거 추천해요. 8점짜리 영화는 아닌듯',
#   '9',
#   '8',
#   '2',
#   datetime.datetime(2017, 11, 17, 16, 6),
#   0],
#  ['targ****',
#   '한편의 그래픽노블같았습니다',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2017, 11, 17, 15, 53),
#   0],
#  ['wonj****',
#   '지루하지않고 웃기고 잼나요',
#   '8',
#   '8',
#   '2',
#   datetime.datetime(2017, 11, 17, 7, 33),
#   '관람객'],
#  ['반지하제왕(pzzx****)',
#   '잼나요 볼만합니다 차기작기대됩니다',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2017, 11, 19, 1, 21),
#   '관람객'],
#  ['촉촉(cham****)',
#   '대박  잼났습니다.마블도 긴장하셔야할듯!!!',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2017, 11, 18, 21, 53),
#   '관람객'],
#  ['절망눈빛(sini****)',
#   '적당히 진지하고 적당히 웃김',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2017, 11, 16, 22, 48),
#   '관람객'],
#  ['swee****',
#   '저스티스리그2도 기대됨. 쿠키영상 2개임',
#   '8',
#   '9',
#   '3',
#   datetime.datetime(2017, 11, 15, 21, 38),
#   '관람객'],
#  ['71321(fris****)',
#   '액션씬조아요 ㅇㅇㅇㅇ',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2017, 11, 17, 16, 31),
#   '관람객'],
#  ['kknd****',
#   '넘나재미난것 다음시리즈도 기대만땅',
#   '10',
#   '11',
#   '5',
#   datetime.datetime(2017, 11, 16, 22, 53),
#   '관람객'],
#  ['김가영(rlar****)',
#   '역시역시 잼잼잼ㅋㅋㅋㅋ룰루랄라룰루라랄라라라아아라우나아투우다아처구니마어투쿸ㅋㅋㅋ',
#   '10',
#   '11',
#   '5',
#   datetime.datetime(2017, 11, 15, 23, 33),
#   '관람객'],
#  ['nothing(vthe****)',
#   '애즈라 밀러 개드립 칠때마다 관객 웃음 하나도 안터지고....ㅎㅎㅎㅎ 왜 자꾸 마블처럼 가볍게 가려고 하는건지 ~ 배대슈가 훨씬 나았음.',
#   '6',
#   '15',
#   '9',
#   datetime.datetime(2017, 11, 16, 13, 20),
#   '관람객'],
#  ['울산한화팬(seon****)',
#   '평점 테러는 하지맙시다 ㄹㅇ',
#   '10',
#   '15',
#   '9',
#   datetime.datetime(2017, 11, 15, 13, 55),
#   0],
#  ['쿠쿠(deva****)',
#   '기대하고 봤는데도 볼거리가 장난아님요!',
#   '10',
#   '21',
#   '15',
#   datetime.datetime(2017, 11, 15, 18, 32),
#   '관람객'],
#  ['세잎클로버(rain****)',
#   '드디어 DC가 마블에 대항마가 되는가~~',
#   '10',
#   '37',
#   '31',
#   datetime.datetime(2017, 11, 15, 18, 32),
#   '관람객'],
#  ['Cool한늑대(blac****)',
#   '역시액션신은,D.C.가최고임!!!진짜재미있게봤어요',
#   '10',
#   '61',
#   '55',
#   datetime.datetime(2017, 11, 15, 19, 1),
#   '관람객'],
#  ['딱총나무(jung****)',
#   '이제 마블의 독주를 막을 대항마가 등장했다.',
#   '9',
#   '242',
#   '236',
#   datetime.datetime(2017, 11, 15, 0, 0),
#   0],
#  ['정진유(nigh****)',
#   '마블빠들 평점 테러하는거보소 그것만봐도 니들수준 알만하다',
#   '10',
#   '348',
#   '342',
#   datetime.datetime(2017, 11, 15, 7, 39),
#   0],
#  ['쩝(go_d****)',
#   'ㅋㅋ혼자서는 세상을 구할 수 없다매요... 슈퍼맨 혼자 다하는데요....',
#   '5',
#   '5',
#   '0',
#   datetime.datetime(2019, 10, 6, 0, 13),
#   0],
#  ['jjh0****',
#   '헬로.카봇  보다  재미없어요',
#   '1',
#   '5',
#   '0',
#   datetime.datetime(2019, 7, 28, 2, 43),
#   0],
#  ['suy9****',
#   'DC유니버스는 아무리 발악한들 마블유니버스를 이길수없다 페미,인성논란때문에 망할거라고 했던 캡틴마블마저 성공했다   DC는 더이상 영화를 만들지말고 그돈으로 유니세프에 기부해라',
#   '2',
#   '5',
#   '0',
#   datetime.datetime(2019, 7, 28, 1, 53),
#   0],
#  ['젤리밤(yunu****)',
# ...
#   '아싸식 민망한 개그 개연성 부족한 액션들끝!',
#   '3',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 6, 16, 21),
#   '관람객'],
#  ['꼬맹지섭(rlae****)',
#   '잭 스나이더를 기다려보는걸로 ...',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 5, 19, 41),
#   '관람객'],
#  ['nive****',
#   '맨 오브 스틸이 그립다.',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 5, 19, 29),
#   0],
#  ['계왕신(blen****)',
#   '4점짜리영화 밸런스 맞추러왔습니다..',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 2, 11, 24),
#   0],
#  ['날피(aqua****)',
#   '볼만한 엑션이네요  후속도 기대 됨',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 1, 19, 23),
#   '관람객'],
#  ['ifu(cods****)',
#   '기대안하고봤는데 걍 나쁘지않아요',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 30, 14, 54),
#   '관람객'],
#  ['김죠스(alrn****)',
#   '흠 너무너무 아쉬웠다 그렇다',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 28, 12, 2),
#   '관람객'],
#  ['천시몬(simo****)',
#   'It was less than expected.  Very disappointing',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 28, 10, 36),
#   '관람객'],
#  ['LSB(leez****)',
#   '수어사이드 스쿼드가 묽은 설사라면저스티스 리그는 잘싼 황금변 정도는 됨.',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 28, 0, 41),
#   '관람객'],
#  ['Man(ggam****)',
#   '이제야 조금 볼만하다, 힘내라 DC',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 27, 21, 3),
#   '관람객'],
#  ['이고은(goeu****)',
#   '왜 완성도가 100은 아닌거같지...뒤쪽으로 갈수록 어짜피 슈퍼맨이면 되는건가 생각해게되고 다른게 더 있나 이렇다좀 아쉬움이있었지만 통쾌한 히어로물이였당',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 27, 1, 55),
#   0],
#  ['wleo****',
#   '나름 쟈밋게 잘보앗네요',
#   '5',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 27, 0, 11),
#   '관람객'],
#  ['tbvj****',
#   '슈퍼맨을 어떻게 이겼냐? 매력없는 빌런 히어로는 덤',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 26, 19, 39),
#   0],
#  ['동두랑(hide****)',
#   ',.,.,.,.,.,.,.,.,.,.,.,.',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 26, 19, 2),
#   0],
#  ['히스헤링(dlaw****)',
#   'dc는 잊지말길. 지금 이상태로는 마블 어벤져스에 가까이 갈수도 없음을....영화 흥행실패의 원인에 대한 방향 자체를 잘못잡은거 아닌가 싶다.',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 26, 1, 29),
#   '관람객'],
#  ['INY(rudx****)',
#   '이 좋은 캐릭터를 두고, 시나리오와 세계관은 10년 전의 유행을 답습. 그래서 난 안습.',
#   '5',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 25, 21, 7),
#   0],
#  ['KITCAT(oops****)',
#   '원더우먼으로 쌓은 기대감 다 날려버림ㅠ 이게 머야?ㅠㅜㅜ 스토리가 개연성이라고는 1도 없음ㅠ',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 23, 22, 0),
#   '관람객'],
#  ['스티브(tyoh****)',
#   '결말이 수퍼맨을 위해 존재하는 듯한 균형감 상실이 엔딩을 더더욱 어이없게 만든 것 같다',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 23, 21, 49),
#   '관람객'],
#  ['chan****',
#   '스토리는 너무 어거지 같았지만 액션씬은 훌륭했음',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 23, 15, 0),
#   '관람객'],
#  ['유(na_j****)',
#   '수어사이드랑 다른게 머냐?',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 23, 14, 0),
#   '관람객'],
#  ['양형(gudt****)',
#   '너무 많은 기대를 했구나 ㅠㅜ',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 23, 13, 5),
#   '관람객'],
#  ['ling****',
#   '마블 어벤져스 따라잡기인 느낌에 실망. 본래 DC의 색을 찾아나가길..이제 부터 본격적인 시작이라고 믿고싶다.',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 19, 8),
#   0],
#  ['james kainz lee(soso****)',
#   '영화 스토리는 나름 괜찮음. 그전 배트맨시리즈는  브루스가 배트맨 수트를 입으면 힘이 강해지고 여러가지 무기를 쓰는 재미가 있었는데 슈퍼맨 앞에서면 그냥 하룻강아지 된 느낌?? 힘 밸런스가 필요함.',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 18, 13),
#   0],
#  ['Chris(arch****)',
#   '값비싼 정의닦이 .. 제가 악평 잘 안쓰는데 이건 좀',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 14, 4),
#   0],
#  ['MCloud(dero****)',
#   '재미있었음 마블은 처음에 잘봐지는 영화고 디씨는 후에 다시보기가 새로운 그런 영화 ㅋ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 12, 55),
#   0],
#  ['불쟁이(bulj****)',
#   'DC해줘도 졸지않고 보기 어려움',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 0, 22),
#   0],
#  ['enfl****',
#   '영화관에서 잔적 오랜만이다 꿀잠자고왔다 영화제목바꿔야됨 슈퍼맨과 아이들 재미하나도없다 ㅡㅡ 진짜 화나네',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 22, 0, 14),
#   0],
#  ['타카이시 마쿠토X1(jung****)',
#   '원더우먼 때보다 왜 떨어졌나.. 앞으로 다른 캐릭터들도 슈퍼맨 살린 방식으로 살리면 되겠네. 조드&아레스 이후로 간지나는 악당 좀 나와라..',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 23, 8),
#   '관람객'],
#  ['약오르쥐(alla****)',
#   '슈퍼맨 혼자서두..밸런스가 안맞은 느낌.ㅎ 아쉽네요..배트맨 넘 초라함 ㅎ..',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 23, 4),
#   '관람객'],
#  ['tkcl****',
#   'DC사장이 마블 스파이 아니냐?',
#   '3',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 23, 3),
#   0],
#  ['승주머신(absd****)',
#   '영웅들이 아깝다 영화가 너무 어둡고 지루함',
#   '3',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 21, 47),
#   '관람객'],
#  ['제니(peti****)',
#   '킬링타임용으로는 볼 만 해요',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 20, 3),
#   '관람객'],
#  ['jinn****',
#   '초반엔 지루하고 후반은 진부하다 DC 세계관을 설득력 있게 만들어야 하는데 그것도 안해서 스토리가 얕음 딱 킬링타임용',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 19, 20),
#   0],
#  ['fpzk****',
#   '그냥 한번쯤 볼만한 영화였어요...',
#   '5',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 18, 21),
#   '관람객'],
#  ['맹꽁이(yato****)',
#   '주말 2천원 할인받아 9천원주고봤는데진짜 돈 아깝다고 느낀 영화..최악임.진심 돈 아깝다.슈퍼맨이 갑이고 쌩뚱맞은 스토리전개',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 17, 43),
#   0],
#  ['jama****',
#   '조금부족한느낌,,,,마블의액션을따라가지못하는거같음,,,아쉬움',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 21, 16, 30),
#   '관람객'],
#  ['이승선(vtvt****)',
#   '원더우먼이제일 멋져요',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 20, 20, 6),
#   '관람객'],
#  ['BKJYMCH98(mun2****)',
#   '액션은 확실히 마블보다는 DC네ㅋㅋ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 20, 15, 19),
#   0],
#  ['tpwj****',
#   '역쉬 멋지네요~^^ 슈퍼맨 좋아',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 20, 13, 9),
#   '관람객'],
#  ['더락(vawu****)',
#   '원더우먼은 슈퍼맨 안다치게하려고 살살한거라 치고 플래시는 아직 애라그렇다치고 아콰맨은 육지적응력부족이라치고 대체 감히 다크나이트님을 이따구로 표현한 이유는 뭘까? 잭스나이더가 슈퍼맨빤가??',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 20, 12, 18),
#   0],
#  ['리프벌룬(gktm****)',
#   '원더우먼 완전멋있엉 ㅋㅋ',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 20, 9, 38),
#   '관람객'],
#  ['hans(jeey****)',
#   '슈퍼맨 없으면 지구는 멸망. 다른 히어로들 밸런스 붕괴됐고 악당은 유치하고 캐릭터도 그냥 그렇고..배트맨은 밤의 기사에서 돈많은 스폰서, 죄책감에 쭈글대는 불쌍한 사람이 됐다..배트맨 캐붕 어쩔거임...원더우먼 이뻐...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 21, 17),
#   0],
#  ['미광산업개발(yhac****)',
#   '바로구매후 영화봤어요간만에 아이들과 극장나들이^^',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 18, 2),
#   '관람객'],
#  ['쭌미7632(judy****)',
#   '너무너무재밌게봤어요.다이애나예뻐요.ㅎ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 40),
#   '관람객'],
#  ['또로록(solm****)',
#   '역시 원더우먼 짱이에요.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 36),
#   '관람객'],
#  ['버가모(sykm****)',
#   '디씨 화이팅 다음편 기대된다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 34),
#   '관람객'],
#  ['황형섭(gudt****)',
#   '생각한거보다볼만해요',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 25),
#   '관람객'],
#  ['key1****',
#   '다들 멋지네요 다들 멋지네요',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 8),
#   '관람객'],
#  ['sguu****',
#   '잘보았습니다 .정신없이',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 5),
#   '관람객'],
#  ['금동 맘(jhyu****)',
#   '온 가족이  맘 편히  눈요기로  볼 수  있는  영화',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 4),
#   '관람객'],
#  ['yklo****',
#   '너무 재밋엇어요 ㅎㅎ늦게 봣는데 안졸고 재밋엇어요 ㅎㅎ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 17, 3),
#   '관람객'],
#  ['dona****',
#   '정말 재밌네요~~시간 가는줄 몰랐어요~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 52),
#   '관람객'],
#  ['형(pdm1****)',
#   '재밌네요굳굳굳ㅎㅎ굳',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 51),
#   '관람객'],
#  ['xogu****',
#   '재밋음재밋음재밋음재',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 43),
#   '관람객'],
#  ['인호(rino****)',
#   '디시영화중 가장 잘만듬!!  차기작이 기대되네요!!!',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 33),
#   '관람객'],
#  ['noon****',
#   '가장 코믹스와 비슷한 배트맨 난 DC가 더 맘에 든다. DC는 그냥 DC스러웠음 좋겠다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 28),
#   0],
#  ['뚱덕쿠(sehw****)',
#   '재밌네요 아주좋아요굿',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 16, 25),
#   '관람객'],
#  ['pamu****',
#   '얘들이 좋아해요. 나름 재미있어요',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 12, 35),
#   '관람객'],
#  ['달구사랑(ha0e****)',
#   '조아요 아주 재미있었네요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 7, 43),
#   '관람객'],
#  ['만돌베(kden****)',
#   '그 다음편을 위한 무난한 전개,딱 거기까지만,담편을 기대해본다',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 2, 22),
#   '관람객'],
#  ['가가하(raja****)',
#   '재미있었음하하노다나',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 19, 1, 36),
#   '관람객'],
#  ['콜러스(coll****)',
#   '이정도면 매우극상타 영화 벨붕어쩌고 그러는데 수퍼맨 약했으면 왜살렸냐고 ㅈㄹ 거릴거아닌가?',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 19, 40),
#   0],
#  ['구름없이맑은하늘(cwj1****)',
#   '말도안되... 세 종족이서 겨우 막은 애를 슈퍼맨 한명이서 해치운다고? 거참....',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 17, 59),
#   0],
#  ['펫떳스윙(army****)',
#   '아직까지  내용이  무겁네용~~좀더   힘좀빼자고용~~^^',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 17, 50),
#   '관람객'],
#  ['고스트(pkj5****)',
#   '히어로가6명인데 액션이짧다, 애들모으는데 시간이다갔다,  애들솔로영화먼저해야 사람들이 이해를하는데 저스티스팀이 먼저나오고 아쿠아맨,플래쉬,사이보그 영화가 늦게나온다, 뻔한이야기, 그냥슈퍼맨혼자있으면 맴버들필요없네 (...',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 17, 35),
#   0],
#  ['drea****',
#   '배트맨이 너프 당했네 10자',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 12, 2),
#   '관람객'],
#  ['강씨(kang****)',
#   '지구의 위기라는데 일반인 피해는 0에 수렴하고, 적들은 외곽한적한데서 뭐 해볼려다가 털리고, 종말이란 애는 다른 애들 다 바를 실력인데 게릴라만 하다 슈퍼맨 나와서 탈탈 털리고, 지구의 모든 힘 <<&lt...',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 18, 9, 12),
#   0],
#  ['용짱(snpu****)',
#   '이제부터 스토리 시작이내.앞으로가 더 기대됨.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 22, 18),
#   0],
#  ['jae0****',
#   '하..보세요 꼭 보세요!!! 이게 바로 DC',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 56),
#   0],
#  ['하지맘(rhf0****)',
#   '저는 재밌게 봤어요! 슈퍼맨이 저래 쎈줄 몰랐음ㅋㅋ슈퍼맨존잘!베트맨은 등빨만 커ㅜ',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 53),
#   0],
#  ['무한궤도(ktj9****)',
#   '저는 솔직히 토르보다 낫네요.  진심으로 토르가 뭐가 재밌는지 모르겠어요. 이 영화도 최고는 아니지만 토르보다는 나았습니다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 28),
#   0],
#  ['yhyc****',
#   '미모는 역쉬 원더우먼. 실력의 갑은 슈퍼맨',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 27),
#   0],
#  ['po대충wer(curr****)',
#   '이야기를 만드는 능력과 그것을 보여주는 능력, 둘 다에게 박수!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 26),
#   0],
#  ['돼zico(dmsw****)',
#   '최근에본 DC영화 중에서는 제일 좋습니다 쿠기령상 두개있으니 챙겨보세요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 22),
#   0],
#  ['dkra****',
#   '생각없이 웃으면서 보았네요~~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 13),
#   0],
#  ['nelo****',
#   '오락성은 좋아요. 히어로물 좋아하는 분들은 화려해서 볼만합니다 ^^',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 21, 12),
#   0],
#  ['wntj****',
#   '줄거리가 빈약하고 액션이 다소 약했지만 히어로물을 좋아해서 딱 8점',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 18, 56),
#   '관람객'],
#  ['HniJni(skyl****)',
#   '원더우먼 왜케 예쁘니.. 볼수록 이뻐지네',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 16, 54),
#   0],
#  ['조각(dkwj****)',
#   '다 필요없고 슈퍼맨이 졸라 잘생겼다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 16, 46),
#   0],
#  ['TY(bpre****)',
#   '기대를 안하고 봤기에 실망도 크지는 않다. 그러나 원더우먼으로 그나마 살려둔걸 다시 꺼트리는 느낌 / 수퍼맨이 너무나 강력해서 데우스 엑스 마키나가 아니라 그냥 데우스로 등장했던 것 같다. 영화 내용도 많이본 스토리...',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 11, 35),
#   '관람객'],
#  ['neos****',
#   '이건 저스티스리그가 아니라 슈퍼맨과 똘마니들 아닌가. 그렇게 힘들게 적들과 싸우는데 슈퍼맨 등장으로 올킬 역시 끝판왕은 슈퍼맨이구만',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 10, 28),
#   0],
#  ['wlst****',
#   'so so해요.  마블이상은 아닌듯.  개인적인 차이가 있겠지만 그랴도 헐리웃 영화 cg는.  무시못하죠',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 17, 0, 47),
#   '관람객'],
#  ['cham****',
#   '기대보다 괜찮았음. 다만 슈퍼맨이 다 할꺼면 딴 멤버가 왜필요한지가 좀..  슈퍼맨 살리는거까지가 역할일지는 모르겠지만.베트맨도 너무 근육덩어리가 왔다갔다해 나오면 답답함. 예전 베트맨같은 좀 날씬근육이면 나을듯',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 16, 22, 25),
#   0],
#  ['your****',
#   '원더우먼 너무 멋있게 나와요..근육남들 눈에 않보임!',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 16, 22, 20),
#   0],
#  ['깐돌승준(heey****)',
#   '빅터 귀여웡?? ㅋㅋ imax로 꼭봐야할듯',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 16, 20, 21),
#   0],
#  ['Mr goodcat(zing****)',
#   '재미는 있었지만 170분짜리를 120분으로 컷팅 당한 극장판보다 확장판의 개봉을 보고싶구나~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 16, 10, 48),
#   0],
#  ['그린브리즈(salu****)',
#   '이런 장르의 영화를 좋아하는 편인데솔직히 좀- 지루한 느낌..?  그나마 플래시는 귀여웠음',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 16, 0, 41),
#   0],
#  ['에스(ss12****)',
#   '디씨 영화는 여자캐릭터 하나는 정말 잘살린다 ㅋㅋ',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 15, 23, 32),
#   0],
#  ['KILLMOON(ligh****)',
#   '한반도에 와서 돼지 김정은과 삶은 소대가리 문재인 죽여주세요',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 11, 12, 0, 30),
#   0],
#  ['parkhyonsu(omom****)',
#   '저스티스 리그: 슈퍼맨',
#   '3',
#   '5',
#   '1',
#   datetime.datetime(2019, 8, 31, 15, 24),
#   0],
#  ['한샷(hans****)',
#   '영화면 만화적인 색채를 좀빼고 무게감있게 가야지않나 대사만 폼잡는 아동용이네.. DC는 다크나이트 반에반만이라도 해라~',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 21, 2, 3),
#   0],
#  ['그놈(rmsh****)',
#   '자꾸 마더 마더 엄마 엄청 찾네 악당이란 놈이',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 21, 0, 41),
#   0],
#  ['vsky****',
#   '이 좋은 캐릭과 출연진을 가지고 이정도 수준으로 연출할 수 밖에 없었나...',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 15, 19, 39),
#   0],
#  ['dltj****',
#   '잭스나이더는 도중하차하고 어벤저스1 만들엇던 조스웨던이 만듬 이정도면 마블쪽에서 스파이 보낸거임 디씨 죽일라고',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 13, 0, 39),
#   0],
#  ['축구왕슛돌(chun****)',
#   '디씨 팬들 고생이많다 이런 희대의 3류 쓰레기영화 실드도 쳐야하고',
#   '2',
#   '5',
#   '1',
#   datetime.datetime(2019, 4, 7, 9, 27),
#   0],
#  ['곰아멍멍해봐(pete****)',
#   '맨오브 스틸의 조드장군이 얼마나 강력한적이었는지를 알려주는 영화... 혼자서는 세계를 구할수없다고? 틀렸어 슈퍼맨 아니 크립톤 사람 하나면 인류를 구할수있다',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2019, 2, 2, 18, 32),
#   0],
#  ['튼튼이(jenn****)',
#   '신 (스테판울프) <<<< 외계인 (슈퍼맨)이것이... 말이 되는가...',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2019, 2, 1, 22, 57),
#   0],
#  ['미라클(many****)',
#   '위험에 처한 민간인은 딱 네명?스테판 울프는 민간인 피해를 고려해서 외진 곳에서 일을 벌인건가요..? 끝나고 나란히 위에서서 꽃 피는거 구경하며 “이 장면은 놓치지 않아 다행이군.” 할때 손발 오글 와..저스티스 리...',
#   '3',
#   '5',
#   '1',
#   datetime.datetime(2018, 5, 27, 23, 45),
#   0],
#  ['sorr****',
#   '디시를 바닥까지 추락시킨 작품 이후로 회생불가..',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2018, 5, 16, 17, 0),
#   0],
#  ['새벽(lisu****)',
#   '포스터부터 똥망포스네',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2018, 5, 5, 5, 17),
#   0],
#  ['비디(rudd****)',
#   '믿고거르는 디씨;;;;레알루;;',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2018, 5, 4, 18, 0),
#   '관람객'],
#  ['티오피(khw6****)',
#   '디시충들  평점테러하고 다니는거  꼴보기 싫어서  나도 테러할려고 했는데 막상 보니까 테러 딱히 안해도  5점은 못 넘길 영화더라  게다가  어제 어벤져스 인피니티 워도 봐서 ㅋㅋ 엄청난 비교가',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2018, 4, 28, 16, 12),
#   0],
#  ['Heigle(hyun****)',
#   '진짜 ㅈ노잼....밸붕에 캐붕에 개연성 박살은 기본에 재미까지 없다... DC는 그냥 영화를 만들지 말자',
#   '2',
#   '5',
#   '1',
#   datetime.datetime(2018, 2, 8, 15, 55),
#   0],
#  ['쏭방장(sson****)',
#   '슈퍼맨만있어도 인류를 구할수있는영화에 굳이 다른멤버를 넣어야했나?',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2018, 1, 2, 5, 19),
#   0],
#  ['maybe(cong****)',
#   '다갑이 합동해서 죽일수있게좀하지 ㅋㅋㅋ 슈퍼맨만 밸붕이잖아 ㅡㅡ;',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 31, 21, 45),
#   0],
#  ['이노센트(duke****)',
#   '언제까지 "그래, 이정도면 DC치고는 선방했어."로 자위만 할거냐? 마블 영화들 보면서 뭔가 본 받아야겠다는 생각은 들지 않냐?',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 28, 11, 21),
#   0],
#  ['pbom****',
#   '공짜로  보여줘도 안 볼란다~~~',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 25, 2, 24),
#   0],
#  ['대한몽국(ansr****)',
#   '원래 원더우먼이 슈퍼맨과 90%로는 동급인데 너무약하게나왔다',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 24, 10, 38),
#   0],
#  ['라즈링(kyun****)',
#   '굉장히 실망스러운 영화였다기승전 슈퍼맨...',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 20, 17, 34),
#   '관람객'],
#  ['KJY(jeek****)',
#   'ㅠㅠ 이게 뭐지....ㅜㅜ엉엉',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 19, 8, 40),
#   '관람객'],
#  ['MKIT(raws****)',
#   '아니 진짜 토르보다 재밌었음 ㄹㅇ',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 11, 20, 13),
#   0],
#  ['kjin****',
#   '졸았어요.. 애들도 그냥 그랬데요',
#   '7',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 9, 9, 50),
#   '관람객'],
#  ['kjba****',
#   '스토리도 긴장감도 전혀 없네요. 정말 재미없습니다  중간에 잤습니다',
#   '3',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 7, 2, 16),
#   '관람객'],
#  ['lamg****',
#   '너무나도 뻔한 인물들의 순차적인 등장 및 소개,그보다 더 심각한 CG.. 그중 하이라이트는 알록달록 꽃들이 만개하며 영화의 끝을 알리는 장면이였습니다.과장 안보태고 저랑 같이 봤던 친구들은 자다깨다를 수없이 반복했더...',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 6, 12, 46),
#   0],
#  ['포로포로포(lagu****)',
#   '이게 어떻게8 점이냐 5넘이적당한데',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 2, 11, 50),
#   0],
#  ['미스타로(soho****)',
#   '겁나 재밌는 영화 저스티스리그',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 12, 2, 1, 40),
#   '관람객'],
#  ['qwerasdf(chob****)',
#   '파워레인져보다 유치함',
#   '1',
#   '5',
#   '1',
#   datetime.datetime(2017, 11, 30, 1, 5),
#   0],
#  ['Chorong Park(fhdx****)',
#   '그냥 기대털고 영혼없이 보면 본전',
#   '6',
#   '5',
#   '1',
#   datetime.datetime(2017, 11, 29, 18, 48),
#   '관람객'],
#  ['서승혁(skhj****)',
#   '제발 각본 좀... 왜 항상 시작은 멋있게 해놓고 마무리가 신파극인지...',
#   '6',
#   '5',
#   '1',
#   datetime.datetime(2017, 11, 29, 14, 24),
#   '관람객']]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                           0  ...    6
# 0            야후예스(eocj****)  ...  관람객
# 1              Mu(prau****)  ...    0
# 2                  yks0****  ...    0
# 3                  jinj****  ...    0
# 4             블랙님(jgki****)  ...  관람객
# ..                      ...  ...  ...
# 665         포로포로포(lagu****)  ...    0
# 666          미스타로(soho****)  ...  관람객
# 667      qwerasdf(chob****)  ...    0
# 668  Chorong Park(fhdx****)  ...  관람객
# 669           서승혁(skhj****)  ...  관람객
#
# [670 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                    nickname  ... watch_movie
# 0            야후예스(eocj****)  ...         관람객
# 1              Mu(prau****)  ...           0
# 2                  yks0****  ...           0
# 3                  jinj****  ...           0
# 4             블랙님(jgki****)  ...         관람객
# ..                      ...  ...         ...
# 665         포로포로포(lagu****)  ...           0
# 666          미스타로(soho****)  ...         관람객
# 667      qwerasdf(chob****)  ...           0
# 668  Chorong Park(fhdx****)  ...         관람객
# 669           서승혁(skhj****)  ...         관람객
#
# [670 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
