# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(DC%ED%9E%88%EC%96%B4%EB%A1%9C_%EC%9B%90%EB%8D%94%EC%9A%B0%EB%A8%BC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=125473
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 125473
total_count = 932  ## 전체 크기= 932

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=125473&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 125473
total_count = 932  ## 전체 크기=932

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['엽(holi****)',
#   '나는 오늘을 구할테니 당신은 세상을 구해요',
#   '8',
#   '3222',
#   '328',
#   datetime.datetime(2017, 5, 31, 14, 0),
#   0],
#  ['나랑가(ej2r****)',
#   '갤 가돗 캐스팅이 신의 한수였네.',
#   '10',
#   '2301',
#   '457',
#   datetime.datetime(2017, 5, 31, 11, 34),
#   '관람객'],
#  ['아드레날린(ghgh****)',
#   '초반부엔 지리는데 중반부에 지렸다가 후반부 가서 지린다',
#   '10',
#   '2286',
#   '681',
#   datetime.datetime(2017, 5, 31, 1, 13),
#   0],
#  ['태양이(016n****)',
#   'DC히어로들의 역습이 시작되나? 그 스타트를 원더우먼이 잘 끊어준듯 너무 아름답고 최강인 원더우먼의 탄생이다 갤 가돗 캐스팅이 신의한 수',
#   '10',
#   '1605',
#   '425',
#   datetime.datetime(2017, 5, 31, 13, 59),
#   '관람객'],
#  ['티키닭카티키닭카(zzor****)',
#   '아 진심 본사람들만 댓글단거 맞냐? 그렇게 재밌냐?',
#   '10',
#   '1587',
#   '529',
#   datetime.datetime(2017, 5, 31, 5, 41),
#   0],
#  ['gogl****',
#   '역시 갤가돗 이쁘고 멋있다',
#   '10',
#   '1291',
#   '286',
#   datetime.datetime(2017, 5, 31, 14, 7),
#   '관람객'],
#  ['콜슨(jwa0****)',
#   '드디어 DC가 해냈습니다. 여려분',
#   '10',
#   '1268',
#   '404',
#   datetime.datetime(2017, 5, 31, 6, 40),
#   0],
#  ['이 터널은 선샤인(chan****)',
#   '와.... 다행이다 dc 앞으로 계속 이런식으로 영화 만들어줘',
#   '9',
#   '1215',
#   '390',
#   datetime.datetime(2017, 5, 31, 7, 23),
#   0],
#  ['동동(ydon****)',
#   '마블과 비교를 떠나서 여성 히어로물중 아니 모든 히어로물중에 단연 최고입니다.. 이렇게 여성 히어로에서만큼은 DC가 먼저 선두를 달리게 되는군요',
#   '10',
#   '1057',
#   '325',
#   datetime.datetime(2017, 5, 31, 8, 56),
#   0],
#  ['beyond(cine****)',
#   'dc 작품 중에 가장 재밌고 쌈박하게 만들었다. 원더 우먼으로 이런 스토리를 만들어낼 줄이야.',
#   '10',
#   '929',
#   '268',
#   datetime.datetime(2017, 5, 31, 0, 28),
#   0],
#  ['I am JB(jbsi****)',
#   '초중반엔 멋있어서 소름. 후반부엔 유치해서 소름.',
#   '8',
#   '716',
#   '142',
#   datetime.datetime(2017, 6, 1, 15, 13),
#   '관람객'],
#  ['Forever샤드(bang****)',
#   '지금 로튼 96%임 미쳤음ㅋㅋㅋㅋ',
#   '10',
#   '779',
#   '320',
#   datetime.datetime(2017, 5, 31, 3, 24),
#   0],
#  ['mrkk****',
#   '여성히어로의 가능성을 보여준 영화!',
#   '8',
#   '700',
#   '243',
#   datetime.datetime(2017, 5, 31, 10, 35),
#   '관람객'],
#  ['리버사이드(fpel****)',
#   '드디어 dc가 정신차렸다..',
#   '10',
#   '694',
#   '251',
#   datetime.datetime(2017, 5, 31, 0, 9),
#   0],
#  ['쥰아(aram****)',
#   '팔찌와 방패가 이렇게 통쾌하다니.',
#   '10',
#   '564',
#   '143',
#   datetime.datetime(2017, 5, 31, 16, 12),
#   '관람객'],
#  ['rocker(nail****)',
#   '최근 DC세계관 영화 중에 제일 재밌습니다',
#   '7',
#   '569',
#   '177',
#   datetime.datetime(2017, 5, 31, 14, 6),
#   '관람객'],
#  ['에이브릴라빈(neib****)',
#   '지젤이 원더우먼으로 살아 돌아온 것 만으로도 행복하다 최고',
#   '10',
#   '538',
#   '168',
#   datetime.datetime(2017, 5, 31, 0, 8),
#   0],
#  ['Hana Van Beirendonck(hana****)',
#   '갤가돗 진짜 여신. DC에서 제대로 여성 히어로 만들었네요!',
#   '9',
#   '488',
#   '154',
#   datetime.datetime(2017, 5, 31, 11, 55),
#   '관람객'],
#  ['왕사자(ilov****)',
#   '갓더우먼 ㅠㅠ와 개쩜 이건 또봐야함',
#   '10',
#   '462',
#   '178',
#   datetime.datetime(2017, 5, 31, 11, 44),
#   '관람객'],
#  ['황현동(mana****)',
#   '여주 하는 행동들은 하나같이 짜증나기만하고 액션신은 유치찬란. 종탑 무너지는장면에선 어이가 없어서 헛웃음밖에 안나왔다. 조연들은 사연있는것처럼해놓고 아무것도안하는 쩌리. 빌런이라는놈은 위엄이나 매력은 하나도없음. 두...',
#   '1',
#   '787',
#   '510',
#   datetime.datetime(2017, 6, 4, 4, 36),
#   0],
#  ['박들후(psy8****)',
#   '좀 유치하고 지루한 느낌이있었어요',
#   '7',
#   '590',
#   '314',
#   datetime.datetime(2017, 5, 31, 23, 25),
#   '관람객'],
#  ['cpupupu(arma****)',
#   '히어로의 시작을 알리는데는 이만한 영화가 없다고 생각한다. 그동안의 히어로 영화를 통틀어서도 손에 꼽는 쾌조의 스타트다',
#   '10',
#   '420',
#   '159',
#   datetime.datetime(2017, 5, 31, 14, 28),
#   '관람객'],
#  ['연수(suju****)',
#   '노잼이다.. 갤가돗은 이뻤다 그게 전부였다',
#   '1',
#   '619',
#   '366',
#   datetime.datetime(2017, 6, 3, 3, 38),
#   '관람객'],
#  ['으뜸엄마(mati****)',
#   '뭘 자꾸 지린다는거냐? 지린놈들은 요실금있는거니 가까운 병원가봐라. 나 원 아침드라마보다가 지릴놈들일세',
#   '1',
#   '474',
#   '243',
#   datetime.datetime(2017, 5, 31, 15, 13),
#   0],
#  ['임호빈(cobi****)',
#   '솔직히 생각보단 별로입니다',
#   '5',
#   '444',
#   '221',
#   datetime.datetime(2017, 5, 31, 22, 59),
#   '관람객'],
#  ['내가(kolp****)',
#   '전체적으로 잘 만들었고 재밌게 잘 봤습니다. 그리고 원더우먼이 어떤 히어로인지 이 영화로 말하고 싶었던게 뭔지 잘 보여집니다.',
#   '10',
#   '339',
#   '117',
#   datetime.datetime(2017, 5, 31, 11, 41),
#   '관람객'],
#  ['BBOINGL(zzan****)',
#   '갤 가돗 대박.. 원더우먼 완전 존멋임 ㅠㅠ  N차각ㅠㅠ!',
#   '10',
#   '311',
#   '110',
#   datetime.datetime(2017, 5, 31, 11, 42),
#   '관람객'],
#  ['Lachdanan(prot****)',
#   '배댓슈 같은 막장 전개는 없지만 좀 지루한 편이고, 액션 씬은 화려하지만 전체 러닝타임에 비해 액션이 많지 않습니다. 보면서도 언제 싸우나 이런 생각이 듭니다.',
#   '6',
#   '290',
#   '101',
#   datetime.datetime(2017, 6, 1, 1, 59),
#   0],
#  ['우디하디(shst****)',
#   '대박.. 원더우먼 진짜 첨부터 끝까지 멋짐 ㅠㅠ',
#   '10',
#   '284',
#   '100',
#   datetime.datetime(2017, 5, 31, 10, 57),
#   '관람객'],
#  ['돔(dond****)',
#   'Dc의 다크나이트 이후의 최고작 이라고도 불릴만한 영화이다',
#   '10',
#   '500',
#   '344',
#   datetime.datetime(2017, 5, 31, 0, 9),
#   0],
#  ['테리(wand****)',
#   '초반부엔 지루한데 중반주에는 더지루하다가 후반부에는 집에 가고 싶어짐. 정말 지루하고 재미도 없는데 전투씬도 슬로모션에디시 영화 특유 bgm 나오고 진짜 오글거리고 후반부에 마구떄려패는 장면 정말 오글거림 dc영화는...',
#   '1',
#   '386',
#   '233',
#   datetime.datetime(2017, 6, 1, 12, 15),
#   0],
#  ['아돌(ehdw****)',
#   '사람들 평가가 너무 좋길래 엄청 기대하고 봤는데 되게 실망함 스토리 지루하고 유치하고 진부함 갤가돗 예쁘다고 10점 주는애들은 뭔생각으로 영화보냐? 1점짜리 영화는 아니지만 10점이 너무많아서 1점준다',
#   '1',
#   '281',
#   '130',
#   datetime.datetime(2017, 6, 2, 12, 34),
#   '관람객'],
#  ['엉짱(w76j****)',
#   '드디어 DC가 반격을 나섰다.. DCEU작품중 최고인건 말이필요없다..이제 저스티스 리그를 기다리면 되는걸까?',
#   '10',
#   '296',
#   '147',
#   datetime.datetime(2017, 5, 31, 7, 27),
#   0],
#  ['소망(dkzl****)',
#   '바쁜시간 쪼개서 영화관으로 나들이 가시는 분들. 이 영화 실 평점 4점입니다. 알고 보시면 당황스럽진 않을거에요. 청라 메가박스에서 보고 말씀드리는 겁니다. 평점 알바에 가린 진실을 알리고 싶어 말씀드리는 거니까 믿...',
#   '1',
#   '277',
#   '138',
#   datetime.datetime(2017, 6, 3, 17, 31),
#   0],
#  ['단풍(yung****)',
#   '여성 히어로는 DC 승!',
#   '9',
#   '254',
#   '120',
#   datetime.datetime(2017, 5, 31, 2, 20),
#   0],
#  ['띠로리(chm5****)',
#   '와.. 원더우먼 걸크러쉬 제대로다!!! 갤가돗은 넘나 이쁘고 ㅠㅠ',
#   '10',
#   '206',
#   '78',
#   datetime.datetime(2017, 5, 31, 11, 41),
#   '관람객'],
#  ['머스탱(p2ar****)',
#   '역시 군대 갔다온 여자의 액션연기란!!! 최고',
#   '10',
#   '237',
#   '109',
#   datetime.datetime(2017, 5, 31, 13, 59),
#   0],
#  ['Sheldon(dhk9****)',
#   '여기 다 평점 조작임?? ㄹㅇ 개 씹노잼 지루 그 자체 영화였는데여주 남주 얼굴만 좋지 스토리 ㄹㅇ 핵 망',
#   '1',
#   '208',
#   '82',
#   datetime.datetime(2017, 6, 3, 9, 38),
#   0],
#  ['제주감귤(0102****)',
#   '아 원더우먼 테마 우짤껴 진짜 음악 대박....',
#   '10',
#   '177',
#   '62',
#   datetime.datetime(2017, 5, 31, 0, 12),
#   0],
#  ['livertine sss(arro****)',
#   '야  이  워너  바보 수뇌부 들아  진작에  이걸로  세계관 구축했어야지!!',
#   '10',
#   '210',
#   '98',
#   datetime.datetime(2017, 5, 31, 0, 26),
#   0],
#  ['박재민(hyun****)',
#   '방금 보고왓는데 이런 쓰레기영화는 초딩들이 볼수준이던데 뭔 내용이 뒤죽박죽',
#   '1',
#   '220',
#   '109',
#   datetime.datetime(2017, 6, 3, 17, 26),
#   0],
#  ['똥코볼(yess****)',
#   '솔직히  사운드트랙 빼고는 별로인영화  갤가돗 비명소리 존나 이상함 그리고  dc최강자중 하나인 아레스를  존나 매력없는 수염할배로 만들어버림 ㅠㅠ 그리고 아레스 존나 먼치킨인데 원더우먼한테 개털림  그리고 유치뽕짝...',
#   '1',
#   '170',
#   '64',
#   datetime.datetime(2017, 6, 4, 12, 52),
#   0],
#  ['Taehwi Lee(gold****)',
#   '하...그리스신화 내용을 토대로  제작되었다는 말듣고 평점도 안보고 갔던 나는 바보....',
#   '1',
#   '185',
#   '86',
#   datetime.datetime(2017, 6, 4, 19, 12),
#   '관람객'],
#  ['곰수니(goms****)',
#   '끝까지 한시도 눈을 뗄 수가 없었다 ㅠㅠㅠ 진짜 DC의 희망이다!!',
#   '10',
#   '197',
#   '99',
#   datetime.datetime(2017, 5, 31, 11, 42),
#   '관람객'],
#  ['오함마준비해야쓰겄다(css9****)',
#   '갤가돗만 봐도 돈아깝지 않다 진짜 여신급 이다 스칼렛 요한슨? 꺼지라그래 코믹스의 최고의 여신은 갤가돗이다',
#   '10',
#   '233',
#   '137',
#   datetime.datetime(2017, 5, 31, 11, 46),
#   0],
#  ['라밤바(laba****)',
#   '주인공이 역경을 극복하는  히어로물답게, 빈약한 스토리 및 후반부의 엉성한 편집을 갤가돗 혼자 겁나 캐리함.',
#   '1',
#   '168',
#   '73',
#   datetime.datetime(2017, 6, 1, 12, 37),
#   0],
#  ['동입(cndg****)',
#   '대립군 알바들 1점주는거 보소ㅋㅋㅋ',
#   '10',
#   '233',
#   '139',
#   datetime.datetime(2017, 5, 31, 7, 32),
#   0],
#  ['zoon****',
#   '영화가 긴건 알았지만 중반부가 너무 지루해서 졸뻔...',
#   '7',
#   '170',
#   '78',
#   datetime.datetime(2017, 5, 31, 21, 17),
#   '관람객'],
#  ['skyi****',
#   '엉성한스토리에 한숨만 나온영화 ㅡㅡ;;',
#   '1',
#   '218',
#   '130',
#   datetime.datetime(2017, 6, 1, 21, 6),
#   '관람객'],
#  ['베네(qkrt****)',
#   '으아아악 고통뿐이다!',
#   '1',
#   '154',
#   '74',
#   datetime.datetime(2017, 6, 4, 17, 31),
#   '관람객'],
#  ['ㅇ(shin****)',
#   '태어나서 본영화중에 가장 유치하고 재미없었다3류 영화중에 3류 영화 개연성따위는 찾아볼수없을정도로 말도안되는 전개...;;; 추석특선으로 티비에서 틀어줫어도 10분보다가 채널돌렸을듯..',
#   '1',
#   '179',
#   '101',
#   datetime.datetime(2017, 6, 1, 12, 28),
#   0],
#  ['ofcl****',
#   '믿고 거르는 디씨  누가 한 말인지는 모르지만 명언으로 남을듯평점에 제대로 낚였다..또 속다니 !',
#   '1',
#   '156',
#   '83',
#   datetime.datetime(2017, 6, 1, 0, 52),
#   0],
#  ['kyeo****',
#   '예고편이 영화의 전부인거 같습니다 기대 많이 했었는데....아쉽네요 기대가 너무 컸던건지...',
#   '2',
#   '179',
#   '106',
#   datetime.datetime(2017, 6, 1, 8, 30),
#   '관람객'],
#  ['계구리(blen****)',
#   '스토리 밸런스 붕괴. DC는 영화 전체 다시 리부트하는게 빠를듯.잘가시게. 나는 다시는 영화관 가서는 안본다.거의 드레곤볼 레볼루션 수준. 에네르기 파!!!! 끝.',
#   '1',
#   '110',
#   '40',
#   datetime.datetime(2017, 6, 4, 16, 20),
#   0],
#  ['자문 자 답(just****)',
#   '왜 마블마블 하는지 알았다',
#   '1',
#   '113',
#   '43',
#   datetime.datetime(2017, 6, 4, 14, 4),
#   0],
#  ['kill****',
#   '망한집안을 첫재딸이 일으켜세우네요',
#   '9',
#   '95',
#   '27',
#   datetime.datetime(2017, 6, 1, 12, 13),
#   '관람객'],
#  ['브라질(aalo****)',
#   '지루합니다. 설명이 깁니다. 그런데 마블처럼 세련? 되게 풀어내지 못합니다. 주인공 이쁘고 잘생겼는데. 엄청지루함. 스토리 진부한게 이유. 액션신은 좋음',
#   '1',
#   '113',
#   '49',
#   datetime.datetime(2017, 6, 3, 3, 43),
#   0],
#  ['불광동식용유(matt****)',
#   '슈퍼맨보다 강하고 배트맨보다 멋있고 할리퀀보다 우아하다! 갤 가돗 그 자체가 원더우먼!!!♡',
#   '9',
#   '115',
#   '52',
#   datetime.datetime(2017, 5, 31, 4, 55),
#   0],
#  ['푸하하(hee1****)',
#   '생각지도 못한 화려한 액션',
#   '9',
#   '125',
#   '63',
#   datetime.datetime(2017, 5, 31, 12, 49),
#   '관람객'],
#  ['뻥튀기(http****)',
#   '진짜 개재미없고 처음에 지루해서 자고 중간에 깨서 마지막에 또 잤다 저기 위에 좋은 글들 다 알바니깐 믿지마세여',
#   '1',
#   '117',
#   '60',
#   datetime.datetime(2017, 6, 1, 22, 29),
#   0],
#  ['이준서(de08****)',
#   '왠만해선 잘 안다는데....역대급 망작임 평점8절대 이해안가고 스토리엉망에 하나같이 유치했음..;;',
#   '1',
#   '103',
#   '51',
#   datetime.datetime(2017, 6, 4, 2, 56),
#   0],
#  ['게롤트(mans****)',
#   '솔직히 원더우먼 졸!예! 보는 내내 설랜다...내용도 재미있다.. 액션씬이 뭔가 호쾌해...',
#   '10',
#   '101',
#   '50',
#   datetime.datetime(2017, 5, 31, 6, 5),
#   0],
#  ['wite****',
#   '이제야 dc가제대로 만든듯!',
#   '9',
#   '110',
#   '60',
#   datetime.datetime(2017, 5, 31, 16, 10),
#   '관람객'],
#  ['kbs4****',
#   '아르바이트생들, 무지 애쓰네요 보면 압니다 말이 필요없음ㅠㅠ',
#   '1',
#   '108',
#   '59',
#   datetime.datetime(2017, 6, 1, 12, 45),
#   0],
#  ['김미화(next****)',
#   '알바생들 정말 많은가봄. 절대 9점 이상영화 아니고여. 압쪽에 9~10점 다 깔아두고 엄청 기대하고 봣는데  정말 유치뽕짝임. 예고편에만 멋있는 그럴듯한 액션신이고 중간은 여주몸매 팔이에만 힘주고 ~종반엔  파워레인...',
#   '1',
#   '113',
#   '64',
#   datetime.datetime(2017, 5, 31, 17, 52),
#   0],
#  ['무비 헤븐(sher****)',
#   '그동안 초록등불 박쥐대외계인 자살특공대가 길을 많이 닦아줘서 망할 수가 없었다.',
#   '10',
#   '79',
#   '31',
#   datetime.datetime(2017, 5, 31, 7, 33),
#   0],
#  ['삼청태현넥(nexn****)',
#   '지금 평점단사람들 본거 맞음???',
#   '10',
#   '83',
#   '35',
#   datetime.datetime(2017, 5, 31, 7, 59),
#   0],
#  ['푸른나비(butt****)',
#   '최악..너무 지루함 그리고 댓글 알바들 너무 많네',
#   '1',
#   '94',
#   '46',
#   datetime.datetime(2017, 6, 4, 12, 46),
#   0],
#  ['kuje****',
#   '갤 가돗이랑 크리스 파인 너무 좋다…',
#   '10',
#   '63',
#   '16',
#   datetime.datetime(2017, 5, 31, 14, 26),
#   0],
#  ['V6 BEARS(care****)',
#   '평점 진심인가?여주 이쁜거 말고는 영화관에서 보기는 돈아까움 4점주려했지만 평점이 말도안되게 높은거 같아 1점줍니다.',
#   '1',
#   '74',
#   '29',
#   datetime.datetime(2017, 6, 4, 14, 43),
#   0],
#  ['주비(wowo****)',
#   '원더우먼 히어로중 최고다!!!',
#   '10',
#   '95',
#   '50',
#   datetime.datetime(2017, 5, 31, 4, 5),
#   0],
#  ['이코(leni****)',
#   '다크나이트를 이을 DC의 강력한 어퍼컷.',
#   '10',
#   '152',
#   '107',
#   datetime.datetime(2017, 5, 31, 1, 24),
#   0],
#  ['블루(free****)',
#   '현실적으로 말씀드리겠습니다. 많이 기다려온 입장에서 충분히 재미있습니다. (일반 캐릭터나 원작부분을떠나서라도 재미를 느낄수있습니다.) Dc의 재미는 원더우먼을 기점으로 만족할만큼 잘살릴것같고 져스티스리그를 얼마나 재...',
#   '9',
#   '78',
#   '34',
#   datetime.datetime(2017, 5, 31, 16, 16),
#   0],
#  ['강정호(eins****)',
#   '지금 원더우먼 로튼토마토 97% ㅋㅋㅋㅋ 다크나이트 넘었네 ㅋㅋ 잭스나이더 당장하차하고 이감독이 DC작품 계속하자... 느금마사 같은 대참사는 안나올꺼다.. 잭스나이더 저스티스리그도 예고보니 망이더만 ㅋㅋㅋ',
#   '10',
#   '103',
#   '59',
#   datetime.datetime(2017, 5, 31, 8, 56),
#   0],
#  ['youn****',
#   '해외 평 좋길래 기대하고 있었는데 시사회로 미리 보고 왔습니다 보고 나니까 왜 해외 평이 좋았는지 알 것 같더라구요 오랜만에 보는 히어로물이기도 했는데 그게 원더우먼 단독 영화라 더 좋았던거 같습니다',
#   '10',
#   '65',
#   '23',
#   datetime.datetime(2017, 5, 31, 14, 25),
#   0],
#  ['미스터Y(sadf****)',
#   '할리퀸이랑 원더우먼 둘이 나오면 씹꿀잼일듯 ㅇㅈ?',
#   '10',
#   '138',
#   '97',
#   datetime.datetime(2017, 5, 31, 1, 22),
#   0],
#  ['주응가(sera****)',
#   '갤가돗 겁나 멋짐ㄷㄷ...',
#   '10',
#   '51',
#   '11',
#   datetime.datetime(2017, 5, 31, 16, 56),
#   0],
#  ['조은이(212e****)',
#   '액션장면에서의 영상미는 진짜.... 계속 감탄하면서 봤네요',
#   '10',
#   '65',
#   '25',
#   datetime.datetime(2017, 5, 31, 15, 4),
#   '관람객'],
#  ['leonel(7joo****)',
#   'DC의 제대로 된 반격이 시작됬다',
#   '10',
#   '92',
#   '52',
#   datetime.datetime(2017, 5, 31, 3, 37),
#   0],
#  ['시작(sang****)',
#   '진심 최악  대사 개유치  초딩영화를 만들어났노  지리긴 뭘지려 눈이 지리하다  돈들여서 쓰레기를 만들었네  댓글 평점 알바쓰나  정말  앉아있는게 고역  뭔놈의 아레스를  그리찾노',
#   '1',
#   '68',
#   '29',
#   datetime.datetime(2017, 6, 4, 13, 50),
#   0],
#  ['신슝(shin****)',
#   '이 영화 본 사람들은 제대로 본 건지 영화 수준이 이해가 안 감. DC는 다음부터 믿고 걸러도 될듯. 이게 DC 최고의 영화면 이걸로 DC 영화 다 본듯. 지루함과 졸림의 싸움',
#   '1',
#   '107',
#   '68',
#   datetime.datetime(2017, 5, 31, 20, 59),
#   0],
#  ['아싸02(mini****)',
#   '저는 별로네요 지루했어요',
#   '5',
#   '58',
#   '22',
#   datetime.datetime(2017, 6, 3, 9, 12),
#   '관람객'],
#  ['더블류지(wjdw****)',
#   '마케팅의 거짓말 처음영화 나왔을때 평점 9점이 넘었고 감상평도 DC가 해냈다. 등등 찬양글이 쏟아져서 봤는데 DC가 알바를 풀었다고 밖에 생각이 안나는 지루하고 유치하고 재미없는 영화였다.',
#   '1',
#   '61',
#   '25',
#   datetime.datetime(2017, 6, 3, 9, 53),
#   0],
#  ['ktgn****',
#   '마,  진작에 이런거 만들었으면 으잉, 욕도 안먹었고 좋았잖아!!',
#   '10',
#   '70',
#   '34',
#   datetime.datetime(2017, 5, 31, 11, 0),
#   0],
#  ['광나루(okyi****)',
#   '나만 당할 수 없다. 진심 재미있음',
#   '10',
#   '42',
#   '7',
#   datetime.datetime(2017, 6, 1, 22, 45),
#   0],
#  ['닥터제이(numb****)',
#   '맨옵스틸,배대슈와 비교하는 사람들한테 묻고싶다. 원더우먼서 뭘 건진거죠 도대체? 전 두작품은 난해한 스토리와 전개 대신 초인적인 cg와 액션이라도 보여줬지, 원더우먼은 90분이면 끝날 것 영화 150분이나 끌어먹고 ...',
#   '4',
#   '73',
#   '38',
#   datetime.datetime(2017, 6, 1, 16, 27),
#   0],
#  ['머어쩌라고(jsp6****)',
#   '하 원더우먼 제발 저스티스도 이정도만 좀 해주길',
#   '10',
#   '49',
#   '15',
#   datetime.datetime(2017, 5, 31, 14, 11),
#   0],
#  ['넥타이맨(mmx6****)',
#   '원더우먼 정말 몰입도 진심 트랜스포머 처음나왔을때 두근거림',
#   '10',
#   '65',
#   '32',
#   datetime.datetime(2017, 5, 31, 8, 21),
#   0],
#  ['한국광(jeff****)',
#   '마블을 향한 DC의 작지만 강했던 반격. DC의 희망을 볼 수 있었던 영화였다.',
#   '10',
#   '83',
#   '50',
#   datetime.datetime(2017, 5, 31, 0, 1),
#   0],
#  ['tkar****',
#   '거짓말이 아니라 대사가 너무 유치하고 처음부터 너무 지루합니다 정말 시간과 돈이 많으신분들에게만 추천해 드립니다 위에 재밌다고 하시는분들 말 믿지마세요 저도 유투버의 추천으로 봤다가 지옥을 봤네요;;;',
#   '1',
#   '51',
#   '19',
#   datetime.datetime(2017, 6, 4, 20, 35),
#   0],
#  ['각(hsjm****)',
#   '시간 아깝다 ...  눈베림',
#   '1',
#   '45',
#   '14',
#   datetime.datetime(2017, 6, 4, 18, 40),
#   0],
#  ['이상대(mylo****)',
#   '처음으로 평점 남겨보아요~2시간 잘자다가 나왔어요~돈이 아까워서 중간에 나가지는 않았지만초등학교 자녀분 있으시면 보시는거 추천합니다~!5세~13세 까지 아주 좋아할만한 영화네요',
#   '1',
#   '51',
#   '20',
#   datetime.datetime(2017, 6, 4, 13, 21),
#   0],
#  ['요술공주영구(fofo****)',
#   '하.. 손가락으로 벽타고올라갈때부터 어이없고 졸림.',
#   '1',
#   '55',
#   '24',
#   datetime.datetime(2017, 6, 4, 14, 52),
#   0],
#  ['상처(xena****)',
#   '남자 둘이 망쳐 놓은거 원더우먼이 살렸네요 ^^재미있습니다',
#   '10',
#   '51',
#   '21',
#   datetime.datetime(2017, 5, 31, 14, 16),
#   0],
#  ['하얀구름(hjcg****)',
#   '원더우먼 전쟁에 혼자 나설 때 진짜 감탄하면서 봤다영화도 영화지만 비주얼이 대박!! 자막도 디씨스럽지않아 좋았음',
#   '9',
#   '52',
#   '22',
#   datetime.datetime(2017, 5, 31, 23, 11),
#   '관람객'],
#  ['까망수달(mibj****)',
#   '갤가돗만으로도 충분한 영화~ 악의 축이 좀 빈약한듯 보이지만 퍼스트어벤져식으로 원더우먼의 시작으로는 나쁘지 않음. 액션씬이 그리많지 않았음에도 드라마가 지루하지 않았음.',
#   '9',
#   '43',
#   '15',
#   datetime.datetime(2017, 6, 1, 9, 55),
#   '관람객'],
#  ['로스트리프(qpwo****)',
#   '영화장면장면이 따로노는느낌 배우들 연기도 못하고 바보가 영화찍은거같다 평점알바에 속아서 영화관내에서 같이보러간 부모님에게 이영화엄청재밌데 엄청재밌다던데?? 이랫던 내가 영화끝나니 부모님께 민망해서 집에오는내내 감독욕...',
#   '1',
#   '57',
#   '29',
#   datetime.datetime(2017, 5, 31, 23, 49),
#   0],
#  ['도깨비(dkff****)',
#   '스토리엉망개연성 없음남친이랑 둘이 보러갔다가둘다잠역시 마블이짱인듯',
#   '1',
#   '42',
#   '15',
#   datetime.datetime(2017, 6, 4, 18, 13),
#   0],
#  ['돛무(jeeh****)',
#   '별 1개도 아깝다 OOO기영화 스토리는 뭔 그물망 마냥 구멍투성이 뜬금없고 원더우먼 중2병걸린 미친x마냥 감정기복 왓다갓다하는거 어이업음 앞으로 디씨영화는 믿고거른다',
#   '1',
#   '43',
#   '16',
#   datetime.datetime(2017, 6, 4, 20, 33),
#   0],
#  ['하루하루(smir****)',
#   '핵지루함. 매력없는 조연들.. 잠옴',
#   '1',
#   '43',
#   '16',
#   datetime.datetime(2017, 6, 4, 2, 57),
#   0],
#  ['다솜이(best****)',
#   '파워레인저 보는 느낌 초반은 볼만했으나 끝으로 가서는 폭망이네',
#   '1',
#   '44',
#   '17',
#   datetime.datetime(2017, 6, 4, 14, 53),
#   0],
#  ['gjtwnvjdm(kaka****)',
#   '댓글 알바 풀었나? 난 되게 재밌게 봤는데 ㅋㅋ ㄷㄹㄱ이 왜 이거보다 평점이 높음?',
#   '10',
#   '49',
#   '22',
#   datetime.datetime(2017, 6, 1, 7, 55),
#   0],
#  ['프롬(koo1****)',
#   '기대하고 갔다가 실망. 스토리 너무 약하다. 아 저학년 만화도 아니고 완전실망. 대화내용이 초딩1학년 수준.  고추(?)이야기나, 정의, 사랑 뭐 좋은 단어 주워와서 대사를 만들었으나 감동없이 짜증만. 신은경 주연의...',
#   '1',
#   '42',
#   '16',
#   datetime.datetime(2017, 6, 4, 7, 57),
#   0],
#  ['플럼(cona****)',
#   '취향차이인가.. 영화관에서 봤는데 진짜 핵노잼',
#   '1',
#   '32',
#   '7',
#   datetime.datetime(2017, 6, 17, 14, 59),
#   0],
#  ['구름다리(xman****)',
#   '갤 가돗은 마치 원더우먼을 위해 태어난것 처럼 캐릭터와 하나됨을 느낀다. 원더우먼이 등장하는 장면 장면이 마치 CF처럼 화면을 꽉꽉채운다. 영화의 전반적인 스토리는 약간 미흡할지라도...원더우먼(갤 가돗)이 꽉꽉채운...',
#   '10',
#   '33',
#   '8',
#   datetime.datetime(2017, 5, 31, 21, 26),
#   0],
#  ['구름(llaw****)',
#   '여주 히어로물중에 이렇게 흥한건 없을듯',
#   '10',
#   '45',
#   '20',
#   datetime.datetime(2017, 5, 31, 22, 53),
#   '관람객'],
#  ['larc****',
#   '평점이 너무 높습니다스토리 최악이고 개연성 제로에 원더우먼은 고구마 백개는 먹은듯',
#   '1',
#   '31',
#   '7',
#   datetime.datetime(2017, 6, 18, 15, 53),
#   0],
#  ['TIQ1321(3dfx****)',
#   '정말 재미 없음 극장에서 잠',
#   '1',
#   '36',
#   '12',
#   datetime.datetime(2017, 6, 4, 18, 22),
#   0],
#  ['러스(ghks****)',
#   '세일러문 보는 줄 ....',
#   '1',
#   '42',
#   '18',
#   datetime.datetime(2017, 6, 4, 3, 23),
#   0],
#  ['life****',
#   '보지마세요 후회합니다 차라리 치킨을 사드세요',
#   '1',
#   '32',
#   '9',
#   datetime.datetime(2017, 6, 17, 23, 18),
#   0],
#  ['마셔너리(kang****)',
#   'DC의 시작은 원더우먼으로 했어야 했다. 이제라도 깨우쳤으니 다행.',
#   '9',
#   '47',
#   '24',
#   datetime.datetime(2017, 5, 31, 8, 20),
#   0],
#  ['jkp0****',
#   '액션이 뛰어나지도 스토리가 탄탄하지도 않아 지루했음',
#   '1',
#   '32',
#   '10',
#   datetime.datetime(2017, 6, 6, 13, 26),
#   0],
#  ['Jordan(airs****)',
#   '와 베스트 댓글 요실금 환잔가? 뭐가 지린다는겨..핵노잼',
#   '1',
#   '37',
#   '15',
#   datetime.datetime(2017, 6, 4, 17, 25),
#   0],
#  ['폭염술(kjbs****)',
#   '시간가는줄 모르고 재밌게 봤어요 후반부 액션짱',
#   '10',
#   '48',
#   '26',
#   datetime.datetime(2017, 5, 31, 22, 18),
#   '관람객'],
#  ['NeverGoBack(ljs8****)',
#   '감독님 감사합니다 DC를 살리셧습니다 이제 저스티스리그 만 잘되면 좋겟다',
#   '10',
#   '53',
#   '31',
#   datetime.datetime(2017, 5, 31, 5, 32),
#   0],
#  ['pieces(piec****)',
#   '그지같은 시간이 아깝다 아오',
#   '1',
#   '35',
#   '14',
#   datetime.datetime(2017, 6, 4, 3, 29),
#   0],
#  ['클라클라(john****)',
#   '내용 진짜 유치하고 허접하고 ㅋㅋ 여주 걸크인거 빼곤 볼것도 없음 ㅋㅋㅋ 너무실망이다 ㅠㅜ 게임 인저스티스2 시네마틱 영상 2시간짜리가 더 재밌음 ㅋㅋㅋㅋ 디시 마블 따라오려면 멀었다 아직 ㅠㅜ',
#   '1',
#   '39',
#   '18',
#   datetime.datetime(2017, 6, 4, 12, 34),
#   0],
#  ['JD(alle****)',
#   '이야;; 원더우먼 진짜 dc의 역작이다.. 내 기준으론 히어로 무비로써는 다크나이트를 훨씬 뛰어넘었다.. 다크나이트 트릴로지가 보여주지 못했던 히어로적인 면들을 원더우먼이 채워줬다..',
#   '10',
#   '75',
#   '54',
#   datetime.datetime(2017, 5, 31, 1, 17),
#   0],
#  ['디오드(nsgt****)',
#   '망작알바들 다 뒤졌으면.',
#   '1',
#   '25',
#   '5',
#   datetime.datetime(2017, 6, 16, 13, 42),
#   0],
#  ['duddngg(vmlf****)',
#   '보는 재미는 있었지만 소름 돋게 유치했음',
#   '1',
#   '26',
#   '6',
#   datetime.datetime(2017, 6, 17, 20, 20),
#   0],
#  ['우리형(bban****)',
#   '이건 뭐 할 말이 없다. 만약 이게 한국 영화였으면 개까였을텐데 외국영화라고 그래도 빠는 사람이 있긴 하구나',
#   '1',
#   '33',
#   '13',
#   datetime.datetime(2017, 6, 4, 3, 30),
#   0],
#  ['끄앙(redc****)',
#   '너무재미없더라 정말....',
#   '1',
#   '34',
#   '14',
#   datetime.datetime(2017, 6, 4, 20, 4),
#   0],
#  ['gian****',
#   '와 이번에 디씨 신경좀 썼네 이런 영화는 아이맥스 추천~',
#   '10',
#   '34',
#   '14',
#   datetime.datetime(2017, 5, 31, 13, 50),
#   0],
#  ['첫눈(kmin****)',
#   '원더우먼 대박이다 갤가돗 왤케 멋있고 섹시하냐',
#   '10',
#   '37',
#   '17',
#   datetime.datetime(2017, 6, 1, 9, 44),
#   '관람객'],
#  ['긍정적아이디(damn****)',
#   '그냥 여배우 얼굴보는 영화임. 스토리 개연성도 엉망이고 액션조차 최악임. 심지어 후반에는 아예 방패조차 없이 맨손으로 싸움',
#   '1',
#   '27',
#   '8',
#   datetime.datetime(2017, 6, 7, 5, 5),
#   0],
#  ['묵묵묵(sunm****)',
#   '0점 주려고 로그인했는데 왜 1점밖에 못주냐....',
#   '1',
#   '29',
#   '10',
#   datetime.datetime(2017, 6, 4, 17, 38),
#   0],
#  ['까칠한민이(blue****)',
#   '진짜 역대 히어로물중에 이렇게 재미없고 초딩같은 영화는 다시는 안나올듯ㅋㅋ댓글 알바들 진짜 쩌네ㅡㅡ',
#   '1',
#   '29',
#   '10',
#   datetime.datetime(2017, 6, 4, 15, 56),
#   0],
#  ['중고나라(enfn****)',
#   '댓글 알바에 속지 마시길...',
#   '1',
#   '29',
#   '10',
#   datetime.datetime(2017, 6, 4, 3, 1),
#   0],
#  ['NONAME(leeu****)',
#   "주인공 너무 멋지네요 ~  '어린이 영화' 인줄 모르고 봤는데,, 어린이 영화 치고는 퀄리티가 높네요 ~ 6세 정도가 관람하기에 딱 좋은 영화 같습니다",
#   '1',
#   '31',
#   '12',
#   datetime.datetime(2017, 6, 3, 23, 56),
#   0],
#  ['theb****',
#   'DC의 멸망을 알리는 신호탄 이 영화를 보고 암이 나았습니다',
#   '1',
#   '32',
#   '13',
#   datetime.datetime(2017, 6, 4, 17, 10),
#   0],
#  ['vvvi****',
#   '개재미없네 빡친다 민강산이보자했다',
#   '1',
#   '20',
#   '2',
#   datetime.datetime(2017, 6, 17, 2, 27),
#   0],
#  ['박동환(ghks****)',
#   '다른댓글 무시하고 내말만믿어 절대보지마 제발 ㅠ',
#   '1',
#   '23',
#   '5',
#   datetime.datetime(2017, 6, 17, 20, 35),
#   0],
#  ['김현우(zizi****)',
#   '원더우먼이 매력적이라는 점 외엔 남는 게 없는 영화.원더우먼 자체가 현실적이지 않더라도 스토리 구성이 너무 비현실적.',
#   '1',
#   '26',
#   '8',
#   datetime.datetime(2017, 6, 6, 7, 6),
#   0],
#  ['씨아이(hell****)',
#   '진심 본사람만 댓글단건가..? 아님 초반만 본건가..?초반은 재밌는데 중반은 그저그렇고 후반엔 CG너무 티나는데다 이펙만 난무하고 스토리 없이 어떻게든 시간 맞출려고 질질 끌려하는 느낌.. 진짜 재미없어서 사람구경하...',
#   '1',
#   '26',
#   '8',
#   datetime.datetime(2017, 6, 4, 19, 44),
#   0],
#  ['함수함미(kiim****)',
#   '유대인 우월주의자 갤가돗. 가자지구 백린탄 무차별폭격 지지하는 인간',
#   '1',
#   '27',
#   '9',
#   datetime.datetime(2017, 6, 4, 13, 19),
#   0],
#  ['놀이동산(emma****)',
#   '미친 알바색기들이냐 도대체 이게 왜 잘만들고 재밋다는거냐 아..',
#   '1',
#   '28',
#   '10',
#   datetime.datetime(2017, 6, 4, 8, 27),
#   0],
#  ['박성부(sb08****)',
#   '별한개주는것마저 아까워죽겟다 내가 여태 본 히어로몰중에서 제일 지루한 영화 베스트3안에 꼽히는 영화인거같다왠만하면 글 잘안쓰는데... 스토리가 너무 루즈하기 그지없다보는 동안에 내가 이걸 돈내면서 보는게 아까워서 억...',
#   '1',
#   '21',
#   '4',
#   datetime.datetime(2017, 6, 22, 7, 56),
#   0],
#  ['songjimin(song****)',
#   '별로입니다 기대를 저버리지 않는 디씨',
#   '1',
#   '21',
#   '4',
#   datetime.datetime(2017, 6, 18, 17, 12),
#   0],
#  ['마니주(rlag****)',
#   '솔직히 말해서 별점 1도 아까움 ㅋㅋㅋ 진짜 영화보면서 돈아깝기는 난생처음이었음  대체 이게 왜 평점이 높은거임?? 이햐할수가 없네 내용만 질질끌고 영화 보다가 졸았음 진짜 개재미없음 보지마세요 차라리다운받아 보시길...',
#   '1',
#   '21',
#   '4',
#   datetime.datetime(2017, 6, 18, 0, 14),
#   0],
#  ['싸나이(1739****)',
#   '나만 재미없나...',
#   '1',
#   '21',
#   '4',
#   datetime.datetime(2017, 6, 6, 11, 0),
#   0],
#  ['그르누이(alej****)',
#   '갤가돗 정말 예쁘다..스토리는 캡아가 떠오르긴하지만 볼만했다',
#   '8',
#   '23',
#   '6',
#   datetime.datetime(2017, 5, 31, 22, 26),
#   '관람객'],
#  ['파프리카(skyj****)',
#   '지린다는 놈들은 도대체 뭐가 지린다는거냐?? 조연들 개성 하나도 못살리고 원더우먼 혼자 다하드만...진짜 유치 찬란한 영화...평점에 속았다.',
#   '1',
#   '24',
#   '7',
#   datetime.datetime(2017, 6, 19, 6, 57),
#   0],
#  ['피글렛(panc****)',
#   '스토리도 탄탄하지 못하고 원더우먼을 제외한 캐릭터들도 별로고 연출은 촌스럽고 지루합니다. 1점 짜리 영화는 아니지만 알바들이 10점을 퍼부어서 평점을 낮추기 위해 1점 줍니다 평점 6점대에 있어야 할만한 영화에요',
#   '1',
#   '25',
#   '8',
#   datetime.datetime(2017, 6, 26, 13, 2),
#   '관람객'],
#  ['hschoi(rame****)',
#   '원더우먼 = 갤 가돗. 이걸로 모든 게 정리됨.',
#   '10',
#   '28',
#   '11',
#   datetime.datetime(2017, 6, 2, 10, 12),
#   '관람객'],
#  ['헤르(jesu****)',
#   '히어로무비가 줄 수 있는 재미와 볼거리 종합 선물세트네요 갤 가돗 새로운 얼굴의 발견. 크리스 파인도 완전 귀엽~! ㅋㅋㅋ',
#   '10',
#   '28',
#   '11',
#   datetime.datetime(2017, 6, 1, 8, 39),
#   '관람객'],
#  ['김말자(jiho****)',
#   '퀸동님ㅠㅠ 저스티스리그2는 감독님이 맡아주세요ㅠ',
#   '10',
#   '29',
#   '12',
#   datetime.datetime(2017, 5, 31, 16, 13),
#   0],
#  ['봉봉쥬스(yull****)',
#   '더이상 새로울 것 없어보였던 하어로 영화. 원더우먼이 등장했다!! 갤 가돗.. 넘나 매력적인 배우 ㅠㅠ',
#   '10',
#   '30',
#   '13',
#   datetime.datetime(2017, 6, 1, 8, 33),
#   '관람객'],
#  ['언그니(mani****)',
#   '다이애나가 이영화 살려냄',
#   '10',
#   '30',
#   '13',
#   datetime.datetime(2017, 5, 31, 15, 14),
#   '관람객'],
#  ['좋은 날들(lasd****)',
#   'dc라 기대 안하고 갔다.. 영상 스케일은 좀 부족했지만.. 개인적으로는 추억 더듬기만으로도 즐거웠다..여성 히어로라 신선..예뻤다..가상과 현실을 엮은 점..스토리..메세지..사랑까지...좋았다..갤가돗 캐스팅은 ...',
#   '7',
#   '34',
#   '17',
#   datetime.datetime(2017, 6, 1, 3, 35),
#   '관람객'],
#  ['skfl****',
#   '최종보스가 고작 콧수염 할배였다니..전쟁,액션,로맨틱 장르는 절대아니다. 구지 고르자면 드라마쪽에 가깝다.액션이라고는 찾아볼수가없다. 모니터로 봤다면 → 연타했을것이다. 갤가돗땜에 1점은 준다.',
#   '1',
#   '38',
#   '21',
#   datetime.datetime(2017, 6, 5, 23, 57),
#   '관람객'],
#  ['여우꼬랑지(cyan****)',
#   'DC히어로들의 역습~~~여신이 따로없군~~',
#   '10',
#   '28',
#   '12',
#   datetime.datetime(2017, 6, 1, 0, 3),
#   '관람객'],
#  ['바른 시민(k2an****)',
#   '차별하는건 반대지만 이세상 질서를 어지럽히는데 탁월한 지능이 있는 이스라엘출신이 정의를 연기한다는게 참 꼴상사나움',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2017, 6, 15, 13, 14),
#   0],
#  ['stor****',
#   '에라이...이것도 영화라고...댓글 알바풀었나...ㅋㅋㅋㅋ 영화본 시간이 아깝다. 1점도 아까운데 0점이 없어서 1점준다.',
#   '1',
#   '19',
#   '4',
#   datetime.datetime(2017, 6, 16, 23, 48),
#   0],
#  ['국민거품최형우(nice****)',
#   'Dc에서 가장쎈 슈퍼맨보다 더쎈 원더우먼 과연 신의 딸',
#   '10',
#   '20',
#   '5',
#   datetime.datetime(2017, 5, 31, 14, 33),
#   0],
#  ['갱신(pus3****)',
#   '처음에 한시간 보다자고 일어나서 마지막 10분 봤는데 아무지장 없더라',
#   '5',
#   '22',
#   '7',
#   datetime.datetime(2017, 6, 1, 11, 45),
#   0],
#  ['슈슈(elfi****)',
#   '이런 영화가 왜 평점이 높은지스토리가 재미없음',
#   '1',
#   '24',
#   '9',
#   datetime.datetime(2017, 6, 4, 18, 59),
#   0],
#  ['유역비(leem****)',
#   '오늘 대립군도 봤다. 쓰레기보고 난뒤라 더 높은평점을 주는듯 하다. 액션은 돈으로 만든다는것을 다시금 깨달았다.dc는 여성 히어로물만 만들어야 한다고 다시금 생각했다. 할리퀸에 이어 꽤나 매력적인 캐릭터가 탄생했다....',
#   '8',
#   '17',
#   '3',
#   datetime.datetime(2017, 5, 31, 21, 53),
#   0],
#  ['KATO(ddae****)',
#   '스토리 정리도 안되고 잠만오드라 평점 작업아님?',
#   '1',
#   '18',
#   '4',
#   datetime.datetime(2017, 6, 16, 23, 56),
#   0],
#  ['쉰(shui****)',
#   '수뤠기..속았다..진부하고 유치한..돈도 시간도 아까웠다.평론가님들..이게 어떻게 악녀보다 평이 좋지?',
#   '1',
#   '19',
#   '5',
#   datetime.datetime(2017, 6, 16, 3, 19),
#   0],
#  ['가을(nice****)',
#   '재밌어요 추억돗네요~^^*',
#   '10',
#   '19',
#   '5',
#   datetime.datetime(2017, 6, 2, 3, 36),
#   '관람객'],
#  ['aghs****',
#   '초,중반은 흥미있고 재미있었지만 중반이후 너무 재미가없었어요....',
#   '1',
#   '20',
#   '6',
#   datetime.datetime(2017, 6, 12, 10, 32),
#   '관람객'],
#  ['투산(novi****)',
#   '히어로 영화라도 싸우는 장면만 가득해선 안 된다는 것을 보여준 좋은 영화다. 인간의 본질적 문제나 그에 대한 고민이 담긴 이 영화는 확실히 미래의 히어로 영화가 지향해야 할 것이 무엇인지를 배트맨 시리즈처럼 보여준 ...',
#   '10',
#   '20',
#   '6',
#   datetime.datetime(2017, 5, 31, 19, 0),
#   0],
#  ['YaseGi(lims****)',
#   '로튼 믿었는데 OOO드르.. OO 내 1만1천원...PTSD걸린 저격수는 왜 나온거냐? 매력넘치던 인물들은콧수염 아저씨 장남감으로 전락.. 정작 아레스는 똥폼만 잡다 삐까츄행 ㅎㅎ.. 12세 이상이 아니라 12세 전...',
#   '1',
#   '23',
#   '9',
#   datetime.datetime(2017, 6, 4, 19, 31),
#   0],
#  ['surfkim(mis1****)',
#   '최근 본 영화중 최악이였네요..돈 아까워라ㅠ',
#   '1',
#   '27',
#   '13',
#   datetime.datetime(2017, 6, 1, 16, 7),
#   0],
#  ['행복바이러스보균자(psk2****)',
#   '원더우먼이 DC를 살렸다!! 소리질러!!',
#   '10',
#   '30',
#   '16',
#   datetime.datetime(2017, 5, 31, 12, 31),
#   0],
#  ['pol7846(pol0****)',
#   'DC 원더우먼을 시작으로 꽃길만 걷자ㅜㅜ',
#   '10',
#   '39',
#   '25',
#   datetime.datetime(2017, 5, 31, 0, 20),
#   0],
#  ['지콕(wltj****)',
#   '이런 정신병자같은 영화 처음봄',
#   '1',
#   '15',
#   '2',
#   datetime.datetime(2017, 6, 17, 14, 18),
#   0],
#  ['92_514(hyeo****)',
#   '역시 최고의 여성히어로라는 점은 변함이 없었고,보는 내내 눈에는 놀라움만, 몸에는 소름만 돋았다.',
#   '10',
#   '15',
#   '2',
#   datetime.datetime(2017, 6, 1, 6, 58),
#   0],
#  ['정경빈(bin1****)',
#   'DC가 드디어 해냈다라는 글 봤는데 DC가 드디어 해내긴했다. 최악의 히어로 영화를..스토리, 연출, 연기력, 액션, cg 전부 최악 그 중에서도 슬로우 모션들은 정말 소름끼칠 정도..1990년도 영화만도 못 함',
#   '1',
#   '16',
#   '3',
#   datetime.datetime(2017, 6, 21, 3, 18),
#   0],
#  ['솔복(solv****)',
#   '글쎄요.. 히어로물을 좋아하는 제게도 원더우먼은 너무나도 지루한 영화였네요. DC가 뭔가 급하게 만든듯한 느낌마져 드네요',
#   '1',
#   '16',
#   '3',
#   datetime.datetime(2017, 6, 15, 22, 41),
#   0],
#  ['daju****',
#   '마지막에 아레스랑 주고받는대사 진짜...파워레인저 대산줄... 유치해서 오그라들어서 못보겠더라...',
#   '1',
#   '16',
#   '3',
#   datetime.datetime(2017, 6, 15, 14, 44),
#   0],
#  ['서창식(scs2****)',
#   '전반적인 평이 좋았고, 짜디 짠 평론가 박평식이 6점을 줬기에 나름 큰 기대를 하고 보았는데, 역시 기대가 크면 실망이 크다랄까.. 액션, 캐스팅 이런 것은 나무랄 때가 없지만 중간중간 루즈한 타임이 있어 재밌었지만...',
#   '1',
#   '18',
#   '5',
#   datetime.datetime(2017, 6, 18, 13, 8),
#   '관람객'],
#  ['llmentorll(bers****)',
#   '믿음이다. 선한 사람도 있기때문에.',
#   '8',
#   '18',
#   '5',
#   datetime.datetime(2017, 6, 1, 3, 31),
#   '관람객'],
#  ['블로D(ethe****)',
#   '영화 시작한지 한시간 지났는데 도대체 내가 뭘보고 있는지도 모르겠다. 고등학교 영화감상부 졸업작품이냐? 내셔널 지오그래피 코알라편 보는게 더 재밌겠다...환장하겠다 진짜 dc...왜 이러냐 진짜...일어날란다 아오씨...',
#   '1',
#   '19',
#   '6',
#   datetime.datetime(2017, 6, 5, 21, 54),
#   0],
#  ['한혜원(jhlo****)',
#   '원더우먼 꼭 보세요 꼭!! 같은 여자가 봐도 갤 가돗 너무 이쁘고 걸크러쉬 쩔어요ㅠㅠㅠㅠ 특히 머리 풀고 슈트(?) 입을 때가 너무 이뻤어... 많은 총알도 튕겨내는 장면 진짜 쩔었고... 스포 아니고 예고편에도 나...',
#   '10',
#   '21',
#   '8',
#   datetime.datetime(2017, 6, 1, 2, 25),
#   0],
#  ['신감자(gris****)',
#   '마블영화를 아이언맨1이 되살렸다면 DC는 원더우먼이 되살렸음',
#   '9',
#   '21',
#   '8',
#   datetime.datetime(2017, 5, 31, 15, 46),
#   0],
#  ['커피한잔할래(shiv****)',
#   '... 장난하나 평점... 안나왔어야될 영화구만 무슨  미국히어로물이 대체적으로 재미가 없지만 이것도 그중 하나내',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2017, 6, 15, 20, 23),
#   0],
#  ['cont****',
#   '아무리 히어로 물이지만 스토리 진행 개연성 등에 현실감이 너무 떨어져서 유치하게 느껴지고 액션도 기대보다 별로고 전체적으로 좀 몬가 아쉬웠는데 나만 그렇게 생각한건가 평이 너무 좋네..',
#   '1',
#   '15',
#   '3',
#   datetime.datetime(2017, 6, 20, 6, 45),
#   0],
#  ['popo(pung****)',
#   '존잼 완잼 ㅠ 하 원더우먼이 dc를 살렸네',
#   '10',
#   '16',
#   '4',
#   datetime.datetime(2017, 6, 1, 9, 38),
#   '관람객'],
#  ['popopopopopo(pape****)',
#   '최근개봉작중 제일 괜찮네요',
#   '10',
#   '18',
#   '6',
#   datetime.datetime(2017, 6, 1, 1, 18),
#   0],
#  ['gkvklcvjlxc(chok****)',
#   '이거 댓글알바조지네 진짜로 구라안치고 방금전에본사람인데 보지말길 더럽게재미없으니',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 6, 5, 21, 19),
#   0],
#  ['오뚜기칼에(hidr****)',
#   '항상 느꼈던 거지만 다시 또 느낀다. dc영화는 걍 집에서 스킵하면서 보는게 최고다... 슈퍼맨 배트맨에 비해 스케일이 너무 작고 유치하다. 서론이 너무 긴데 그것조차 흥미없게 만든다. 액션도 허접하다. 다만 원더우...',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 6, 4, 10, 8),
#   0],
#  ['테리옹(dhwn****)',
#   '히어로 물을 다 좋아하는데 DC는 확실히 마블에 비해 후한 평가를 받는거 같다. 실제로는 3점 짜리 영화. 맨 오브 스틸보단 약간 별로고 배댓슈 수어사이드보단 훨씬 나음, 평점보고 영화보려는 사람들 참고하길...',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2017, 6, 3, 11, 44),
#   0],
#  ['안녕(kooo****)',
#   '영화 대박 스케일쩔고 캐릭터 매력터짐 ㅠㅠ',
#   '10',
#   '20',
#   '8',
#   datetime.datetime(2017, 6, 1, 9, 1),
#   '관람객'],
#  ['seok****',
#   '알바 적당히들해라 한국영화랑 겹쳐개봉한다고 역시나 몰려들오네 ㅋㅋㅋㅋ 일베같은 놈들',
#   '10',
#   '20',
#   '8',
#   datetime.datetime(2017, 5, 31, 21, 39),
#   0],
#  ['micr****',
#   '갤가돗보고 눈힐링하고 푹자다가 왓습니다초반 잼 중반 그럭저럭 후반 코~~하고왔습니다',
#   '1',
#   '21',
#   '9',
#   datetime.datetime(2017, 6, 4, 18, 17),
#   0],
#  ['dogsss(hajo****)',
#   '1점도아까워요 파워레인저 어른버전..정말 애니메이션어른버전',
#   '1',
#   '21',
#   '9',
#   datetime.datetime(2017, 6, 4, 3, 29),
#   0],
#  ['난 천재(rkdd****)',
#   'DC는 이제 완전 망했군 ㅉㅉ',
#   '1',
#   '22',
#   '10',
#   datetime.datetime(2017, 6, 3, 9, 50),
#   0],
#  ['02cu****',
#   '고의적으로 평점 내리는 이들때문에 10점 주고들어감 예매완료',
#   '10',
#   '23',
#   '11',
#   datetime.datetime(2017, 5, 31, 9, 57),
#   0],
#  ['Walt3(walt****)',
#   '원더우먼의 휴머니즘이 느껴진다.',
#   '10',
#   '25',
#   '13',
#   datetime.datetime(2017, 5, 31, 15, 24),
#   '관람객'],
#  ['유림축(cjsa****)',
#   '졸잼.이두마디면되는데열자제한에러..',
#   '10',
#   '25',
#   '13',
#   datetime.datetime(2017, 5, 31, 14, 4),
#   0],
#  ['위보기아래보기(hyun****)',
#   '뭐이딴 그지같은영화가 재밌다고 빨아대냐 여기 디씨빠만잇냐',
#   '1',
#   '13',
#   '2',
#   datetime.datetime(2017, 6, 15, 19, 49),
#   0],
#  ['bhll****',
#   '진짜 영화 본인간들이면 베플이 저따구일리가 없다.궁금하면 직접 가서 보시길근데 제발 다크나이트랑 비교하지마 급이달라',
#   '5',
#   '13',
#   '2',
#   datetime.datetime(2017, 6, 3, 11, 52),
#   0],
#  ['하내(badu****)',
#   '감독 바꿔라 그럼 2탄 안본다. 액션은 거의없고  주디만 2시간을 터네.',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2017, 6, 18, 15, 9),
#   0],
#  ['울랄라흥(sayz****)',
#   '원더우먼역에 정말 잘 어울리네요..',
#   '10',
#   '15',
#   '4',
#   datetime.datetime(2017, 6, 1, 23, 57),
#   '관람객'],
#  ['faf43526dv(dnja****)',
#   '배댓슈보다 더욱더 볼만했군',
#   '9',
#   '15',
#   '4',
#   datetime.datetime(2017, 6, 1, 0, 4),
#   '관람객'],
#  ['군림천하(bigr****)',
#   '와 여주 액션 지리네 팔레스타인 공습하는 기분으로 촬영한듯ㅉㅉ',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2017, 6, 19, 2, 56),
#   0],
#  ['어벙벙(jwm9****)',
#   '여성 히어로 멋있당  죽인당',
#   '9',
#   '16',
#   '5',
#   datetime.datetime(2017, 6, 1, 7, 24),
#   '관람객'],
#  ['코코아(inho****)',
#   '처음엔 유치하다 생각했는데 볼수록 볼만했어요~',
#   '9',
#   '17',
#   '6',
#   datetime.datetime(2017, 6, 1, 0, 2),
#   '관람객'],
#  ['롤(heal****)',
#   '와 엄청재밌네요 별기대안했는데',
#   '10',
#   '18',
#   '7',
#   datetime.datetime(2017, 6, 1, 8, 54),
#   '관람객'],
#  ['wlsf****',
#   '반할거같다 진차볼만함',
#   '10',
#   '19',
#   '8',
#   datetime.datetime(2017, 5, 31, 12, 59),
#   0],
#  ['오리궁뎅이버섯(bswp****)',
#   '드디어 DC가 부활하다',
#   '10',
#   '19',
#   '8',
#   datetime.datetime(2017, 5, 31, 8, 49),
#   0],
#  ['finr****',
#   '후반부에 조금 오글거림이 있었지만 액션 멋지고 원더우먼 존예 디씨 저스티스리그도 이렇게 만들어줘요',
#   '9',
#   '20',
#   '9',
#   datetime.datetime(2017, 5, 31, 14, 40),
#   '관람객'],
#  ['cadet28(shin****)',
#   '올해 최고의 영화네요. 다음 영화가 벌써 기다려집니다.',
#   '10',
#   '22',
#   '11',
#   datetime.datetime(2017, 5, 31, 23, 31),
#   '관람객'],
#  ['박봉곤(bg90****)',
#   '전쟁영웅 스티브,다이애나 짱짱피플',
#   '9',
#   '22',
#   '11',
#   datetime.datetime(2017, 5, 31, 12, 51),
#   '관람객'],
#  ['Roy Kim(roy_****)',
#   '다크나이트말곤 디씨꺼 도저히 못보겠던데 드디어 빤스입은 히어로물에도 재미를 느꼇다. 여주 캐스팅도 퍼펙트!!',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2017, 7, 26, 13, 47),
#   0],
#  ['TRuck(joon****)',
#   '원더우먼의 순수함이란 ㅋ',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2017, 7, 15, 14, 43),
#   '관람객'],
#  ['일원(kin9****)',
#   '남주가 솔직히 존멋이다.',
#   '8',
#   '10',
#   '0',
#   datetime.datetime(2017, 6, 8, 14, 36),
#   '관람객'],
#  ['자두맛캔디(stee****)',
#   '관전 포인트는 갤가돗의 미모!!!보너스 포인트는 테마곡.',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2017, 6, 1, 4, 9),
#   0],
#  ['라스트(sixn****)',
#   '이정도면 대박입니다 100%만족 연출 액션 느끼한 히어로 감성 까지 ㅋㅋ',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2017, 5, 31, 13, 58),
#   0],
#  ['천상재회(woos****)',
#   '독일군 전쟁 배경이라서 좀 어두운데 원더우먼과 남자 주인공의 로맨스는 돋보임.',
#   '8',
#   '11',
#   '1',
#   datetime.datetime(2017, 6, 5, 23, 28),
#   '관람객'],
#  ['hwoa****',
#   '원더우먼을 위해태어난듯한 갤가돗~ 진짜 지립니다..액션신 완전 최고~~ 스토리도 괜찮고 dc가 이번에 제데로 일 냈어요',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2017, 6, 4, 1, 38),
#   '관람객'],
#  ['poda****',
#   '히어로물을 평소에 즐겨보지 않는데 이 영화는 전개도 깔끔하고 재밌네요ㅎㅎ무엇보다 주인공이 참 맘에 듭니다 굿굿',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 6, 4, 19, 56),
#   '관람객'],
#  ['pmj3****',
#   '예고편으로 생각했던것 보다 코믹하면 재미있다. 많이 추천해드리고 싶다',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 6, 3, 1, 55),
#   '관람객'],
#  ['Aku mimpi(manp****)',
#   '당신을 극장에서 보기위해 40년을 기다렸습니다.',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 6, 1, 8, 24),
#   0],
#  ['Idun(wony****)',
#   'DC가 해냈습니다 여러분',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 6, 1, 1, 23),
#   0],
#  ['Sunny Side Up(ecaa****)',
#   '갤 가돗이 아니라 원더우먼 그 자체였음.',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 6, 1, 1, 11),
#   0],
#  ['민솔맘(magi****)',
#   '최대 한글 140자까지 가능하며, 스포일러는 삭제될 수 있습니다.주인공들 캐스팅부터 스토리, 액션 다 좋았습니다^^',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2017, 5, 31, 14, 26),
#   0],
#  ['glgl(huj8****)',
#   '한번 꼭 봐보세요^^짱이요',
#   '9',
#   '12',
#   '2',
#   datetime.datetime(2017, 5, 31, 12, 32),
#   0],
#  ['님열라안습(yout****)',
#   '심야영화보러간보람이있는영화였음..',
#   '9',
#   '13',
#   '3',
#   datetime.datetime(2017, 6, 5, 0, 26),
#   '관람객'],
#  ['다이야(pjh8****)',
#   '이정도면 잘만는거 아닌감? ㅋㅋ 정말 꿀잼',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2017, 6, 1, 7, 26),
#   0],
#  ['who3****',
#   '짜입니다다요~!!!',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2017, 6, 1, 7, 2),
#   '관람객'],
#  ['kims****',
#   '후반이 좀 아쉬웠지만 디씨의 가능성을 열어준 걸크러쉬에 10점을',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2017, 6, 1, 5, 26),
#   0],
#  ['지녀니나노(zxcv****)',
#   '마지막에 빌런과 전투장면이 단순해서 아쉬웠지만 그것을 제외하면 영화가 말하고자 주제라던지 나머지의 전투 장면의 연출은 정말 보는내내 소름이었다 러브라인을 표현한 표현력도 섬세했다 돈아깝지 않은 영화',
#   '9',
#   '13',
#   '3',
#   datetime.datetime(2017, 5, 31, 19, 46),
#   0],
#  ['upgrrr(spir****)',
#   '플롯도 구린데 액션은 OO 액션감독시말서 쓰게해야된다. 막판 갤가돗 백만볼트 전기공격은 우뢰매의 그것을 보는듯하다. 이 영화는 돈을주고 보기보다는 돈을 받고 보는것이 옳다.',
#   '1',
#   '15',
#   '5',
#   datetime.datetime(2017, 6, 17, 23, 23),
#   0],
#  ['하히헤후(kjh3****)',
#   'ㅋㅋ 평점 내리는놈들 도대체  평소에 어떤영화 보는지 궁금하다 ㅋㅋㅋ레알 액션 스토리 음악 영상미 이정도면 점수 후하게 줘도 되지 않나??',
#   '10',
#   '15',
#   '5',
#   datetime.datetime(2017, 6, 1, 1, 18),
#   0],
#  ['jiwo****',
#   '와...알바들보소...두 줄짜리 평 남긴 놈들 대부분 알바놈들임. 영화도 안보고썼냐? 액션은 섬에서가 제일 좋고 다음부턴 헛웃음나옴. 또 각 캐릭들 사연있게 만들어놓고 떡밥회수도 안함. 특히 스나이퍼 캐릭은 도대체 ...',
#   '1',
#   '16',
#   '6',
#   datetime.datetime(2017, 6, 18, 22, 53),
#   0],
#  ['안정훈(ever****)',
#   '이게  재미없으면  영화 볼거없음재미있게 잘 봤어요',
#   '10',
#   '16',
#   '6',
#   datetime.datetime(2017, 6, 1, 7, 59),
#   0],
#  ['피아노쟁이(leej****)',
#   '와 이건 진짜 내 태어나서 인생작이다. 와 정말 최고의 영화에요  Awesome!',
#   '10',
#   '16',
#   '6',
#   datetime.datetime(2017, 6, 1, 2, 14),
#   0],
#  ['wnrh****',
#   '재밌습니다 퍼스트 어벤져스랑 배경이 비슷한데  비교하자면 내용 ,액션, 전체적분위기가 훨 좋아요 은근 재밌는 장면도 중간중간 들어가있고 꼭보세요 후회 안합니다',
#   '10',
#   '16',
#   '6',
#   datetime.datetime(2017, 5, 31, 13, 23),
#   0],
#  ['애디(edju****)',
#   '이게 재미없으면 한쿡영화나 봐라 원더우먼 지리고 ost에 뻑갔다',
#   '10',
#   '17',
#   '7',
#   datetime.datetime(2017, 5, 31, 21, 26),
#   0],
#  ['dickie(yubi****)',
#   '중반 어린아이와 민간인들을 위해 전장으로 뛰어들때의 모습은 진심 지렸다ㅋ 원더우먼의 등장! 종반 아레나인지 아레스인지와의 전투씬은 손 발가락이 오그라들어 엔딩후 극장을 제대로 걸어 나올수 없었음ㅜㅜ',
#   '7',
#   '17',
#   '7',
#   datetime.datetime(2017, 5, 31, 16, 9),
#   0],
#  ['세기의걸작히오스(davi****)',
#   '정통 히어로를 잘 보여준 영화. DC가 오랜만에 괜찮은 영화 만든듯',
#   '9',
#   '17',
#   '7',
#   datetime.datetime(2017, 5, 31, 14, 1),
#   0],
#  ['elec****',
#   '베드신 기대했는데...그 장면에서 순간 영화관이 조용....',
#   '10',
#   '18',
#   '8',
#   datetime.datetime(2017, 5, 31, 12, 20),
#   0],
#  ['ㄴㅇㄹ(iqpi****)',
#   '대립군 보다 평점이 낮은걸 보니 적폐세력이 여기도?',
#   '10',
#   '19',
#   '9',
#   datetime.datetime(2017, 6, 1, 8, 25),
#   0],
#  ['바람코지(sadh****)',
#   '마블충들과 국내영화충들이 몰려와서 1점테러하는거 꼴보기 싫어서 10점준다 이거 1점받을 영화는 아니다.평점테러 앵간히 해라~',
#   '10',
#   '19',
#   '9',
#   datetime.datetime(2017, 5, 31, 12, 36),
#   0],
#  ['공겨울(gaeu****)',
#   '로튼지수값합니다 여러분ㅠㅠ 갤가돗 존예보스',
#   '10',
#   '20',
#   '10',
#   datetime.datetime(2017, 6, 1, 8, 23),
#   '관람객'],
#  ['승재리(hair****)',
#   '갓갓갓갓 소소한 재미를 잘 캐치한 영화예요',
#   '10',
#   '21',
#   '11',
#   datetime.datetime(2017, 6, 1, 1, 34),
#   '관람객'],
#  ['계란(wlwh****)',
#   'dc 바보.. 왜 이제서야 이런 영화를 낸고야....ㅠㅠㅠ 속으로 보러 가서 오줌 찌리고 옴...ㄹㅇ...',
#   '10',
#   '25',
#   '15',
#   datetime.datetime(2017, 5, 31, 8, 25),
#   0],
#  ['주경야독(veji****)',
#   '액션 스토리 비주얼 감동 빠지는게 없다 .. 또 보고싶다.. 2번 울었다..',
#   '10',
#   '27',
#   '17',
#   datetime.datetime(2017, 5, 31, 12, 19),
#   '관람객'],
#  ['Destiny(dbsw****)',
#   '팝콘맛에 집중할 수 있어서 좋았습니다.웬만한 영화는 엔딩크레딧 다보고 나왔는이 영화는 끝나자마자 바로 나옴',
#   '1',
#   '28',
#   '18',
#   datetime.datetime(2017, 6, 1, 16, 37),
#   0],
#  ['섭이(fort****)',
#   '친구들이랑 보자고 데려갔다가 보고나와서 미안하다고 사과함.',
#   '1',
#   '31',
#   '21',
#   datetime.datetime(2017, 6, 2, 10, 52),
#   0],
#  ['dbqj****',
#   '연출 유치하기 짝이없고걍 영화내내 꿀잠자고 개운하게 영화관 나옴.',
#   '1',
#   '36',
#   '26',
#   datetime.datetime(2017, 6, 5, 16, 39),
#   '관람객'],
#  ['이준완(dlwn****)',
#   '절대보지마세요개핵노잼입니다',
#   '1',
#   '44',
#   '34',
#   datetime.datetime(2017, 6, 6, 2, 40),
#   '관람객'],
#  ['rlaq****',
#   '아...개재밌게봤네 갤가롯 너무이뻐...마지막까지감동이구만...극장가서볼걸...난너무재밌고 슬프게봤다 추천!',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2017, 7, 26, 0, 27),
#   0],
#  ['No21NunoGomes(thep****)',
#   '정말 재미있게 봤음..마지막에 귀가 안들릴때 이 사람이 무슨말을 했는지 다시 한번 생각해보는 장면에서 참 감동적이었고 사랑이란 감정이 위대하구나 느낌..',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2017, 7, 19, 6, 33),
#   0],
#  ['dkdk****',
#   '너무너무재밋자넘나멋잇어요추천',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2017, 6, 4, 19, 20),
#   '관람객'],
#  ['김정은(ps_b****)',
#   '재밌어요 시원한 영화입니다',
#   '9',
#   '9',
#   '0',
#   datetime.datetime(2017, 6, 4, 17, 26),
#   '관람객'],
#  ['찐만두(kjmm****)',
#   '가돗 혼자 하드캐리~~~~',
#   '8',
#   '9',
#   '0',
#   datetime.datetime(2017, 6, 4, 15, 45),
#   '관람객'],
#  ['ghfu****',
#   '마지막 남자주인공 죽기 전 시계넘겨주면서 했던말이 너무 멋있었다. "난 오늘을 구하고 당신을 세계를 구해라" 그리고 마지막 사랑해ㅜ',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 7, 23, 21, 17),
#   0],
#  ['only****',
#   '디씨 살린 원더우먼 갤가돗 이쁨',
#   '8',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 4, 22, 20),
#   '관람객'],
#  ['qkrr****',
#   '개재밌어요 주인공 진짜 대박',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 4, 22, 20),
#   '관람객'],
#  ['최형옥(hyeo****)',
#   'DC의 최고의 선택이다! 강추합니다. 중간에 울뻔 ㅠ ㅋㅋ',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 4, 11, 25),
#   '관람객'],
#  ['o___****',
#   '지젤눈웃음 여자인데 심쿵 ㅠㅠ',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 4, 5, 46),
#   '관람객'],
#  ['땡(chob****)',
#   '갤 가돗 앞으로 DC코믹스를 책임쳐주세요.',
#   '9',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 3, 23, 45),
#   '관람객'],
#  ['cir3max(spos****)',
#   '와 진짜욕나오게재밋다 개쩐다 이번년도최고영화다 주인공도존나이쁘다!!!진심 인정 미친듯이재밋다!!!',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 3, 22, 6),
#   '관람객'],
#  ['ikar****',
#   '슈퍼맨vs배트맨보다 훨씬낫네',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 3, 21, 27),
#   '관람객'],
#  ['tntm****',
#   '한번 더 볼 만한거같아욬ㅋㅋ액션씬이 진짜 좋았어요!',
#   '8',
#   '10',
#   '1',
#   datetime.datetime(2017, 6, 3, 1, 51),
#   '관람객'],
#  ['국민꽃미남 구자욱(lion****)',
#   '지렿다 꼭 보셈  존나강추',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 5, 31, 13, 33),
#   0],
#  ['noble savage(snas****)',
#   '이정도면 1만원 내고 볼만하지.',
#   '9',
#   '10',
#   '1',
#   datetime.datetime(2017, 5, 31, 12, 31),
#   0],
#  ['jazz(njjy****)',
#   '지금 조조 보고 나왔는데, 미쳤다. 반할수 밖에 없다. 짱짱걸♥♥♥',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 5, 31, 11, 36),
#   0],
#  ['현9(heon****)',
#   '선장님은 진짜 캡틴이었다',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2017, 5, 31, 11, 30),
#   0],
#  ['양다정(rhae****)',
#   '아바타인지 파워레인저인지 어벤저스인지 하나만하길...',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 17, 16, 46),
#   0],
#  ['편운거(pani****)',
#   '원더우먼....= 갤 가돗....들판에서 기관총을 막아내는 씬이 압권이었으며음악과 함께 어우러진 갤 가돗의 액션씬...원더우먼 역에 딱 맞춤이었네요.DC의 구원투수 역활을 잘 해낸것 같습니다.',
#   '9',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 3, 16, 29),
#   '관람객'],
#  ['gksp****',
#   '여성만이 느낄수있는 카타르시스가 있었습니다. 재밌었어요',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 18, 48),
#   '관람객'],
#  ['duke****',
#   '올해 개봉한 슈퍼히어로 영화 중 제일 재미있네요. 저스티스리그도 이 레벨 이상으로 완성해주길! !',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 9, 4),
#   '관람객'],
#  ['김우주(wjms****)',
#   '유치한데 이래야 원더우먼이지그리고 중간중간 울컥하기도함...',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 8, 44),
#   0],
#  ['별명따위(tjem****)',
#   '애플랙형! 보고있어? 형 배트맨 솔로영화 나올것같아!!',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 8, 6),
#   0],
#  ['Wolverine(hoha****)',
#   '메인 테마 깔리면서 전장으로 들어갈때 진짜 개소름',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 7, 8),
#   0],
#  ['Neue(neue****)',
#   '완벽한 dc의 귀환, 저스티스 리그가 기다려지는 나날이다!',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 4, 15),
#   0],
#  ['허니랜드(kict****)',
#   '저스티스 리그. 활활 타오르는 그 축제의 횃불.',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 3, 1),
#   0],
#  ['백현유딩(uj_u****)',
#   '원래 이런장르 영화안보는데 이건 진심 핵잼??완전 멋있어!!!!????',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 2, 57),
#   0],
#  ['꿍야(love****)',
#   '기대하고봤는데 기대를 훨씬 뛰어넘음',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 2, 26),
#   0],
#  ['cumanio(jiho****)',
#   '알바들이 올린건줄 알고 안보려다 시간 딱 맞아서 봤는데 디씨 영화중에 가장 잘만들었다 영화평점은 8.7점 정도 주고 싶은데 드디어 정신차린거 같아서 기특해서 10점 준다 제발 앞으로 잘만들어서 좋은 히어로 영화만들어...',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 2, 10),
#   0],
#  ['미네온(hele****)',
#   '여자를 따르고 싶은마음이 생기는 ... 진정한 히어로 영화!! DC성곡작!!',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 1, 5),
#   0],
#  ['ysk3****',
#   '완전 꿀  잼이네요..여성 히어로 대박~^^',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 6, 1, 0, 38),
#   '관람객'],
#  ['스텔라(ro52****)',
#   '미국평론가극찬흥행대박',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 5, 31, 14, 31),
#   0],
#  ['kyon****',
#   '배우들 하나 하나 너무 멋짐ㅋㅋㅋ 그래도 원더우먼이 짱이였으',
#   '10',
#   '11',
#   '2',
#   datetime.datetime(2017, 5, 31, 13, 58),
#   0],
#  ['하않갉(ungc****)',
#   '여지껏 나온 DC 영화 중에서는 제일 나은 거 같다. 액션도 나름 괜찮다.',
#   '9',
#   '11',
#   '2',
#   datetime.datetime(2017, 5, 31, 11, 44),
#   0],
#  ['수중전(khk1****)',
#   'ㄴㅈ 기대하지말고볼것',
#   '1',
#   '12',
#   '3',
#   datetime.datetime(2017, 6, 15, 12, 1),
#   '관람객'],
#  ['Flying Ace(baji****)',
#   '재밌다! 아레스는 확실히 좀 아쉬워서 재미없다고 하는 사람들도 이해는 되지만 난 굉장히 재밌게 봤다',
#   '9',
#   '12',
#   '3',
#   datetime.datetime(2017, 6, 4, 23, 25),
#   '관람객'],
#  ['슬기둥기(tmfr****)',
#   '원더우먼..밤에 볼거없어서 급하게 예매하고 본건데 진짜 기대이상...개대존잼ㅜㅠ진짜 보는동안 소름돋고 남자 히어로들보다 개존멋 걸크러쉬..여운오래남음 또볼거야 쓰리디로또볼까',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 6, 1, 2, 10),
#   0],
#  ['치기(jj34****)',
#   '멋진 언니가 시원하게 부수는 영화...쓸데없는 부분이 없어서 좋았어요ㅜㅜㅜ언니!!!멋져요!!!TvT',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 6, 1, 1, 25),
#   0],
#  ['늑도르(mymi****)',
#   '하도 디씨유니버스가 죽을쒀서 평타만쳐도 후한점수 줄랫는데 이건뭐 기대한 이상은 되네. 신여성의 발로를 경험할 수 있을것임.',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 6, 1, 1, 16),
#   0],
#  ['momi****',
#   '뭐죠?ㅋㅋ 디씨 왜갑자기 사람 감동시키고 그래..',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 21, 15),
#   0],
#  ['원종철(dnjs****)',
#   '재밌어요~.원더우먼 이뻐요.',
#   '8',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 16, 19),
#   0],
#  ['이용택(dldy****)',
#   "평점 낮게 준애들 아이디 누르고 과거 평점 목로 보면 두부류로 나뉜다 ㅋㅋ 말투 초딩에 점수 기준 없이 막 주는애들, 아니면 아이디 새로 만들어서 '원더우먼'에만 평점 준 기록 밖에 없는애들  ㅋㅋ 레...",
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 15, 47),
#   0],
#  ['으음(quai****)',
#   '이제야 DC 다운 영화가 나오네. 앞으로도 계속 이렇게만 해주세요!',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 14, 36),
#   0],
#  ['하늘바람(bond****)',
#   '액션도 멋있고 재밌습니다 .',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 14, 31),
#   0],
#  ['백미선(mi-s****)',
#   '솔직히 여자 히어로 영화라서 기대 안했는데 시사회 갔다가 반하고 왔다',
#   '10',
#   '12',
#   '3',
#   datetime.datetime(2017, 5, 31, 14, 31),
#   0],
#  ['민원(lmw3****)',
#   'DC 영화 중 베트맨 시리즈 이후 최고의 영화',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2017, 6, 3, 1, 49),
#   '관람객'],
#  ['dnjs****',
#   '캐스팅 진짜 너무 잘햇다',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2017, 6, 1, 10, 17),
#   '관람객'],
#  ['카페모카(alsr****)',
#   '원더우먼의 성공적탄생기, 순수한 눈빛을 잊을 수 없다.',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2017, 6, 1, 10, 4),
#   '관람객'],
#  ['케빈(kcas****)',
#   '배댓슈와 수어사이드 스쿼드로 너무나 낮아진 관객의 기준 덕분일까?  맨오브스틸 수준으로 다시 돌아온 것일 뿐 여전히 스토리를 풀어나가는  DC의 능력은 빈약하고 약점 또한 분명하다.',
#   '6',
#   '13',
#   '4',
#   datetime.datetime(2017, 6, 1, 1, 36),
#   0],
#  ['미나(1240****)',
#   '개노잼 영화 왜 이렇게 만들어요???....',
#   '1',
#   '25',
#   '16',
#   datetime.datetime(2017, 6, 6, 13, 57),
#   '관람객'],
#  ['Vallentein(joos****)',
#   '나쁘지않은 페미니즘 같음 뭔가 옛날식에 진짜 여성들을 위한 페미니즘? 캡마같이 멍청하게 페미 끼워넣고 팔아먹는거랑 다르게 훨씬더 괜찮다고 생각됨',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 7, 28, 0, 10),
#   0],
#  ['oozzap(oozz****)',
#   '남주 멋있었다 ㅋㅋ 원더우먼도 정의감 사명감 대단한데 개인적으로 남주에 마지막에 남들을위한 희생정신에 감동적이었고 마지막에 원더우먼한테 귓속말로 한말 사랑해 그말 진심 되게좋았음 ㅎㅎㅎ 찡했음 원더우먼보고 감동을느낄...',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2017, 6, 15, 23, 45),
#   '관람객'],
#  ['아우라지(leec****)',
#   '나중에 너무 빠른 전개? 갑자기 끝판왕 등장ㅋ~',
#   '8',
#   '8',
#   '0',
#   datetime.datetime(2017, 6, 11, 19, 43),
#   '관람객'],
#  ['rainbow(yeag****)',
#   '여주인공 너무 매력적이에요',
#   '8',
#   '8',
#   '0',
#   datetime.datetime(2017, 6, 4, 23, 11),
#   '관람객'],
#  ['몽블랑(jhsh****)',
#   '갑작스런  아레스 빼면 원더폴',
#   '9',
#   '8',
#   '0',
#   datetime.datetime(2017, 6, 4, 0, 30),
#   '관람객'],
#  ['양찬호(yang****)',
#   '진정한 페미니스트 영화이고 캡틴마블보다 백만배 더 꿀잼인 영화',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 3, 15, 21, 33),
#   0],
#  ['김리나(sylo****)',
#   '갤 가돗 캐스팅 최고. 완벽한 원더우먼',
#   '8',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 11, 13, 55),
#   '관람객'],
#  ['칼바이스(vvhy****)',
#   '그래도 상당히 선방한 DC유니버스 영화',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 7, 11, 14),
#   '관람객'],
#  ['은해(dmsg****)',
#   '영화는 진짜 좋았어요..근데 덕천 메가박스 2시 테이블m관 왼쪽 두자리 있는곳에 앞에서 3번째 앉은 아줌마랑 아들..진짜 장애 있는줄 알았네요 애가 자막을 모르면 데려오지를 마세요. 진짜 쳐 죽이고 싶었습니다. 애새...',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 6, 16, 28),
#   '관람객'],
#  ['신광민(sing****)',
#   '섹시,간지 모든요소가 압도적이다.',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 6, 10, 59),
#   '관람객'],
#  ['싸이퍼(lyhg****)',
#   'Dc에서 일낸건 팩트고 이뻐요',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 6, 0, 52),
#   '관람객'],
#  ['rang****',
#   '다음 편이 기대되게 만들어준 영화',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 6, 0, 37),
#   '관람객'],
#  ['MME(mme_****)',
#   '걸크러쉬 제대로 느낄수있는 영화',
#   '8',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 6, 0, 6),
#   '관람객'],
#  ['성마이(xenn****)',
#   '갤가돗 보러들어갔다가크리스가 더 기억나는 영화투는 꼭 치타 나왔으면',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 5, 3, 48),
#   '관람객'],
#  ['없다이눔아라라(lee5****)',
#   '무난햇엇고재밋엇서요',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 18, 2),
#   '관람객'],
#  ['상추(will****)',
#   '뭐하나 단점이랄게 없는영화 ... 몰입도가 장난아니고 진짜 겔가돗 웬만한 남자히어로들 그냥 발라버리게 멋있다',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 16, 52),
#   '관람객'],
#  ['김소정(soju****)',
#   'DC의 소녀가장이네요 ㅋㅋ 같이 본 사람은 유치하다고 하는데 저는 액션신도 멋있었고 정말 재밌었습니다 뒤에 나올 저스티스리가 정말 기대되네요',
#   '8',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 16, 15),
#   '관람객'],
#  ['TT(seun****)',
#   '다이애나가 너무 이쁘게 나온다 그리고 액션도 존멋 꼭봐라',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 11, 26),
#   '관람객'],
#  ['나나(mr_r****)',
#   '근래에 나온dc영화중에서는 가장좋은듯',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 4, 42),
#   '관람객'],
#  ['보노보노(sjwg****)',
#   '그냥저냥 볼만함 액션도 멋있음',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 3, 0),
#   '관람객'],
#  ['모브(mauv****)',
#   '저는 굉장히 재밌었어요.',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 4, 0, 34),
#   '관람객'],
#  ['gtss****',
#   '꿀잼 ㅎㅎ 핵잼 ㅋㅋ 졸잼 ㅋㅋ 포디나오면 또봐야지',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 3, 23, 41),
#   '관람객'],
#  ['dhgm****',
#   'DC가 드디어 정신을 차렸네.!',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 3, 23, 7),
#   '관람객'],
#  ['yaon****',
#   '여자 주인공이 정말 예쁘네요',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 3, 21, 22),
#   '관람객'],
#  ['쌈킬러(dlgj****)',
#   '잼나는디유 꼭보세요 ㅎㅎㅎ',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 1, 23, 18),
#   '관람객'],
#  ['지금이(ks48****)',
#   '원더우먼 너무 멋있고 영화는 재밌네요~',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 1, 21, 48),
#   '관람객'],
#  ['valis(rnsw****)',
#   '캐스팅이 신의 한수인듯',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2017, 6, 1, 21, 30),
#   '관람객'],
#  ['eatpraylove(rldu****)',
#   '이렇게 재밌게 만들줄 알면서 도대체 배대슈는 왜 그랬냐고..^^',
#   '9',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 7, 9, 12),
#   '관람객'],
#  ['KIMAD(kuku****)',
#   '아무 정보 없이 봐서..처음엔 하늘에서 스타트랙 함장이 떨어져서 좀 당황스러웠지만 갈수록 감동 재미 반전 다 잡아줘서 슬픈영화 아닌데 나는 왠지 잔뜩 울고 나왔다..',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 7, 1, 54),
#   '관람객'],
#  ['cocas(lee2****)',
#   '원더우먼....재밌음....',
#   '9',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 4, 23, 44),
#   '관람객'],
#  ['다크나이트(qkd3****)',
#   '갤 가돗에 빠져버렸당....',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 4, 7, 7),
#   '관람객'],
#  ['사람(9560****)',
#   '재밋당ㅎㅎ 감덩적이야',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 3, 20, 25),
#   '관람객'],
#  ['정엽(gnlr****)',
#   '시간가는줄모르고봤다 앞으로의 시리즈가 너무기대됨',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 2, 11, 35),
#   '관람객'],
#  ['원초딩(wonc****)',
#   '짱 짱!!!! 갤 가돗에게 완전 반했어요!!!',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 2, 1, 38),
#   '관람객'],
#  ['맥시안맨(hoju****)',
#   '정말 재미있게 봤습니다.저스티스리그 기대되네요',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2017, 6, 2, 0, 55),
#   '관람객'],
#  ['초성(sant****)',
#   '보면서 이 영화 핵노잼에 지루하기까지한 영화라 생각함',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2017, 7, 7, 20, 9),
#   '관람객'],
#  ['오렌지걸(babo****)',
#   '진짜재미있다. 대박. 대리만족느낌.',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2017, 5, 31, 23, 0),
#   '관람객'],
#  ['레바뮌첼(wolf****)',
#   '나중에 후회하지말고 꼭 극장에서 보시오',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2017, 5, 31, 14, 30),
#   0],
#  ['고마해라마이묵읏다(enoc****)',
#   '잼있게 봤음~ 간만에 쌓인 스트레스 풀고 암튼 잘 봤음!역시 극장에서 봐야 함',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2017, 5, 31, 14, 19),
#   0],
#  ['구르름(zprp****)',
#   '지리고지리고지린다.',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2017, 5, 31, 14, 6),
#   0],
#  ['음식(imc8****)',
#   '말이 안나오는 쓰레기 영화 마지막 전투씬은 전대 히어로물급',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 6, 16, 21, 5),
#   0],
#  ['김영광(kido****)',
#   '재밋다고 한 놈들 알바질에 놀아난 영화.스토리, 배우들 대사 오글거려서 끝까지 손발이 안 펴침.',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 6, 4, 22, 13),
#   0],
#  ['aruk****',
#   '베댓때문에 한개준다진심노잼영화...볼꺼라면 기대하지말고 볼것',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2017, 6, 4, 21, 3),
#   0],
# ...
#   0],
#  ['HJKIM(hjk_****)',
#   '알바가 꽤 있는듯? 원작 좋아하는 사람은 모르겠는데 기대만큼은 아님 점수균형을 위해 1점',
#   '1',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 13, 22, 49),
#   0],
#  ['하루하루가 판타지(hjs5****)',
#   '세상물정 모르는 원더우먼의 어리바리도 어느정도여야 재밌고  중간엔 말이 너무 많아서 졸뻔했습니다. 마지막에 악당이 하는 말을 정말 진지하게 듣다가 갑자기 원더우먼이 에네르기파 쏘고 등등하던 악당이 맞고 엌하고 죽는거...',
#   '1',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 10, 17, 11),
#   0],
#  ['what****',
#   '매우 지루한 영화임. 액션도 개뿔도 없음. 히어로물인지 로맨슨지. 일반인 싸움 잘하는 정도로 싸우다가 갑자기 강력한 악당 등장. 갑자기 강력해 지며 지루한 액션 시작 금방 끝. 시간은 겁나 안가고 뛰쳐나가고 싶은 맘...',
#   '1',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 9, 14, 10),
#   0],
#  ['오르막(kims****)',
#   '5점을 준건 순전히 여주인공이 이뻐서다...이영화를 한줄로 평가한다면"여주인공이 이쁨" 이정도가 아닐까 생각한다',
#   '5',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 9, 11, 35),
#   0],
#  ['블로구(jeon****)',
#   '이게 진정 10개받을만한가;; 내취향이 특이한건가 신기하네.',
#   '6',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 8, 18, 42),
#   0],
#  ['김현수(kimh****)',
#   '여자친구가 원더우먼이 되고싶데요~~~~',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 2, 18, 11),
#   '관람객'],
#  ['rocketman(blue****)',
#   '왜이리 평점이 낮지?잼있고 갤 가돗 넘 멋지던데.',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 8, 44),
#   0],
#  ['아무로(whan****)',
#   '이제야 DC다운 히어로군!',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 8, 33),
#   0],
#  ['타누(slcg****)',
#   '최고다...DC 간만에 사고 쳤네.. 남성히어로 보다 훨씬 멋있음',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 7, 37),
#   0],
#  ['최남제(anxi****)',
#   '비긴즈에서 해야할거 함. 이뻐서 10점',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 6, 24),
#   0],
#  ['동동주(ayok****)',
#   '재밋네요 간만에.히어로물..',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 4, 32),
#   0],
#  ['인생은아름다워(fory****)',
#   '스토리, 액션 ~ 심야봐도 졸리지가 않았다!! 머딛따♡ 원더우먼♡',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 4, 6),
#   0],
#  ['홍익이(chri****)',
#   '굿입니다 101010',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 3, 30),
#   0],
#  ['히힛ㅎㅎ(5656****)',
#   '처음부터 끝까지 감탄사만 날렸다...안보면 후회해요!!!',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2017, 6, 1, 1, 42),
#   0],
#  ['호구형아(toke****)',
#   'DC 시리즈중에서는 제일 낫다. 아쿠아맨 진짜 쓰레기',
#   '8',
#   '9',
#   '4',
#   datetime.datetime(2019, 1, 6, 2, 3),
#   0],
#  ['Snaru(tjdd****)',
#   '난 이게 왜 평이 좋은지 하나도 모르겠다. 스토리가 특출나지도 않으면서 액션도 구리다. 굳이 칭찬하자면 갤 가돗의 비주얼뿐이다.',
#   '4',
#   '9',
#   '4',
#   datetime.datetime(2018, 11, 28, 10, 53),
#   0],
#  ['바밤밤(dasi****)',
#   '평점은 유통사 알바들인가?후레쉬맨 전대물 보는줄 알았네요.;;;;',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 7, 2, 3, 30),
#   0],
#  ['탱그르르(pink****)',
#   '초반에는 뭔가 진행될 것 처럼 해놓고 중간부터 막바지까지는 완전 산만함의 끝을 보여준 영화....높은 평점에 제대로 낚였네요:)',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 26, 0, 54),
#   0],
#  ['쿠구구궁(secr****)',
#   '6점짜린데 10점이 많아서 1점. dc영환 본적 없지만 이게 제일 나은거라면 나머지는 안 봐도 충분할듯. 연출·액션·캐릭터·스토리 전부 다 유치함. 초반의 섬 풍경, 여전사들 전투씬만 볼만 하다. 왜 이렇게 빨아대는...',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 24, 20, 6),
#   0],
#  ['우체통(crdr****)',
#   '극장에서 보지마세요 개유치함 점잔떠는사람아닌데 개 유치함',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 23, 6, 2),
#   0],
#  ['열심히(hss1****)',
#   '수퍼히어로 무비가 아니라 드라마네. 티비방영용이나 비디오출시용 영화다. 서양에서 추억의 올드팬들한테는 호평받겠지만, 우리나라선 글쎄? 수퍼빌런과의 충돌이 수퍼히어로 무비의 핵심인데, 수퍼히어로 활동은 한시간은 지나야...',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 16, 22, 57),
#   0],
#  ['월천(fall****)',
#   '상영 전 광고 10분이 가장 재미있어요.',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 14, 1, 3),
#   0],
#  ['이태호(leet****)',
#   '질~~~질~~~계~~~~속~~~~끌~~~~어~~~',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 13, 23, 26),
#   0],
#  ['muon(kp85****)',
#   '개인적으로 내용 개연성도 없고 밸런스도 안맞고 최악의 영화라고 생각함. 영화관 내 사람들도 다 어이없어하던데.. 네이버 평점 진짜 알바쓰나...',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 13, 10, 47),
#   0],
#  ['chl1****',
#   '태어나서 평점을 처음으로 남겨본다. 핵노잼 !!!내 인생에서 제일 재미없었던 영화;;별점 1점도 아깝다. 시작부터 끝까지 대화만 하는 영화',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 9, 22, 5),
#   0],
#  ['dlss****',
#   '재미없었습니다...',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 9, 3, 58),
#   0],
#  ['아리가봐(ruci****)',
#   '우뢰매 비하발언 논란될까봐 안 쓰려고 했는데 댓글 중 우뢰매 논란 있어서 나도 쓴다. 진짜 우뢰매 생각 존나 남. 한번 봐보리니까?? 진짜 에스퍼맨 생각 종니 남...',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 7, 14, 2),
#   0],
#  ['머신건(nons****)',
#   '디씨는 아직도 정신을 못차렸다',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 6, 22, 39),
#   0],
#  ['분홍마녀(saga****)',
#   '사랑이란 진부한 소재, 말도 안돼는 스토리의 흐름... DC가 훌륭한 캐스팅에도 불구하고 항상 영화가 망하는 이유가 궁금하다면 꼭 이 영화를 보시길. 나는 영화보는 내내 시간을 보게될 것이라고 확신한다.',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 6, 20, 50),
#   0],
#  ['체리(doob****)',
#   '보는 내내 손발이 오글거려 죽는줄 알았다. 이건 무슨 우뢰매도 아니고..',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 6, 14, 18),
#   0],
#  ['디카프리오창(sexy****)',
#   '알바 나쁜놈들 죽여버리고 싶가',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 5, 20, 16),
#   0],
#  ['sapz****',
#   '액션때만잠깐깨고 졸앗던영화너무늘어지는 스토리',
#   '5',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 5, 12, 17),
#   '관람객'],
#  ['Df시월애(kik6****)',
#   '갤가돗 땜에 이 정도...빌런이 너무 뜬금없다',
#   '7',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 1, 13, 10),
#   '관람객'],
#  ['혜리니사랑(homm****)',
#   '이야 드디어 디씨가 정신차렸네~~~졸잼이다!!!',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 1, 3, 12),
#   0],
#  ['djdj****',
#   '재밌네요 ~~~~ 꼭보세요',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 1, 2, 57),
#   0],
#  ['마하(woni****)',
#   '감독님이 여성분이지만 이영화 강렬하고 시원한 액션으로 무장함. 액션이 좀더 많았다면 좋았을 것을. 돈 주고  또 보고싶음.',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 1, 2, 32),
#   0],
#  ['뚱때지(chau****)',
#   '역대급 여성 히어로의 탄생!! 갤가돗과 크리스 파인은 최고의 캐스팅이었다.. ㅠㅠ',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 6, 1, 2, 29),
#   0],
#  ['스타일러쉬(cjsr****)',
#   '예고편이 다인줄 알았는데... 갤 가돗 캐스팅 굿뜨!',
#   '9',
#   '9',
#   '4',
#   datetime.datetime(2017, 5, 31, 16, 23),
#   0],
#  ['노창환(shck****)',
#   '와..dc...다시봤습니다ㅎ진짜 말이 필요 없습니다!!!대박입니다..',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 5, 31, 16, 23),
#   0],
#  ['킥마스터(jung****)',
#   '너무 너무 너무 멋지다~!',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 5, 31, 16, 19),
#   0],
#  ['jiyo****',
#   '원더우먼이 단독으로 영화로 나오다니ㅜㅜㅜ 보는내내 감격함ㅜ',
#   '10',
#   '9',
#   '4',
#   datetime.datetime(2017, 5, 31, 14, 46),
#   0],
#  ['알라콩(masa****)',
#   '상당히 유치했습니다.. 갓웨폰 이라니;;',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2019, 1, 20, 16, 20),
#   0],
#  ['길무짱(alsa****)',
#   'OO노잼 차라리 배트맨대슈퍼맨이나을정도 배우캐스팅만신경씀',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 9, 12, 2),
#   0],
#  ['453(kang****)',
#   '원더우먼 혼자만 평생 알고 있어야할 흑역사',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 8, 20, 46),
#   0],
#  ['캡틴하록(neom****)',
#   '이게 영화냐..그돈으로 이것밖에 못만드남. 줄거리. 감동, 반전, 연기력, 볼거리..머하나 없네..총알낭비 영화',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 7, 15, 9),
#   0],
#  ['최윤호(libr****)',
#   '진짜 유치함 포켓몬스터보다 못한 영화ㅋㅋㅋ아레스가 원더우먼 주인공버프 받아서 개털리고액션씬 개유치;;;어린애들용 영화다 걍',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 7, 12, 48),
#   0],
#  ['나구라(trym****)',
#   '지금 가사디지털 롯데시네마에서 보다 말고 나왔어요. ㅠㅠ',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 6, 21, 10),
#   0],
#  ['gogo****',
#   '알바실화냐ㅋㅋ개재미없는데',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 6, 12, 38),
#   0],
#  ['mins****',
#   '진짜이건아니잔아.... 평점보고속앗다 하 ㅅㅂ 부모님이랑 보러갔는데 두분다 주무시더라..미안해서 집가는길에 고개를못듬.. 조연들 대체 왜나온지 이해x 특히 스나이퍼 아레스는 카리스마 1도없고 스토리 유치하고 엉성하고...',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 5, 22, 48),
#   0],
#  ['전창식(jenn****)',
#   '성조기를 두른 원더우먼 팔레스타인 공습을 지지하는 여배우가 평화의 상징? 안본다 OO들아',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 5, 10, 39),
#   0],
#  ['Less is More(thec****)',
#   '알바평점 믿지마세요!',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 4, 12, 9),
#   0],
#  ['hongji(hong****)',
#   'ㅜㅜ 영상미나 액션은 멋있었지만 스토리가...  킬링타임용추천해주고 싶진 않아요ㅜ ㅜ',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 3, 23, 4),
#   0],
#  ['호랭이(yw_e****)',
#   '평점 잘 안쓰는데 정말 재미없어서 씀 보다 3번 졸았음 평점 좋게 주는 사람들은 영화 보고 쓰시는 건가요 당최 이해 안됨',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 3, 17, 22),
#   0],
#  ['게임중독자(tude****)',
#   '이거 평점 조작이냐? ㅋㅋㅋㅋ 와 이게 8점대라고?? 원더우먼 컨셉자체가 영화로 만든건 무리수였다.',
#   '1',
#   '10',
#   '5',
#   datetime.datetime(2017, 6, 3, 2, 14),
#   0],
#  ['WayWise(taer****)',
#   '갤 가돗은 압도적으로 아름다웠다. 캡틴 아메리카를 보는 것 같은 그녀의 반전영화 서사시. 그간 DC에서 나온 시리즈 중에 최고였다.',
#   '8',
#   '10',
#   '5',
#   datetime.datetime(2017, 5, 31, 13, 51),
#   0],
#  ['타후티(tang****)',
#   '한순간도 놓치지않았다. 반했다.사랑에 빠졌다.재밌다. 좋았다.',
#   '10',
#   '10',
#   '5',
#   datetime.datetime(2017, 5, 31, 13, 1),
#   0],
#  ['bbarak(bbar****)',
#   '평이 좋았던 기억이나 기대하며 봤지만 내 소중한 주말밤을 망쳤다..액션은 진부하고 유치하기 짝이 없고 메인빌런은 무서움1도 없는 가족영화 아빠로 나올법한 귀여운 아재가 어색한 cg갑옷입고 날라댕기질 않나 스토리는 전...',
#   '2',
#   '11',
#   '6',
#   datetime.datetime(2018, 10, 28, 0, 50),
#   0],
#  ['행복(eber****)',
#   '딱 초등학생 수준의 영화입니다.본인이 그래도 초등학생보다는 수준이 높다고 생각하시는분들은 절대 기대하지 말고 보시길. .너무 유치하고 스토리는 엉성하고 개연성도 없어요.10점 평점들 중 93프로는 알바로 짐작되고.나...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 11, 28, 13, 53),
#   0],
#  ['인켈(ccsp****)',
#   '망작 인거 같네요 ㅎㅎ 재미 없었습니다 ㅎㅎ',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 8, 3, 10, 44),
#   '관람객'],
#  ['김신일(tjsr****)',
#   '왠만하면 등록안하는데 진짜 ...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 19, 15, 5),
#   0],
#  ['강수영(youo****)',
#   '재미없음노잼핵노잼! 댓글알바한테 속앗음',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 13, 15, 46),
#   0],
#  ['러브레나(lena****)',
#   '돈아까워 죽는줄알았네... 진짜 노잼... 무슨 내용인줄도 모르겠다 내내 피곤하고 따분하고 차라리 디즈니만화영화가 훨배낫더라 이걸 솔까 10점주는사람 뭔가 가짜평점인듯',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 8, 22, 35),
#   0],
#  ['cjw0****',
#   '마블히어로를 상상하고 가시면아침드라마를 보고 오실겁니다절대 보지  마세요',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 6, 12, 9),
#   0],
#  ['posts(open****)',
#   '이런 거 왜 수입한거예요?',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 6, 1, 11),
#   0],
#  ['craz****',
#   '와 알바ㅅㄲ들 상도덕이 있지 이걸 평점 8점대를 만드냐',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 5, 23, 16),
#   0],
#  ['원식(wons****)',
#   '내인생의 DC영화는 원더우먼을 마지막으로 ... 왜 이렇게 지루하고 유치한지 ㅠ 퍼시픽 림 보다 창피했음',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 5, 23, 12),
#   0],
#  ['건축인(arch****)',
#   '알바 정말 많네요... 절대 보지 마세요... 와.. 첫 전투신 까지는정말 괜찮았습니다 첫 전투신만 cg와 액션이 깔끔했고 나머지는 완전...갤가돗의 연기또한 너무 어색하였고 후반부 스토리는 유치합니다 140자 등록...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 5, 8, 50),
#   0],
#  ['마르코정(frj1****)',
#   '배는 자꾸 산으로 가고 갤가돗은 억지로 띄워주려하고, 이 좋은 재료를 마블이었다면 멋지게 만들어 냈을듯 .. DC가 안되는 이유를 정확히 알았다 .. 보는 내내 소름돋더라 어이가 없어서 ... ㅜㅜ',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 5, 8, 45),
#   0],
#  ['목양(moks****)',
#   '역시 dc... 노잼의 정점....',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 5, 2, 13),
#   0],
#  ['yeon****',
#   '평점, 후기 웬만하면 안다는데... 이 영화 진짜 어떻게 평점이 8점대가 나오는지 1도 이해가 안됨... 히어로가 나오는 영화중에 이렇게 지루했던 영화가 있었나 싶을 정도...차라리 망작이라는 배트맨VS슈퍼맨이 훨 ...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 4, 2, 31),
#   0],
#  ['켓치(cket****)',
#   '유치하기로는  수어사이드스쿼드 이상입니다',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 4, 1, 33),
#   0],
#  ['stardust(love****)',
#   '역대 최악입니다.왠만해선 혹평을 안하는데... 아..시간 아까워요.알바써서 평점 올린거예요.속지마세요.스토리가 엉망진창..개연성도없고 ..  이야기 조합이 다 깨지고 진부하고..한 20년전 영화같아요.보는내내  힘들...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 4, 1, 9),
#   0],
#  ['마퓨파이터(touc****)',
#   '진심 이영화보고 쓰레기라고 하는것들 니네가 말하는 수준높은 영화는 뭔데? ㅋㅋㅋ진짜 한심하다....충분히 dc에서 수작나왔구 충분히 기대에 부응하는 영화였다... 오락영화에서 뭘그렇게 따지나? 나도 마블좋아하지만 마...',
#   '10',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 2, 3, 47),
#   0],
#  ['꾸꾸(kkh9****)',
#   '진자 태어나서 눈알뜨고 본 영화 중 가장 재미없음한가지 좋은점은 끝나고 같이 영화 욕하면서 모르는 관객이랑 친해질 수 있음ㅋㅋ 시작하고 한시간동안 제대로 된 액션신하나 없음 ㄹㅇ 간디도 이거 보면 주먹쥡니다. DC가...',
#   '1',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 2, 1, 45),
#   0],
#  ['여행생활자(meso****)',
#   '마블에 비해 여전히 아쉽지만 그동안 디씨와 비교하면비교적 약진함',
#   '5',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 1, 22, 39),
#   '관람객'],
#  ['퓨렉스코리아(pure****)',
#   '너무나 매력적이고 이뻐서 만점..♥♥',
#   '10',
#   '11',
#   '6',
#   datetime.datetime(2017, 6, 1, 7, 47),
#   0],
#  ['갓한순(dkdl****)',
#   '8.26? 평점 실화냐. 누가 봐도 9점대거늘! DC를 구할 히어로 누구인가 원더우먼이시다 ㅜㅜㅜ 영화가 너무 잘 뽑혀서 행복함. 스티브 트레버도 원더우먼 못지 않게 멋진 히어로임!',
#   '10',
#   '11',
#   '6',
#   datetime.datetime(2017, 5, 31, 17, 4),
#   0],
#  ['장수말벌(kenz****)',
#   '히어로물영화에서  아카데미남우조연상을탄  다크나이트도 대단했지만  또한번 DC영화에서  아카데미음악상이나  영상미술상 같은거 받기를 기대합니다.',
#   '10',
#   '11',
#   '6',
#   datetime.datetime(2017, 5, 31, 14, 28),
#   0],
#  ['Dodo(lmjk****)',
#   '지금까는놈들ㅋㅋㅋ이제와서? 니네 분명 처음본거아닐꺼아냐;;; 근데 이제와서 별로다 연기 못한다....웃기지마ㅋㅋㅋ진짜 왜저럴까? 교육못받은거 티내고 싶을까?',
#   '10',
#   '12',
#   '7',
#   datetime.datetime(2019, 1, 6, 13, 13),
#   0],
#  ['나무늘보(heal****)',
#   '이딴걸 돈주고 보다니... 후반부에 나가고싶더라 하 ....내시간',
#   '1',
#   '12',
#   '7',
#   datetime.datetime(2017, 6, 6, 1, 40),
#   0],
#  ['독독독고다E(tvfx****)',
#   '1점도 아까움  아마존 공주님 사랑으로 세상 많이 구하옵소서 부디 멀리서 안보이게 구하셨으면 좋겠다',
#   '1',
#   '12',
#   '7',
#   datetime.datetime(2017, 6, 5, 2, 9),
#   0],
#  ['sycJ(vvv5****)',
#   '스토리도 이상하고 무엇보다 잘가다가 결말부분에서왜 그렇게 끝냈는지 의문만이 드는 영화였습니다그리고 마블이랑 비교하면 진짜 오글거립니다',
#   '1',
#   '12',
#   '7',
#   datetime.datetime(2017, 6, 3, 23, 13),
#   0],
#  ['kore****',
#   '진짜 내가 평점안쓰는데 이건아니다 진짜 dc는 희망이없다',
#   '1',
#   '12',
#   '7',
#   datetime.datetime(2017, 6, 3, 21, 38),
#   0],
#  ['joon****',
#   '지루함잠와죽는줄알앗네',
#   '1',
#   '13',
#   '8',
#   datetime.datetime(2017, 6, 11, 20, 24),
#   '관람객'],
#  ['철인(prox****)',
#   '평점 알바의 존재 처음으로 실감. ㅜㅜ 안웃긴 코미디 영화. 씨지 개판. 이렇게 돈과 시간이 아까운 영화 실로 오랜만이다. 여주 예쁘지만 은근 짜증나는 민폐여성캐릭터. 남주 아깝고. 그나마 초입부 여성전사들의 전투씬...',
#   '1',
#   '13',
#   '8',
#   datetime.datetime(2017, 6, 6, 9, 0),
#   0],
#  ['gjeo****',
#   '저스티스리그급 영화. 영화관 나오는 사람들이 대부분 이게 왜 평점이 높지? 하는 표정으로 퇴장함. 한 5점되는거같은데 평점이 쓸데없이 높아 기대하지말라고 평균낮춰드림',
#   '1',
#   '13',
#   '8',
#   datetime.datetime(2017, 6, 6, 4, 8),
#   0],
#  ['청솔(ych7****)',
#   '리뷰 검토하고 봤는데  알바가 진짜 있구나...생각했어요.주인공은 이쁘고 멋진데 무슨 독일군 전쟁하는곳에 원더우먼이ㅜ대사유치ㅜ완전 기가차게 황당ㅋ이런악평이 뜨면 알바들이 또 우루루 리뷰 써서 제 글 노출안되게 밑으로...',
#   '5',
#   '13',
#   '8',
#   datetime.datetime(2017, 6, 4, 0, 20),
#   '관람객'],
#  ['guf1****',
#   'ㅋㅋ머지.평점 좋아서 봤는데 이럴수가 있나?비교 하기 싫지만 마블 하고 넘 차이나네요',
#   '1',
#   '13',
#   '8',
#   datetime.datetime(2017, 6, 1, 15, 25),
#   0],
#  ['탱이(hyun****)',
#   '어떤점에서 재미를 찾아야하는지 모르겠는영화진행도 뚝뚝 끊기고 설정구멍에뻔한 반전 후반 급전개 급한 마무리이해가 안되는 동선',
#   '1',
#   '14',
#   '9',
#   datetime.datetime(2017, 6, 5, 0, 28),
#   0],
#  ['학교개학(dy63****)',
#   '지루하고 뻔한내용 보면서 전부예상',
#   '1',
#   '14',
#   '9',
#   datetime.datetime(2017, 6, 4, 23, 51),
#   0],
#  ['seeu****',
#   '진짜 댓글알바 샛기들이 내가 영화보다 잔게 맨오브스틸이후로 첨이얐다 이거는 코미디도아니고 히어로물도아니고 뭔 망상속의 귀신들린 영화같다',
#   '1',
#   '14',
#   '9',
#   datetime.datetime(2017, 6, 2, 2, 14),
#   0],
#  ['준걸(june****)',
#   '재미없고짜증나요완전최악임',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2017, 6, 5, 0, 38),
#   0],
#  ['doln****',
#   'DC의 최후 진짜 노잼...',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2017, 6, 4, 23, 45),
#   0],
#  ['쏘츠(qnfm****)',
#   '슈퍼히어로 영화라지만 마블이랑 차이 ㅈㄴ 많이나네나는 DC는 아닐세베대슈 엄마이름같다고 동지가 되는 스토리 개노잼뭔가 임펙트도 없고 두번은 봐야 이해하겟다차라리 캡틴아메리카 더 퍼스트 어벤져스가 개꿀이었네믿고 거르는...',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2017, 6, 1, 13, 18),
#   0],
#  ['여유(x-xx****)',
#   '크로스 빔 뭐냐. 데마시아냐? 세상 촌스러워서...남친한테 원래 재미없어도 재밌다고 하는데 이건 세상에 이런 쓰레기..인간의 앞날은 인간이 정하는 거라더니 막판 총성들리니까 뛰쳐나가는 다이애나 머가리 데코레이션.믿고...',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2017, 6, 5, 3, 1),
#   0],
#  ['wonh****',
#   '진짜 평점왠만하면 안남기는데 알바에 낚임 스토리 노말 씨지 약간부족 현실성 제로 긴장감 스릴감 제로 140분동안 도대체 뭐하는지 3500언주고 봐도 돈아깝',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2017, 6, 1, 11, 59),
#   0],
#  ['강현뀨(khk9****)',
#   '너무 재미없네요 돈아깝습니다',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2017, 6, 1, 1, 32),
#   0],
#  ['옴밋텍(le26****)',
#   '하... 쓰레기.. 이렇게 재미없는 영화는 처음. 돈주고 보라해도 안볼거에요',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2017, 6, 1, 12, 13),
#   0],
#  ['rkad****',
#   '역할이랑 현실이랑 정말 안어울린다 저런사람이 사람들을 지킨다고?',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2017, 6, 2, 20, 52),
#   '관람객'],
#  ['망퉁이(addi****)',
#   '갤 가돗 매력적인거 말고는 볼 게 없는 영화. 갤 가돗덕에 그나마 평점 5.5 줍니다. 네이버 평점 낮추기위해 1.',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2017, 6, 1, 12, 46),
#   0],
#  ['hjh1****',
#   'DC는 그만하자그리고 댓글알바 진짜 극혐이다',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2017, 6, 2, 5, 31),
#   0],
#  ['강우아빠(del1****)',
#   '잠 안올때 보심됨 잠잘옴  ㅋㅋ',
#   '1',
#   '20',
#   '15',
#   datetime.datetime(2017, 6, 1, 12, 28),
#   0],
#  ['타락천사(dlql****)',
#   '응 내가볼땐 별루다....',
#   '1',
#   '38',
#   '33',
#   datetime.datetime(2017, 5, 31, 19, 4),
#   '관람객'],
#  ['STEELHEART(mool****)',
#   '초딩용으로 잘만든영화. 갤가돗 캐스팅은 역대급!',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 1, 3, 19, 24),
#   0],
#  ['수리수리맨수리(yobo****)',
#   '이쁘고 착하고 싸움도 잘하네 저런여자만나고 싶군!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 10, 18, 19, 8),
#   0],
#  ['BOWMON(mn06****)',
#   'DC 특유의 어둑어둑한 분위기에서 벗어나서 괜찮은 영상미를 보여줌.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 10, 8, 15, 55),
#   0],
#  ['cccvbgx(cyan****)',
#   '원더우먼과 스티브 트레버 둘다 겁나 용감하고 멋있어요.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 27, 23, 1),
#   0],
#  ['Now(maes****)',
#   '캐스팅 훌륭, 연기 훌륭. 하지만 오글거림이 심하다.',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 19, 2, 39),
#   0],
#  ['러블리블리(ador****)',
#   '와 재밌다 이럴 줄 알았으면 영화관에서 볼 걸ㅜㅜ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 3, 23, 33),
#   0]]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                       0  ...    6
# 0           엽(holi****)  ...    0
# 1         나랑가(ej2r****)  ...  관람객
# 2       아드레날린(ghgh****)  ...    0
# 3         태양이(016n****)  ...  관람객
# 4    티키닭카티키닭카(zzor****)  ...    0
# ..                  ...  ...  ...
# 925   수리수리맨수리(yobo****)  ...    0
# 926    BOWMON(mn06****)  ...    0
# 927   cccvbgx(cyan****)  ...    0
# 928       Now(maes****)  ...    0
# 929     러블리블리(ador****)  ...    0
#
# [930 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                nickname  ... watch_movie
# 0           엽(holi****)  ...           0
# 1         나랑가(ej2r****)  ...         관람객
# 2       아드레날린(ghgh****)  ...           0
# 3         태양이(016n****)  ...         관람객
# 4    티키닭카티키닭카(zzor****)  ...           0
# ..                  ...  ...         ...
# 925   수리수리맨수리(yobo****)  ...           0
# 926    BOWMON(mn06****)  ...           0
# 927   cccvbgx(cyan****)  ...           0
# 928       Now(maes****)  ...           0
# 929     러블리블리(ador****)  ...           0
#
# [930 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
