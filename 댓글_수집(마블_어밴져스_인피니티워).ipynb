# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(%EB%A7%88%EB%B8%94_%EC%96%B4%EB%B0%B4%EC%A0%B8%EC%8A%A4_%EC%9D%B8%ED%94%BC%EB%8B%88%ED%8B%B0%EC%9B%8C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=136315
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 136315
total_count = 1409  ## 전체 크기=1409

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136315&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 136315
total_count = 1409  ## 전체 크기=1409

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['순대볶음(gdcv****)',
#   '닥터 스트레인지 마지막 대사 "이제 다 끝났어"는 오역입니다. "이게 마지막 단계야"가 옳은 번역입니다. 모두들 볼 수 있게 위로 올려주세요. 또 마블의 번역가 박읍읍씨가 해냈네요. 영화...',
#   '10',
#   '23713',
#   '567',
#   datetime.datetime(2018, 4, 25, 15, 34),
#   0],
#  ['RecOn(zkrp****)',
#   '번역가좀 짤라주세요 제발',
#   '1',
#   '14999',
#   '550',
#   datetime.datetime(2018, 4, 25, 16, 26),
#   0],
#  ['wndu****',
#   '그렇다. 토르는 신이엿다...',
#   '10',
#   '12922',
#   '299',
#   datetime.datetime(2018, 4, 25, 10, 54),
#   '관람객'],
#  ['박우진(wls8****)',
#   '그냥 너무 충격먹어서 할말이없다...',
#   '10',
#   '9509',
#   '306',
#   datetime.datetime(2018, 4, 25, 10, 32),
#   0],
#  ['별명(bomu****)',
#   '내년까지 살아가야 할 이유가 생겼습니다',
#   '10',
#   '8785',
#   '255',
#   datetime.datetime(2018, 4, 25, 11, 22),
#   '관람객'],
#  ['창전동비욘세(anna****)',
#   '3시간짜리 어벤져스4  예고편보고옴',
#   '9',
#   '8357',
#   '306',
#   datetime.datetime(2018, 4, 25, 13, 7),
#   0],
#  ['천냉(0806****)',
#   '토르 지구 귀환 씬에서 탄성이 절로 나옴',
#   '10',
#   '7765',
#   '118',
#   datetime.datetime(2018, 4, 25, 15, 35),
#   0],
#  ['rlar****',
#   '영화는 너무 좋은데 자막 돌았나? 닥터 스트레인지가 마지막에 이젠 다 끝났어가 아니라 이제 최종단계야가 맞는 해석아님? 글고 쿠키영상에 마더파커를 어머니찾는 효자로 만들어놨네ㄷㄷ 영화의 재미를 자막이 반감시키는듯 하...',
#   '10',
#   '6791',
#   '154',
#   datetime.datetime(2018, 4, 25, 13, 14),
#   0],
#  ['송호종(ax_e****)',
#   '마블한테 댓글알바랜다 ㅋㅋㅋ마이클잭슨이 음반사재기 하는소리하네',
#   '9',
#   '5619',
#   '208',
#   datetime.datetime(2018, 4, 25, 10, 13),
#   0],
#  ['alsl****',
#   '타노스에게 당하고도 주늑들지 않았던것은 토르뿐이였다영화마지막 4살짜리 아이처럼신을찾는 캡틴과 스타크의 좌절..결국 그들도 영웅이기 이전에 재앙과 전쟁이 두려운 그저 인간이었다는것 누가쎄다 약하다보다 인간과 신의차이를...',
#   '10',
#   '5514',
#   '208',
#   datetime.datetime(2018, 4, 25, 13, 31),
#   0],
#  ['ClasS(perk****)',
#   '성지예약)) 잘봐라 닥터스트레인지가 첨에 분명 느그들 다 죽어도 타임스톤 지킨다고 했지 글구나서 이기는 경우 1개라했고 근데 토니 죽기직전에 타임스톤을 넘김 이건, 타임스톤을 넘겨야만 승리한다는것. 여기서 예측=타노...',
#   '10',
#   '6560',
#   '1309',
#   datetime.datetime(2018, 4, 25, 18, 19),
#   0],
#  ['Henry(henr****)',
#   '이 영화의 최고의 빌런은 번역가다.',
#   '9',
#   '4788',
#   '83',
#   datetime.datetime(2018, 4, 25, 16, 45),
#   '관람객'],
#  ['스미스(surp****)',
#   '타노스는  손가락 튕기는것 만으로 어벤져스의 진골과 성골을 구별한다.',
#   '10',
#   '4487',
#   '111',
#   datetime.datetime(2018, 4, 25, 14, 22),
#   0],
#  ['김혜린(hyer****)',
#   '미세먼지 원인이 타노스 였다...',
#   '7',
#   '4448',
#   '131',
#   datetime.datetime(2018, 4, 25, 15, 38),
#   0],
#  ['효르스(dar1****)',
#   '스타로드 때문에 망한영화...',
#   '10',
#   '5350',
#   '1217',
#   datetime.datetime(2018, 4, 25, 11, 42),
#   0],
#  ['김진성(kjs9****)',
#   '진짜 영화 다끝나고 나서 영화관에 사람들 전부다 벙쪄있다.. 본사람만 알듯..',
#   '10',
#   '4073',
#   '102',
#   datetime.datetime(2018, 4, 25, 11, 3),
#   0],
#  ['일체유심조(esot****)',
#   '유튜버 추측한 인간들 다 틀렸어 ㅋㅋㅋ',
#   '10',
#   '4032',
#   '133',
#   datetime.datetime(2018, 4, 25, 11, 43),
#   0],
#  ['목욕탕(kang****)',
#   '본식사를위한 에피타이져를 너무 거하게 차려놓음',
#   '10',
#   '3818',
#   '145',
#   datetime.datetime(2018, 4, 25, 11, 7),
#   '관람객'],
#  ['pooh(zsez****)',
#   '토르가 이리치이고 저리치여도 신은 신이였다',
#   '10',
#   '3520',
#   '50',
#   datetime.datetime(2018, 4, 25, 12, 37),
#   '관람객'],
#  ['12341(hdk9****)',
#   '미친아빠의 휴먼드라마 ㅜㅜ',
#   '10',
#   '3499',
#   '143',
#   datetime.datetime(2018, 4, 25, 10, 51),
#   0],
#  ['Lucid(luci****)',
#   '사랑에 눈먼 스타로드 ...',
#   '10',
#   '3418',
#   '142',
#   datetime.datetime(2018, 4, 25, 11, 42),
#   0],
#  ['승큐(ksk4****)',
#   '잔칫집이라고 들어갔는데 나올땐 상갓집  다녀온 느낌....',
#   '10',
#   '3254',
#   '59',
#   datetime.datetime(2018, 4, 25, 17, 25),
#   0],
#  ['영이(kkss****)',
#   '헐크가 수트타고 뛰어가다가 자빠지니깐  와칸다 여전사가  (뭐지 이새기는)  라는 표정으로 쳐다보는거 개웃김',
#   '10',
#   '3093',
#   '50',
#   datetime.datetime(2018, 4, 26, 1, 20),
#   0],
#  ['Sr(sang****)',
#   '스타로드 욕하지마라 스타로드때문에 4편이 있다는걸 고마워 해야지',
#   '10',
#   '3063',
#   '125',
#   datetime.datetime(2018, 4, 25, 14, 31),
#   0],
#  ['white bird(dldb****)',
#   '진짜 마블코리아 돈 먹었어요? 수많은 사람들이 박지훈 그만 쓰라고 온갖 난리를 피우고 또 지금처럼 영화 스토리 자체를 바꿔버리는 오역이 발생하는데 왜 자꾸 쓰는 지 이해가 안되네 ㅋㅋㅋ 데드풀 번역가 분 좀 쓰면 덧...',
#   '6',
#   '2952',
#   '106',
#   datetime.datetime(2018, 4, 25, 17, 48),
#   0],
#  ['park****',
#   '번역하는사람 진짜 마지막에 어머니보고 할말을 잃었다',
#   '10',
#   '2811',
#   '70',
#   datetime.datetime(2018, 4, 25, 13, 0),
#   0],
#  ['hy05****',
#   '딴 건 모르겠고 번역가는 짤라야됨 상태 개판이었음스포라서 말은 못하겠는데 중요한 떡밥대사를 전혀 다른 의미로 해석해놨어',
#   '9',
#   '2678',
#   '57',
#   datetime.datetime(2018, 4, 25, 13, 55),
#   0],
#  ['jwon****',
#   '새벽에 마누라 몰래 나와서 봤다 지금 주차장인데 못올라 가겠다 폰에 마눌님 이름으로 부재중이 2통이다. 간격은 1시간 처음은 위치확인 두번째는 경고 이제 올라가면 거실 소파에 타노스가 앉아있을것이다',
#   '10',
#   '2812',
#   '217',
#   datetime.datetime(2018, 4, 26, 2, 39),
#   0],
#  ['가지(gkdu****)',
#   '앤트맨이랑 호크아이는 출연진에 왜 써져 있는겨...',
#   '10',
#   '2670',
#   '100',
#   datetime.datetime(2018, 4, 25, 14, 0),
#   0],
#  ['인간(tkek****)',
#   '확실히 원작안본사람들한텐 결말 충격적이긴할듯 진짜 겁나처절함',
#   '10',
#   '2647',
#   '91',
#   datetime.datetime(2018, 4, 25, 10, 53),
#   0],
#  ['안드레아(kch2****)',
#   '타노스가 꿈꾸는 복지사회',
#   '10',
#   '2287',
#   '49',
#   datetime.datetime(2018, 4, 25, 13, 24),
#   0],
#  ['기린(bin7****)',
#   '어벤져스에 굳이 댓글알바가 필요한가?',
#   '10',
#   '2282',
#   '167',
#   datetime.datetime(2018, 4, 25, 9, 16),
#   0],
#  ['ly55****',
#   '타노스 입장 타노스 시점인 영화 이놈은 나쁜놈이야! 이놈은 져야돼! 라는 생각이 들지 않고 이 악당의 마음 생각들을 읽어내면서 타노스라는 악당에게 몰입되는 그냥 일반 히어로 트랜스포머 같은 영화가 아닌 수준 높은 아...',
#   '10',
#   '2189',
#   '165',
#   datetime.datetime(2018, 4, 25, 10, 46),
#   0],
#  ['Seung Hee Cho(seun****)',
#   '이정도면 다음주에 인피니티 워 2 개봉해야된다',
#   '10',
#   '2015',
#   '34',
#   datetime.datetime(2018, 4, 25, 17, 19),
#   0],
#  ['FirstPitch(mrzu****)',
#   '나의 히어로들이 쩌리 취급 받는 모습보니 개 우울',
#   '10',
#   '1982',
#   '42',
#   datetime.datetime(2018, 4, 25, 12, 56),
#   0],
#  ['파츠(np10****)',
#   '솔직히 한국영화가 비빌 수 있는 수준이 아니다 신의영역이다',
#   '10',
#   '1927',
#   '78',
#   datetime.datetime(2018, 4, 25, 18, 59),
#   0],
#  ['유뇨현(hy99****)',
#   '8시 조조로 봣는데 보니까 너무 허무하고 현타 온다',
#   '10',
#   '2008',
#   '160',
#   datetime.datetime(2018, 4, 25, 10, 50),
#   0],
#  ['1346****',
#   '닉 퓨리는 어머니를 애타게 찾는 효자였다',
#   '10',
#   '1826',
#   '46',
#   datetime.datetime(2018, 4, 25, 15, 53),
#   0],
#  ['알트(opop****)',
#   '스포안당할려고 8시 조조로 보고왓습니다.절대로 스포 당하지 말고보세요 그래야  이 감정을 당신도 느낍니다',
#   '10',
#   '1804',
#   '68',
#   datetime.datetime(2018, 4, 25, 10, 52),
#   0],
#  ['정주연(luvl****)',
#   '아.. 약간 화가나요.. 내가 뭘본건가 싶고.. 영화가 안끝났으면 하는마음으로 시계를 봤어요.',
#   '10',
#   '1817',
#   '109',
#   datetime.datetime(2018, 4, 25, 10, 36),
#   0],
#  ['ㅁㅁㅁㅁㅁㅁ(zhrl****)',
#   '토르가 강하긴하네..',
#   '10',
#   '1723',
#   '23',
#   datetime.datetime(2018, 4, 25, 12, 21),
#   0],
#  ['듀로탄(alst****)',
#   '역대 히어로물 영화 중에 빌런 해피엔딩은 이번이 처음이다...',
#   '10',
#   '1821',
#   '132',
#   datetime.datetime(2018, 4, 25, 11, 11),
#   0],
#  ['ashj****',
#   '내한멤버의 가슴 아픈 공통점...ㅠㅜ',
#   '10',
#   '1743',
#   '57',
#   datetime.datetime(2018, 4, 25, 13, 4),
#   0],
#  ['ZTT(zunt****)',
#   '롤러코스터 탔는데 마지막에 선로가 끊어진 기분이었다....',
#   '10',
#   '1717',
#   '51',
#   datetime.datetime(2018, 4, 25, 11, 53),
#   '관람객'],
#  ['물방울(ho12****)',
#   '초반 5분에 충격먹었다... 그 이후는 더 충격 하..',
#   '10',
#   '1716',
#   '64',
#   datetime.datetime(2018, 4, 25, 9, 36),
#   0],
#  ['융끼(udan****)',
#   '디씨 이제 마블에  비빌 시도도 못할듯',
#   '10',
#   '1697',
#   '60',
#   datetime.datetime(2018, 4, 25, 14, 51),
#   0],
#  ['N21(sjk1****)',
#   '캡틴은 싫어하지만 등장씬 레전드였다',
#   '10',
#   '1709',
#   '100',
#   datetime.datetime(2018, 4, 25, 11, 42),
#   0],
#  ['해사마님(haes****)',
#   '먼지가 되어 날아 가야지바람에 날려',
#   '10',
#   '1749',
#   '179',
#   datetime.datetime(2018, 4, 25, 10, 53),
#   0],
#  ['kym(hell****)',
#   '이번편처럼 오프닝이 무서웠던적이없다.',
#   '10',
#   '1430',
#   '33',
#   datetime.datetime(2018, 4, 25, 12, 0),
#   0],
#  ['DIny(diny****)',
#   '토르랑 결혼하고 싶다...',
#   '10',
#   '1438',
#   '54',
#   datetime.datetime(2018, 4, 25, 11, 28),
#   '관람객'],
#  ['안쫑(ilov****)',
#   '토니는 집에 어떻게 갈까 ?',
#   '10',
#   '1379',
#   '17',
#   datetime.datetime(2018, 4, 25, 16, 40),
#   0],
#  ['곰팅이(aswd****)',
#   '닥터스트레인지의 큰 그림이길 바래야지...',
#   '10',
#   '1366',
#   '16',
#   datetime.datetime(2018, 4, 25, 15, 5),
#   0],
#  ['엔디버(wj36****)',
#   '티리온 라니스터 왜 우주에서 대장장이하고 있냐.',
#   '10',
#   '1334',
#   '29',
#   datetime.datetime(2018, 4, 25, 15, 22),
#   0],
#  ['ChaeSooBin(fast****)',
#   '타노스는 정말 무자비한 악당일까?',
#   '10',
#   '1377',
#   '76',
#   datetime.datetime(2018, 4, 25, 11, 18),
#   '관람객'],
#  ['stelle(chw1****)',
#   '살려낼 거 다 아니까 참았는데 ㅠㅠㅠㅠ 미친 거 아닙니까.... 스파이디 아이언맨한테 안겨서 울 때 주먹울음.... 왜 로다주 우주에서 제일 불쌍한 인간 만들어요.... 미친....',
#   '10',
#   '1332',
#   '36',
#   datetime.datetime(2018, 4, 25, 15, 27),
#   0],
#  ['김은성(qpwo****)',
#   'DC의 다크함마저 마블이 앗아갔다.',
#   '10',
#   '1303',
#   '40',
#   datetime.datetime(2018, 4, 25, 14, 43),
#   0],
#  ['무명사랑(naky****)',
#   '영화후기? 한마디만할께요.뒷감당 알아서 하세요.  하 마블이 10년동안 준비한 영화가 나한테 빅엿을 선사했네...',
#   '10',
#   '1870',
#   '674',
#   datetime.datetime(2018, 4, 25, 10, 45),
#   0],
#  ['힝(ikhg****)',
#   '토르 등장씬에서 온몸에 전율이~~',
#   '10',
#   '1174',
#   '13',
#   datetime.datetime(2018, 4, 25, 16, 24),
#   '관람객'],
#  ['fjd3534(sgn1****)',
#   '닥스의 "It\'s end game" 대사를 이제 다 끝났다라고 번역해서 한국 관객들만 멘붕 저건 "이제 최종 단계야"라는 뜻인데..또 닉 퓨리의 "mother fxxk\x03...',
#   '10',
#   '1187',
#   '39',
#   datetime.datetime(2018, 4, 25, 16, 55),
#   0],
#  ['형(rhdb****)',
#   '그래서 뭘 잃었어? Everything..',
#   '10',
#   '1164',
#   '28',
#   datetime.datetime(2018, 4, 25, 16, 28),
#   0],
#  ['망탱파더(osun****)',
#   '충격적...토르겁나쌤',
#   '10',
#   '1109',
#   '15',
#   datetime.datetime(2018, 4, 25, 12, 28),
#   0],
#  ['이우석(z123****)',
#   '와칸다 포에버! 소름..',
#   '10',
#   '1115',
#   '21',
#   datetime.datetime(2018, 4, 25, 15, 54),
#   0],
#  ['사상(rimu****)',
#   '옆에 남자분 못일어 나네요 아무래도 지리신듯... 쿠키영상 끝났는데 말리고 나가시려나... 난 그래서 기저귀 차고 왔는데....',
#   '10',
#   '1197',
#   '103',
#   datetime.datetime(2018, 4, 25, 10, 55),
#   0],
#  ['별이되는게쉽냐(nong****)',
#   '아니 평이 까는 늬앙슨데도 왜 점수는 다들 10점 주는거지? 왜냐면 보면 알아요..',
#   '10',
#   '1111',
#   '24',
#   datetime.datetime(2018, 4, 25, 14, 42),
#   0],
#  ['05ru****',
#   '감독의 말대로 메인빌런인 타노스의 시점에서 흘러가는 영화, 그리고 몇몇히어로들이 먼지가될때 관객들의 멘탈도 먼지가 됨',
#   '10',
#   '1178',
#   '116',
#   datetime.datetime(2018, 4, 25, 11, 59),
#   '관람객'],
#  ['초록거미(whtj****)',
#   '박지훈이 번역하는동안은 난 계속 1점줄란다닥터스트레인지의 역대급 한마디를 난 오해하고 봤다는게 개빡친다. 비장의 한수를 뒀던 닥스가 희대의 씹트롤러가됐다. 박지훈 짤라라.',
#   '1',
#   '1053',
#   '38',
#   datetime.datetime(2018, 4, 26, 1, 11),
#   '관람객'],
#  ['다치코마(an23****)',
#   '욕쟁이 닉퓨리를 효자로 만들어 버렸다.',
#   '10',
#   '1033',
#   '25',
#   datetime.datetime(2018, 4, 25, 14, 34),
#   0],
#  ['포이부스(abck****)',
#   '쿠키에서 닉퓨리가 캡틴마블 부른거 맞죠?',
#   '9',
#   '1088',
#   '83',
#   datetime.datetime(2018, 4, 25, 11, 39),
#   0],
#  ['Soulchild(tash****)',
#   '헐크, Dr. 타노스 만나고 분노조절장애 완치.',
#   '10',
#   '1016',
#   '15',
#   datetime.datetime(2018, 4, 26, 3, 43),
#   0],
#  ['양재준(jun_****)',
#   '타노스 왠지모르게 외로워보인다.',
#   '10',
#   '967',
#   '22',
#   datetime.datetime(2018, 4, 25, 11, 30),
#   0],
#  ['내일모래(hich****)',
#   '토르만 속시원한 영화 .. 혼자 하고싶은거 다함',
#   '10',
#   '955',
#   '12',
#   datetime.datetime(2018, 4, 25, 19, 18),
#   0],
#  ['ks0052(yks0****)',
#   '닥스형 .. 도르마무 내가왔다 라고 무한반복했었자나...이번에도 주문걸어놨지? 그치? 단지 반복 주기가 1년인거지?ㅠ',
#   '10',
#   '963',
#   '23',
#   datetime.datetime(2018, 4, 25, 13, 52),
#   0],
#  ['힐러(hela****)',
#   '다 필요없고 사춘기 그루트 존나귀엽지않음?',
#   '10',
#   '936',
#   '12',
#   datetime.datetime(2018, 4, 26, 22, 44),
#   0],
#  ['sang****',
#   '이걸볼수있는 세상에 태어나서 참 감사하다 ..',
#   '10',
#   '950',
#   '44',
#   datetime.datetime(2018, 4, 25, 9, 37),
#   0],
#  ['나빠(guys****)',
#   '그냥충격. 근데 타노스 마음이 조금 이해간다 왜지?',
#   '10',
#   '929',
#   '62',
#   datetime.datetime(2018, 4, 25, 11, 8),
#   0],
#  ['스마일(gnk5****)',
#   '이전까지 봤던 어밴져스와 분위기가 사뭇 다르다.모든 것이 닥터 스트레인지가 말한 단 한번의 승리의 일부이길...',
#   '8',
#   '877',
#   '19',
#   datetime.datetime(2018, 4, 25, 11, 41),
#   0],
#  ['next****',
#   '사실 타노스 그는 주인공 이였다....',
#   '10',
#   '868',
#   '31',
#   datetime.datetime(2018, 4, 25, 12, 30),
#   0],
#  ['innerglow(ayaa****)',
#   '쿠키까지 기다렸으나 멘붕으로 나옴',
#   '10',
#   '811',
#   '24',
#   datetime.datetime(2018, 4, 25, 11, 7),
#   '관람객'],
#  ['세기의걸작히오스(davi****)',
#   '번역한분 다른직업 찾아보자',
#   '10',
#   '780',
#   '17',
#   datetime.datetime(2018, 4, 25, 16, 27),
#   0],
#  ['삼류작가(dama****)',
#   '이 영화는 진짜 미친 영화다 영화 크레딧이 올라갔을 때 모든 사람들이 일관적으로 입을 벌리고 멍을 때리고 있었다 영화 자체로도 먹먹하고  절망적이지만 어떻게 2019년을 기다려야 하는지가 더 크다',
#   '10',
#   '783',
#   '23',
#   datetime.datetime(2018, 4, 25, 14, 54),
#   0],
#  ['daughtry(mayb****)',
#   '소문난 잔치가 고구마 잔치였고 그 고구마만으로 관객을 충격의 도가니로 빠트리는 마블 당신들은 도덕책..',
#   '9',
#   '766',
#   '44',
#   datetime.datetime(2018, 4, 25, 12, 7),
#   0],
#  ['Qush(tmxh****)',
#   '이 영화를 보기 위해 필요한 것은음료도, 팝콘도, 과자도 아닌 우황청심환이다.',
#   '10',
#   '732',
#   '28',
#   datetime.datetime(2018, 4, 25, 12, 32),
#   '관람객'],
#  ['아르카디아(ulla****)',
#   '짱개들이 할리우드에 돈 쳐발라서 중국색 입히려고 하는데 제발 마블에다가는 투자 못하게했으면',
#   '10',
#   '672',
#   '18',
#   datetime.datetime(2018, 4, 25, 18, 12),
#   0],
#  ['세느19(bob6****)',
#   '닥터가 1개가이긴다했지 스타크가살아있어야이긴다는 말인듯 보고나왔는데 일이손에안잡힌다',
#   '10',
#   '652',
#   '12',
#   datetime.datetime(2018, 4, 25, 13, 30),
#   0],
#  ['pswd****',
#   '번역가 누구냐...mother fxxx 가 "어머니"냐?  번역이 좋은 영화 조져서 반개뺐다.. 영화는 두번 봐라! 대박임',
#   '9',
#   '632',
#   '22',
#   datetime.datetime(2018, 4, 25, 14, 45),
#   0],
#  ['폭탄발언(shla****)',
#   '피터 퀼....꼭 그랬어야만 속이 후련했냐!!!',
#   '10',
#   '626',
#   '31',
#   datetime.datetime(2018, 4, 25, 11, 29),
#   0],
#  ['inspirit(leah****)',
#   '끝나고 다 같이 벙쪄있음... 이게 끝난 건가 싶고 끝나고 20분 동안 이게 뭐지 라는 말만 반복함 확실히 재미는 있지만 이게 뭐지...? 본 사람만 알 듯',
#   '10',
#   '601',
#   '20',
#   datetime.datetime(2018, 4, 25, 12, 3),
#   0],
#  ['렝루롤(yjh1****)',
#   'the end game 닥터스트레인지의 대사인데요. 이것은 마지막 단계야 라는 의미도 있지만 체스에서 왕을 잡을때 두는 수를 보고 의미하는 말입니다',
#   '10',
#   '589',
#   '10',
#   datetime.datetime(2018, 4, 26, 1, 20),
#   0],
#  ['용이오빠(tige****)',
#   '정말 149분이 이렇게 빨리 지나가기는 처음이다.... 영화가 끝나지 않기를 바랬다.. 영화관내의 모두가 숨을 죽이면서 봤고.. 다들 자신이 어벤져스인마냥 깊은 패배감과 슬픔을 가진 시선으로 스크린을 바라보고 있었다...',
#   '10',
#   '595',
#   '22',
#   datetime.datetime(2018, 4, 25, 15, 19),
#   0],
#  ['비랄(sung****)',
#   '토르.. 히어로 오브 어벤져스 인정합니다.',
#   '10',
#   '553',
#   '8',
#   datetime.datetime(2018, 4, 25, 12, 58),
#   0],
#  ['snoo****',
#   '제발 번역가 적폐청산좀 진짜 너무 화납니다 저런 능력없는 사람이 인맥빨로 당당히 번역하고 있다는게 너무 역겹습니다',
#   '10',
#   '543',
#   '7',
#   datetime.datetime(2018, 4, 25, 20, 11),
#   0],
#  ['아(msw-****)',
#   "영화 마지막 쿠키영상의 문양은 '캡틴마블'을 의미합니다.",
#   '10',
#   '554',
#   '19',
#   datetime.datetime(2018, 4, 25, 13, 21),
#   0],
#  ['gowl****',
#   '블랙펜서 “와칸다포에버” 하고 다같이 달려갈때 솔직히 지렸다 추천ㅋ',
#   '10',
#   '539',
#   '12',
#   datetime.datetime(2018, 4, 27, 19, 51),
#   0],
#  ['hjk1****',
#   '나는 로키가 제일 인상깊었음. 그눈빛 아직도생각나는데 왜 아무도 거론을안하지 ㄷㄷ',
#   '10',
#   '530',
#   '11',
#   datetime.datetime(2018, 4, 26, 21, 18),
#   0],
#  ['심지(ytra****)',
#   '갑자기 입맛이 없고 우울하네요..',
#   '10',
#   '537',
#   '24',
#   datetime.datetime(2018, 4, 25, 12, 21),
#   0],
#  ['만돌(kuma****)',
#   '덕후들은 만족할만한 디테일을 뽑아냈지만스타로드에게 발암포지션을 맡길줄...아쉽다!Part1인걸로 만족하쟈',
#   '9',
#   '545',
#   '38',
#   datetime.datetime(2018, 4, 25, 10, 53),
#   0],
#  ['qodu****',
#   '첫째로 이렇게 희망과 꿈이 없는 영화는 처음.. 둘째는 악당인 타노스에게 반하게 되고..셋번째로는 이번편이 끝이 아니고 2부가 나올것을 아니까 제발 영화가 끝나지 않길 바랬다..',
#   '10',
#   '548',
#   '41',
#   datetime.datetime(2018, 4, 25, 11, 36),
#   '관람객'],
#  ['hataegi(glgg****)',
#   '여기 들어와서 이댓글 보는순간 당신은 이미 스포당한 상태입니다 인터넷끄시고 극장으로 뛰어가세요',
#   '9',
#   '506',
#   '15',
#   datetime.datetime(2018, 4, 25, 15, 33),
#   '관람객'],
#  ['saki****',
#   '처발릴거라 예상은했지만.. 많이어둡다. 엔딩크렛딧 올라갈때 나오는 음악조차 어둡다',
#   '10',
#   '503',
#   '13',
#   datetime.datetime(2018, 4, 25, 12, 52),
#   0],
#  ['다빈치(ohk3****)',
#   '2002년 월드컵 4강전 패배한 그날의 느낌. . .졌는데 졸라 잘해서 할 말이 없어',
#   '9',
#   '492',
#   '9',
#   datetime.datetime(2018, 4, 26, 0, 54),
#   0],
#  ['라벨로(wjdx****)',
#   '시리즈가 갈수록 힘이빠지는게 아니라 역대급으로 경신... 다시 예매하러 감 .꼭 아무 스포없이 가세요',
#   '10',
#   '487',
#   '16',
#   datetime.datetime(2018, 4, 25, 12, 38),
#   '관람객'],
#  ['마카리나(kang****)',
#   '충격의 결말을 맞이하라',
#   '9',
#   '491',
#   '23',
#   datetime.datetime(2018, 4, 25, 10, 53),
#   '관람객'],
#  ['미용계에서 부자(qkdt****)',
#   '가슴이 아니라 목을 베어야지...',
#   '10',
#   '462',
#   '3',
#   datetime.datetime(2018, 4, 25, 19, 13),
#   0],
#  ['네코와24(axdp****)',
#   '어벤져스:타노스의 무한파워',
#   '10',
#   '466',
#   '19',
#   datetime.datetime(2018, 4, 25, 11, 34),
#   0],
#  ['어쿠스틱꼴라보(heli****)',
#   '주인공은 토르...망치 들고 등장할때 소름~~',
#   '10',
#   '462',
#   '17',
#   datetime.datetime(2018, 4, 25, 13, 7),
#   0],
#  ['acourve(tjdw****)',
#   '와 나 영화보고 집가는길에 천천히 다시 생각해봤는데닥터스트레인지가 왜 타임스톤 넘긴지 생각해봤는데 일부러넘긴거였어ㅋㅋㅋㅋ개소름돋네진짜 타임스톤넘긴게 이길수있는 한가지방법이였는데 넘긴게 타노스가 어떠한이유로 다시 시간...',
#   '10',
#   '450',
#   '18',
#   datetime.datetime(2018, 4, 25, 21, 38),
#   0],
#  ['AHHA(kdyi****)',
#   '토르는 역시 신이구먼. 잠시나마 잊고 있었어.',
#   '10',
#   '438',
#   '12',
#   datetime.datetime(2018, 4, 25, 12, 46),
#   0],
#  ['별의전설(kyuy****)',
#   '누가토르가 조밥이라고했노? 다죽일삘라토르가 마블에서 1인자다',
#   '10',
#   '437',
#   '13',
#   datetime.datetime(2018, 4, 25, 21, 53),
#   0],
#  ['그깟대충(gomu****)',
#   '마크러팔로가 실수로 스포한게 진짜였을줄이야ㅋㅋㅋ',
#   '9',
#   '434',
#   '15',
#   datetime.datetime(2018, 4, 25, 19, 4),
#   0],
#  ['또리(iaan****)',
#   '스타로드 욕하는 인간들아 ;; 닥터가 그것까지 안보고 일저질렀겠냐?? 생각좀',
#   '10',
#   '426',
#   '16',
#   datetime.datetime(2018, 4, 25, 17, 47),
#   0],
#  ['혁이(sksk****)',
#   '14000602분의 1',
#   '10',
#   '415',
#   '18',
#   datetime.datetime(2018, 4, 25, 19, 24),
#   0],
#  ['핸(jhae****)',
#   '거의 어벤져스 구조조정',
#   '10',
#   '397',
#   '6',
#   datetime.datetime(2018, 4, 26, 0, 19),
#   0],
#  ['마징가(goon****)',
#   '비젼 동네개찐따처럼만들어놨네 이마에보석아깝다 ㅡㅡ',
#   '8',
#   '395',
#   '10',
#   datetime.datetime(2018, 4, 26, 15, 48),
#   0],
#  ['피탕(peta****)',
#   '옆에 계신 분이 마지막 장면을 보고 어이가 없어서 입을 못 다무신 모습 잘 관람하였습니다.',
#   '8',
#   '402',
#   '17',
#   datetime.datetime(2018, 4, 25, 11, 43),
#   0],
#  ['벅경(kyun****)',
#   '아이언맨 광팬이였던 내가...토르만 생각이난다.. 토르는 신이였다.',
#   '10',
#   '380',
#   '2',
#   datetime.datetime(2018, 4, 26, 2, 51),
#   '관람객'],
#  ['고태성(rh98****)',
#   'DC우는 소리가 여기까지 들린다ㅋㅋㅋ',
#   '10',
#   '373',
#   '15',
#   datetime.datetime(2018, 4, 25, 17, 36),
#   0],
#  ['NOC(vkfk****)',
#   '박지훈이라는 번역가가 대작 하나를 망치는구나',
#   '10',
#   '357',
#   '4',
#   datetime.datetime(2018, 4, 25, 19, 52),
#   0],
#  ['라지쥬(sawa****)',
#   '그거 하나 생각났다.. 마블시리즈가 더 안나오면 볼영화 없겠구나....',
#   '10',
#   '364',
#   '11',
#   datetime.datetime(2018, 4, 25, 14, 19),
#   0],
#  ['박정훈(8242****)',
#   '닥터스트레인지가 말한 한 가지 승리 방법이 타노스가 직접 후회하게 만들어서 시간을 되돌리는 겁니다.',
#   '10',
#   '367',
#   '18',
#   datetime.datetime(2018, 4, 25, 23, 2),
#   0],
#  ['월야1234(cotm****)',
#   "닥터 스트레인지의 최후반부 대사  '이제 다 끝났어'   는 틀린 번역입니다 이게 최종단계야 가 옳은 표현입니다 Mother fucker라는 욕을 '어머니'라고 번역했습니다 이글을 읽으신...",
#   '10',
#   '352',
#   '8',
#   datetime.datetime(2018, 4, 25, 16, 51),
#   0],
#  ['해온(haeo****)',
#   '형형색색의 공기돌을  수집하는 딸바보 아빠의 우주여행기',
#   '10',
#   '342',
#   '5',
#   datetime.datetime(2018, 4, 28, 16, 31),
#   0],
#  ['타마(dutl****)',
#   '우주를 살리기위한 타노스 선생의 위대한 희생정신이 빛나는 영화',
#   '10',
#   '354',
#   '17',
#   datetime.datetime(2018, 4, 25, 13, 43),
#   '관람객'],
#  ['정윤서(duri****)',
#   '10년동안 마블의팬이셨던분들은 기존의식상한 엔딩과는다른 신선한엔딩을볼수있어서 충격과 어벙찜이 공존할것이고 히어로물을 처음보신분들이라면 그냥 쓰레기영화.',
#   '10',
#   '418',
#   '86',
#   datetime.datetime(2018, 4, 25, 11, 10),
#   0],
#  ['Kindtoast(dlwo****)',
#   '진짜 관객을 호구로 보나? 헤임달은 흑마법사처럼 되고 통과 능력을 페이징이라 쓰고  속편을 기대하게 만들어야 하는 닥터 스트레인지의 말을  가망 없는것마냥 번역해버리네. 돈주고 티켓산 관객들한테 피해를 줄거면 그냥 ...',
#   '10',
#   '338',
#   '7',
#   datetime.datetime(2018, 4, 25, 23, 0),
#   0],
#  ['피타입(xosk****)',
#   '닥터가 시간을 앞질러 몇십만개의 미래를 보고왔다고했을때토니가 승리할수있는 방법이 있냐고 물었을때단 한가지 있다고 했다분명히 닥터는 보석을 순순히 넘겨준게 아니다',
#   '10',
#   '321',
#   '5',
#   datetime.datetime(2018, 4, 26, 9, 39),
#   '관람객'],
#  ['일이삼사(bong****)',
#   '히어로물에 권선징악이 없다니..',
#   '10',
#   '326',
#   '12',
#   datetime.datetime(2018, 4, 25, 13, 18),
#   0],
#  ['찹쌀개(sahr****)',
#   '스포 하지마라 진짜 우리가 느낀 그 결말의 충격을 모든 사람들이 느껴야 해',
#   '10',
#   '317',
#   '5',
#   datetime.datetime(2018, 4, 25, 14, 36),
#   0],
#  ['곰곰(mank****)',
#   '토르랑 스칼렛만 개쎄다.',
#   '8',
#   '315',
#   '7',
#   datetime.datetime(2018, 4, 25, 20, 41),
#   0],
#  ['이창주(ckdw****)',
#   '기대한만큼 꿀잼인데 그냥 충격이다',
#   '10',
#   '308',
#   '10',
#   datetime.datetime(2018, 4, 25, 11, 4),
#   0],
#  ['브랄레ㅔ렐(zlap****)',
#   '가벼운 마음으로 봣다간 현타오는 영화',
#   '10',
#   '303',
#   '6',
#   datetime.datetime(2018, 4, 25, 12, 57),
#   '관람객'],
#  ['소현이빠(duli****)',
#   '미친...맨탈파괴다마지막에',
#   '10',
#   '312',
#   '17',
#   datetime.datetime(2018, 4, 25, 10, 50),
#   0],
#  ['dgfas(lgk9****)',
#   '혼자보겟지 생각햇지만 역시 혼자봣다',
#   '10',
#   '298',
#   '10',
#   datetime.datetime(2018, 4, 25, 10, 53),
#   0],
#  ['시넝이(syri****)',
#   '엄청난 스케일에 한 번 놀래고 그 많은 영웅들 빠지지 않게 스토리가 잘 짜여있어 제작진 능력에 감탄하였습니다.',
#   '8',
#   '290',
#   '8',
#   datetime.datetime(2018, 4, 25, 21, 22),
#   '관람객'],
#  ['풀라(als5****)',
#   '닉퓨리 효자설....',
#   '10',
#   '284',
#   '4',
#   datetime.datetime(2018, 4, 25, 20, 59),
#   0],
#  ['김프로(just****)',
#   '와칸다 포에버 어벤져스 포에버',
#   '10',
#   '278',
#   '4',
#   datetime.datetime(2018, 4, 25, 20, 49),
#   0],
#  ['한국어좀해줘(emrw****)',
#   '토르는 소름돋을정도로 멋졌고 결말은.. 멘탈이 가루가 되어버리네..',
#   '10',
#   '278',
#   '4',
#   datetime.datetime(2018, 4, 25, 15, 29),
#   0],
#  ['BetterThanFlower(njs3****)',
#   '충격 그자체..마블은 매번 역대급이네..',
#   '10',
#   '273',
#   '12',
#   datetime.datetime(2018, 4, 25, 11, 53),
#   0],
#  ['back****',
#   '2편이 나와야만 하내 헐....',
#   '10',
#   '276',
#   '21',
#   datetime.datetime(2018, 4, 25, 10, 40),
#   0],
#  ['ddddddd(qhtj****)',
#   '댓글알바아니고 그냥 호감순 1등 먹으려는애들 아님? ㅋㅋㅋㅋ 국산영화도아니고 뭐 댓글알바가잇냐',
#   '10',
#   '336',
#   '81',
#   datetime.datetime(2018, 4, 25, 9, 28),
#   0],
#  ['혀언(yhki****)',
#   '세번소름끼쳤다첫번째 캡틴아메리카 등장할때두번째 토르무기들고 복귀할때세번째 시간끝났는데 사람들이 다 앉아서 멍깔때',
#   '10',
#   '251',
#   '3',
#   datetime.datetime(2018, 4, 25, 14, 53),
#   '관람객'],
#  ['이수현(masu****)',
#   '타노스의 감성이 폭발한다.',
#   '7',
#   '264',
#   '17',
#   datetime.datetime(2018, 4, 25, 12, 40),
#   '관람객'],
#  ['RhfepQk(helo****)',
#   '캡아 등장씬이 거진 수양대군등장씬에맞먹음ㅋ 진지충캡아대존잘ㅜㅠ',
#   '10',
#   '243',
#   '6',
#   datetime.datetime(2018, 4, 25, 20, 50),
#   0],
#  ['육지단(dydd****)',
#   '"우당탕탕"을 기대하고 갔다가 내 뒷통수 "우당탕탕" 뚜두러 맞고 집에 돌아왔다...',
#   '10',
#   '236',
#   '8',
#   datetime.datetime(2018, 4, 25, 12, 50),
#   '관람객'],
#  ['김민성(hell****)',
#   '정말 그나마 스포안당하고 조조로 본거에 감사하는중,,ㅎ',
#   '10',
#   '235',
#   '11',
#   datetime.datetime(2018, 4, 25, 11, 25),
#   '관람객'],
#  ['dlwh****',
#   '이게 다 목을 안 쳤기 때문이다',
#   '9',
#   '226',
#   '6',
#   datetime.datetime(2018, 4, 25, 21, 13),
#   0],
#  ['gktj****',
#   '스톰브레이커를  들고 와칸다에 등장한 토르의 모습을 보고 온 몸에 전율이 돋았다.',
#   '10',
#   '223',
#   '4',
#   datetime.datetime(2018, 4, 26, 21, 23),
#   0],
#  ['기현이안녕(rlgu****)',
#   '무슨 말이 더필요하죠?',
#   '10',
#   '255',
#   '37',
#   datetime.datetime(2018, 4, 25, 9, 27),
#   0],
#  ['현규(sund****)',
#   '아마 이 관객의 반도 멘탈이 먼지처럼 날아갔을듯.',
#   '10',
#   '219',
#   '9',
#   datetime.datetime(2018, 4, 25, 16, 1),
#   0],
#  ['케사장(kyun****)',
#   '이번 어벤져스의 주인공은 타노스라고 생각하고 영화보셔야 재밌습니다',
#   '8',
#   '221',
#   '11',
#   datetime.datetime(2018, 4, 25, 13, 23),
#   0],
#  ['용쨩(ehdd****)',
#   '토르 진짜 왜이렇게 멋있냐 소름돋았다',
#   '10',
#   '208',
#   '3',
#   datetime.datetime(2018, 4, 26, 21, 29),
#   0],
#  ['happ****',
#   '신랑이내일보자그래서 오늘몰래혼자보러왔는데 내일안본척하고신랑이랑또봐야겠어요',
#   '10',
#   '218',
#   '22',
#   datetime.datetime(2018, 4, 25, 12, 35),
#   0],
#  ['tyan****',
#   '스트레인지 대사가 이상하다고 생각했는데 오역이였다니...스토리 전체를 말아먹는 오역이네',
#   '10',
#   '183',
#   '4',
#   datetime.datetime(2018, 4, 25, 20, 52),
#   0],
#  ['crim****',
#   '재밌었다... 드디어 타노스를 만나게 되서 너무 좋았고 향후 10년 마블 스토리가 어떻게 전개될지 너무 궁금하다. 마블 세대에 살고 있다는 게 감사하다. 스타워즈 시리즈에 열광하는 사람들을 이해 못 했었는데 마블 시...',
#   '10',
#   '176',
#   '2',
#   datetime.datetime(2018, 4, 26, 23, 20),
#   0],
#  ['아르펠리노(robo****)',
#   '어벤져스를 그저 어린 애들을 위한 영화라고 생각하고 보면 큰 오산이다',
#   '10',
#   '181',
#   '8',
#   datetime.datetime(2018, 4, 25, 15, 8),
#   0],
#  ['뛰뛰빵빵(ihod****)',
#   '번역하시 분.. 나오세요..',
#   '10',
#   '179',
#   '7',
#   datetime.datetime(2018, 4, 25, 16, 23),
#   0],
#  ['저녁(over****)',
#   '소울스톤 가지러 갈 때 그 망령같은애 캡틴아메리카 1편에 걔 아님?',
#   '10',
#   '182',
#   '10',
#   datetime.datetime(2018, 4, 26, 17, 45),
#   '관람객'],
#  ['Grayhound(beom****)',
#   '야이 개념없는 ㅅㄲ들아 댓글에다 스포좀 하지마라이거 법적으로 책임좀 물려야지 참나...',
#   '10',
#   '190',
#   '27',
#   datetime.datetime(2018, 4, 25, 10, 9),
#   0],
#  ['아잉잇팅(hyck****)',
#   '박지훈 번역가좀 짤라주세요말한마디로 영화판도가 달라짐마더퍼커가 어떻게 어머니를 찾는 효자로 바뀝니까?이거는 중학생들도 알겠구만 차라리구글번역기를 써라',
#   '10',
#   '164',
#   '5',
#   datetime.datetime(2018, 4, 25, 19, 34),
#   0],
#  ['봉이(dmlq****)',
#   '헐크 타노스 만나고 분노조절 장애 완치됨 ㅋㅋ',
#   '8',
#   '161',
#   '3',
#   datetime.datetime(2018, 4, 26, 1, 24),
#   '관람객'],
#  ['psh9****',
#   '완벽하지 못한 영웅들과 자기나름대로의 철학을 가진 최강의 악당 타노스',
#   '10',
#   '154',
#   '2',
#   datetime.datetime(2018, 4, 25, 13, 32),
#   0],
#  ['JeongDooKim(jdhe****)',
#   '이거 엔딩후 영상있나요? 엔딩크레딧 졸라길어서 안보고 나왔는데.. 있으면 추천,없으면비추좀..',
#   '10',
#   '166',
#   '20',
#   datetime.datetime(2018, 4, 26, 1, 57),
#   0],
#  ['이쁜레아(pret****)',
#   '이번편  제목은 "타노스의 대모험"',
#   '9',
#   '149',
#   '5',
#   datetime.datetime(2018, 4, 25, 22, 4),
#   0],
#  ['스플래쉬(lord****)',
#   '영화끝나고 나서 타임스톤으로 149분전으로 돌아가고 싶었습니다. 예고편으로 스토리라인 예상하면 엿드시게 될거고 기존 마블영화와 후반부와 엔딩의 분위기가 180도 달라요 .. 극중 한 캐릭터의 대사를 제 마음에 빗대어...',
#   '8',
#   '158',
#   '15',
#   datetime.datetime(2018, 4, 25, 12, 53),
#   0],
#  ['옆집강아지가질래(dhaw****)',
#   '도대체 앤트맨이랑 호크아이는 주연 출연진에 왜있는거임?',
#   '10',
#   '152',
#   '10',
#   datetime.datetime(2018, 4, 25, 20, 8),
#   0],
#  ['붉은교룡(crup****)',
#   '이 영화 최대 빌런은 타노스가 아니라 박지훈이다',
#   '10',
#   '136',
#   '1',
#   datetime.datetime(2018, 4, 25, 23, 45),
#   '관람객'],
#  ['얌얌쩝쩝(www3****)',
#   '토르 미쳤다 정말....너무 섹시하다',
#   '10',
#   '138',
#   '4',
#   datetime.datetime(2018, 4, 27, 13, 24),
#   0],
#  ['돋네(whrb****)',
#   '“타노스는 돌아온다” 에서 소름돋았네요',
#   '10',
#   '133',
#   '2',
#   datetime.datetime(2018, 4, 25, 21, 27),
#   '관람객'],
#  ['MonkeyHoon(monk****)',
#   '다른 나라에서는 환호성 치는 장면이 우리나라에서는 번역가 때문에 개암울한 장면이 됨. 엄청 기대하고 봤고 닥터 좋아하는데 이상한짓 하길래 뭐지 싶어서 찾아보니까 오역. 영화결말을 바꿔버렸네 진짜.',
#   '10',
#   '129',
#   '2',
#   datetime.datetime(2018, 4, 26, 1, 5),
#   0],
#  ['104t****',
#   '토르가즘이 온몸을 통해서 부르르르',
#   '10',
#   '127',
#   '1',
#   datetime.datetime(2018, 4, 27, 13, 44),
#   0],
#  ['감띠(gold****)',
#   '캬 어벤져스를 문화의 날로 5천원주고 봤는데 5천원밖에 안준게 미안할정도의 영화였다 ㄹㅇ',
#   '10',
#   '128',
#   '2',
#   datetime.datetime(2018, 4, 26, 2, 55),
#   0],
#  ['mamo****',
#   '일이 손에 안잡힌다..',
#   '10',
#   '127',
#   '2',
#   datetime.datetime(2018, 4, 25, 19, 25),
#   '관람객'],
#  ['틱톡(jkdk****)',
#   '스포일러에게 맞지 않으려면 선빵치는 방법밖에 없다. 그렇다 분명 나는 선빵을 쳤지만 영화에게 처절하게 짓밟혔다.',
#   '10',
#   '125',
#   '1',
#   datetime.datetime(2018, 4, 25, 18, 25),
#   '관람객'],
#  ['dddn(boyb****)',
#   '닉퓨리가 거기서 왜 엄마를 찾냐? 뒤에 f단어 하지못한거겟지. 영알못인 나도 그정도는 알겟다',
#   '8',
#   '127',
#   '3',
#   datetime.datetime(2018, 4, 25, 18, 30),
#   0],
#  ['osw7****',
#   '아니 얘들아 어차피 첫 조조타임이 8시 30분이고 지금 9시 반이라 첫 상영보는사람도 아직 다 안보고 보는중이야. 지금 평점 쓴애들은 다 안본애들이라고 생각하면되',
#   '10',
#   '232',
#   '112',
#   datetime.datetime(2018, 4, 25, 9, 46),
#   0],
#  ['슬픈개소리(sest****)',
#   '일찍볼수록 보람이 있어요 온갖스포에 시달리기전에 가는게 좋을듯',
#   '8',
#   '125',
#   '6',
#   datetime.datetime(2018, 4, 25, 11, 20),
#   0],
#  ['브래드피트(sana****)',
#   '잘봤는데 3시간으론 부조하더라 5시간으로 만들어도 될 영화다.',
#   '10',
#   '117',
#   '4',
#   datetime.datetime(2018, 4, 26, 2, 26),
#   0],
#  ['세빈(lind****)',
#   '박지훈이 말아먹은 닥스 이미지 누가 회복해주죠? 제발 양심이 있다면 지금이라도 영화계에서 발 빼세요 정말 오만가지 상욕들이 다 나오고 그냥 진짜 딱 한대만 후려칠 수 있으면 소원이 없겠다고ㅋㅋ 번역이 애들 장난이야?...',
#   '10',
#   '118',
#   '5',
#   datetime.datetime(2018, 4, 26, 3, 3),
#   0],
#  ['79799s(chan****)',
#   '제레미레너 주연은뭐여ㅋ',
#   '10',
#   '120',
#   '7',
#   datetime.datetime(2018, 4, 25, 12, 40),
#   0],
#  ['리퐁(hoih****)',
#   '타임스톤으로 인워 보기전으로 돌려주십쇼 진짜 마음에 준비 좀 하고 다시보게',
#   '10',
#   '113',
#   '1',
#   datetime.datetime(2018, 4, 25, 15, 38),
#   0],
#  ['겁나피곤해(lsj1****)',
#   '일보고 난뒤 찝찝한기분 2편은 언제나올려나?',
#   '10',
#   '116',
#   '9',
#   datetime.datetime(2018, 4, 25, 11, 18),
#   '관람객'],
#  ['hyub(hyub****)',
#   '정은이한테 지금 이영화 보여주면 5월 북미회담 100프로 성공한다  -북한 김정은 위원장 핵폐기선제조건 어벤져스4 스포공개 원해-',
#   '10',
#   '110',
#   '5',
#   datetime.datetime(2018, 4, 26, 3, 36),
#   0],
#  ['스야(dlwh****)',
#   '번역가는 대가리박고 사과해야한다. 영화의 품질을 떨어트리는  수준.',
#   '1',
#   '109',
#   '5',
#   datetime.datetime(2018, 4, 26, 8, 8),
#   0],
#  ['milreo(wnsc****)',
#   '번역가 정말 대단하네요. "Mother fu.."라는 대사를 어머니로 번역해놓으셨어요',
#   '10',
#   '104',
#   '1',
#   datetime.datetime(2018, 4, 25, 21, 7),
#   '관람객'],
#  ['95(qwee****)',
#   '보지도않고 댓글쓰는애들 특징 - 말이필요없다하고 웅장하다하고 쿠키영상중요하다고함 .. 누가모르니?ㅋㅋㅋ',
#   '9',
#   '134',
#   '33',
#   datetime.datetime(2018, 4, 25, 10, 7),
#   0],
#  ['가온길(kkam****)',
#   '다 좋은데 마지막 오역 왜 그렇게 꼬아두면서 떡밥 하나를 가려버린건지 모르겠다',
#   '10',
#   '103',
#   '3',
#   datetime.datetime(2018, 4, 25, 19, 27),
#   '관람객'],
#  ['유승현(ssam****)',
#   '충격입니다 충격 그 이외에는 할말이 딱히...',
#   '10',
#   '107',
#   '12',
#   datetime.datetime(2018, 4, 25, 10, 32),
#   0],
#  ['ella****',
#   '분명 재밌는데 욕하면서 나옴. 본 사람은 무슨 말인지 이해할거고 볼 사람들도 보고나면 무슨 뜻인지 알듯.',
#   '10',
#   '96',
#   '2',
#   datetime.datetime(2018, 4, 25, 20, 31),
#   0],
#  ['Twinkle(cors****)',
#   '오역이 아쉽지만 너무 잘만든 영화..마블이 작정하고 만듬.지루한장면이 하나도 없다',
#   '10',
#   '94',
#   '1',
#   datetime.datetime(2018, 4, 25, 22, 20),
#   '관람객'],
#  ['1223****',
#   '타노스는 그저 강할뿐  모든면에서...타노스도  지금 이렇게 허무할까?',
#   '10',
#   '96',
#   '3',
#   datetime.datetime(2018, 4, 25, 13, 3),
#   '관람객'],
#  ['꽈일(arar****)',
#   '물 많이 먹지마세요 지리는 장면이 많아서 진짜 참다가 죽을뻔 나가려고 했는데 일어나면 관객들이 어벤져스마냥 나를 빌런으로 생각하고 죽일까봐 고민하다가 닥터스트 빙의해 과거로 돌아가 군대 화생방 참던시절의 초능력을 발...',
#   '10',
#   '97',
#   '4',
#   datetime.datetime(2018, 4, 27, 19, 57),
#   0],
#  ['꼬마곈(nohw****)',
#   '살면서 이렇게 큰 허무와 상실감을 느껴본 적이 없었는데 어벤져스로 느끼게 되네요. 제 기억도 가루와 함께 사라졌으면 좋겠습니다. 슬픈 영화가 아닌데도 허무와 공허함으로 눈물이 날 거 같아요.',
#   '10',
#   '101',
#   '8',
#   datetime.datetime(2018, 4, 25, 15, 57),
#   0],
#  ['설거지하는남자(wwwj****)',
#   '이거 보고 레슬링 예고보면 헛웃음만 나온다 구라없이현타 오진다.',
#   '10',
#   '95',
#   '8',
#   datetime.datetime(2018, 4, 25, 12, 58),
#   0],
#  ['갱(anch****)',
#   '영화끝나고 사람들.. 다 뻥져서 나오는 이유가 있죠..ㅜㅠ 흐윽.. 몇년을 기다린 영화인데..',
#   '10',
#   '101',
#   '14',
#   datetime.datetime(2018, 4, 25, 12, 37),
#   '관람객'],
#  ['TWICE갓사나(ookg****)',
#   '토르의 와칸다 등장신은 가히 최고.',
#   '10',
#   '86',
#   '0',
#   datetime.datetime(2018, 4, 30, 1, 35),
#   0],
#  ['히카르도(imwi****)',
#   '2019년까지 살지못하는 사람은 어떡하라고;; 기다리다 하트어택으로 사망할듯;이기적인놈들 개처럼일해서이번해에내라! 안그럼 마브르코믹스 너네의 반이 죽을것이다!',
#   '10',
#   '130',
#   '44',
#   datetime.datetime(2018, 4, 25, 12, 14),
#   0],
#  ['멍뭉잉(ksj8****)',
#   '진짜 이건  충격적이다절대로 이건 영화관에가서봐야  이충격적인 감정을  느낄수있어요',
#   '10',
#   '91',
#   '6',
#   datetime.datetime(2018, 4, 25, 13, 52),
#   0],
#  ['첼강딱딱(arsh****)',
#   '맞아 토르는 신이였었어',
#   '10',
#   '85',
#   '1',
#   datetime.datetime(2018, 4, 27, 18, 27),
#   0],
#  ['소라노텐시(jsl3****)',
#   '박지훈님 마더빠커 잘계세요?',
#   '1',
#   '91',
#   '7',
#   datetime.datetime(2018, 4, 27, 13, 45),
#   0],
#  ['leok****',
#   '소오름....한국에 온  배우들     .소오름...다음편 안볼수 없는...',
#   '8',
#   '85',
#   '4',
#   datetime.datetime(2018, 4, 25, 15, 7),
#   0],
#  ['마하드(dnwn****)',
#   '영화는 최고인데 애들 좀 데리고 영화보러 오지 마라 최소한 보러 올거면 교육 좀 시키고 오던가 영화관이 자기네들 안방인줄 아네;;',
#   '10',
#   '86',
#   '5',
#   datetime.datetime(2018, 4, 26, 22, 19),
#   0],
#  ['dw33****',
#   '캡틴,토르 등장할때 소름..',
#   '10',
#   '81',
#   '1',
#   datetime.datetime(2018, 4, 27, 12, 37),
#   0],
#  ['헌희(sue0****)',
#   '내년까지 살아야지...',
#   '10',
#   '89',
#   '9',
#   datetime.datetime(2018, 4, 25, 12, 4),
#   0],
#  ['name(elro****)',
#   '닥스가 토니를 살리기 위해 스톤을 넘겨준 이유는 천만번중 한번의 승리가 토니가 이룬 승리이기 때문일 것이다',
#   '10',
#   '86',
#   '8',
#   datetime.datetime(2018, 4, 27, 21, 23),
#   0],
#  ['bhst****',
#   '토르는 진짜 신이구나를 느낌.. 멋지다',
#   '10',
#   '77',
#   '0',
#   datetime.datetime(2018, 4, 27, 22, 38),
#   '관람객'],
#  ['beau****',
#   '영화 초반부에는 타노스를 욕하게 만들다가, 영화가 끝나고 나올때는 타노스를 이해하게 만드는 영화',
#   '10',
#   '87',
#   '10',
#   datetime.datetime(2018, 4, 25, 16, 9),
#   0],
#  ['장재원(cjw2****)',
#   '짜장면 맛집 3시간기다렸는데 짜장면이 흰색임',
#   '8',
#   '87',
#   '13',
#   datetime.datetime(2018, 4, 25, 16, 29),
#   0],
#  ['AlphaHyeon(alph****)',
#   '타노스 : 인피니티 워.',
#   '10',
#   '78',
#   '5',
#   datetime.datetime(2018, 4, 25, 13, 6),
#   0],
#  ['육륙(hanm****)',
#   '감독양반 이거 무슨 일일 드라마도 아닌데 결말이 너무 심하잖소.. 1년을 기다려야 한다니. 미칠노릇이구만. 아맥으로 한번더 보ㅓ야지..',
#   '10',
#   '75',
#   '4',
#   datetime.datetime(2018, 4, 25, 13, 47),
#   0],
#  ['BW S(kt51****)',
#   '자막 오역 너무 심하다...',
#   '10',
#   '71',
#   '1',
#   datetime.datetime(2018, 4, 25, 16, 34),
#   0],
#  ['알아서자율주행(heal****)',
#   "닉퓨리 '어머니'번역에서 유일하게 인상 찌푸렸다",
#   '10',
#   '75',
#   '5',
#   datetime.datetime(2018, 4, 25, 16, 56),
#   0],
#  ['qwewdwq(pcwc****)',
#   "It's end game. 번역자가 이걸 이 게임은 끝났어. 라고 해석 해버림 the도 없는데. end game 자체가 '마지막 단계'라는 관용적인 명사로 쓰이고 있는데 번역한놈 나보다 영어 못...",
#   '10',
#   '76',
#   '8',
#   datetime.datetime(2018, 4, 25, 17, 56),
#   0],
#  ['류현우(sten****)',
#   '여러분 영화보기전까진 인터넷을 멀리하세요 아니 그냥 눈과 귀를 닫은채로 세상과 단절하고 지내길 추천드립니다 꼭 스포 당하지 않은채로 보셔야합니다',
#   '10',
#   '68',
#   '2',
#   datetime.datetime(2018, 4, 25, 22, 4),
#   '관람객'],
#  ['asaz****',
#   '갓토르.. 어벤져스 결말 ㅜㅜ',
#   '10',
#   '68',
#   '2',
#   datetime.datetime(2018, 4, 25, 15, 21),
#   0],
#  ['ERIS(kseo****)',
#   '박지훈 번역가만 아니였으면...',
#   '10',
#   '64',
#   '3',
#   datetime.datetime(2018, 4, 25, 18, 18),
#   '관람객'],
#  ['높이날던새(immi****)',
#   'ㅅㅂ 미세먼지가 타노스 때문이었다니..',
#   '10',
#   '66',
#   '5',
#   datetime.datetime(2018, 4, 26, 21, 35),
#   0],
#  ['sung****',
#   '아...일단 변역가좀 바꿔라 오역 짜증나서 못보겠다',
#   '9',
#   '60',
#   '0',
#   datetime.datetime(2018, 4, 25, 20, 31),
#   '관람객'],
#  ['김영회(four****)',
#   '나는 호날두와 메시, 그리고 어벤져스와 동시대에 살고있음을 감사한다.',
#   '10',
#   '64',
#   '4',
#   datetime.datetime(2018, 4, 25, 23, 56),
#   0],
#  ['소프라노 김예진(gjqk****)',
#   '액션 영화인데 눈물 흘린사람 저밖에없나요...',
#   '10',
#   '61',
#   '2',
#   datetime.datetime(2018, 4, 26, 17, 33),
#   0],
#  ['순수소년(otu2****)',
#   '모든것이  완벽하다  영화  오프닝 부터  엔딩 까지  하지만  단 하나의  흠은  자막이다. 타임스톤을  내가 가지고 있다면  시간을  돌려  이  번역가가  이 일을  못하게  시간을  되돌리고 싶다.',
#   '10',
#   '60',
#   '2',
#   datetime.datetime(2018, 4, 26, 8, 3),
#   0],
#  ['감성팔이 극혐(esh9****)',
#   '영화전개를  위해 다크나이트가 된 스타로드 ㅋㅋㅋ.뻔하지 않은 전개라 ㄱㅊ았다.중간에 서로를 알아가는 게 좀 압축되었지만 어쩔 수 없으니 이해한다.',
#   '9',
#   '62',
#   '4',
#   datetime.datetime(2018, 4, 25, 13, 25),
#   '관람객'],
#  ['addt****',
#   '진심 역대 마블영화중 최고였다....아직도 충격적이다',
#   '10',
#   '63',
#   '5',
#   datetime.datetime(2018, 4, 25, 15, 6),
#   0],
#  ['지형이(mjh4****)',
#   '제발 박지훈 좀 짤라라 번역 개 ㅈ같이 해놨네',
#   '1',
#   '64',
#   '6',
#   datetime.datetime(2018, 4, 26, 0, 11),
#   0],
#  ['임성오(lso3****)',
#   '영화끝나고 엄청조용했습니다.. 저도 놀라서 아무말도 못했습니다',
#   '10',
#   '58',
#   '1',
#   datetime.datetime(2018, 4, 26, 20, 0),
#   0],
#  ['jlov****',
#   '남편따라 억지로보러갔다가 핵잼이라 내가더 흥분해서나옴.. ㅡㅡ 맺고끊음이 아침드라마인줄',
#   '10',
#   '60',
#   '3',
#   datetime.datetime(2018, 4, 26, 11, 40),
#   0],
#  ['곰(rose****)',
#   '사람을 열받게하는 두가지방법중 첫번째는 말을하다 마는것이고두번째는',
#   '6',
#   '71',
#   '14',
#   datetime.datetime(2018, 4, 26, 2, 18),
#   '관람객'],
#  ['Vixx별빛(vixx****)',
#   '엄청난 떡밥과 그 후를 위한 장치들이 넘 마음을 혼란 스럽게 했다...ㄷㄷㄷ',
#   '10',
#   '57',
#   '1',
#   datetime.datetime(2018, 4, 25, 19, 8),
#   '관람객'],
#  ['처갓집취킨(kys5****)',
#   '충격적인 결말이 아니라 후기작을 위한 발판 느낌임. 싸움씬은 많지만 먼가 답답하고 밸런스 완급조절 실패함. 비젼보면 어벤져스2 비젼맞는지 의문. 이번작만보면 고개가갸우뚱대겠지만 평가는 어벤져스4랑 묶어서 하는게 맞을...',
#   '8',
#   '102',
#   '46',
#   datetime.datetime(2018, 4, 25, 16, 32),
#   0],
#  ['원숭이LOVE검둥이(rlaa****)',
#   '댓글알바 ㅇㅈㄹ 그냥 어벤져스는 닥추임',
#   '10',
#   '75',
#   '21',
#   datetime.datetime(2018, 4, 25, 9, 32),
#   0],
#  ['모구리구리구리(wje3****)',
#   '짧게 요약하자면이번인피니티워는다음줄거리를 위한미완성영화라호불호크게갈릴 수밖에 없는 영화입니다. 그리고 거대한 마블 스토리를 2시간 러닝타임으로 담기에도 부족했던터라 빠릿빠릿한 스토리전개가 불가피한 상화에 좀 과한 유...',
#   '8',
#   '101',
#   '47',
#   datetime.datetime(2018, 4, 25, 11, 34),
#   '관람객'],
#  ['이종운(phoa****)',
#   '살면서 느껴본적 없는 새로운 현타....아...타노스....퀼 이모지리야ㅜㅜ',
#   '10',
#   '56',
#   '3',
#   datetime.datetime(2018, 4, 25, 12, 17),
#   0],
#  ['hamo****',
#   '이제 데드풀 기다려야지~',
#   '10',
#   '55',
#   '3',
#   datetime.datetime(2018, 4, 25, 13, 31),
#   '관람객'],
#  ['미더더덕(tige****)',
#   '타노스의 슬픔, 타노스의 고뇌, 타노스 앞에 놓인 역경과 그걸 이겨내고 짓는 웃음...완벽한 기승전결에 얼이 빠져 한 마디밖에 할 수 없었다 ‘어머니....’',
#   '10',
#   '52',
#   '1',
#   datetime.datetime(2018, 4, 26, 19, 51),
#   0],
#  ['Dovahkiin(ckdt****)',
#   '사무엘잭슨 마더퍼커는 진짜유명한대사인데그걸 어머니라고 번역;; 쳐돌앗네이런것도 국민청원넣어서 박ㅇㅇ짤라야되냐?개 적폐 번역가',
#   '10',
#   '54',
#   '3',
#   datetime.datetime(2018, 4, 26, 3, 15),
#   0],
#  ['상상(hosu****)',
#   '진짜 모든사람이 스포안당하고내가느꼈던 그먹먹함을느끼길....',
#   '10',
#   '51',
#   '1',
#   datetime.datetime(2018, 4, 27, 2, 25),
#   0],
#  ['지또니(tlsw****)',
#   '마블 영화중 역대급으로 처절하고 암울한 싸움이였다ㅠㅠ결말 허무한데 옳은 결말인듯 ㅠㅠㅠㅠ2번 3번 더 볼수있어',
#   '10',
#   '50',
#   '1',
#   datetime.datetime(2018, 4, 26, 22, 3),
#   0],
#  ['lsok****',
#   '실화임? 이거볼려고 3년기다림ㅠㅠ 영어듣기공부 해서 해석없이 다시보고픔ㅠㅠ',
#   '10',
#   '50',
#   '1',
#   datetime.datetime(2018, 4, 25, 22, 41),
#   0],
#  ['고정협(ksrk****)',
#   '결말이 당연히 않좋지 이피니티워는 어벤져스들이 발린편이고 그다음 편이 이기는 편인데 ㅋㅋ 해리포터도 죽음의성물 1일땐 안좋게끝남',
#   '9',
#   '53',
#   '5',
#   datetime.datetime(2018, 4, 25, 17, 41),
#   0],
#  ['TONDO(hkjk****)',
#   '앜ㅋㅋㅋ 영화보기전까지 스포안당할려구 이제 영화보고나서 댓글보니까 겁나 주옥같은댓글들넘쳐나네여  개욱김ㅋㅋㅋㅋ  후우 내년 볼 영화 예고편같은 느낌적인 느낌',
#   '10',
#   '50',
#   '3',
#   datetime.datetime(2018, 4, 27, 0, 16),
#   0],
#  ['알퐁소(jhjk****)',
#   '하.. 보고나면 현타온다. 글고 좀 화가 난다. 멘탈 다 찢긴것 같다 ㅜㅜ',
#   '10',
#   '50',
#   '4',
#   datetime.datetime(2018, 4, 25, 15, 22),
#   0],
#  ['아찌(rjad****)',
#   '쿠키영상 놓치지말아라 소름돋는다 히어로계 섹시글래머 나오신다',
#   '8',
#   '100',
#   '54',
#   datetime.datetime(2018, 4, 25, 11, 43),
#   0],
#  ['쿠크다스(dbtk****)',
#   '마지막에 This is end game 을 이젠 다 끝났어로 번역하다니.. 나는 떡밥 눈치채서 괜찮았지만 이해안간 사람들은 결말 보고 욕했겠네 최소한 거의 다 했어, 이제 마지막 단계야 라고 번역했어야하는거 아닌가',
#   '9',
#   '48',
#   '3',
#   datetime.datetime(2018, 4, 25, 22, 58),
#   '관람객'],
#  ['스타맨(take****)',
#   '정의의 리그의 히어로 조무사들이 따라잡기엔 너무나도 까마득히 격차를 벌려버린 마-블의 영웅들',
#   '10',
#   '47',
#   '3',
#   datetime.datetime(2018, 4, 25, 15, 46),
#   0],
#  ['고래밥(kotu****)',
#   '스타로드만 아니면 영화 잘끝났는데..',
#   '10',
#   '74',
#   '30',
#   datetime.datetime(2018, 4, 25, 12, 7),
#   0],
#  ['허허허(y6ng****)',
#   '오역 있구나 어쩐지 닥터가 게임을 너무 던진다 했어 ㅋㅋ 어머니!!',
#   '10',
#   '46',
#   '3',
#   datetime.datetime(2018, 4, 26, 0, 22),
#   0],
#  ['Heima(cumj****)',
#   '사람많는 영화관 같은데 오면 제발 좀 씻고 다녀라 부산서면 2시반 아이맥스관 h열내옆에 앉은 새1끼 몸에서 쉰내 ㅈㄴ 나서 보는내내 집중이 안됨 거기다 신발까지 쳐벗고 앉아서 ㄹㅇ 노답 얼마나 안씻으면 몸에서 그런 ...',
#   '10',
#   '45',
#   '4',
#   datetime.datetime(2018, 4, 26, 19, 12),
#   0],
#  ['k022****',
#   '이거 스포하는 지인들 걍 인연 끊어야됨 스포하면 부모님 없는 사람임',
#   '10',
#   '50',
#   '9',
#   datetime.datetime(2018, 4, 25, 19, 32),
#   0],
#  ['뽀이(lawy****)',
#   '번역빼고 다 좋았다.  순식간에 닉퓨리를 효자로 만들어버린 번역가님ㅋ',
#   '8',
#   '42',
#   '2',
#   datetime.datetime(2018, 4, 25, 21, 59),
#   0],
#  ['기초생활수급자(vanh****)',
#   '번역다시해서 재개봉해라 ㅅㅂ 적당히 해야지 아다르고 어다르다는 말은 이걸보고 하는거구나 싶네 진짜 ㅋㅋㅋㅋ',
#   '10',
#   '43',
#   '3',
#   datetime.datetime(2018, 4, 26, 3, 4),
#   0],
#  ['AVENGERS(qhth****)',
#   '박지훈 좀 짤라라 마블 코리아 디즈니 코리아 정신 똑바로 차리고 일해라 짜증나니까 그 대사를 듣고 소름이 돋아야 됐는데 걍 벙쪄있었다 제발 똑바로 일해라 좀;;;;',
#   '10',
#   '39',
#   '0',
#   datetime.datetime(2018, 4, 26, 22, 5),
#   0],
#  ['Jagerz(madm****)',
#   '내가 박읍읍 때문에 영어를 배워야겠다고 느낌',
#   '9',
#   '40',
#   '1',
#   datetime.datetime(2018, 4, 26, 18, 45),
#   0],
#  ['ghtj****',
#   '지루해서 시계를 보는게 아닌 더 보고싶은 마음에   시계를 들여다보게 된다',
#   '10',
#   '38',
#   '0',
#   datetime.datetime(2018, 4, 28, 16, 31),
#   0],
#  ['음음(mins****)',
#   '닉 퓨리가 효자인 사실을 알기 위해 149분을 투자해야 하는 영화',
#   '10',
#   '40',
#   '2',
#   datetime.datetime(2018, 4, 26, 14, 9),
#   0],
#  ['건(emer****)',
#   '인류의 절반이 사라진 지금, 다행히 살아남아 내년 영화를 볼 수 있게 되었다! ㅜ',
#   '10',
#   '38',
#   '1',
#   datetime.datetime(2018, 4, 27, 21, 57),
#   0],
#  ['김머슬베이비(hong****)',
#   '영화 끝나고 사람들, 목석된 것 실화냐...',
#   '10',
#   '39',
#   '2',
#   datetime.datetime(2018, 4, 26, 12, 31),
#   0],
#  ['hofbydkhk(pite****)',
#   '보고나면 장엄해서 할말을 잃음...',
#   '10',
#   '40',
#   '3',
#   datetime.datetime(2018, 4, 25, 15, 6),
#   0],
#  ['써니(dark****)',
#   '타노스 눈이 너무 슬프다 ㅜㅜ',
#   '10',
#   '34',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 48),
#   0],
#  ['라크디안(trah****)',
#   '마블의 이전 작품들을 보지 않았다면 이 영화를 설명할 방법이 없고, 마블의 이전 작품들을 보았다면 이 영화를 설명할 필요가 없다. 한 작품으로서의 완결성은 아쉬우나, 그 외의 모든 것이 완벽하다! 이 영화를 보고 어...',
#   '9',
#   '37',
#   '3',
#   datetime.datetime(2018, 4, 28, 6, 2),
#   0],
#  ['Luoden(minh****)',
#   '김광석이 부릅니다.먼지가 되어',
#   '10',
#   '35',
#   '2',
#   datetime.datetime(2018, 4, 25, 17, 12),
#   0],
#  ['Snapper YUN(lyhv****)',
#   '하...결말이 너무 딥다크해서 자살하는사람 생길것같다',
#   '10',
#   '177',
#   '144',
#   datetime.datetime(2018, 4, 25, 10, 47),
#   0],
#  ['Rilla(andr****)',
#   '허무와 감동의 사이에 내가 서있다',
#   '10',
#   '32',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 48),
#   '관람객'],
#  ['달소녀(dlan****)',
#   '프로 머더퍼커러를 뭘로보고',
#   '8',
#   '32',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 52),
#   '관람객'],
#  ['달밤소리(ngm2****)',
#   '무조건 스포일러를 피해야한다. 여기 평점 보러도 오면 안 된다. 이 글 보는 순간 창 닫으세요.',
#   '10',
#   '34',
#   '2',
#   datetime.datetime(2018, 4, 26, 2, 45),
#   0],
#  ['월홍(nada****)',
#   '평점에 스타로드 욕하는 평점이 있길래 왜 그런가 했더니 스타로드는 타노스 파워 만큼 욕 먹어도 싸다.',
#   '10',
#   '41',
#   '9',
#   datetime.datetime(2018, 4, 25, 20, 39),
#   0],
#  ['jhpl****',
#   '오늘 보니 왜 번역이 논란인지 알 수 있겠더군요, 하필이면 복선을 알려주는 문장을 오류내서 복선인지 모르게끔 해놨으니 지탄받는거네요. 검색해보니 이 분은 번역 초보도 아닌던데 그냥 능력 부족이네요. 마더퍼커라는 욕을...',
#   '9',
#   '31',
#   '0',
#   datetime.datetime(2018, 4, 28, 8, 14),
#   0],
#  ['JSY(dols****)',
#   '스포절대당하지 말고보세요.. 마블덕후들 손수건준비하시고ㅜ',
#   '10',
#   '33',
#   '2',
#   datetime.datetime(2018, 4, 25, 21, 27),
#   '관람객'],
#  ['NasirJones(ty99****)',
#   '역대 마블 영화의 퀄리티에 놀랐다고? 이 영화를 보면 기절할꺼다',
#   '10',
#   '30',
#   '0',
#   datetime.datetime(2018, 4, 25, 13, 52),
#   0],
#  ['똥글팟(alsk****)',
#   '유튜브 예상 분석한사람들 다 버로우 타라.',
#   '10',
#   '32',
#   '2',
#   datetime.datetime(2018, 4, 25, 17, 47),
#   0],
#  ['나시고랭(aike****)',
#   '타노스의 의도도 충분히 이해할수있을거같음',
#   '10',
#   '29',
#   '0',
#   datetime.datetime(2018, 4, 26, 12, 41),
#   0],
#  ['ㅇㅇ(chob****)',
#   '몰입도 역대 최고다... 한국은 영원히 이런 영화 못만들꺼 같음',
#   '10',
#   '31',
#   '2',
#   datetime.datetime(2018, 4, 27, 22, 1),
#   0],
#  ['얼그레이(hone****)',
#   '닉퓨리가 그렇게 효자였던가...',
#   '10',
#   '31',
#   '2',
#   datetime.datetime(2018, 4, 26, 16, 3),
#   0],
#  ['조랭이떡(joyo****)',
#   '번역가 수준에 화가나네요. 마더뻐커를 어머니라고 번역하고 이제 마지막 단계야를 다 끝났어로 만드는 수준 보니 정말 충격적이네요. 영어 안 배우셨어요..?',
#   '1',
#   '33',
#   '4',
#   datetime.datetime(2018, 4, 26, 12, 19),
#   0],
#  ['레이(r3si****)',
#   '번역 진짜 문제임;;;;',
#   '1',
#   '34',
#   '5',
#   datetime.datetime(2018, 4, 25, 20, 56),
#   0],
#  ['달려라한이(simo****)',
#   '현실을 잘 반영한 미세먼지 급의 충격적인 결말~ 빌런이 이렇게 매력적이다니 타노스 우주폭발 대멋짐~',
#   '10',
#   '30',
#   '2',
#   datetime.datetime(2018, 4, 25, 12, 39),
#   0],
#  ['남팅이(nams****)',
#   '그 번역가라 오역이 있습니다.영화는 쩌는데 자막이 망칠수 있으니 참고바랍니다.',
#   '8',
#   '31',
#   '3',
#   datetime.datetime(2018, 4, 25, 17, 45),
#   '관람객'],
#  ['무늉(pink****)',
#   '전형적인 빌런은 나쁜놈, 빌런은 권선징악의 마블의 패턴을 생각했다가 호되게 혼난기분이다.. 여운이 아직도 안가신다',
#   '10',
#   '28',
#   '1',
#   datetime.datetime(2018, 4, 26, 22, 53),
#   0],
#  ['시원(aswi****)',
#   '일년기다리기 힘드네여',
#   '10',
#   '29',
#   '2',
#   datetime.datetime(2018, 4, 26, 0, 19),
#   '관람객'],
#  ['brig****',
#   '엄청난 퀄의 그래픽과 싸움씬은 가히 압도적이었지만 스톤이 뺏기는 한 컷 한 컷 장면들의 스토리들이 뭔가 조금씩 허무하다.',
#   '8',
#   '34',
#   '7',
#   datetime.datetime(2018, 4, 25, 17, 25),
#   0],
#  ['준희s 파파(wowm****)',
#   '닥터스트레인지 : 타노스, 거래를 하러 왔다.',
#   '10',
#   '27',
#   '1',
#   datetime.datetime(2018, 4, 25, 15, 13),
#   0],
#  ['piolin(jbs_****)',
#   '이때까지 본 마블영화중 가장 충격',
#   '10',
#   '28',
#   '2',
#   datetime.datetime(2018, 4, 26, 12, 30),
#   '관람객'],
#  ['캄프누알바생(skad****)',
#   '번역 진짜 제대로 안할래? 박지훈 안 짜르고 뭐하냐?',
#   '8',
#   '29',
#   '3',
#   datetime.datetime(2018, 4, 25, 19, 37),
#   0],
#  ['Jonghwa(hwpj****)',
#   '닥스가 그럴수밖에 없었다는게 안타깝다 혼자 본 승리 미래의 과정이 이럴수밖에없었던 건가 모든 결과는 어벤져스4로',
#   '10',
#   '31',
#   '5',
#   datetime.datetime(2018, 4, 25, 13, 0),
#   0],
#  ['카게노카케라(shs1****)',
#   '인피니티 워의 주인공은 타노스',
#   '10',
#   '32',
#   '6',
#   datetime.datetime(2018, 4, 25, 12, 15),
#   0],
#  ['무지개홍(suba****)',
#   '결국 스트레인지가 타임스톤을 넘긴 이유는 그때 아이언맨을 살렸어야지만 이길 수 있었기 때문이었군요 ㅠㅠㅠ',
#   '10',
#   '25',
#   '0',
#   datetime.datetime(2019, 4, 26, 22, 29),
#   0],
#  ['psr0****',
#   '제목정정 바랍니다.어벤져스 마지막회 : 타노스의 인생극장',
#   '10',
#   '30',
#   '5',
#   datetime.datetime(2018, 4, 25, 23, 57),
#   '관람객'],
#  ['스텔라(than****)',
#   '전투씬 다 진심 미쳤구요ㅜㅜ닥터의 빅픽처를 기대합니다! 그리고 번역가는 좀 짜르세요. 영화 망친 장본인이네요. 이런 대작에 박읍읍 끼얹기가 말이 됩니까? 오역이 난무해서 별1개 뺍니다. 디즈니코리아 정신 차리세요!',
#   '9',
#   '24',
#   '0',
#   datetime.datetime(2018, 4, 26, 12, 38),
#   '관람객'],
#  ['단것이좋아(ysce****)',
#   '이 영화는 심장에 안 좋은 영화다. 멋진 장면, 전투 장면 나올 때마다 소름 돋고 흥분이 가시지 않아. 아이언맨 블리딩엣지, 아이언 스파이더맨, 창 잡는 캡틴아메리카 첫등장 완죤 심멎영화 ㅜㅜ  부재는 타노스의 인피...',
#   '10',
#   '26',
#   '2',
#   datetime.datetime(2018, 4, 28, 17, 26),
#   '관람객'],
#  ['황승현(rlfk****)',
#   '어... 하고 나왔다굉장히 색다르게 충격적이다',
#   '10',
#   '28',
#   '4',
#   datetime.datetime(2018, 4, 25, 12, 14),
#   0],
#  ['슈슈(sook****)',
#   '쿠키영상 맨 마지막에 하나 나옵니다. 이게 영화 핵심임 슈발. 본 내용은 어벤져스4의 스토리 진행을 위한 밑밥정도.. 개 현타온다 ㅋㅋ',
#   '10',
#   '28',
#   '4',
#   datetime.datetime(2018, 4, 25, 12, 13),
#   0],
#  ['이삼일(tkdz****)',
#   '미쳤네요 내년까지 열심히 살겠습니다 ㅠㅠ 꼭 보고싶네요',
#   '10',
#   '23',
#   '0',
#   datetime.datetime(2018, 4, 27, 22, 21),
#   0],
#  ['yghq****',
#   '안보면 후회한다. 영화 초반 화장실가고 싶었던 생리적 욕구도 견디게 했다!!',
#   '10',
#   '23',
#   '0',
#   datetime.datetime(2018, 4, 25, 23, 17),
#   '관람객'],
#  ['빈(tomu****)',
#   '마블아, 우리 완다 좀 그만 괴롭혀라ㅠㅠ 어린 시절 부모 잃고, 강화인간으로 실험 학대 받고, 마녀라고 손가락질 받으며 자라서, 의지할 데는 오빠 뿐이었는데, 오빠도 죽고, 그 이후 생긴 연인까지 자기 손으로 죽여야...',
#   '8',
#   '24',
#   '1',
#   datetime.datetime(2018, 4, 30, 11, 5),
#   0],
#  ['sant****',
#   '와..끝나자마자 또보고싶은 영화는 처음',
#   '10',
#   '24',
#   '1',
#   datetime.datetime(2018, 4, 27, 3, 13),
#   0],
#  ['Weiz(koh8****)',
#   '번역한거 빼고 괜찮았다.특히 타노스 캐릭터를 너무 잘만들어서 욕만 곱씹는중..',
#   '9',
#   '25',
#   '2',
#   datetime.datetime(2018, 4, 26, 8, 47),
#   '관람객'],
#  ['JOHN(john****)',
#   'LG는 어벤저스 31일 관람건만 봐도 기업 운영을 얼마나 개떡같이 하는줄 알 수 있다.소비자들이 미리 돈 내고 기다리는데 니들은 곧 죽어도 소비자 마인드을 못 읽는다.',
#   '10',
#   '22',
#   '0',
#   datetime.datetime(2018, 7, 31, 0, 42),
#   0],
#  ['빵매(kise****)',
#   '엘지유플러스 인피니티워 31일날부터 볼수있다고 광고해놓고 아직까지 안되는건 농단이냐 오늘 12시까지 얼마나 기다렸는데 약속지켜라',
#   '10',
#   '22',
#   '0',
#   datetime.datetime(2018, 7, 31, 0, 28),
#   0],
#  ['꼬마(sy02****)',
#   '엌 옼 엥 하다 끝남ㅋ 아 글구 번역 상태 실화?',
#   '10',
#   '23',
#   '1',
#   datetime.datetime(2018, 4, 25, 20, 28),
#   0],
#  ['al8k211(al8k****)',
#   '너무 좋았지만 번역이 !!!! 마블 코리아 !!!!  팬들이 만만하냐',
#   '10',
#   '24',
#   '2',
#   datetime.datetime(2018, 4, 25, 19, 36),
#   0],
#  ['Yozora(lyli****)',
#   '근데 자막은 왜 저따위죠?',
#   '9',
#   '25',
#   '3',
#   datetime.datetime(2018, 4, 25, 14, 18),
#   0],
#  ['동준동이(ehdw****)',
#   '평론가 평점 아직도 안 나왔네. 평론가들도 보고 말문이 막혔나보다.',
#   '10',
#   '21',
#   '0',
#   datetime.datetime(2018, 4, 27, 10, 48),
#   0],
#  ['처밀도(ssvv****)',
#   '그치... 너무 방대해서 1부 2부 나눈거봐...',
#   '10',
#   '21',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 16),
#   0],
#  ['나무아래하나가둘(bert****)',
#   '타노스가 주인공. 볼만했음.',
#   '8',
#   '20',
#   '0',
#   datetime.datetime(2018, 4, 28, 14, 18),
#   0],
#  ['김까스돈밥(jeb2****)',
#   '영화 보다가 그동안 아이언맨을 본 추억 때문에 그만  울  뻔..다행히 창피하지 않게 참았습니다ㅋㅋ마블 쵝오~~',
#   '10',
#   '20',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 9),
#   0],
#  ['Sang(muaa****)',
#   '역대급 재미. 원작을 꽤 아는데, 이 정도면 파워 밸런스도 잘 맞췄고, 재해석도 좋았다. 아쉬운 점이 아예 없지는 않다. 하지만 이런 재미를 가진 오락영화도 없다.',
#   '10',
#   '21',
#   '1',
#   datetime.datetime(2018, 4, 27, 21, 55),
#   0],
#  ['Bal(wywa****)',
#   '심한충격 .. 해피엔딩충이라 파트2를 기다린다 ㅜ ㅜ',
#   '9',
#   '21',
#   '1',
#   datetime.datetime(2018, 4, 25, 13, 17),
#   0],
#  ['쥰(blaz****)',
#   '마블판 반지의제왕 예상외전개..',
#   '9',
#   '22',
#   '2',
#   datetime.datetime(2018, 4, 27, 22, 20),
#   0],
#  ['크리스티나로날드덕(yang****)',
#   '히어로에 대한 고정과 편견을 개박살 낸 영화',
#   '10',
#   '22',
#   '2',
#   datetime.datetime(2018, 4, 27, 2, 22),
#   '관람객'],
#  ['고형민(zlfe****)',
#   '사람들은 허무한거 엄청싫어하네... 난 허무하고 허탈하고 열린결말 그런게 좋던뎅... 일부로 그런것만 찾아보는데 이번 편은 내 취향에 딱 맞는둣',
#   '8',
#   '24',
#   '4',
#   datetime.datetime(2018, 4, 27, 2, 24),
#   0],
#  ['djaj****',
#   '할말 개 많은데 하지않겠다....',
#   '10',
#   '20',
#   '1',
#   datetime.datetime(2018, 4, 27, 1, 43),
#   0],
#  ['채희(alwa****)',
#   '히어로물  보고 허무하긴 처음.  다음편 타임스톤 다시 뺏어서 시간 돌리는거 말고는 대책이 안서는데',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 4, 25, 13, 17),
#   0],
#  ['작두(200z****)',
#   '정말너무잼있다...언제기다리냐또ㅠ',
#   '10',
#   '18',
#   '0',
#   datetime.datetime(2018, 4, 28, 11, 46),
#   0],
#  ['ndy9****',
#   '영화보고 충격받아서 한동안 못 일어남 ㄷㄷ 그나저나 박지훈 번역가 좀 쓰지 말자 제발',
#   '10',
#   '18',
#   '0',
#   datetime.datetime(2018, 4, 26, 1, 30),
#   0],
#  ['아존햄(song****)',
#   '박읍읍씨의 번역 덕분에닥스의 대사 "It\'s end game이 \'이제 끝났어\' 가 되버리고 닉퓨리의 대사"motherfu.."이 엄마 찾는 국장을 만들었네요....',
#   '6',
#   '19',
#   '1',
#   datetime.datetime(2018, 4, 26, 2, 2),
#   0],
#  ['Ddrus(mind****)',
#   '제발 번역가좀 바꿔주면안돼냐; 쟨 진짜 다른직업 찾아야돼',
#   '6',
#   '19',
#   '1',
#   datetime.datetime(2018, 4, 25, 19, 45),
#   0],
#  ['친절한김군(cycl****)',
#   '상상그이상! 오역 쩔어줌',
#   '10',
#   '19',
#   '1',
#   datetime.datetime(2018, 4, 25, 15, 59),
#   0],
#  ['곡자(love****)',
#   '토르 졸라멋있다!!!',
#   '10',
#   '17',
#   '0',
#   datetime.datetime(2018, 4, 28, 5, 3),
#   0],
#  ['Alsdltmd(dltm****)',
#   '최대 빌런은 타노스가 아니라 박지훈이다... 영화 본 사람들은 오역 찾아서 보세요',
#   '10',
#   '17',
#   '1',
#   datetime.datetime(2018, 4, 26, 3, 22),
#   0],
#  ['난아마안될꺼야(lsw8****)',
#   '토르 지구 귀환할때 토르 3 배경음악 나왔으면 좋았을텐데',
#   '10',
#   '14',
#   '0',
#   datetime.datetime(2018, 4, 30, 17, 50),
#   0],
#  ['문기(gye1****)',
#   '개인적으로 엔드게임보다 더재밌었음',
#   '9',
#   '15',
#   '1',
#   datetime.datetime(2020, 4, 30, 13, 10),
#   '관람객'],
#  ['싸펑피펑(love****)',
#   '아니 왜 안봐지는건데 31일 00시 되면 볼수있다면서 영구소장으로 10800원 구매했는데',
#   '10',
#   '15',
#   '1',
#   datetime.datetime(2018, 7, 31, 0, 43),
#   0],
#  ['박태정(xowj****)',
#   '돈안아까운영화bbb',
#   '10',
#   '15',
#   '1',
#   datetime.datetime(2018, 4, 29, 8, 38),
#   '관람객'],
#  ['꼬랑내(blue****)',
#   '와 씨 어벤져스 4도 기대된다 ㄷㄷ',
#   '10',
#   '18',
#   '4',
#   datetime.datetime(2018, 4, 25, 13, 3),
#   '관람객'],
#  ['갈매기(noji****)',
#   '믿고보는 마블 말이 필요없다.',
#   '10',
#   '33',
#   '19',
#   datetime.datetime(2018, 4, 25, 9, 30),
#   0],
#  ['정석환(chrh****)',
#   '닥터가 토니보고 이방밥밖에 없었어가 타임스톤때문이 아니라 토니보고 미안하다는 뜻이였구나.. 정말 슬프다.',
#   '8',
#   '13',
#   '0',
#   datetime.datetime(2019, 4, 27, 0, 23),
#   0],
#  ['bmin****',
#   '유플티비 사람낚냐   네이버에 구매자 다 뺐길까봐 31일 시청가능이라고해놨냐  개떡같이운영하네',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2018, 7, 31, 1, 0),
#   0],
#  ['피샤드(saku****)',
#   '엘지유플티비는 사업접어야겠다.인피니티워 12시부터 보려고 기다리는사람이 몇인데?니들은 다음날 9시 땡하면 즉시 반품이다.다른데로 볼란다!',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2018, 7, 31, 0, 58),
#   0],
#  ['으라차차(nfor****)',
#   '엘지유플러스티비 쿠폰은 12시 땡하면 유효기간 만료되고 31일 시청가능하다고 광고해댄 인피니티워는 아직이냐',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2018, 7, 31, 0, 41),
#   0],
#  ['가객(help****)',
#   '내 왠만해선 영화보고 이런소리 안하는데...정말 끝내줌~  자막만 짜증남... 마지막에 대사가 "머더 퍼....ㄱ" 인데 자막이 "어머니..." 임...참 나',
#   '10',
#   '16',
#   '3',
#   datetime.datetime(2018, 4, 27, 21, 55),
#   0],
#  ['인포(sjb2****)',
#   '번역과 전개빼곤 괜찮았던 영화. 그리고 엔드게임보다 나은 영화.',
#   '8',
#   '13',
#   '1',
#   datetime.datetime(2019, 5, 10, 9, 27),
#   0],
#  ['눈꽃(blea****)',
#   '루소형제에겐 어벤져스1편인 작품.. 역시 형만한 아우없나.. 4보단 3이 더 재밌었네요.',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2019, 4, 24, 23, 32),
#   0],
#  ['위크미크(kaeu****)',
#   '엘지유플러스 재생되면 아무나 여기에 한줄만 써주세요',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2018, 7, 31, 0, 57),
#   0],
#  ['잭슨도사(p760****)',
#   '조조보고난후 제대로 엿 먹었네요. 대충격 대실망',
#   '10',
#   '77',
#   '65',
#   datetime.datetime(2018, 4, 25, 10, 56),
#   0],
#  ['haejoong(dlgo****)',
#   '인피니티워가 워낙 충격적이고 잘 뽑아내줘서기대치가 너무 커서 엔드게임이 덜해 보이는거지 엔드게임이 수준미달인건 아니다 더군다나 1세대와 이별이다 보니 허무하고 텅텅 공허해서 더 그렇지',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 4, 25, 19, 38),
#   0],
#  ['없음(ckdd****)',
#   '어벤져스 엔드게임 보고 온 사람 손 !!!',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 4, 24, 23, 21),
#   0],
#  ['강예은(kang****)',
#   '엔드게임 시작할때 울것 같네요.',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 4, 18, 19, 50),
#   0],
#  ['알피엠(kook****)',
#   '적폐 번역가를 왜 자꾸 쓰는거죠?',
#   '1',
#   '11',
#   '0',
#   datetime.datetime(2018, 5, 3, 23, 56),
#   0],
#  ['gogo****',
#   '아 엘지 OOO들 전나짜증나네ㅡㅡ',
#   '2',
#   '13',
#   '2',
#   datetime.datetime(2018, 7, 31, 0, 43),
#   0],
#  ['ScarletTea(woon****)',
#   'https://blog.naver.com/elik1119/220766349573 박지훈 번역가 역대 오역 총정리',
#   '10',
#   '15',
#   '4',
#   datetime.datetime(2018, 4, 25, 19, 59),
#   0],
#  ['율하(hij9****)',
#   '에피타이져인줄 알았는데 메인보다 낫다. 우열을 가릴 순 없는데 더 충격적인건 인피티니워.',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2019, 4, 24, 12, 47),
#   0],
#  ['dydg****',
# ...
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 22, 8),
#   0],
#  ['유재원(yuja****)',
#   '어벤져스 시리즈 중에 제일 충격이다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 22, 4),
#   '관람객'],
#  ['두더지무우(ddjm****)',
#   '토르 뎡말 최고  마블에서 제일 좋아하는 캐릭터인데 젤 멋있게 나와서 행복하다 ㅜ 등장할때 넘모나 소름',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 22, 3),
#   0],
#  ['김슬아(kims****)',
#   '스파이더맨 너무귀여워서 좋아하는데ㅜㅜ 마지막에 울엇습니다..ㅠㅠ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 52),
#   '관람객'],
#  ['sami****',
#   '멋진영화임 다음이 기대됨',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 16),
#   '관람객'],
#  ['qkrt****',
#   '가오갤나오고 영화분위기가바뀜 ㅋㅋ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 19, 11),
#   0],
#  ['드림워크(drea****)',
#   '시작 초반부터 숨도 못쉴만큼 봤음.많은 히어로의 등장이 잘 연결됐고 스톰브레이커 사용하는 토르에 전율~ 예고편들 보고 추측했던... 예상못한 전개에 뒷통수!스포당하지 말고 보세요. 확~깨는 전개입니다.최고의 마블 영...',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 17, 56),
#   '관람객'],
#  ['페트라(petr****)',
#   '영화끝나고 멍한 느낌이었고 멘붕이었다. 번역의 오류를 알고 기분이 매우 안좋았다.',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 17, 45),
#   '관람객'],
#  ['신갑례(geki****)',
#   '영어를 하나도 모르는 나도 뭔가 해석이 이상하다는걸 느꼈다..',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 15, 29),
#   '관람객'],
#  ['박종훈(whdw****)',
#   '영화를 자막 없이 봤으면 더 재미있게 봤을텐데... 어벤져스4를 기대하게 만드는 훌륭한 2시간 30분짜리 예고편이었다.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 14, 36),
#   '관람객'],
#  ['키티장군(bgr6****)',
#   '마음의 준비를 하고 갔는데도 충격받음',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 12, 51),
#   '관람객'],
#  ['맛있는김포(envy****)',
#   '인간적으로 같은  돈 내고 수없이 다른 영화를 보지만 이건 아깝다는 생각이 안드네? 나만 그런건 아니죠?',
#   '9',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 12, 48),
#   '관람객'],
#  ['김지원(jxhn****)',
#   '2019년만 기다리게된다 ㅠ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 12, 39),
#   '관람객'],
#  ['최규성(ggon****)',
#   '타노스 짱멋짐~~~~ 히어로인줄',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 11, 2),
#   '관람객'],
#  ['고스트(kly2****)',
#   '23명의 인물들이 잘녹아들었음. 빠른 장면전환, 숨막히는 전개.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 10, 8),
#   '관람객'],
#  ['김현빈(hyun****)',
#   '전투씬 대박이었습니다. 총출동 굳',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 9, 38),
#   '관람객'],
#  ['jins****',
#   '마지막에  닥터스트레인져 왜 아이언맨 살려줌 ?닥터스트레인져 가 아이언맨과 목숨 바꾼 이유가 있음예지력 으로보니  다음편에서  아이언맨이 한건한다',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 9, 12),
#   '관람객'],
#  ['가은(yose****)',
#   '토니... 진짜 역대급 마블 영화...',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 9, 4),
#   '관람객'],
#  ['이윤주(yoon****)',
#   '개핵잼 토르 존멋탱이임',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 8, 3),
#   '관람객'],
#  ['JY(rapi****)',
#   '4편도 용아맥으로 봐야지..',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 7, 46),
#   0],
#  ['thec****',
#   '이 돈 주고 이런 영화 보는거 감사했습니다.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 6, 39),
#   0],
#  ['이다솜(zxcv****)',
#   '진짜 토르는..신의 한수엿다...',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 3, 11),
#   '관람객'],
#  ['이가영(aria****)',
#   '진짜 미친 영화다....',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 3, 10),
#   0],
#  ['죽음과세금(yngw****)',
#   '영화 끝나고 화가나면서도 평점 10점 줄수밖에없는 마블 최고의 수작',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 47),
#   0],
#  ['박건서(pksy****)',
#   '타노스 악당인듯 악당아님',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 42),
#   '관람객'],
#  ['메멘토(lhwd****)',
#   '타노스 생각보다 인간적이네',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 36),
#   '관람객'],
#  ['현지혜(mk89****)',
#   '미친영화.... 아바타 영화는 그제 먼지일뿐..',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 31),
#   0],
#  ['yr42****',
#   '이런 결말은 예상 못했슴다ㅋㅋ 쿠키보고 소리지를뻔ㅋㅋ',
#   '9',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 2, 0),
#   '관람객'],
#  ['갓에넬(dldl****)',
#   '눈물난다. 보면안다 토르등장씬에서개지렸다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 1, 42),
#   0],
#  ['이유진(lyji****)',
#   '어벤져스만큼 대단한 영화는 없다 내년까지 어떻게 기다리나요',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 1, 41),
#   '관람객'],
#  ['범범이(qjad****)',
#   '와.... 그냥 미쳤다..',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 26, 0, 29),
#   '관람객'],
#  ['하핫(repl****)',
#   '히어로 영화보다가 운적은 처음이네요...너무 충격이었고 오늘 하루종일 멘붕이었어요',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 50),
#   0],
#  ['tnsr****',
#   '타노스는 아버지였다 흑',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 43),
#   '관람객'],
#  ['zelg****',
#   '이건 두세번 볼 영화가 아니네....투디 삼디 포디 아맥 네번가즈아!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 41),
#   '관람객'],
#  ['kdch****',
#   '리얼 올타임 레전드...',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 21),
#   '관람객'],
#  ['tlac****',
#   '미래로가고싶다 어벤져스4 개봉하는날로',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 4),
#   0],
#  ['ozko****',
#   '무엇을 상상하던 그 이상의 충격이다.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 21, 13),
#   '관람객'],
#  ['에피소드(libi****)',
#   '결말이 굉장히 충격적이었다... 지인에게는 절대로 미리 찾아보지말고 보라고 추천하고싶다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 20, 40),
#   '관람객'],
#  ['최인호(rago****)',
#   '진심 와... 이렇게 충격적일수가 없음!!!액션 대박에 내용은 진짜 더 초 대박 ㅋㅋㅋㅋ갓 닥터스트레인지 이길 바라면서!!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 20, 37),
#   '관람객'],
#  ['Min(sinn****)',
#   '결말은 충격적이지만 역대급 마블영화였다....특히 스파이더맨 나올때마다 너무 좋았다 ㅠ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 20, 32),
#   '관람객'],
#  ['OnlyPopSong(just****)',
#   '마블의 본격 제작비 줄이기 전략..',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 20, 12),
#   0],
#  ['추은비(choo****)',
#   '절대리뷰보지 마세요 평점도 보지마세요',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 19, 54),
#   0],
#  ['더벅(tkvk****)',
#   '설마했던 결말... 진짜로 이럴줄은... 빅픽쳐 클라스가 다르다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 18, 4),
#   '관람객'],
#  ['리준STYLE(reas****)',
#   '인간의 나약함과 토르의 각성',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 15, 22),
#   0],
#  ['떡마귀(beck****)',
#   '2019년 후속편이 더더욱 기대된다. 정말 재미있었다. 볼거리도 많고 내용도 내년에 나올 후속편으로 잇기 위한 역할을 하는 편이었다.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 13, 47),
#   0],
#  ['은진(tntp****)',
#   '보면 다 똑같은 말을 할거같다',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 13, 42),
#   0],
#  ['수제불벅백개(love****)',
#   '기존 마블 영화랑 다른 결말',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 25, 12, 52),
#   '관람객'],
#  ['이세윤(idgg****)',
#   '이걸 영화관 가서 못본 내가 패배자',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 10, 6, 1, 9),
#   0],
#  ['kdoy****',
#   '마블 영화 중 최고 팀영화',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 9, 25, 22, 48),
#   0],
#  ['또재맘(hye0****)',
#   '우아~~진짜 재미있는 영화입니다!',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 8, 3, 9, 32),
#   0],
#  ['Bullt(subi****)',
#   '그동안의 해피엔딩이라는 틀을 부셨다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 7, 14, 10, 2),
#   0],
#  ['유로파닭(goru****)',
#   '나는 마블작품을 되게 혐오한다 시대관이 확실히 정립되지 못했고 작위적이고 뻔한 클리셰에 결국엔 모든 영화가 자유의 가치를 말하고 정의는 승리한다 근데 이 작품은 나를 미소짓게 만든다 이것보다 완벽했던 마블영화는 없다...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 5, 12, 21, 57),
#   0],
#  ['김명주(kchj****)',
#   '마블이 10년동안 쌓아온 이야기의 클라이맥스 인데 인워 한편만 보고 평점테러는 좀 오바 아닌가 이건 마치 원피스 734화 한편보고 이게 무슨 명작?? 신의탑 2부 193화 한편보고 이게 무슨 명작?? 이라는거랑 다를...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 4, 18, 5, 34),
#   0],
#  ['seandean(sean****)',
#   '3시간짜리로 안 만든 게 아쉬울 정도',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 12, 27, 19, 30),
#   0],
#  ['킹왕짱주식(niga****)',
#   '번역이 아쉽고 허망하네요..',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 7, 14, 15, 2),
#   '관람객'],
#  ['물망초(kko8****)',
#   '아마추어번역가 데려다 번역시켜놓고 무슨 영화표 만원이나 받아쳐먹냐 오역인 걸 알면 수정을 해서 상영하든가 해야지 이거 뭐 장난하는 것도 아니고',
#   '1',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 16, 15, 14),
#   '관람객'],
#  ['홈런공장가동했나요(logi****)',
#   '토르를 무기 성애자로 만들고 닉퓨리를 효자로 만들고 닥터를 쉽게 포기하는 그런 캐릭터로 만든 각본가 박모씨 다음편에서는 제발 사라지세요 소설쓰지마시고 유능한 번역가에게 넘기세요.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 7, 17, 59),
#   0],
#  ['박정빈(pcal****)',
#   '토르가 제일 멋있었고 스타로드가 제일 암걸렸다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 6, 20, 36),
#   '관람객'],
#  ['Hun(hunt****)',
#   '역대급이었고 보는 내내 입이 안 다물어짐 ㄷㄷ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 5, 21, 1),
#   0],
#  ['지원(smil****)',
#   '블랙팬서 왜 죽여 .. 많이 나오지도 않았는데 ..',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 5, 21, 0),
#   0],
#  ['PREMIT(nnm3****)',
#   '번역가 좀 잘라라 좀 ㅅㅂ 어캐 욕쟁이를 효자로 만들 생각을 했냐?',
#   '1',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 3, 23, 57),
#   0],
#  ['사파(arc_****)',
#   '타노스가 박지훈 번역가는 없애지 못했다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 3, 9, 49),
#   '관람객'],
#  ['김국장(mw10****)',
#   '우선 여태껏 본 마블 영화중에 최고였던거 같네요... 그냥 무조건 적인 액션이 아닌 뭔가 생각할 수 있는 여지를 남겨준 영화 그리고 "이제 다 긑났낫어" 라는 대사가 오역이 아닐 수도 있는거 아닌가요?...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 3, 8, 51),
#   '관람객'],
#  ['도토리(co92****)',
#   '와.... 토르 진짜 역대급 이다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 3, 0, 23),
#   0],
#  ['ohga****',
#   '시간이 너무 짧네요 5시간했으면',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 1, 17, 4),
#   '관람객'],
#  ['Sanghoney(ksh0****)',
#   '20명이 넘는 히어로들이 나오는데도 혼잡스럽지 않았다 ㄷㄷ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 1, 14, 27),
#   0],
#  ['thsu****',
#   '번역이 진짜 화나게 하지만 나머지는 다 최고 2편이 기대됨',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 1, 4, 19),
#   0],
#  ['김유민(yoom****)',
#   '어벤져스 역사상 최고의 스케일, 충격',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 19, 9),
#   0],
#  ['정ㅋ벅ㅋ(stou****)',
#   '정말 마블영화중 최고의 영화다 이때까진 히어로들의 승리만을 그려냈다면  악당 타노스의 승리를 보여주며 화려하게 끝나고 다음 영화를 기대하게 만든다 길면 2,3년 후에 영화가 나올텐데 너무 기대된다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 19, 7),
#   0],
#  ['연규(dusr****)',
#   '너무재밌었어요 다음편이 너무 기다려져요',
#   '9',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 19, 6),
#   '관람객'],
#  ['erna(jein****)',
#   '토르 지구진입 씬은 첨보는 장면이 아닌데 볼때마다 소름',
#   '9',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 19, 0),
#   0],
#  ['Gabriel(xodn****)',
#   '어벤져스4 끝나고 와칸타 스타벅스 1호점에 모여서 커피타임',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 10, 24),
#   '관람객'],
#  ['에임하이(bara****)',
#   '하여간 또 라이 기래기 평론가들 평점봐라...쓰레기 한국영화엔 후하고, 창의적이며, 상상력이 풍부한 마블 영화에는 인색하네...진정한 평론가는 네티즌들이다..이런 스토리 라인 만들 수 있는 놈들있냐? 판타지와 공상과...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 30, 1, 57),
#   0],
#  ['vellotte(vell****)',
#   '어벤저스 시리즈 중에 제일 재밌었던 것 같아요ㅠㅠ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 29, 19, 25),
#   '관람객'],
#  ['qnfw****',
#   '히어로들 처음 등장할때마다 왠지 모르겠는데 울고 싶었음',
#   '9',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 29, 19, 1),
#   0],
#  ['훈이(sull****)',
#   '이 영화는 떡밥의 연속이였다.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 29, 11, 37),
#   '관람객'],
#  ['kuil****',
#   '역시 토르는 신이었음. 1500살 , 로키 개과천선 후 바로 사망 역시 사람이 갑자기 바뀌면 죽는다는 교훈적인 내용이었습니다.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 28, 12, 5),
#   0],
#  ['롯데걸(jiye****)',
#   '로키 왜 죽이는데? 미워할 수 없는 캐릭인데...흑흑',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 28, 4, 4),
#   0],
#  ['callmegray(j6t1****)',
#   '저 영화 2번봤는데 2번 더볼거에여. 5번봐도 아깝지않은... 특히 솔직히 지하철역 그림자속에서 등장하는 캡아나올때 어벤져스 브금 나오면서 토르 와칸다로 내려오면서 타노스 데려와 라고 말하면서 스톰브레이커로 찍어내리...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 27, 19, 1),
#   0],
#  ['유니(jiyu****)',
#   '연출 진짜 볼 때마다 감탄함. 전혀 오글거리지도 않고 황홀할 정도의 연출력에 연기는 말할 것도 없고 마블 히어로들을 다 모아뒀음에도 난잡하지않고 너무 재밌게 봤음. 역시 마블',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 27, 17, 18),
#   0],
#  ['KingLode(kimj****)',
#   '이건 꼭 세 번 이상 본다 최소',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 27, 3, 52),
#   '관람객'],
#  ['수빈(coco****)',
#   '토르 전기뿜는 등장씬 소름이었어여.. 뤼얼대박소름입니다 또보고싶어요',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 26, 21, 12),
#   0],
#  ['아마니(kll6****)',
#   '번역이 좀 마이너한 분야인가? 적폐 쩌네. 번역기 돌려서 다듬는 수준.',
#   '1',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 26, 13, 52),
#   0],
#  ['훈페이즈(hoon****)',
#   '박지훈 번역가 짤라라 제발',
#   '1',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 26, 13, 28),
#   0],
#  ['토실(emfo****)',
#   '넘치는 액션 긴박한 스토리 그리고 현자타임',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 25, 12, 55),
#   0],
#  ['Good(abcd****)',
#   '1점 뺀 이유는 스타로드를 분노조절장애 OO으로 만들어서.',
#   '8',
#   '7',
#   '2',
#   datetime.datetime(2020, 4, 1, 9, 37),
#   0],
#  ['박찬웅(cksd****)',
#   '벌써 6번째보는 영화(극장3번+집3번)진짜 인피니티워를 이길영화는 앤드게임밖에 없다.',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2019, 4, 6, 18, 45),
#   0],
#  ['JIYO(jiyo****)',
#   '시작부터 끝까지 단 1초도 재미없던 순간이 없었고, 지금까지 영화에서 느낄 수 없었던 묘한 감정을 느낌. 이게 재미없다는 사람은 그냥 감정이 없거나 인생이 겁나게 슬퍼서 기쁠줄 모르는거 아닌가 싶을정도.',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 5, 1, 23, 51),
#   0],
#  ['예지(dldp****)',
#   '10점으론 한참 모잘라',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 28, 13, 58),
#   0],
#  ['타미(ksm8****)',
#   '영화는 좋았는데, 박지훈 발번역 때문에 재미가 반감됨. 박지훈 꺼져라',
#   '1',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 26, 18, 49),
#   0],
#  ['궁중비책(ohna****)',
#   '타노스 기대 이상의 빌런이였음..마블 역대급 빌런',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 15, 8),
#   0],
#  ['hotr****',
#   '스포가두려워 눈뜨자마자보고왔다 개슬프네',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 14, 54),
#   0],
#  ['BGLOG1(rhkd****)',
#   '닥터가 떡밥을 주네요 ㅋㅋㅋㅋ 이거 또 맞추느라 고생들 하것넹',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 13, 29),
#   0],
#  ['김데일리(kkid****)',
#   '재밌다고 하기에도 슬프다고 하기에도 충격적이라고 하기에도 뭐하다. 어차피 어벤져스4에서 해결 되겠지 타임스톤이 잘못했다. 전부 타임스톤 때문이다.',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 13, 27),
#   0],
#  ['지형(vksk****)',
#   '진짜 나올때 다들 벙쪄서 말한마디없이나온다 역대급타노스이다정말로',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 12, 43),
#   0],
#  ['DOK2(echa****)',
#   '일찍보길잘했다충격이다',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2018, 4, 25, 11, 34),
#   '관람객'],
#  ['수사국장(20f0****)',
#   '마블 시리즈와 동시대를 살며 극장에서 보는자체가 영광이다',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2018, 4, 29, 19, 12),
#   0],
#  ['kim9****',
#   '닥터스트레인지 번역 오역 설명 영상 보고 내용을 이제 이해함. 반대의 의미로 오역해버려서 끝나는 내내 갸우뚱 함. 다끝났자고 얘기할거면 스톤을 왜줬어? 다음 작품 번역가 다른사람이 하면 좋겠다 제발',
#   '1',
#   '8',
#   '3',
#   datetime.datetime(2018, 4, 28, 3, 11),
#   0],
#  ['유진(nine****)',
#   '루소형제 대박이다. 걸작을 만들었네. 그걸 번역가 박지훈의 오역으로 망쳐놨다 ㅡㅡ 번역계의 ㅈㅍ',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2018, 4, 27, 0, 36),
#   '관람객'],
#  ['밍꾸(hgs0****)',
#   'motherfucxxx을 어머니라고  번역한 이 박읍읍 씨 닉퓨리 강제 효자행',
#   '1',
#   '8',
#   '3',
#   datetime.datetime(2018, 4, 26, 21, 53),
#   0],
#  ['오빠(kfc1****)',
#   '전염병 소굴 중국놈들 손가락 하나로 사라져 버려쓰면 좋겠다.',
#   '5',
#   '9',
#   '4',
#   datetime.datetime(2020, 4, 19, 19, 46),
#   0],
#  ['용석이애비(dydt****)',
#   '아무도 유효타 못냈던 타노스한테 한방 먹인 토르 개멋있다. 부탁한다, 스톰 브레이커! (피리릿 파파파파 푸슉!!!)',
#   '7',
#   '9',
#   '4',
#   datetime.datetime(2020, 4, 4, 15, 20),
#   0],
#  ['스마일조커(ehfn****)',
#   '진심 청와대 민원에 번역가 자격박탈좀 넣어줘라.',
#   '1',
#   '9',
#   '4',
#   datetime.datetime(2018, 4, 26, 6, 42),
#   0],
#  ['바람(brow****)',
#   '타노스의 타노스에 의한 타노스를 위한',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2020, 5, 17, 11, 35),
#   0],
#  ['히미밍(gmla****)',
#   '브링미타노스에서 전율이~~~ ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 3, 11, 14, 51),
#   0],
#  ['come****',
#   '진짜 어벤져스를 봤다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 11, 4, 4, 7),
#   0],
#  ['초코농약(wate****)',
#   '그냥 마블영화는 최고다 다시봐도 굿',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 21, 12, 22),
#   0],
#  ['서진맘_79년_본리동(hyun****)',
#   '와 마지막에 너무 울컥!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 17, 18, 7),
#   0],
#  ['메롱(ha_e****)',
#   '마블 세계관을 잘 모르는데도 불구하고 그 안으로 깊숙이 빨려들어간다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 14, 12, 40),
#   0],
#  ['소마(soma****)',
#   '최고입니다 너무 좋아요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 7, 19, 26),
#   0],
#  ['이승현(vr10****)',
#   '어벤져스 인피니티 워 스톤',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 22, 22, 42),
#   0],
#  ['hannah kim(imym****)',
#   '너무 좋아ㅜㅜㅜㅜ마블 영원하자',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 17, 11, 49),
#   0],
#  ['FromMe(boom****)',
#   '최고의 시리즈가 끝을 향해 달려간다. 히어로즈 대서사시의 충격적인 결말.',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 12, 22, 31),
#   0],
#  ['amit****',
#   '인피니티 스톤을 건 최후의 전쟁!타노스는 엔드게임에서 돌아온다!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 27, 23, 6),
#   0],
#  ['hyu(hyuk****)',
#   '너무 재미있고 앞으로도 화이팅!!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 16, 12, 17),
#   0],
#  ['smbo****',
#   '타노스랑 1:1 맞짱 가능 -> 토르, 스칼렛위치, 닥터 스트레인지.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 0, 8),
#   0],
#  ['몬스터에일리언(surs****)',
#   'Avengers: Infinity War, 2018',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 1, 22, 7),
#   0],
#  ['don(dong****)',
#   '짱 진짜 아이언맨간지 근데 결말이 반이죽어서 슬픔',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 26, 12, 35),
#   0],
#  ['황치웅(hwan****)',
#   '가망이 없어 가망이 없어 가망이 없어',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 18, 1),
#   0],
#  ['AAA(lklk****)',
#   '재밌네요~ 10점 줄만하네요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 12, 40),
#   0],
#  ['말라리아(hdk0****)',
#   '타노스가 굉장히 매력적이다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 17, 18, 36),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                        0  ...    6
# 0         순대볶음(gdcv****)  ...    0
# 1        RecOn(zkrp****)  ...    0
# 2               wndu****  ...  관람객
# 3          박우진(wls8****)  ...    0
# 4           별명(bomu****)  ...  관람객
# ...                  ...  ...  ...
# 1395      천상천하(srlt****)  ...    0
# 1396            lee2****  ...    0
# 1397  jyaj8709(jya3****)  ...    0
# 1398       비와이(ytre****)  ...    0
# 1399            tose****  ...    0
#
# [1400 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                 nickname  ... watch_movie
# 0         순대볶음(gdcv****)  ...           0
# 1        RecOn(zkrp****)  ...           0
# 2               wndu****  ...         관람객
# 3          박우진(wls8****)  ...           0
# 4           별명(bomu****)  ...         관람객
# ...                  ...  ...         ...
# 1395      천상천하(srlt****)  ...           0
# 1396            lee2****  ...           0
# 1397  jyaj8709(jya3****)  ...           0
# 1398       비와이(ytre****)  ...           0
# 1399            tose****  ...           0
#
# [1400 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
