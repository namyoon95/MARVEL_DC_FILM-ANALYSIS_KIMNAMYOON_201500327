# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(%EB%A7%88%EB%B8%94_%EC%96%B4%EB%B0%B4%EC%A0%B8%EC%8A%A4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=72363
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 72363
total_count = 2188  ## 전체 크기=2188

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=72363&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 72363
total_count = 2188  ## 전체 크기=2188

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['tang****',
#   '후반 40분 시퀀스의 CGI 효과는 가슴이 벅차고 놀랍다. 견고하고 정교하게 잘 만들어진 정석 히어로 블록버스터.',
#   '8',
#   '647',
#   '63',
#   datetime.datetime(2013, 7, 2, 0, 35),
#   0],
#  ['attl****',
#   '1점주는 것들은 제정신이 아닌듯 느그들땜시 10점준다',
#   '10',
#   '640',
#   '116',
#   datetime.datetime(2013, 6, 17, 23, 49),
#   0],
#  ['스나입허(tmsk****)',
#   '솔직히 이만한 sf는 찾아봐도 없다..',
#   '10',
#   '579',
#   '98',
#   datetime.datetime(2013, 7, 30, 0, 38),
#   0],
#  ['와양(dang****)',
#   '2편이 기대되는 영화',
#   '9',
#   '465',
#   '53',
#   datetime.datetime(2013, 6, 5, 14, 22),
#   0],
#  ['aaas****',
#   '어메이징 마블!',
#   '9',
#   '435',
#   '40',
#   datetime.datetime(2013, 6, 2, 17, 32),
#   0],
#  ['설란(nalu****)',
#   '너무 재미있게 봤어요~ 특히 마지막 부분 헐크가 로키 패대기 치는 장면 ㅎㅎ',
#   '10',
#   '390',
#   '17',
#   datetime.datetime(2013, 11, 6, 14, 40),
#   0],
#  ['S비밀(ming****)',
#   '덕후양성이 이해가는.. 이걸 왜 영화관가서 제때 안봤을까ㅜㅠㅠ 캐릭터 모두 매력터짐 끝나면 더 보고싶은 영화',
#   '10',
#   '289',
#   '9',
#   datetime.datetime(2014, 2, 1, 23, 44),
#   0],
#  ['HelloGoodBye(ktk0****)',
#   '특급  재료들을 모두 살려낸 쉐프',
#   '9',
#   '286',
#   '17',
#   datetime.datetime(2013, 9, 12, 21, 26),
#   0],
#  ['blue****',
#   '스토리는 뻔하지만 재미 하나는 예술일세. 히어로물에서 신나게 웃은 건 처음이다 ㅋㅋ 엔딩 크레딧 끝까지 웃겼다 ㅋㅋ',
#   '10',
#   '262',
#   '15',
#   datetime.datetime(2013, 10, 25, 23, 56),
#   0],
#  ['eksWkr(ghal****)',
#   '어벤져스 잴 재밌음 누가 영화에서 슈퍼히어로들 이렇게 많이 나오는 거 상상이나 했겠음? 최고의 영화',
#   '10',
#   '258',
#   '18',
#   datetime.datetime(2013, 11, 24, 23, 48),
#   0],
#  ['awesomelife(cjs3****)',
#   '사공이 많은데도 배가 똑바로 갔다..',
#   '9',
#   '209',
#   '6',
#   datetime.datetime(2016, 4, 10, 1, 30),
#   0],
#  ['버섯(luky****)',
#   '영웅들도 여럿이니깐 더멋있네',
#   '9',
#   '194',
#   '9',
#   datetime.datetime(2013, 10, 3, 3, 21),
#   0],
#  ['umba****',
#   '이거 한편 보고 영화보는 취미가 생겼고, 마블빠가 되었고, 그동안의 마블 히어로 영화를 모두 찾아봤다. 윈터솔져, 에이지 오브 울트론도 기대중',
#   '10',
#   '166',
#   '3',
#   datetime.datetime(2014, 3, 3, 23, 51),
#   0],
#  ['비밀(gall****)',
#   '각 히어로들의 개성과 조화를 무리없이 조율. 특히 후반부 압도적 스케일과 물량의 액션 시퀀스는 입이 쩌억~ 참고로 쿠키영상에 나온 최강의 적 타노스는 2탄 아니고 3탄에 나오신답니다. 대승적 차원에서 소니만 협력해줬...',
#   '10',
#   '117',
#   '8',
#   datetime.datetime(2013, 12, 28, 0, 7),
#   0],
#  ['아우디(popp****)',
#   '마지막 전쟁씬은 트랜스포머 전쟁씬이 지루 할 정도',
#   '10',
#   '104',
#   '10',
#   datetime.datetime(2014, 2, 2, 0, 4),
#   0],
#  ['hsb3****',
#   '상당히 벌여놓고 작정한듯 저질러놓는다.매우 유치한게 흠이지만 마블히어로들을 한 영화에서볼수있는게 어딜까.',
#   '8',
#   '90',
#   '18',
#   datetime.datetime(2014, 2, 2, 0, 37),
#   0],
#  ['신동(sdm1****)',
#   '슈퍼히어로들이 모여서 더 잼있다',
#   '9',
#   '78',
#   '10',
#   datetime.datetime(2013, 9, 15, 22, 32),
#   0],
#  ['Soarin(pji8****)',
#   '헐크  로키 패는거 왜이렇게웃김 ㅋㅋㅋ',
#   '9',
#   '66',
#   '4',
#   datetime.datetime(2016, 6, 1, 21, 53),
#   0],
#  ['레피테르(demo****)',
#   '잘 만들어진 히어로 영화.볼거리도 괜찮고 내용도 그럭저럭.',
#   '8',
#   '61',
#   '6',
#   datetime.datetime(2013, 8, 15, 14, 26),
#   0],
#  ['영국신사(jpt8****)',
#   '블록버스터 영화의 진수를 보여준 영화',
#   '10',
#   '56',
#   '7',
#   datetime.datetime(2014, 5, 25, 20, 14),
#   0],
#  ['Gammaray(dpft****)',
#   '마지막 스타크 인더스트리 건물의 하나남은 A 가 의미심장하다.',
#   '9',
#   '45',
#   '2',
#   datetime.datetime(2016, 10, 12, 22, 52),
#   0],
#  ['Elk(yosh****)',
#   '어차피 이거 1점주는 놈들도 다음 마블붙은 영화 나오면 풀발 하면서 보러갈꺼면서 뭔 비평가 코스프레?',
#   '10',
#   '47',
#   '4',
#   datetime.datetime(2015, 2, 26, 21, 44),
#   0],
#  ['bcoco2(qor2****)',
#   '레전드 영화의 시작 마블의 노예로 만든 작품',
#   '10',
#   '41',
#   '2',
#   datetime.datetime(2015, 4, 21, 22, 4),
#   0],
#  ['dake****',
#   '한마디로 그냥 최고다. 2편이 정말 기대됨',
#   '10',
#   '41',
#   '4',
#   datetime.datetime(2014, 2, 1, 23, 40),
#   0],
#  ['고로케(sunj****)',
#   '힘들어서 밥 꾸역꾸역 먹는겈ㅋㅋㅋ 완전웃곀ㅋㅋㅋㅋ',
#   '10',
#   '40',
#   '4',
#   datetime.datetime(2016, 6, 12, 20, 58),
#   0],
#  ['Only Now(k050****)',
#   '솔직히 극장에서 보고나와 재미없다는 사람은 그때 정신 나간거다',
#   '10',
#   '56',
#   '20',
#   datetime.datetime(2014, 2, 1, 23, 38),
#   0],
#  ['정요리너스(rlaw****)',
#   '안녕 토니, 안녕 아이언맨',
#   '10',
#   '38',
#   '4',
#   datetime.datetime(2019, 4, 24, 21, 45),
#   0],
#  ['fjfkskzkzk(gusr****)',
#   '캡틴이 토니에게 희생도 못하는사람이라하는데 지금 보면 울컥하는대사..',
#   '10',
#   '33',
#   '2',
#   datetime.datetime(2019, 5, 5, 22, 10),
#   0],
#  ['HongJunKii(besu****)',
#   '이거 2 언제나와? 1년 반이나 더 기다려야 한다니ㅠㅠㅠ',
#   '10',
#   '40',
#   '9',
#   datetime.datetime(2014, 2, 1, 23, 42),
#   0],
#  ['강태관(siwo****)',
#   '후반부에 영웅들 모여서 한바퀴 앵글잡는장면 진짜 멋있다.',
#   '10',
#   '29',
#   '0',
#   datetime.datetime(2018, 4, 25, 22, 16),
#   0],
#  ['행복한왕자(chom****)',
#   '영화관에서 보고 스맛폰으로보고 티비로보고 그랜드슬램 달성... 역시 어벤져스 스케일 단연코 최고임.. 캐릭 중에서는 역시 헐크짱!!! 스트레스 제로메이커임 ^^♥♥♥',
#   '10',
#   '35',
#   '7',
#   datetime.datetime(2014, 2, 1, 23, 42),
#   0],
#  ['우훌루후후(dngk****)',
#   '사공이 많다고 배가 산으로 가는 게 아니다. 속편인 에이지 오브 울트론이 더욱 기대되는 이유',
#   '8',
#   '24',
#   '2',
#   datetime.datetime(2015, 4, 22, 20, 46),
#   0],
#  ['nick****',
#   '이 시대에 태어나서 mcu와 함께라서 행복하다',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2018, 1, 29, 2, 1),
#   0],
#  ['원생이(wypa****)',
#   '다시보니까 정말 역대급이였네...ㄷㄷ',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2016, 5, 10, 22, 56),
#   0],
#  ['기곰천사(lsh5****)',
#   '히어로들을 한데 모았다는 것에서 일단 10점',
#   '10',
#   '22',
#   '2',
#   datetime.datetime(2015, 4, 19, 9, 8),
#   0],
#  ['워메으채야쓰까잉(pmh2****)',
#   '다양한캐릭터들과 헐크의반전더군다나가끔나오는 코믹정교한그래픽뭐하나빠질께없다 나도영화광이지만어벤저스는정말잼있다.호크아이.나타샤영화만나오면대박일듯',
#   '10',
#   '22',
#   '2',
#   datetime.datetime(2014, 4, 1, 2, 41),
#   0],
#  ['fullmoon(ef14****)',
#   '후반에 가면 미친듯이 재미있다',
#   '9',
#   '20',
#   '2',
#   datetime.datetime(2015, 6, 8, 16, 24),
#   0],
#  ['Jester(zerr****)',
#   'Dc 니네는 왜 이런거 못만드냐...',
#   '8',
#   '23',
#   '5',
#   datetime.datetime(2018, 2, 1, 17, 23),
#   0],
#  ['임전무퇴(holy****)',
#   '내가본 첫 마블영화. 그때는 아무것도 모르고 액션 보는 재미로 봤었다. 최근 어벤져스3를보고 흥미가 생겨 일주일만에 가오갤1,2 토르1,2,3 아이언맨 1,2,3 순으로 마블영화를 정주행했다. 그리고 오늘 어벤져스를...',
#   '10',
#   '18',
#   '1',
#   datetime.datetime(2018, 5, 22, 22, 42),
#   0],
#  ['재능10노력7(snfl****)',
#   '결국 1편에 나오는 원년 멤버들만 살렸군.',
#   '10',
#   '18',
#   '2',
#   datetime.datetime(2018, 4, 26, 22, 12),
#   0],
#  ['크리스탈(tnwj****)',
#   '내 개인적으로 마블 영화중에서 최곤거같다.마블 히어로들이 다 나와서 그런지 더 스릴있고 멋있다왠지 과자 선물 세트를 받은 느낌이랄까?2편이 기대된다 진짜 최고.♡',
#   '10',
#   '21',
#   '5',
#   datetime.datetime(2014, 10, 5, 1, 48),
#   0],
#  ['후달달달(ookb****)',
#   '밑에놈.. 토르 망치는 토르빼곤 아무도못드는거임원래. 세계관도 이해못하면서 뭘 영화를 까고안잣음..',
#   '10',
#   '21',
#   '6',
#   datetime.datetime(2016, 5, 9, 21, 48),
#   0],
#  ['손예진(bhhb****)',
#   '더빙따위로 봤는데도 이정도면 머 게임 끝이라고생각한다..',
#   '10',
#   '19',
#   '5',
#   datetime.datetime(2014, 2, 2, 12, 29),
#   0],
#  ['2booms(crea****)',
#   '어벤져스, 전설의 시작',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2019, 5, 1, 16, 45),
#   0],
#  ['쿨아키(yoon****)',
#   '개인적으로 헐크가 짱이닼ㅋㅋ',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2015, 5, 5, 20, 14),
#   0],
#  ['Empty(soma****)',
#   '마블시리즈는 언제나 나를 실망시키지 않는다.',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2014, 3, 28, 15, 59),
#   0],
#  ['톰헨슨(qock****)',
#   "I'm always angry",
#   '10',
#   '15',
#   '2',
#   datetime.datetime(2015, 4, 25, 5, 15),
#   0],
#  ['김민석(topt****)',
#   '스토리가 느슨해도 액션신 하나로 관중들을 압도한다.',
#   '8',
#   '17',
#   '4',
#   datetime.datetime(2014, 9, 22, 17, 44),
#   0],
#  ['깊은(itre****)',
#   '모든 캐릭터가 자신들의 존재감을 화려하게 화끈하게',
#   '7',
#   '12',
#   '0',
#   datetime.datetime(2019, 5, 2, 15, 56),
#   0],
#  ['유나미르(tlst****)',
#   '어벤져스 시리즈 중 최고다. 한번 더 봐도 좋을정도로.. 아이언맨 3000만큼 사랑해',
#   '10',
#   '12',
#   '0',
#   datetime.datetime(2019, 4, 27, 14, 59),
#   0],
#  ['HOMEP HOJIB(col1****)',
#   '히어로 무비, 그 전설의 시작',
#   '10',
#   '12',
#   '0',
#   datetime.datetime(2018, 4, 4, 7, 48),
#   0],
#  ['dandy94김영균(kyk7****)',
#   '찡했다 어벤져스를 앞으로 못본다는 생각에',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2019, 5, 6, 10, 52),
#   0],
#  ['호갱(smdu****)',
#   '어벤져스 왜 이제야 봤을까.... 이건 직접 영화관 가서 봐야 했다 ㅜㅜㅜ 아 진짜 존멋 미친 존멋 왜 마블 마블 하는지 알겠어요 엉엉 어벤져스 사랑해요 ?????? 마지막 엔딩 귀욥 ㅎㅎ',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2017, 3, 18, 14, 41),
#   0],
#  ['굶주린배(fsre****)',
#   '엔드게임 시청하고 다시보니 감회가 남다른 영화. 어벤져스 시리즈 중에서 액션신만은 1편의 뉴욕전이 쵝오!!!! 부다페스트 대사는 여기서도 나오는군... 토니는 핵미사일을 안고서 여기서도 헌신을 했다... 엔딩크레딧 ...',
#   '9',
#   '14',
#   '2',
#   datetime.datetime(2019, 5, 4, 21, 12),
#   0],
#  ['지혀니(wlgu****)',
#   '처음부분은좀지루한감이 있었는데후반부는정말재밌었어요!',
#   '9',
#   '18',
#   '6',
#   datetime.datetime(2014, 2, 2, 1, 48),
#   0],
#  ['킹날두빛날두갓날두(htmd****)',
#   '본격적인 마블 시네마틱 유니버스의 시작. 히어로를 한데 뭉치게하는건 성공했지만 일부 멤버의 경우는 아이덴티티는 둘째치고 기본적인 정보조차도 결여되어진 상태에서의 출발이 낯설게 느껴진다.',
#   '7',
#   '16',
#   '5',
#   datetime.datetime(2019, 6, 25, 14, 44),
#   0],
#  ['hansh1021다솜(hans****)',
#   'DC를 이기기 시작한 전설',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2019, 4, 27, 6, 31),
#   0],
#  ['다니엘혀니(dani****)',
#   '7년만에 다시 봤는데 오프닝때 인류를 재로 만든다는 멘트가 나오고  엔딩 쿠키에서 타노스가 나옴ㄷㄷㄷ',
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2019, 4, 1, 9, 51),
#   0],
#  ['김태하(taeh****)',
#   '노트북으로 봤는데도 이렇게 재미있다니..! 2편도 기대되네요.',
#   '10',
#   '12',
#   '2',
#   datetime.datetime(2015, 4, 25, 1, 9),
#   0],
#  ['풋사과(dbsw****)',
#   '진짜 재밌다. 역시 마블은 믿고 볼 수 있어요. 사랑해요.',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2016, 7, 31, 19, 46),
#   0],
#  ['주꾸미P(side****)',
#   '히어로 영화에서 다크나이트의 그림자를 걷어내는데 성공한 영화 이 뒤에 나온 대부분의 히어로 영화가 어벤져스1을 모방하는데 허덕이고 있다',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2019, 4, 27, 0, 58),
#   0],
#  ['jjaj****',
#   '이전 마블영화를 다 예고편으로 만들어버리는 영화.. 물론 그런 의도였겠지만',
#   '9',
#   '11',
#   '2',
#   datetime.datetime(2014, 5, 20, 18, 58),
#   0],
#  ['쿵쿵뿜뿜(love****)',
#   '1편인데 너무 잘만들었네',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 8, 24, 23, 8),
#   0],
#  ['GTR(rela****)',
#   '정주행중인데 지금봐도 안꿀리네',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 5, 7, 0, 59),
#   0],
#  ['RKskell(juny****)',
#   '전설의 시작을 알리는 작품',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 4, 28, 1, 6),
#   0],
#  ['OST(orph****)',
#   '1점 주는 인간들 때문에 10점이다..',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2018, 7, 11, 10, 14),
#   0],
#  ['정소연(symo****)',
#   '이런걸 국뽕 삼류영화랑 비교하나 ㅋㅋ 진심',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 8, 18, 16, 41),
#   0],
#  ['반찬(raul****)',
#   '저스티스리그보면 이 영화가 얼마나 더 대단한지 알수있음',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 7, 31, 20, 31),
#   0],
#  ['토르(mini****)',
#   '어벤져스 시리즈중 가장 재밌다',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 5, 3, 21, 42),
#   0],
#  ['느와르(qorw****)',
#   '1점주는 것들은 제정신이 아닌듯 느그들땜시 10점준다',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2018, 4, 29, 15, 42),
#   0],
#  ['Whity(yjbg****)',
#   '연출도 CG도 모두 좋은데, 그 중에서도 OST는 진짜 잘 만들었다..',
#   '9',
#   '9',
#   '1',
#   datetime.datetime(2018, 4, 27, 12, 34),
#   0],
#  ['oksi****',
#   '이걸 왜 진작에 안 봤는지ㅠㅠㅠ 진짜 너무 재밌다',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2016, 8, 23, 12, 57),
#   0],
#  ['고슴도치(newn****)',
#   '아 왜 이 영화를 이제서야 봤을 까 ㅡㅡ;',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2014, 7, 27, 2, 43),
#   0],
#  ['채린(cher****)',
#   '지금 보니까 캡틴 복장 엄청 촌스럽네ㅋㅋㅋㅋ',
#   '8',
#   '10',
#   '2',
#   datetime.datetime(2019, 4, 13, 23, 11),
#   0],
#  ['노코멘또(sjss****)',
#   '확실히 마블 시네마틱에 대해 어느정도는 파악해야 이영화를 재밌게볼듯.. 솔직히 아무것도 모르고 봤을땐 별로 재미없었음',
#   '7',
#   '11',
#   '3',
#   datetime.datetime(2016, 11, 4, 16, 51),
#   0],
#  ['아헤벨겨(kkc7****)',
#   '전작을 안본 사람들도 이해되는 작품',
#   '8',
#   '7',
#   '0',
#   datetime.datetime(2019, 4, 25, 13, 20),
#   0],
#  ['ajksdhjksq(kore****)',
#   '내가 이걸 여태까지 10점을 안줬다고? ㅋ',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 4, 28, 22, 7),
#   0],
#  ['고록바의슬픔(ehst****)',
#   '말이 필요한가 굳이? 음?',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 4, 1, 16, 47),
#   0],
#  ['샤프클로(ldw5****)',
#   'Avengers assemble!!',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 1, 19, 10, 35),
#   0],
#  ['무파마(sohw****)',
#   '어느 순간부터 액션물이나 환타지물에게도 철학을 묻게된다.',
#   '9',
#   '8',
#   '1',
#   datetime.datetime(2015, 5, 4, 2, 11),
#   0],
#  ['다크아이(jerl****)',
#   '히어로들도 골고루 잘 나오고 짱잼임!',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2015, 4, 15, 22, 14),
#   0],
#  ['펀크(rlar****)',
#   '핵꿀잼이었느데 왜 8점이냐',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2015, 4, 13, 16, 39),
#   0],
#  ['핥(gkag****)',
#   '난 이 영화가 다른 마블영화들과 연결되어 지는줄도 몰랐고 지팡이에 스톤이 이렇게 중요한지도 몰랏다8년전에 영화관에서 봤을땐 그냥 액션영화 같아서 그냥 본건데지금와서 이영화를 다시 봐야할정도로 스토리 짜임새가 대단함',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2020, 4, 9, 0, 5),
#   0],
#  ['김연우(0510****)',
#   '이것의 탄생으로 모든것이 시작됬다',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 10, 3, 12, 51),
#   0],
#  ['지미(elem****)',
#   '종합선물세트로는 제격',
#   '7',
#   '6',
#   '0',
#   datetime.datetime(2019, 9, 12, 18, 11),
#   0],
#  ['뮤뮤(chea****)',
#   '이제서야 본걸 후회중이에요',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 9, 4, 23, 13),
#   0],
#  ['장형(wkdt****)',
#   '다시봐도 재밋다. 헐크와 언맨의 캐미 ㅋㅋ',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 7, 11, 22, 16),
#   0],
#  ['나는야속기사(ljra****)',
#   '다시봐도 역시 재밌다. 이때 봤을때만해도 짐작할수도 없었는데ㅠ 쿠키에 타노스가 나왔을줄이야.',
#   '9',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 30, 22, 0),
#   0],
#  ['mjw1****',
#   '영화를 본 뒤엔 슈와마를 먹어주자.',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 30, 3, 44),
#   0],
#  ['mins****',
#   '히어로 영화계의 새로운 역사를 보여준 걸작.',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 29, 11, 57),
#   0],
#  ['호랑이 파워(wpwn****)',
#   '이때부터 마블의 전성기이자 스케일이 엄청 커진 영화.',
#   '8',
#   '6',
#   '0',
#   datetime.datetime(2018, 6, 14, 1, 52),
#   0],
#  ['김세호(gim9****)',
#   '위대한 마블시리즈의 시작',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2018, 4, 24, 17, 9),
#   0],
#  ['크앙(z826****)',
#   '마블은 아묵하고 10점 ㅇㅋ?',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2018, 4, 23, 9, 7),
#   0],
#  ['Damien(yoos****)',
#   '히어로물은 뻔한 권선징악에 유치하다는 편견으로 마블영화 거의 안봤다가 요즘 시간남아 몰아보고 있는데 내가 왜 그 딴 생각을 했나 반성하게됨. 왜 사람들이 마블에 환장하는지 알겠더라.',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2019, 2, 25, 2, 1),
#   0],
#  ['박실(qkrt****)',
#   '이거 평점을 왜 이제야 쓰게 되었는가? 개봉 당시 큰 충격을 가져 온  희대의 역작, 어벤져스',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 4, 15, 6, 42),
#   0],
#  ['구민재(mmjj****)',
#   '평론가 허지웅씨 예지력 오지네ㄷㄷ',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2018, 3, 22, 18, 14),
#   0],
#  ['햇살소년(wjdg****)',
#   '어벤져스부터 마블 영화 보기 시작한 사람 손!',
#   '9',
#   '5',
#   '0',
#   datetime.datetime(2019, 10, 10, 1, 18),
#   0],
#  ['바탕색(zzhe****)',
#   'CG 가상적이고 좋았다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 9, 12, 18, 52),
#   0],
#  ['피카츄(pika****)',
#   '아이언맨이주인공인줄',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 9, 1, 8, 25),
#   0],
#  ['탱고와페라리(swel****)',
#   '마블을 흥행이라는 궤도에 성공적으로 안착시키다',
#   '7',
#   '5',
#   '0',
#   datetime.datetime(2019, 8, 31, 16, 23),
#   0],
#  ['완치확정현석(glgl****)',
#   '마블 히어로들이 모였다 마블영화중에서는 최고의 영화',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 8, 6, 2, 49),
#   0],
#  ['wthn****',
#   '전설의 시작 주제곡 너무 소름돋음',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 7, 11, 22, 16),
#   0],
#  ['머루(taij****)',
#   '2019년에 오신분!!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 6, 5, 0, 55),
#   0],
#  ['BonaFide(rhee****)',
#   '헐크가 로키 뚜까팰때 겁나 사이다 ㅋㅋㅋ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 5, 26, 21, 53),
#   0],
#  ['강태일(gsh2****)',
#   '다시보는 시즌1! 완전 꿀잼~',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 5, 9, 16, 11),
#   0],
#  ['찬s(cwoo****)',
#   '동료가 지나갈 수 있게 철조망에 누워줄 인물이 아니지..여기서 울컥했다.. ㅠㅠ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 5, 7, 3, 1),
#   0],
#  ['xcv5****',
#   '채널 돌리다 ocn에서 하길래 보는중인데,가만보니 어벤져스들의 첫만남이 다시보는 시점에서 유쾌하면서도 뭉클하다 ㅎ',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 5, 3, 20, 37),
#   0],
#  ['가레스(leeu****)',
#   '어벤져스의 탄생과 그시작',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 4, 30, 20, 35),
#   0],
#  ['kkw0****',
#   '마블 포에버 명작명작명작',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 4, 29, 23, 49),
#   0],
#  ['3점슛(hoju****)',
#   '슈퍼 블록버스터의 서막. 슈퍼 히어로들이 한 영화에 다 같이 나온다는 것만으로도 기념비적인 영화.',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 7, 23, 0, 22),
#   0],
#  ['Roller(48co****)',
#   '미래에서 왔다... 너희들을 보며 말하고 싶은 말은... 오늘 저녁은 치킨이닭!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 5, 9, 21, 25),
#   0],
#  ['미니언즈(mari****)',
#   '어벤져스 시리즈의 첫시작... 그자체로도 인상깊다.',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 5, 9, 12, 5),
#   0],
#  ['미드최고(kcys****)',
#   '지금 다시보니알겠다. 이게 마블씨리즈 중에 최고다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 5, 9, 2, 13),
#   0],
#  ['유대혁(ydh8****)',
#   '액션영화 라면 이래야지..',
#   '7',
#   '5',
#   '0',
#   datetime.datetime(2018, 5, 4, 0, 56),
#   0],
#  ['ghks****',
#   '자 과거로 돌아가보자 again gers',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 4, 27, 2, 24),
#   0],
#  ['전예은(jjh2****)',
#   '다시봐도 언제봐도 재밌고 푹 빠져서 봤습니다사랑해요 어벤져스♥? 정말 인생 영화 입니다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 3, 3, 5, 43),
#   0],
#  ['khs9****',
#   '무슨말이 필요한가 그냥 전설이지',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 2, 28, 5, 15),
#   0],
#  ['가나다라(wyve****)',
#   '액션은 역대 슈퍼히어로 영화중에서는 최고였음. 6명의 분량을 적절히 배분시킴',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 2, 26, 20, 26),
#   0],
#  ['리즈(duwn****)',
#   '이 영화때문에 2010년대 슈퍼히어로 무비가 유행이 된거고 너도나도 각자만의 세계관(시네마틱 유니버스)구축을 하게됨. 단독 주연 히어로 영화에서 보던 각자의 캐릭터들이 한 자리에 모였다는게 정말 소름이 돋을정도로 기...',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 2, 23, 9, 21),
#   0],
#  ['넥셔스이글(alsw****)',
#   '여러 히어로들이 만난것 만으로도 의미있는 작품',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2018, 2, 16, 21, 56),
#   0],
#  ['knni****',
#   '말이 필요없음 이건 ㅇㅈ?',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 1, 30, 16, 34),
#   0],
#  ['대나무소금(akde****)',
#   '캡틴아메리카 의상만 괜찮았다면 완벽했을 영화',
#   '7',
#   '5',
#   '0',
#   datetime.datetime(2017, 11, 13, 14, 23),
#   0],
#  ['wehrmacht(woon****)',
#   '마블의 모든 기운이 모였다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2017, 10, 4, 20, 46),
#   0],
#  ['히드라 리스크(zamd****)',
#   '이게 가능하다고????',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 10, 20, 11, 56),
#   0],
#  ['서디귿(phea****)',
#   '어벤져스의 첫 팀웍 활동.',
#   '8',
#   '6',
#   '1',
#   datetime.datetime(2019, 10, 27, 0, 41),
#   0],
#  ['KILLMOON(ligh****)',
#   '한반도에 와서 돼지 김정은과 삶은 소대가리 문재인 죽여주세요',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 10, 18, 21, 38),
#   0],
#  ['FromMe(boom****)',
#   '어벤져스가 어벤져스했다. 정주행으로 보니 진가를 깨달았다.',
#   '8',
#   '6',
#   '1',
#   datetime.datetime(2019, 5, 14, 12, 46),
#   0],
#  ['사비스트레인지(vhvh****)',
#   '올해 고3인데 나의 마지막10대를 책임져준 어벤져스 시리즈가 이렇게또 끝나네 ㅠㅠ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 4, 29, 7, 0),
#   0],
#  ['강화지(yugo****)',
#   '솔직히 2, 3보다 1이 낫다.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 27, 17, 40),
#   0],
#  ['아트하랑(cjdg****)',
#   '만화를 영화로 본 순간 손에 땀이남..ㅠㅠ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 15, 19, 45),
#   0],
#  ['dlax****',
#   '마블이 드디어 꿈을 이룬 거 같아 내가 오히려 기쁜 마음이 들었다. 이런 영화를 만들 수 있다는 것은 그야말로 대박이다.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 1, 16, 22, 31),
#   0],
#  ['river 13914(kmin****)',
#   '마블 최고!! 역시 어벤져스',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2016, 8, 15, 20, 3),
#   0],
#  ['신현남(hoho****)',
#   '이건 걍 짱이다.엄청나다',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2016, 7, 24, 17, 3),
#   0],
#  ['you830(llss****)',
#   '깨알 재미요소하고 멋있는 액션씬하고 잘 어울리는 영화중간에 토니가 중년남성 5명중에1명은 부전 이라고 말한거 뿜음',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2016, 7, 21, 17, 26),
#   0],
#  ['Sy(sssy****)',
#   '과거에 아이언맨만 보고봣을때 이해도잘안되고 와닿는것도없어서 그냥저냥보고말앗는데..이번에 마블시리즈순서대로보고나니 이해도재미도 확실히 장난아니엇음. 각각 알고잇엇던 영웅들을 합쳐놓으니 참 신박하고 흥미로워서 재미도더햇...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2016, 5, 11, 10, 31),
#   0],
#  ['인형(cuty****)',
#   '재밌엉 ㅠㅠㅠㅠcg짱짱맨',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2015, 4, 10, 21, 6),
#   0],
#  ['진민우(jmw0****)',
#   '짱!!!!  헐~크!!!',
#   '9',
#   '6',
#   '1',
#   datetime.datetime(2015, 2, 28, 21, 11),
#   0],
#  ['삐돌이777(alex****)',
#   '솔직히 이게  왜 8점대지;;',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2015, 1, 19, 16, 36),
#   0],
#  ['jby0****',
#   '닝겐노유리와튼튼데스네 가 제일인상적이었습니다.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2014, 10, 21, 18, 48),
#   0],
#  ['정통국사(zkvl****)',
#   '유치하거나 말거나 재미만 있었다. 킬링타임용 영화 중에서도 단연 최고인듯.',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 36),
#   0],
#  ['zaqz****',
#   '솔직히 너무 재밌었다... 디씨도 분발해서 저스티스 리그 오브 아메리카 빨리 만들자.',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2014, 1, 31, 5, 53),
#   0],
#  ['baer****',
#   '어설픈 스토리와 전개는 재껴두자~ 모든마블영웅들의 이야기가 궁금해지는 영웅s영화!! 속편들 두고두고 나오길 기대해본다',
#   '8',
#   '9',
#   '4',
#   datetime.datetime(2013, 9, 10, 9, 5),
#   0],
#  ['pix(pixa****)',
#   '어쩌면 엔드게임에서 수십명의 영웅들이 모인 장면보다도 이 영화에서 6명의 영웅들이 모인 장면이 훨씬 더 위대한 것일지도...',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 5, 16, 9, 19),
#   0],
#  ['행복은 지금 이 순간(harr****)',
#   '이걸 먼저 봤을땐 그저그랬는데, 전작들을 다 복습하고 보니 더 좋더라.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2020, 1, 31, 21, 45),
#   0],
#  ['토트넘챔스가자제발(ftgm****)',
#   '완벽그자체인영화!!!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 11, 16, 15, 13),
#   0],
#  ['yana****',
#   '무난하다고 본다...',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 25, 1, 20),
#   0],
#  ['김경원(gyeo****)',
#   '4번째 ㅠ 최고에요 !!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 7, 8, 23),
#   0],
#  ['timeist(chun****)',
#   '슈퍼히어로 액션의 신기원을 열다',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 8, 5, 12, 15),
#   0],
#  ['parkhyonsu(omom****)',
#   '재개봉 해줬으면 좋겠음',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 21, 3, 51),
#   0],
#  ['김혜승(gptm****)',
#   '아벤져스는 역시 어벤져스 ㄷㄷ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 7, 12, 15, 45),
#   0],
#  ['킹갓누노(zksn****)',
#   '저도 어벤져스 지원 가능한가요?',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 2, 2),
#   0],
#  ['조선왕조실룩샐룩(yulj****)',
#   '조스 웨던의 장점이 여과없이 드러나는 영화',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 6, 1, 4),
#   0],
#  ['스폰지밥(coco****)',
#   '개사랑해토니스타크ㅠㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 18, 23, 50),
#   0],
#  ['7405****',
#   '액션최고.볼만함아주',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 7, 19, 26),
#   0],
#  ['TMA(yyw2****)',
#   '재미있게 잘 봤습니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 4, 27, 11, 36),
#   0],
#  ['신짱아(hhho****)',
#   '전설의 시작. 전부 레전드. 근데 난 그중에서 아이언맨이랑 블랙위도우가 제일 최고!! 역대급 블록버스터.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 3, 6, 13, 28),
#   0],
#  ['doll****',
#   '10자 싫다... 전설의 시작.',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2019, 2, 24, 16, 14),
#   0],
#  ['만화가좋은주탱(sout****)',
#   '스토리자체는 외계인으로부터 영웅들이 지구를 지키는 평범한 스토리지만 cg효과등 눈을 즐겁게 해주는 요소가많이있다.',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2019, 2, 21, 12, 14),
#   0],
#  ['러블리즈 응원합니다(maum****)',
#   '스카이캐슬 상위 0.5프로 능력자들이 모였을때 생기는 안좋은예.과다경쟁과 개성이 없어지는 부작용을 느낄 수 있다.결국 최고 능력자는 로키였음을 깨닫게 됐다..',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2019, 2, 20, 17, 47),
#   0],
#  ['유똥이(yutt****)',
#   '진짜 2, 3편도 재미있지만 1편이 레전드인듯',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 1, 9, 11, 14),
#   0],
#  ['스파이더맨(ljs9****)',
#   '마블의 존재조차 몰랐던 내가 마블을 알게해준 영화 지금봐도 흠 잡을 데가 없는 훌륭한 명작',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 10, 11, 2, 30),
#   0],
#  ['cookie(love****)',
#   '개봉날 봤었는데 스토리 다 잊어버려서 다시봄.. 캡틴아메리카와 아이언맨 불화가 처음부터 있었구나.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 10, 8, 11, 13),
#   0],
#  ['김주영(kjyo****)',
#   '전설의 시작 아니겠냐.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 8, 31, 16, 37),
#   0],
#  ['신유민(mins****)',
#   '극장에서 본지 6년 됐는데 이것도 추억이 되어가는건가... 역시 어벤져스는 진리다. 아이언맨은 사랑입니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 8, 28, 23, 4),
#   0],
#  ['웅동(enoq****)',
#   '왜 세계관을 공유하는 영화가 유행하는지 단번에 이해할 수 있겠다',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2018, 8, 27, 2, 50),
#   0],
#  ['JYmv(qwqw****)',
#   '어벤져스1 캡틴 유니폼이 너무촌스럽긴한데 영화 자체는 좋앗따',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 8, 5, 20, 52),
#   0],
#  ['mwit****',
#   '이걸 이제보다니...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 7, 24, 6, 57),
#   0],
#  ['cmlg****',
#   '정석대로 묵묵히 몰아붙이면 이런 영화가 나온다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 7, 21, 23, 20),
#   0],
#  ['권나연(dafn****)',
#   '진짜 믿고보는 마블... 로키 넘 좋아♥',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 7, 12, 19, 59),
#   0],
#  ['미래(heyw****)',
#   '외계인들 지겹도록 끊임없이 쳐들어와서 보는 나도 힘드니 히어로들 고생하는구나 생각했다.. 영화지만',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 7, 11, 5, 14),
#   0],
#  ['오성빈(seon****)',
#   '믿고보는 마블영화 봐도봐도 안질린다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 6, 30, 22, 48),
#   0],
#  ['임현우(lhw2****)',
#   '정말로 마블 이때에도 대형사고를 쳤구나',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 6, 29, 22, 7),
#   0],
#  ['옌디아(dnvk****)',
#   '개꿀잼 진짜 ㄷ ㄷ ㄷ 오그라드는 장면 몇 있지만 히어로물이니께 ㅎㅎ',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2018, 6, 24, 1, 28),
#   0],
#  ['pullu(pull****)',
#   '진짜 전설의 시작이였지...첫번째는 아이언맨1 이고...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 6, 16, 21, 9),
#   0],
#  ['sur0****',
#   '내 인생영화 입니다 마블시리즈 끝나지말아요 ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 6, 12, 13, 38),
#   0],
#  ['판타스틱싱어(coco****)',
#   '후반 40분은 화려함의 극을 달리는 스케일. 조스웨던 감독의 각본과 연출력에 박수를 보낸다',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2018, 5, 30, 5, 56),
#   0],
#  ['김지민(fore****)',
#   '콜슨 좋아했어요ㅠㅠ 헐크짱!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 5, 9, 1, 0),
#   0],
#  ['김효달(rlat****)',
#   '진짜  최고의 영화 전설의 시작',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 5, 7, 22, 54),
#   0],
#  ['smile(0319****)',
#   '전설의 시작. 아, 캡틴아메리카1이던가',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 4, 28, 3, 7),
#   0],
#  ['백설공주(llka****)',
#   '치타우리가 깽판치는 뉴욕 중심에서어벤져스 모두가 모이고 그들에게 포커스를 맞추면서 돌때 눈물이 났다..',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 4, 22, 13, 33),
#   0],
#  ['수빈(4220****)',
#   '말이 필요한가?  전설의 시작.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 3, 31, 13, 40),
#   0],
#  ['은이은이(youn****)',
#   '최고의 영화 최고의 액션',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 1, 5, 1, 27),
#   0],
#  ['부끅곰(rkqa****)',
#   '명작 이건 상줘야함 ㄹㅇ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 12, 15, 19, 7),
#   0],
#  ['레고(lego****)',
#   '마블 시네마틱 유니버스의 최고 흥행작일 자격이 있다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 11, 2, 15, 40),
#   0],
#  ['ㅌㅌ(jjj1****)',
#   '최고의 히어로물 마블 영화 어렸을때 안본걸 후회한다 ㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 10, 5, 18, 42),
#   0],
#  ['rnjs2302(rnjs****)',
#   '이걸 이제야 보다니ㅠ ㅠ 역시 사람들한테 인기있는 영화는 이유가 있다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 9, 15, 22, 30),
#   0],
#  ['인간(tkek****)',
#   '마블의 역대급프로젝트답게 역대급임 히어로들이 각각 다 매력있고 마블다운 유머도 적절했고 액션씬은 장난아니라는거 ㅇㅇ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 3, 17, 20, 5),
#   0],
#  ['동네형(best****)',
#   '최고의 오락영화 확실히1편은 재미졌음',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2017, 1, 26, 9, 58),
#   0],
#  ['Danny Seong(whun****)',
#   '거의 상영관 끝물에 겨우 극장가서 봤는데.. 극장에서 보길 잘했다고 생각이 드는 마블 영화~~!!!! 엄지 척!!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 10, 10, 11, 22),
#   0],
#  ['준이맘(kwak****)',
#   '마블의 역전, dc의 부진',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 25, 20, 10),
#   0],
#  ['플(powe****)',
#   '이 영화는 놀랍다만으로 부족한 영화인것같습니다. 잘 짜여진 각본과 히어로들의 개연성 및 파트별로 잘 나뉘어진 연출은 히어로물의 한획을 그엇습니다. 소름이 돋더군요.',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 7, 18, 40),
#   0],
#  ['Clayton Kershaw(poze****)',
#   '마블이 왜 최고의 자리에 있는지 이 영화만 봐도 알 수 있다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 7, 6, 16, 47),
#   0],
#  ['zz(bosu****)',
#   '여섯 영웅들 다 너무 멋있음 ㅠㅠ 특히 아이언맨최고,,',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 5, 21, 23, 50),
#   0],
#  ['KHW(hyun****)',
#   '내가 마블에 빠지게된 이유',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2019, 5, 14, 0, 22),
#   0],
#  ['슈퍼돼지(jyc1****)',
#   '엔드게임을 보고 다시 본 어셈블. 새삼스럽지만 알고 다시 보니 이후 영화에 대한 힌트를 말해주고 있었다.',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2019, 5, 3, 21, 17),
#   0],
#  ['삭제당한아뒤(tkrw****)',
#   '너 때문에 마블 영화 빠돌이가 됬으니까 책임져!',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2018, 9, 4, 12, 57),
#   0],
#  ['juve(zi04****)',
#   '마지믹에 슈와마 먹는장면 개귀엽네ㅋㅋㅋ',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2018, 1, 9, 14, 40),
#   0],
#  ['mons****',
#   '영웅물 선물셋. 중요한건 잼있다.',
#   '9',
#   '5',
#   '1',
#   datetime.datetime(2016, 8, 3, 0, 41),
#   0],
#  ['소라(jins****)',
#   '지루한 일상에 지쳤다면 이들의 깐족거림과 케미를 봐주어야 할 때',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2015, 5, 26, 2, 2),
#   0],
#  ['bark****',
#   '2보다 1이 훨씬 재밌음 마지막 뉴욕 전투장면은 최고',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 4, 26, 3, 5),
#   0],
#  ['볼아(bora****)',
#   '아직까지 이만한영화못봄토요일날 2편보러가야징소풍가는기분 ㅜㅜ 설렘',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 4, 24, 3, 15),
#   0],
#  ['명수연(9303****)',
#   '정말 대단한영화 자칫 유치해질수있는 부분을 완벽하게 표현해낸영화 최고의영화다 다시봐도질리지않는다 사랑합니다 헐크',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 4, 20, 2, 20),
#   0],
#  ['플로플라(mera****)',
#   '10점이 아깝지 않은 2012년 최고의 영화',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 2, 24, 23, 36),
#   0],
#  ['o0깜찍녀0o(jess****)',
#   '5번을 봐도 짱짱재밋음 어벤져스2가 기대됨!!!!',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 2, 24, 20, 7),
#   0],
#  ['파파야(luis****)',
#   '히들이 연기잘한다.. 다음 영화도 기대합니다 사랑해♡',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 2, 21, 16, 15),
#   0],
#  ['김예은(rlay****)',
#   '이 영화를 극장에서 못본게 내 평생 한이다.',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2015, 2, 16, 22, 48),
#   0],
#  ['펄잼(jws2****)',
#   '헐리우드가 가질 수 있는 장점을 모두 표현한 헐리우드식 블록버스터의 완성본. 개봉시점 기준으로 이것보다 재밌는 영화가 있을까? 싶을 정도의 작품',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2014, 10, 12, 2, 47),
#   0],
#  ['freemankim(free****)',
#   '스토리는 어느정도 예측가능 그러나 예상치못한곳에서 빵터짐,온갖재미를끌어모았던 마블영화의 주인공들이 집결 최고다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2014, 9, 19, 23, 3),
#   0],
#  ['다라(yonk****)',
#   '정말 재미있게 잘 만든 영화인듯. 마지막에 연출 짱짱맨...',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2014, 9, 6, 17, 56),
#   0],
#  ['명탐정(skip****)',
#   '봐도 봐도 다시 보고 싶은 명장면들의 향연',
#   '9',
#   '5',
#   '1',
#   datetime.datetime(2013, 8, 19, 0, 4),
#   0],
#  ['좋은기억(tany****)',
#   'CG 만으로 모든걸 압도하는 배짱. 유머와 액션.. 볼거리 풍부한 히어로영화.',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2013, 8, 15, 17, 17),
#   0],
#  ['김재희(aji1****)',
#   '쩐다...그냥 쩐다..',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2013, 8, 12, 6, 27),
#   0],
#  ['케인(mjo3****)',
#   '평식이 니영화함만들어봐라어디서 6점주고앉아잇뉴?',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2019, 5, 9, 17, 11),
#   0],
#  ['siverline(silv****)',
#   '로키 패대기 치는게 제일웃김ㅋㅋㅋ',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2018, 6, 2, 13, 49),
#   0],
#  ['별명(yjw3****)',
#   '2보니까 1이 얼마나 재미있고 스토리도 좋고 전개도 적당하고 스릴 넘친지 알겠다 1은 진짜 꿀잼 2는 연기력이 별로고 대체로 대사도 오글거리고 스토리 전개도 빨라서 재미없었음 진짜 1편은 다시 보고싶을 정도임',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2015, 5, 11, 21, 45),
#   0],
#  ['나다(paul****)',
#   '역시 마블이야....',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2015, 2, 20, 18, 50),
#   0],
#  ['shed****',
#   '최고다. 영화표 한장값에 이런 영화를 보게해준 감독에게 존경을 표한다.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 9, 18, 12, 17),
#   0],
#  ['음악평론가(mard****)',
#   '앞에 5개의 작품을 보고 보면 꿀잼 보장',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 3, 12, 7, 56),
#   0],
#  ['남희진(jin2****)',
#   '이런게 영화지!!!!',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 50),
#   0],
#  ['thgu****',
#   '제가 좋아하는 히어로들은 다모였네요',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 48),
#   0],
#  ['에페(ep_e****)',
#   '몇 번을 봐도 꿀잼ㅁㅁㅁ',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 38),
#   0],
#  ['뱅뱅(wank****)',
#   '긴 말이 필요없다. 그냥 재미있다. 이걸로 끝이다. 이거 말고 더 할 말이 있나?',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 38),
#   0],
#  ['사이즈95(eoqk****)',
#   '와 대박 스케일 장난 아니다',
#   '9',
#   '6',
#   '2',
#   datetime.datetime(2014, 2, 1, 23, 34),
#   0],
#  ['아으얼억그어억(mc41****)',
#   '오락영화의 필수요소인 할 볼거리, 위트, 개성있는 캐릭터들을 모두 완벽하게 갖췄다',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2013, 8, 9, 13, 52),
#   0],
#  ['달콤한모래(sdh2****)',
#   '진짜 이건 말이 필요 없죠',
#   '10',
#   '7',
#   '3',
#   datetime.datetime(2014, 10, 27, 0, 14),
#   0],
#  ['박곰95(joon****)',
#   '만화 원작이라 유치하지만 통쾌한 영화. 마블 영화는 그맛에 보는거같음.',
#   '10',
#   '7',
#   '3',
#   datetime.datetime(2014, 2, 2, 0, 27),
#   0],
#  ['김윤서(dbst****)',
#   '어벤져스 너무재밋어요ㅠㅠㅠ멋잇엉',
#   '10',
#   '7',
#   '3',
#   datetime.datetime(2014, 2, 1, 23, 44),
#   0],
#  ['whwn****',
#   '유치하진않겠지?보고싶딘 일단10점',
#   '10',
#   '7',
#   '3',
#   datetime.datetime(2013, 9, 9, 0, 23),
#   0],
#  ['seogj(seoj****)',
#   '나중에 미국가면 꼭 슈와마 먹어봐야지.',
#   '10',
#   '8',
#   '4',
#   datetime.datetime(2016, 6, 16, 23, 28),
#   0],
#  ['블록폐쇄(juny****)',
#   '블랙위도우 몸매 좀 오래 잡아주면 좋자냐.',
#   '10',
#   '19',
#   '15',
#   datetime.datetime(2014, 2, 1, 23, 20),
#   0],
#  ['Sunny(kitt****)',
#   '처음부터 끝까지가 완벽했던 영화라고 생각함. 전설의 시작.',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 8, 14, 9, 7),
#   0],
#  ['nodo****',
#   '이때부터 타노스얘기가 나오게 된다는 것을 3번째 보면서 알았다. 마블의 세계관에 다시 한번 놀랐다.',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2020, 7, 7, 13, 11),
#   0],
#  ['김윤서(dsgf****)',
#   '재개봉했길래 영화관에서 보고왔네요 그 넓은 관에 저 혼자밖에 없더라구요역시 집에서 폰으로 보는거랑 다르네요굿!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 4, 29, 12, 30),
#   '관람객'],
#  ['dizi****',
#   '어벤져스의 탄생.. 거의10년동안 우리들을 마블과 어벤져스에 열광하게했고, 우리들에 하나의 아이콘이 되었다.',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 4, 23, 20, 48),
#   0],
#  ['pont****',
#   '마블은 자신들이 빅히트를 쳤음을 깨달았다!',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2020, 4, 2, 10, 33),
#   0],
#  ['박민우(iomm****)',
#   '히어로 액션 무비의 거룩한 금자탑.단연코 이 영화는 히어로 무비의 기념비 적인 작품으로 기록될 것이다.훌륭한 영화 일수록 그 시간이 흐를수록 그 진가가 드러나는 법이기에.',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2020, 3, 18, 20, 49),
#   0],
#  ['David Cooper(ferb****)',
#   '내가 아직도 평점을 안 줬다니',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 3, 17, 17, 52),
#   0],
#  ['아큐(mook****)',
#   '에오쉴 다 보고 더이상 볼게 없어, 콜슨이 그리워서 또 보러왔다네..  내가 본 죽는 연기 중에 제일 잘한 연기임. 사랑해요 클락 그레그ㅠ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 2, 11, 1, 32),
#   0],
#  ['없음(kimh****)',
#   '마블의 성화가 일어난다! 전부 불을붙여라 성화에 절를해라',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2020, 1, 28, 3, 46),
#   0],
#  ['공부방해꾼출현(lhjs****)',
#   '아이언맨,토르,헐크,퍼스트어벤져  다 보고나서 이걸봐야 더 재밌겠네요.다 뭉쳐놓은 어벤져스가 제일 재밌기는하네요. 뭉쳐놔서 재밌는건가..',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2020, 1, 22, 12, 31),
#   0],
#  ['fabulous(oasi****)',
#   '아이언맨은 시작부터 주연이고 헐크 비중이 높았네',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 10, 31, 13, 4),
#   0],
#  ['데몬(kool****)',
#   '왜 어벤저스 어벤저스 그러는지 알겠다. 극장에서 못 본 것이 한ㅠㅜ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 10, 22, 3, 12),
#   0],
#  ['디카프리오(kevi****)',
#   '어벤져스 시리즈 중 엔드게임 다음으로 재미있다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 8, 13, 19, 7),
#   0],
#  ['avengers(marv****)',
#   '뉴욕에서의 치타우리 종족과 어벤져스 간의 전투는 진정 소름 돋는. 쉴드 콜 요원의 희생. 로키야 제발 정신 차려. 쿠키 영상 타노스의 첫 등장.',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 8, 8, 0, 19),
#   0],
#  ['윤병준(bjyu****)',
#   '아주 좋습니다 아주요 그리고 시리즈가 다 재밌어요',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 8, 4, 19, 17),
#   0],
#  ['현(kmh0****)',
#   '개잼있음 꼭보세여 후회안합니다 진짜로',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 7, 26, 0, 30),
#   0],
#  ['더쿠르트(gkdl****)',
#   '재밌다..어벤저스 마리아힐 OO쉬',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 7, 19, 20, 25),
#   0],
#  ['밍(sunm****)',
#   '이 영화는 고민할 필요도 없습니다. 십점만점에 백만점..',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 7, 6, 3, 41),
#   0],
#  ['sw20****',
#   '어벤져스 1편은 다시봐도 레전드다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 6, 9, 17, 42),
#   0],
#  ['탑클래스A동(thej****)',
#   '인간형 히어로는 상향하자',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2019, 6, 6, 18, 23),
#   0],
#  ['김태훈(taeh****)',
#   '조스웨던은 액션,루소형제는 mcu 끝을 정말 잘 이뤄냈다.',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 6, 5, 14, 42),
#   0],
#  ['수리x샤일로(suri****)',
#   '토르 묠니르들고 캡아한테 뭣도 모르고 덤벼들었다가 튕겨 날아가는 장면 나만 웃겼나 ㅋㅋ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 6, 3, 17, 10),
#   0],
#  ['써먼(indi****)',
#   '히어로들이 여럿나오면  재미살리기힘들다고생각했는데  그 틀을깨버렸슴',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 5, 30, 18, 37),
#   0],
#  ['진사성인출(vc10****)',
#   '3000 세카이...!!!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 5, 29, 11, 48),
#   0],
#  ['로우라이트(ichi****)',
#   '마블 캐릭터들의 개성을 한껏 살린 전투씬은 가희 압권! DC가 배워야할 영화!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 5, 7, 17, 4),
#   0],
#  ['가레스(leeu****)',
#   '어벤져스의 탄생과 그시작',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 30, 20, 35),
#   0],
#  ['윤도경(sinj****)',
#   '잼잇구 늦게 봤지만 정주행 할께요!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 28, 9, 47),
#   0],
#  ['potr****',
#   '영화의 장면속 액션이 좋네요...ㅡ',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 26, 20, 19),
#   0],
#  ['이지한(ljh5****)',
#   '어벤져스...위대하고 또 시원 섭섭..',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 24, 12, 11),
#   0],
#  ['거르고보는노씨(zzzz****)',
#   '지금 오씨엔에서 보는데 지금봐도 죽이는데 일주일후면 진짜 죽겟네 ㅋㅋㅋ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 4, 19, 2, 43),
#   0],
#  ['voon(golm****)',
#   '마지막 핵 들고 나는 아이언맨이 너무 멋졌음',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2019, 2, 21, 23, 59),
#   0],
#  ['사랑을 주는 기붐이(born****)',
#   '블랙 위도우 너무 멋있어요!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2019, 1, 21, 15, 13),
#   0],
#  ['정릉정릉(hanm****)',
#   '상상속에 있던 영웅들의 집합체.. 시리즈 정주행중',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2019, 1, 11, 21, 7),
#   0],
#  ['무비필리아(alst****)',
#   '히어로가 뭉치면 산만할 줄 알았는데 잘만들었다 후반부 전투 시퀀스는 최고였다',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2019, 1, 5, 9, 36),
#   0],
#  ['흐히히(11pi****)',
#   '지금 보니 마크러팔로 많이 늙었네..이때까지만 해도 존잘인데..물론 지금도 잘생겼음!!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 8, 24, 17, 56),
#   0],
#  ['그냥펄슨(enjo****)',
#   '재밌어요^^ 또한번 보고싶네요',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 8, 9, 19, 30),
#   0],
#  ['너의기린(lush****)',
#   '정말 훌륭하다. 지금봐도 너무 재미있네요',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 8, 7, 0, 12),
#   0],
#  ['멜로(hong****)',
#   '진짜 언제봐도 재밌다..',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 7, 25, 16, 20),
#   0],
#  ['잉여(ypk8****)',
#   '마블 영화 최근에 몰아서 보고 있는데 재밌네요 ㅋㅋ 개인적으로 여태까지 본 마블영화 중에서 제일 괜찮은듯',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2018, 7, 16, 23, 37),
#   0],
#  ['충충충(choo****)',
#   '지루할 틈 없는 액션씬, 누구 하나 빠지지 않는 완벽한 분배까지. 단체 히어로물의 정석 그대로다.',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2018, 7, 10, 0, 26),
#   0],
#  ['bin(bins****)',
#   '한마디로 하면 믿고 보는 마블',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 7, 8, 17, 29),
#   0],
#  ['예원이(ywmi****)',
#   '꿀잼 여러분 어벤져스하세요~',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 6, 7, 3, 2),
#   0],
#  ['avon****',
#   '정말 재미있어요~ 다시 보고 싶어요',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2018, 5, 1, 19, 52),
#   0],
#  ['문스타(tpfl****)',
#   '전설의 시작! 말이 필요없다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 3, 18, 15, 33),
#   0],
#  ['순대볶음(gdcv****)',
#   '중학생때 영화관에서 본 영화. 헬리케리어가 비행을 시작할때 장면이 생각난다. 입 벌리고 봤지....',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 3, 14, 22, 10),
#   0],
#  ['이시온(chek****)',
#   '마블 히어로들을 영화 한편으로 볼 수 있다는게 행복했다. ㅠㅠ 최고',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 3, 4, 10, 5),
#   0],
#  ['Enjoythismoment(tjdw****)',
#   "개인적으로 2편은 좀 아쉬웠는데 1편은 두말하면 입아픈 '명작'",
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 12, 3, 13, 15),
#   0],
#  ['Currency Exchange(uu00****)',
#   '히어로물은 ‘이렇게 만들어라’ 라고 보여주는듯한 영화',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2017, 11, 27, 18, 36),
#   0],
#  ['예은(wonr****)',
#   '정말 재미있다 . 영화관에서 못보고 폰으로봤다는게 아쉽지만 여러분 제발보세요',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 11, 4, 4, 32),
#   0],
#  ['리꼬(liay****)',
#   '패대기씬이 젤 웃김ㅋㅋㅋ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 10, 27, 5, 13),
#   0],
#  ['노란피구공(frid****)',
#   '와 꿀잼 아이언맨 잘생겼닼ㅋㅋㅋㅋ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 10, 15, 16, 37),
#   0],
#  ['S클래스(dida****)',
#   '네가본 미국 영화 중에 최고다',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 10, 13, 22, 38),
#   0],
#  ['백호(dyki****)',
#   '이 영화를 보면서 헐크를 반했다.',
#   '8',
#   '3',
#   '0',
#   datetime.datetime(2017, 9, 26, 17, 12),
#   0],
#  ['gojaeoh(goja****)',
#   '히어로들의 절묘한 조화 . . 토르 스토리를 끌고온것도 그렇고 마블영화는 하나같이 연결성이 좋아서 마음에 든다. 재미도 좋고 킬링타임으로도 굿^^',
#   '9',
#   '3',
#   '0',
#   datetime.datetime(2017, 6, 16, 7, 27),
#   0],
#  ['블랙맘바(stil****)',
#   '대중문화의 정점은 완성도와 관계없이 그 자체로 걸작이 된다. 마블의 신화는 그리스 신화처럼 앞으로 몇 천년간 회자될 것이고 그 가장 첫 장에는 항상 어벤져스가 있을 것이다.',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 6, 1, 14, 59),
#   0],
#  ['청용이오셨성용(narn****)',
#   '이런영화가또있을까..',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 5, 24, 15, 21),
#   0],
#  ['정미영(jeon****)',
#   '마블의 기념비적인 작품',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 2, 17, 23, 8),
#   0],
#  ['다로스임(chj0****)',
#   '아이언맨 캐리 영화진짜 재밌음',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 1, 29, 17, 49),
#   0],
#  ['chri****',
#   '최고의 영화~!!!!',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 1, 21, 20, 12),
#   0],
#  ['헐(cjk8****)',
#   '뭔가 유치했지만 가슴벅찬경험을 느꼈다.헐크 멋있게나오네ㅋㅋ',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 1, 20, 8, 29),
#   0],
#  ['포대화상미륵존여래불(baks****)',
#   '나는 최고의 슈퍼 액션 히어로 영화로 다크나이트,왓치맨,스파이더맨2(절대 어메이징 스파이더맨2가 아님.토비 맥과이어,커스틴 던스트 주연,다크 맨의 감독 샘 레이미가 감독한 2편임),아이언 맨3,캡틴 아메리카3-시빌 ...',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2017, 1, 15, 6, 56),
#   0],
#  ['max4****',
#   '당연히 10점이지!! 완전명작임',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2015, 9, 20, 22, 50),
#   0],
#  ['문기(gye1****)',
#   '어벤저스 어셈블의 시작 전설의 시작',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2020, 5, 4, 16, 36),
#   '관람객'],
#  ['절대반지(rcan****)',
#   '원팀으로 정교하게 세공해낸 입체적 캐릭터',
#   '7',
#   '4',
#   '1',
#   datetime.datetime(2019, 7, 11, 5, 1),
#   0],
#  ['하이트맛없다(jae_****)',
#   '덕중의덕은 양덕이니라....',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 24, 19, 10),
#   0],
#  ['트둥트둥(ychc****)',
#   '진짜 존나게 맛있는 비빔밥같은 영화. 영웅들을 전부 쓰까놨는데 맛은 미슐랭 못지 않다.',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 20, 20, 34),
#   0],
#  ['최봉근(qhdr****)',
#   '지금의 마블을 만든건 로다주지만 마블영화중 가장 큰 도박을 성공으로 이끈건 죠스웨던이 아닐까 싶다. 2편이 생각보다 아쉬웠지만 1편의 마지막 뉴욕씬은 그 압도적인 스케일과  액션 볼거리가 가득했고 마지막 아이언맨의 ...',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 12, 18, 57),
#   0],
#  ['언데여캐(kiil****)',
#   'cg팀 고생많으셨습니다초록창을 저리 화려하게 만들어주셔성',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 3, 22, 6),
#   0],
#  ['박미선(shin****)',
#   '저두 OCN보는중이요 ㅎ ㅎ 뭔가 뭉클뭉클함 ㅠㅠ',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 3, 20, 42),
#   0],
#  ['여름2규진2(jm2d****)',
#   '평식이는 먼 멍멍소리냐ㅋㅋ에혀',
#   '8',
#   '4',
#   '1',
#   datetime.datetime(2019, 5, 2, 0, 6),
#   0],
#  ['캐릭터바이러스(jbra****)',
#   '어벤져스 3 보고 느낀건데 진짜 연출이 급이 다르다는걸 알았음',
#   '7',
#   '4',
#   '1',
#   datetime.datetime(2018, 10, 18, 1, 0),
#   0],
#  ['최유진(yjc1****)',
#   '헐크가 로키 팰때 개꿀잼',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 6, 6, 2, 6),
#   0],
#  ['황서현(hsh0****)',
#   '갓...MCU....갓 마블....갓 아이언맨..',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 4, 21, 20, 35),
#   0],
#  ['천명(sueb****)',
#   '마블이 여기까지 올라온 이유',
#   '7',
#   '4',
#   '1',
#   datetime.datetime(2018, 4, 7, 18, 59),
#   0],
#  ['초디(zint****)',
#   '어벤져스 엔드게임보고나서 다시 마블 정주행중인데...닉퓨리..이양반은 영화때문에 아주 바보가 된 케이스네...어벤져스에서는 외계인 존재를 안지 1년..캡틴마블에서는....맨인블랙처럼 기억을 잃었나? 눈은 고양이에게 ...',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2019, 4, 27, 19, 46),
#   0],
#  ['제이미 몸(joon****)',
#   '약간유치했다.시빌워가 가장 짱인듯',
#   '7',
#   '6',
#   '3',
#   datetime.datetime(2016, 9, 18, 17, 32),
#   0],
#  ['이준용(juny****)',
#   '본격적인 마블 영화의 시작',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 8, 4, 21, 45),
#   0],
#  ['로체sm6마니아 로에마(lotz****)',
#   '와 이 영화는 말할것도 없음. 최고임.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 7, 13, 18, 7),
#   0],
#  ['tw2(tw23****)',
#   '',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 7, 6, 14, 2),
#   0],
#  ['고투리(jdki****)',
#   '마블 전성기의 시작',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2020, 6, 20, 0, 5),
#   0],
#  ['qwer(pkch****)',
#   '헐크최고',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2020, 6, 3, 2, 10),
#   '관람객'],
#  ['김하늘(1905****)',
#   '어벤져스 초반도 재밌습니다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 30, 12, 33),
#   0],
#  ['김진중(kim0****)',
#   '',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 4, 29, 11, 51),
#   0],
#  ['배소미(mkmi****)',
#   '진짜 한 100번 봐도 안질리는듯, 매력없는 캐릭터가 없고 스토리도 탄탄하고 히어로 영화의 교과서같음',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 4, 28, 9, 57),
#   0],
#  ['김실장(adiu****)',
#   '슬프다..아이언맨이 없을 어벤져스를 생각하니...',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 4, 25, 11, 47),
#   0],
#  ['Eby Parason(hajr****)',
#   '모든 마블유니버스 시리즈중 단연최고다. 각 캐릭터들의 개성, 마블영화 특유의 유머, 각 히어로들간의 갈등과 서로뭉치게 되는 과정까지 잘 드러난 어벤져스 시리즈중 단연최고 작품',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 4, 22, 4, 27),
#   0],
#  ['데수코어(dkst****)',
#   '헐크가 끝판왕이네 ㅋㅋ',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2020, 4, 12, 4, 34),
#   0],
#  ['아이언맨(jiwo****)',
#   '마블은 역시 최고다! 마블은 역시 대박이다!마블 3000만큼 사랑합니다!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 3, 28, 0, 39),
#   0],
#  ['www(ekfk****)',
#   '진짜 마블뽕이 차오른다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 3, 7, 19, 16),
#   0],
#  ['리링(skyo****)',
#   '색깔이 다른 히어로들을 한 작품으로 잘 버무린 것만으로도',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 2, 22, 20, 32),
#   0],
#  ['피톤치드(jieu****)',
#   '마블 다시 재탕 중인데 여기서부터 타노스의 등장이 예고됐었다니...놀랍다ㅋㅋㅋㅋ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 1, 21, 17, 28),
#   0],
#  ['gusd****',
#   '어벤져스 말이 필요없네요 너무나 멋잇고 감동적이였어요 !!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 12, 17, 4, 30),
#   0],
#  ['결국모든것은(zrlg****)',
#   '최고입니다.  스타크가 너무좋아요 ㅋㅋ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 12, 8, 12, 23),
#   0],
#  ['AAAAA(wndk****)',
#   '',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 12, 7, 21, 39),
#   0],
#  ['아이오이이유(ncan****)',
#   '현나이 37세입니다 27세부터봤던 OOO전 꼭 봐야될 인생영화입니다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 12, 4, 21, 23),
#   0],
#  ['바이올린(viol****)',
#   '최고  ~~!!최고  ~~!!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 11, 25, 2, 45),
#   0],
#  ['01205(drkk****)',
#   '어벤져스  2편 3편  4편도 재밋게 봤지만  이것도 진짜 레전드입니다. ㅎㅎ',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2019, 11, 16, 14, 6),
#   0],
#  ['파워(dudt****)',
#   '재미로는 최강이다. 화끈하고 놀랍고 웃기기까지',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 8, 3, 0, 41),
#   0],
#  ['gyu(gyuh****)',
#   '재밌네  아이언맨짱 굿굿',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 7, 5, 21, 42),
#   0],
#  ['이재용(jyyy****)',
#   '아이언맨,아이언맨2ㅡ블랙위도우,토르,토르1ㅡ호크아이,캡틴아메리카,헐크 6명의 영웅을 단독영화를 만들거나 단독영화에 출연시키면서 모두 소개시켜준다음에그들을 연결시켜 한자리로 모이게 한 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 6, 15, 15, 13),
#   0],
#  ['채은짱(chae****)',
#   '수십번봤는데 이렇게울컥하다니....ㅜㅜ아연맨ㅠㅠ다들사랑스러워ㅜㅜ다만 이땐로키가 귀엽지않다는거',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 6, 5, 4, 5),
#   0],
#  ['김동규(kimd****)',
#   '화끈한 도전, 화려한 성취',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2019, 5, 26, 11, 18),
#   0],
#  ['김민우(k864****)',
#   '헤헤 2019녀뉴이닿ㅎㄹ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 4, 26, 22, 12),
#   0],
#  ['아 잘생겻노(kdks****)',
#   '진짜 잼땨용 어벤져스의 시작',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 4, 22, 5, 48),
#   0],
#  ['몽이맘(dksq****)',
#   '너무 재미있게 봤습니다~',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 4, 21, 19, 36),
#   0],
#  ['Kate Barton(ygh1****)',
#   '지금 보면 약간의 유치스러움이 있을 법도 하지만 그때 당시 정말 기억에 남는 영화 였다.',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 26, 22, 47),
#   0],
#  ['댕댕이(codb****)',
#   '뀌에꾸엥후엥뚜잉오잉',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 23, 11, 55),
#   0],
#  ['닭(eyes****)',
#   '어벤져스여 영원하라~~~ 10년후,20년후,30년후,100년후 영원하라~~',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 17, 10, 34),
#   0],
#  ['김호영(rand****)',
#   '중간중간마다 개그있어서 좋았습니다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 16, 23, 11),
#   0],
#  ['포그바의댄싱하는성(oqp3****)',
#   'ost가 웅장하다. 괜찮게 봤지만 어벤져스 재미없게 본사람 이상하다는 사람이 이상한거 아닌가? 소문 듣고 온 뷔페 맛집은 아닌 느낌?',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2019, 3, 9, 18, 55),
#   0],
#  ['맹강딱(ghdr****)',
#   '어벤져스 첫 작품!!!!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 2, 12, 21, 31),
#   0],
#  ['실버불렛(sora****)',
#   '다시 봐도 재밌다 역시 마블이 최고',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 2, 7, 14, 50),
#   0],
#  ['요하(nan9****)',
#   '신이 약골이군... -헐크-',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 1, 29, 23, 51),
#   0],
#  ['알리올리오(hikk****)',
#   '주인공들이 이렇게 한데 모일 수 있다니',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2019, 1, 26, 18, 47),
#   0],
#  ['현란(hyun****)',
#   '로키는 쫌 하고나머지는 짱 근데 앞에 블랙위도우는 왜 잡힘?',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2019, 1, 24, 20, 27),
#   0],
#  ['djsu****',
#   '말이필요없다.짱이었다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 10, 14, 16, 7),
#   0],
#  ['밥(on26****)',
#   '왜 이게 8점대지? 너무 좋았는데',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 10, 6, 23, 9),
#   0],
#  ['무명(jjae****)',
#   '마블 좀 많이 심각하게 재미있는듯 아빠가 밤마다 마블~ 마블~ 노래를 부르네요. 정말 재미있어요.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 9, 22, 10, 19),
#   0],
#  ['블루화(ibp2****)',
#   '이 순간 행복해 지도록 거침없이 살아 숨쉬는 어벤져스 히어로들.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 8, 31, 5, 7),
#   0],
#  ['네이션(dydr****)',
#   '처음 봤을때 진짜 레전드였는데',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2018, 8, 18, 10, 34),
#   0],
#  ['박매력(bht6****)',
#   '공적(共敵)은 우리를 견고하게 만드나니',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2018, 8, 5, 0, 3),
#   0],
#  ['박가연(814b****)',
#   '언제봐도 너무 재밌다 ㅇㅇ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 7, 27, 11, 33),
#   0],
#  ['toww****',
#   '재미있다람쥐꿀재인정',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 6, 2, 12, 53),
#   0],
#  ['포스트잇(inta****)',
#   '오늘 다시봤다. 지금봐도 전혀 구티나지 않고 손색이 없다. 최고다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 5, 21, 6, 21),
#   0],
#  ['Nana(2gal****)',
#   '마블 히어로들 다 좋지만 헐크가 짱이야!!!',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 5, 19, 9, 48),
#   0],
#  ['쿠니맘(dmal****)',
#   '2편보다는  훨씬  잼남!',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2018, 1, 28, 19, 51),
#   0],
#  ['해적왕(kjw9****)',
#   '전투신 나오기 까지 다소 지루하지만 그후에는 흥미진진하다',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2018, 1, 22, 19, 6),
#   0],
#  ['식봉이(llmm****)',
#   '아이언맨이 시작을 끊었다면 어벤져스는 최고치로 끓어올렸다 도심 시퀸스는 그야말로 압권',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 12, 23, 22, 8),
#   0],
#  ['만드레이크(dpwn****)',
#   '최근 다시 보니까 블랙위도우의 솔로 영화가 나와야 된다는 생각이 든다. 로키가 블랙 위도우의 마음을 후벼팔 때, 살인과 거짓으로 점철된 요원의 삶일지라도 역사를 살아왔고 또 늘 자신의 구원을 추구하는 나타샤에게 덕통...',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 12, 20, 6, 32),
#   0],
#  ['홍시(thev****)',
#   '평가처럼 영웅들의 협엽과 전투가 돋보인다.  그런데 뭔가 그 이상이 없어서 아쉬웠음ㅠ 대체적으로 마블영화가 그럴싸한데 딱 거기서 멈추는 느낌이다.  그래도 아이언맨은 멋졌음.',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2017, 11, 28, 11, 7),
#   0],
#  ['toto****',
#   '내 기준 역대 마블 무비중 최고의 작품들은 시빌워랑 윈터솔져랑 어벤져스다 이 3개는 진짜 명작들이다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 11, 26, 21, 7),
#   0],
#  ['Kid J(woxn****)',
#   '다시 보면 이만한 마블 작품도 없었다. 마블 3대 명작을 꼽으라면 손꼽힐 작품.',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 11, 21, 1, 10),
#   0],
#  ['솔로몬(hg69****)',
#   '극장에서 봤을 때의 그 전율...',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 11, 20, 20, 37),
#   0],
#  ['MRX(phs3****)',
#   '작은고추들이 모여 잭팟터지듯.',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 10, 25, 0, 28),
#   0],
#  ['Spock(acea****)',
#   '캐릭터의 다양성이 획일화된 플롯으로 수렴되다.',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2017, 8, 31, 0, 36),
#   0],
#  ['eyebono(eyeb****)',
#   '[ S8 V10 D9 A8 ]\u3000이 캐릭터들이 한 화면에 잡히다니.. 초반은 좀 느슨하지만 중반부터 각 히어로의 캐릭터가 잘 드러나면서 정신없이 몰아친다. 마블은 이제 가장 믿고 보는 영화사가 되었다.',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 8, 11, 16, 57),
#   0],
#  ['아이고오(toto****)',
#   '아진심 넘 멋지고 재밌다ㅋㅋ몇번을 돌려보는지ㅋㅋㅋ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 25, 19, 21),
#   0],
#  ['임진전(wlsw****)',
#   '필ㅠㅠ진짜너무안타까운거아닙니까...더보고싶은캐릭중하나였는데ㅠㅠ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 23, 15, 12),
#   0],
#  ['55wo****',
#   '올만에 다시봤는데 또 봐도 꿀잼이네. 매력터지는 히어로들을 이만큼 잘뭉쳐놓은 영화가 또 있을까싶다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 10, 21, 55),
#   0],
#  ['김행보관(wind****)',
#   '아주 잘 만들어진 오락영화',
#   '9',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 6, 6, 15),
#   0],
#  ['산톨(didr****)',
#   '개인적으로 마지막씬 좋아합니다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 6, 2, 58),
#   0],
#  ['별의조각(joe1****)',
#   '기대했던 액션이 너무 늦게 나온다.헐크는 너무 센거 아닌가..',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2017, 6, 9, 22, 28),
#   0],
#  ['Rio(nano****)',
#   '와우! 역시 마블다운 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 5, 8, 14, 7),
#   0],
# ...
#   '히어로물중에 젤유치함 극장에서도봤지만 두번봐도 유치찬란 스토리전개가 너무 너무 지루해요 쓸데없는 장면들이 너무많음',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 22, 43),
#   0],
#  ['scott(shch****)',
#   '대박잼있어   넘 재미있어',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 21, 46),
#   0],
#  ['소세지(rke4****)',
#   '지금 보고있다. 근데 재밌다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 21, 40),
#   0],
#  ['시크(xmfo****)',
#   '안봤으면 보고, 봤으면 또 보세요.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 21, 30),
#   0],
#  ['x제라툴x(skt1****)',
#   '한마디로 표현 불가능한 영화',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 21, 17),
#   0],
#  ['늑대(audf****)',
#   '정말재밋고 환상적인 블록퍼스터',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 19, 50),
#   0],
#  ['청주호두(q783****)',
#   '나를 로그인하게 만들었다.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 2, 1, 0, 25),
#   0],
#  ['ㅇㅇ(sonj****)',
#   '호크아이 역 제레미레너 분량좀 늘려주길ㅠ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 31, 20, 11),
#   0],
#  ['앤디(hoon****)',
#   '무난했다. 그러나 유머가 너무 많았다.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 29, 10, 7),
#   0],
#  ['이웃집규(dbtj****)',
#   '관객들을 흥분시키기에 충분한CG와 액션헐크 대박..ㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 22, 1, 34),
#   0],
#  ['라임(whdm****)',
#   '정말 한국에서 정말재미있게본것같음. 2번째 어밴져스2는 어떤내용일지 정말 궁금함 !!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 21, 22, 4),
#   0],
#  ['발명왕(kwon****)',
#   '마블 영화 중에서는 최고 영화',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 21, 17, 1),
#   0],
#  ['여신태희(lkyl****)',
#   '캐릭터를 정말 잘 살렸다 하지만  그에비헤 캡틴 아메리카의 능력은 너무 버겁지 않나 싶다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 20, 17, 17),
#   0],
#  ['epun****',
#   '재미있지만 리얼리스틱 하지 않다. 그래도 멋지고 2편이 기대되는 영화.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 20, 14, 3),
#   0],
#  ['mins****',
#   '역사에 남을 영화 짱짱!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 19, 13, 12),
#   0],
#  ['gwoo****',
#   '볼만한것  같습니다.특히 마지막은 집중',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 18, 17, 28),
#   0],
#  ['찌질대지마(ejaq****)',
#   '히어로물의 힘을 보여준다. 마블의 상상력은 뛰어나다 딱 그두가지이다.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 17, 21, 34),
#   0],
#  ['깽이바다(ksju****)',
#   '참 말들 많네 본인 취향에 맞으면 보고 안맞으면 안보면되지 현실적이고 진지한거 좋아하는사람은 드라마나 보고 멜로물이나보라고 어벤져스 같은 영화근처에서 얼씬거리지 말고. 평소만화도 유치하다고 안보면서 어벤져스는왜보냐?...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 17, 10, 3),
#   0],
#  ['양산의영웅(ghkf****)',
#   '중간에 sf/액션 에 맞지 않게 지루한장면이 있었고 퀄리티가 살짝 떨어지는 느낌도 받았구요 하지만 그래도 잘만들었고 재미있었습니다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 15, 14, 13),
#   0],
#  ['Eoruaeyout(yaho****)',
#   '드디어 채널 CGV에서 티비최초하는거같아서 10점준다 이순간만을기다렷어! 어벤져스가티비최초방송하는그순간을! 꼭 채널CGV에서는 인기있고 좀 흥행한 영화들이 티비최초방송하더라 아바타도그랫고',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2014, 1, 4, 22, 58),
#   0],
#  ['ㅆㅅㅌㅊ(snzi****)',
#   '점점나아지리라 믿고, 섬세한캐릭터묘사도 기대해본다',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 24, 1, 50),
#   0],
#  ['sungWook(chlg****)',
#   'ㅋㅋ뭘더말하지 ㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 20, 15, 54),
#   0],
#  ['112233a(gusn****)',
#   '계획성있게 합쳐진 여려영웅들의 세계.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 19, 1, 33),
#   0],
#  ['gust****',
#   '재밌었는데..신이 너무 약한 듯 ㅠ.ㅠ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 17, 17, 40),
#   0],
#  ['ldh7****',
#   '내용을 풀어나가는 과정은 아쉬울수도 있지만 저분들을 한곳에 모아놨다는것만으로 찬양받아 마땅한영화',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 7, 10, 33),
#   0],
#  ['쟈숨이(sjy0****)',
#   '토르랑 로키랑 누구더라그...토르2에서 발가벗고 나오는 할아버지 박사 나와서여',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 12, 3, 20, 37),
#   0],
#  ['nura****',
#   '화려한 블록버스터 영화의 진수. 볼거리는 확실히 제공한다. 근데 난 왜 악당이 더 불쌍해 보이는 건지. 영웅들이 모이니깐 악당이 오히려 불쌍할 지경; 재미가 없지는 않았는데 두번볼 영화는 아닌 듯 하다.',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 24, 3, 6),
#   0],
#  ['pok Boxing(pok_****)',
#   '초반은 지루햇으나 그뒤는 ..정말 작살나는구만',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 22, 17, 16),
#   0],
#  ['송단특별시(emce****)',
#   '볼만한데 정신사나운 면이 있음 ㅋㅋ',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 19, 17, 59),
#   0],
#  ['The way(ggma****)',
#   '내용은 단순하고 보잘것 없지만 오락적인 측면은 월등했다. 몰입도 잘되었고 개그도 충분.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 17, 22, 38),
#   0],
#  ['야(edlq****)',
#   '소름돋게재밋어 아 아이언맨 쨩~!!! 헐크쨩~!! 스칼렛요한슨 너무 섹시',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 17, 12, 13),
#   0],
#  ['don0****',
#   '영웅들이 다 모여 있는데 전혀 어색함이 들지 안았던 영화!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 15, 18, 50),
#   0],
#  ['sehe****',
#   '살짝 정신 없기는 하지만.. 재밌음-! 역시 마블-',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 12, 19, 25),
#   0],
#  ['myfu****',
#   '솔직히 재미있음 이거 평점 지나치게 낮게주는 사람 이해 안됨',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 11, 13, 33),
#   0],
#  ['eh72****',
#   '세상에서 재미있다~ㅏㅏ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 7, 17, 46),
#   0],
#  ['road****',
#   '이런 영화에도 평점 6점 주는 박평식은 히어로영화에 원한이 있는듯하다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 7, 16, 32),
#   0],
#  ['wlsg****',
#   '2편꼭나오길ㅋ너무재밌게봤음ㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 5, 0, 20),
#   0],
#  ['퀸(agr8****)',
#   '컴퓨터로 다시봐도 재밌는 영화',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 3, 16, 34),
#   0],
#  ['엘루이(dltl****)',
#   '꿀잼 딱 9점정도가 어울림',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 11, 1, 4, 53),
#   0],
#  ['patd(kime****)',
#   '빨리 2 나오란 말이야!!! 어벤저스랑 로키까지 다 너무 좋음',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 18, 18, 46),
#   0],
#  ['lox(idfo****)',
#   '다시 볼수록 재미난데 ?',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 14, 7, 8),
#   0],
#  ['수호천사(yuno****)',
#   '2편3편이 기대됩니다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 3, 22, 24),
#   0],
#  ['꿍아(swh1****)',
#   '헐크가 너무 웃겨ㅋㅋ속편이 너무 기대된다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 3, 10, 17),
#   0],
#  ['jeeb****',
#   '이거 점수 넘 낮은거 아닌가. 재미있고 후편 기대된다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 1, 21, 59),
#   0],
#  ['엔젤버그너스(rksl****)',
#   '먼저 어벤져스 토르헐크아이언맨 캡틴아메리카 호크아이 악당로키 가 나오는영화입니다. 이영화는 히어로를 소개한다음 히어로 담당자 닉퓨리가 악당로키를 해치워야하는 어벤져스군단들이 악당로키와 악당로키군단을 물리치는 데에 성...',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 10, 1, 13, 9),
#   0],
#  ['앙훈(s_sa****)',
#   '완벽한 슈퍼히어로 오락영화!! 매력적인 영웅들을 제치고 헐크가 가장 돋보임ㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 29, 22, 3),
#   0],
#  ['LEE YUN JAE(dldb****)',
#   '헐크라는 캐릭터를 성공적으로 잘 살렸다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 28, 20, 50),
#   0],
#  ['날미(gll1****)',
#   '후... 역시.. 마블...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 27, 0, 16),
#   0],
#  ['lokid(blac****)',
#   '할리우드에 입덕할 수 있는 계기를 주었다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 19, 14, 1),
#   0],
#  ['이준영(sixj****)',
#   '난 경기도 안양의 이준영이다!',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 17, 23, 43),
#   0],
#  ['캬르마(lich****)',
#   '정신없이 본 영화.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 16, 18, 42),
#   0],
#  ['박슬옹(o141****)',
#   '킬링타임 영화에 최고봉',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 14, 12, 33),
#   0],
#  ['Lucid Dream(reow****)',
#   '진짜 말할 필요도 없이 엄청재밌어요코믹하기도 해서 완전 짱이네요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 8, 0, 37),
#   0],
#  ['jamb****',
#   '최고의 팝콘 무비.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 7, 21, 11),
#   0],
#  ['프리티 걸(alrl****)',
#   '어벤져스 사랑해요♥완전 머시쪄요♥',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 7, 20, 16),
#   0],
#  ['조군(whit****)',
#   '후속작이 기대된다..',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 5, 20, 39),
#   0],
#  ['알콜제로(hima****)',
#   '3D로 보셔야 진정한재미를 느낍니다.다음편이 기대되는군 ...',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 5, 1, 45),
#   0],
#  ['ckdt****',
#   '제발 이런거 보면서 현실성 따지지말자 보는내내 엄청난 cg와 액션씬은 정말 최고다 내가본 히어로물중 제일이라 생각한다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 3, 11, 31),
#   0],
#  ['hjw1****',
#   '짱재밌어요',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 9, 1, 17, 0),
#   0],
#  ['lim9****',
#   '다른 히어로물보단 좀유치하지만 그래도잼있다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 31, 21, 58),
#   0],
#  ['tnse****',
#   '재밋다 아이언맨 2보다 훨씬낫네 아이언맨3볼려고 먼저 어벤져스 봤는데 어벤져스 후속이 더 기대된다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 30, 2, 2),
#   0],
#  ['구달(noye****)',
#   '후속편이 기대됨',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 28, 0, 51),
#   0],
#  ['호롤롤로(mood****)',
#   '잘 만든 영화. CG도 좋고 캐릭터들도 좋음. 좀 유치한 면이 없잖아 있는데 그래도 볼만함',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 28, 0, 3),
#   0],
#  ['맑은서울(leei****)',
#   '마블히어로 영화중에서도 가장 최고의 작품이 었다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 27, 18, 35),
#   0],
#  ['양갱(sils****)',
#   '!!!!!!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 26, 14, 59),
#   0],
#  ['andr****',
#   '꿈꿔온  수많은 영웅들...저스티스가 기다려진다',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 25, 19, 34),
#   0],
#  ['몬모(hooo****)',
#   '스토리 전개에 내숭떨지 않는다. 어차피 우린 얘네들이 모여 보여주는 액션을 기대하고 돈을 지불한거고 감독은 그걸 간파하고 영화를 만들었다. 어줍잖은 부연설명에 시간 들이지 않은게 성공요인중 하나다. 눈요깃거리 액션영...',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 25, 3, 39),
#   0],
#  ['쿵따리쏴바라빠빠빠빠(thdw****)',
#   '탄탄한 스토리와 cg,그리고 배우들의 짜릿한 액션에 흥분을 멈출수가 없었다.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 25, 1, 38),
#   0],
#  ['망아(abcd****)',
#   '내용자체는 괜찮았지만 후반부에비해 초반부가 지루했다',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 24, 19, 3),
#   0],
#  ['syk4****', '굳', '10', '0', '0', datetime.datetime(2013, 8, 24, 10, 50), 0],
#  ['sinbal(ajik****)',
#   '오락영화가 이끌어내는 힘을 제대로 발휘한 영화다. 마블영화의 정점',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 23, 20, 10),
#   0],
#  ['미즈야(rona****)',
#   '최고의 액션영화!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 20, 19, 9),
#   0],
#  ['gyyjlkohg(real****)',
#   '누가 제목을 어벤져스라고 무식하게 했는지. 어벤져즈에유. 기본적인 영어도 모르는 사람. CG는 놀라울 정도로 최고 수준. 내용은 역시 유아틱. 아이언맨하고 헐크가 제일 멋있게 나오네유. 캡틴 아메리카는 완전 별 볼 ...',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 19, 23, 25),
#   0],
#  ['깍두기(xodl****)',
#   '아이언맨이 나와서 10점줌',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 8, 11, 53),
#   0],
#  ['해골광대(goko****)',
#   '슈퍼히어로들이 모여 만든 슈퍼블록버스터',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 7, 7, 59),
#   0],
#  ['tyro****', 'ㅋㅋ', '8', '0', '0', datetime.datetime(2013, 8, 4, 7, 52), 0],
#  ['스타(ghwl****)',
#   '재밋다!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 2, 22, 27),
#   0],
#  ['hgji****',
#   '영웅들 모음집',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 2, 22, 19),
#   0],
#  ['SJ(tlsq****)',
#   '모든 마블 영화의 집합체를 잘 살려낸 영화 하지만 조금 가볍다',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 1, 23, 57),
#   0],
#  ['dudu****',
#   "이토록 '인간스러운' 히어로들이라니",
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 1, 19, 1),
#   0],
#  ['엄재연(eomz****)',
#   '입이 떡 벌어지는 연출, 살아있는 캐릭터, 그럼에도 중심 잡힌 스토리.',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 1, 17, 28),
#   0],
#  ['오팔이(woo_****)',
#   '뻥안까고 겁나 재밋게봄..ㅠㅠ...도른듯',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 8, 1, 12, 31),
#   0],
#  ['yaks****',
#   'avengers',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 31, 15, 8),
#   0],
#  ['dlkad(op48****)',
#   '최고!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 28, 20, 11),
#   0],
#  ['카트zl존(ghtj****)',
#   '말이 필요없는 영화네.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 27, 18, 21),
#   0],
#  ['아오오니(dlrh****)',
#   '너무길지만 재미있었고 좀더 간단하고 쉽게하면 좋겠습니다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 26, 11, 37),
#   0],
#  ['포춘핑거v(kkdk****)',
#   '너무 재미있었고',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 26, 9, 12),
#   0],
#  ['앤탑(magi****)',
#   ',',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 25, 14, 46),
#   0],
#  ['wooz****',
#   '만화가 원작이긴 하지만 인간 히어로만 나왔으면 덜 만화같을 텐데...',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 24, 15, 9),
#   0],
#  ['라임(movi****)',
#   '간만에 영화보고 통쾌하게 웃으면서 영화 본 것 같다. 거기다 액션까지 시원시원하게 펼쳐주니 영화를 보며 즐겁다란 느낌이 제대로 났다. 토니 스타크를 중심으로 나오는 유머들은 소소함을 넘는 큰 즐거움!',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 23, 6, 39),
#   0],
#  ['없음(rlat****)',
#   '오 기대안했는데... 액션 지리겟다!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 18, 12, 47),
#   0],
#  ['cocokwon(funn****)',
#   '몇번째 보는지... 질리지가 않네..',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 17, 13, 2),
#   0],
#  ['츄 릅(rlfw****)',
#   '시간 엄청 잘 감',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 16, 17, 10),
#   0],
#  ['썬샤인(chan****)',
#   '짱짱 재밌네',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 16, 15, 15),
#   0],
#  ['토마토(ehyu****)',
#   '굿',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 15, 0, 26),
#   0],
#  ['젤루(jjm1****)',
#   '호크아이 활쏘는거 너무 멋있다..',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 15, 0, 19),
#   0],
#  ['qwea****',
#   '돈은 이렇게 쓰는것 ! 마블의 저력을 느낄수 있었다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 14, 20, 59),
#   0],
#  ['상꼬마(choo****)',
#   '헐크에 대한 헐크에 의한 헐크를 위한 영화',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 11, 18, 51),
#   0],
#  ['oran****',
#   '너무재밌어요 ㅋㅋㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 10, 18, 32),
#   0],
#  ['Sean(tscm****)',
#   '시원시원하고 속도감 넘치는 액션이 스트레스를 날려준다. 기술적인 차원만이 아니라 감각적으로도 매우 훌륭하다. 충분히 만족스럽다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 10, 3, 16),
#   0],
#  ['문제원(nest****)',
#   '최고의 액션 히어로물ㅋㅋ',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 10, 2, 4),
#   0],
#  ['ghkd****', '재밋구만', '10', '0', '0', datetime.datetime(2013, 7, 9, 0, 35), 0],
#  ['ql42****', '재밌다', '10', '0', '0', datetime.datetime(2013, 7, 6, 21, 13), 0],
#  ['LP(ogr5****)',
#   '마블의 종합선물세트',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 5, 18, 36),
#   0],
#  ['쌀밥(whit****)',
#   '10점 만점에 10점!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 5, 0, 48),
#   0],
#  ['존존존(hong****)',
#   '역시',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 4, 20, 21),
#   0],
#  ['reds****',
#   '블랙위도우 아이언맨 캡틴아메리카 호크아이 토르 헐크로 이어지는 액션시퀀스는 대박이였음',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 3, 18, 22),
#   0],
#  ['Jeonwoooo(jeon****)',
#   '역시 마블.',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 7, 2, 16, 20),
#   0],
#  ['짱돌(qkqh****)',
#   '미국식 히어로물의 결정체 맘놓고 즐길 영화',
#   '5',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 30, 22, 17),
#   0],
#  ['dlqj****',
#   '이영화에 무슨의미가 있을까를 생각하기전에 무슨의미가 필요할까를 먼저 생각하라',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 30, 22, 14),
#   0],
#  ['우주과학자(cccj****)',
#   '완전 긋ㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 28, 23, 31),
#   0],
#  ['머리크다(bigh****)',
#   '아이언맨하고 헐크가 다해쳐먹네;;그래도 재밌다....',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 27, 20, 31),
#   0],
#  ['아이엔(gold****)',
#   '재밋이',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 27, 7, 41),
#   0],
#  ['로미(may6****)',
#   '정말 재미있게 잘봤습니다.히어로 영화는 그저그렇다는 선입견을 깨준 영화.볼거리와 감동이 충분한 영화',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 26, 4, 6),
#   0],
#  ['마녀(wepp****)',
#   '기대하던 그대로 재밌었습니다',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 24, 2, 52),
#   0],
#  ['psyo****',
#   '로다주♥',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 18, 1, 16),
#   0],
#  ['ㅎ0ㅎ(suim****)',
#   '짱짱',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 18, 0, 48),
#   0],
#  ['꼬양이(ckdd****)',
#   '이제 봤고 토르 라는 영화를 보지 않아서 이해는 약간 안가지만 그래도 재밌었어요 ㅎㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 17, 21, 15),
#   0],
#  ['파스토레(torr****)',
#   '최고의 영화 ㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 17, 14, 39),
#   0],
#  ['그래도(kkw6****)',
#   'ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 16, 20, 16),
#   0],
#  ['soo7****',
#   '올만에 보니 유치함',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 16, 20, 11),
#   0],
#  ['네이쳐(knat****)',
#   '작년에 본 영화중 최고였다!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 16, 17, 7),
#   0],
#  ['축구를잘하는선수(wngu****)',
#   '아재미잇어라',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 15, 10, 44),
#   0],
#  ['비로용담(unhe****)',
#   '또 보고싶다..',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 15, 2, 34),
#   0],
#  ['gjw0****',
#   '그냥.. 괜찮네이말 말곤 할말이 딱히 없다;..',
#   '7',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 9, 21, 30),
#   0],
#  ['ST(spd1****)',
#   '로키 멋있어요...!!!!!!!!!!!!!!',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 9, 11, 39),
#   0],
#  ['김복희(j_ja****)',
#   'ㅋㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 9, 9, 44),
#   0],
#  ['네스티(paul****)',
#   '와 재미지다 ㅋㅋㅋ',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 9, 1, 56),
#   0],
#  ['광현(xkq1****)',
#   '2편 2년후던가',
#   '10',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 8, 15, 47),
#   0],
#  ['zent****', '짱', '10', '0', '0', datetime.datetime(2013, 6, 8, 0, 43), 0],
#  ['리듬(puls****)',
#   '주위에선 재밌다고 난리치던데 전 그냥 그랬습니다. 2편은 더 재밌길 기대합니다.',
#   '6',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 1, 15, 48),
#   0],
#  ['mots****',
#   '킬링타임으로는 수작',
#   '9',
#   '0',
#   '0',
#   datetime.datetime(2013, 6, 1, 5, 20),
#   0],
#  ['clsr****',
#   '헐리우드 식 히어로물들의 종합선물세트! 충분히 눈과 귀가 즐겁지만빈 수레가 요란할 뿐... 이제는 흥행과 스토리는 비례하지 않는다는 사실을 널리 알렸다고 볼 수 있겠다.',
#   '8',
#   '0',
#   '0',
#   datetime.datetime(2013, 5, 31, 11, 47),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                    0  ...  6
# 0           tang****  ...  0
# 1           attl****  ...  0
# 2     스나입허(tmsk****)  ...  0
# 3       와양(dang****)  ...  0
# 4           aaas****  ...  0
# ...              ...  ... ..
# 2175        junn****  ...  0
# 2176        ijia****  ...  0
# 2177        ky2b****  ...  0
# 2178        ddrc****  ...  0
# 2179        top7****  ...  0
#
# [2180 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#             nickname  ... watch_movie
# 0           tang****  ...           0
# 1           attl****  ...           0
# 2     스나입허(tmsk****)  ...           0
# 3       와양(dang****)  ...           0
# 4           aaas****  ...           0
# ...              ...  ...         ...
# 2175        junn****  ...           0
# 2176        ijia****  ...           0
# 2177        ky2b****  ...           0
# 2178        ddrc****  ...           0
# 2179        top7****  ...           0
#
# [2180 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
