# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(%EB%A7%88%EB%B8%94_%EC%96%B4%EB%B0%B4%EC%A0%B8%EC%8A%A4_%EC%95%A4%EB%93%9C%EA%B2%8C%EC%9E%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=136900
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 136900
total_count = 10000  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=965
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=966
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=967
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=968
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=969
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=970
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=971
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=972
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=973
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=974
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=975
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=976
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=977
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=978
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=979
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=980
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=981
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=982
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=983
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=984
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=985
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=986
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=987
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=988
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=989
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=990
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=991
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=992
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=993
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=994
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=995
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=996
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=997
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=998
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=999
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136900&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1000

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 136900
total_count = 5000  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['전은호(eunh****)',
#   '마블 3000만큼 사랑합니다',
#   '10',
#   '23672',
#   '662',
#   datetime.datetime(2019, 4, 24, 10, 31),
#   0],
#  ['송(hiuh****)',
#   'Avengers Assemble!',
#   '10',
#   '15676',
#   '442',
#   datetime.datetime(2019, 4, 24, 9, 35),
#   0],
#  ['ubola(ubol****)',
#   "I'm Ironman.",
#   '10',
#   '15284',
#   '473',
#   datetime.datetime(2019, 4, 24, 10, 32),
#   0],
#  ['해피사과(qord****)',
#   '아이언맨으로 시작해서 아이언맨으로 끝난다..',
#   '10',
#   '13524',
#   '552',
#   datetime.datetime(2019, 4, 24, 11, 5),
#   '관람객'],
#  ['마즈(choi****)',
#   '아스가디언즈 오브 갤럭시 벌써부터 기대됨 ㅋㅋㅋㅋ',
#   '10',
#   '11844',
#   '434',
#   datetime.datetime(2019, 4, 24, 10, 47),
#   0],
#  ['이만호(manh****)',
#   '히어로물보고 울줄 누가알겠습니까',
#   '10',
#   '10256',
#   '305',
#   datetime.datetime(2019, 4, 24, 10, 7),
#   0],
#  ['메주0228693848(wook****)',
#   '인피니티워가 10년을 무너뜨리는 영화라면엔드게임은 10년을 돌아보는 영화입니다',
#   '10',
#   '9710',
#   '260',
#   datetime.datetime(2019, 4, 24, 12, 20),
#   0],
#  ['에헴(krth****)',
#   '쥐가다살렸음 ㅋㅋㅋㅋ',
#   '10',
#   '8978',
#   '258',
#   datetime.datetime(2019, 4, 24, 15, 26),
#   0],
#  ['김대훈(eogn****)',
#   '마지막 한타에서 쌌습니다',
#   '10',
#   '8090',
#   '363',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   '관람객'],
#  ['tlsg****',
#   '10점 안주는 사람들은 마블에 6에서900까지밖에 애정이 없는거 ...',
#   '10',
#   '7595',
#   '440',
#   datetime.datetime(2019, 4, 24, 11, 50),
#   0],
#  ['한승원(brya****)',
#   '영화 늦게 볼 수밖에 없는사람들을 생각해서 스포 자제해주세요ㅠㅠㅠ',
#   '10',
#   '7318',
#   '608',
#   datetime.datetime(2019, 4, 24, 9, 7),
#   0],
#  ['jjw0****',
#   '토르 등장씬보다 멋있는 어벤져스 집결씬',
#   '10',
#   '6694',
#   '181',
#   datetime.datetime(2019, 4, 24, 10, 40),
#   0],
#  ['도망노비(rlad****)',
#   '내 어린시절 11년을 즐겁게 해준 어벤져스 원년 멤버들... 마블 영화 한편 한편이 저의 초중고 시절, 울고 웃었던 추억이 되었어요. 아 눈물날거같애. 그동안 즐거웠고 감사했습니다.',
#   '10',
#   '5812',
#   '204',
#   datetime.datetime(2019, 4, 24, 9, 41),
#   0],
#  ['pkt(anie****)',
#   '고맙다.나의 20대를 채워줘서',
#   '10',
#   '5614',
#   '175',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   '관람객'],
#  ['플레기(azz2****)',
#   '와 내가 3시간동안 화장실을 안갔어 ;;;',
#   '10',
#   '5257',
#   '162',
#   datetime.datetime(2019, 4, 24, 9, 38),
#   0],
#  ['케사장(kyun****)',
#   '가장 큰 충격은 쿠키영상이 없단거다',
#   '8',
#   '5437',
#   '456',
#   datetime.datetime(2019, 4, 24, 10, 29),
#   0],
#  ['AlphaHyeon(alph****)',
#   '헤일... 하이드라...',
#   '10',
#   '4540',
#   '158',
#   datetime.datetime(2019, 4, 24, 10, 42),
#   0],
#  ['민샥(hong****)',
#   '토르 등장씬은 마블 역대 명장면중 2위로 물러났다',
#   '10',
#   '4370',
#   '145',
#   datetime.datetime(2019, 4, 24, 13, 0),
#   0],
#  ['Feel(jp54****)',
#   '토르의 뱃살은 밸런스를 위해서라는 게 학계의 정설',
#   '10',
#   '4354',
#   '137',
#   datetime.datetime(2019, 4, 24, 13, 41),
#   '관람객'],
#  ['Expiration(cras****)',
#   '뭐 심하게 재미있지는 않고... 한 4번정도만 봐야겠어요... 아이맥스로..',
#   '10',
#   '4280',
#   '156',
#   datetime.datetime(2019, 4, 24, 12, 29),
#   '관람객'],
#  ['정순종(jmk8****)',
#   '캡틴이 행복하면 그걸로 됐어.',
#   '10',
#   '4165',
#   '130',
#   datetime.datetime(2019, 4, 24, 13, 53),
#   0],
#  ['정모(wjda****)',
#   '하일하이드라 ㅋㅋㅋㅋ 650석 사람들 다빵터졌다',
#   '10',
#   '3876',
#   '185',
#   datetime.datetime(2019, 4, 24, 11, 36),
#   0],
#  ['어린버섯(wise****)',
#   '자기밖에 모르던 사람은 모두를 위하고타인밖에 모르던 사람은 자기를 위할 줄 알게되는지금까지의 인생에 복수(avenge)할 줄 아는 사람, 그런 영웅들의 이야기',
#   '10',
#   '3756',
#   '98',
#   datetime.datetime(2019, 4, 24, 21, 59),
#   0],
#  ['JB(dksw****)',
#   '앞으로 얼마나 더 재미있고 얼마나 더 웅장한 영화들이 나올지 모르겠지만, 2008년 아이언맨1을 시작으로 2019년 어벤져스 앤드게임까지 내 인생의 영화시리즈중 최고의 10년을 선사해준 마블에 감사합니다. 어벤져스 ...',
#   '10',
#   '3396',
#   '92',
#   datetime.datetime(2019, 4, 24, 10, 41),
#   0],
#  ['김시철(tlcj****)',
#   '그래서로키는어디로감?',
#   '10',
#   '3081',
#   '128',
#   datetime.datetime(2019, 4, 24, 11, 2),
#   0],
#  ['amazing(mins****)',
#   '진짜 대박이라는말밖에 안나옵니다...',
#   '10',
#   '2983',
#   '186',
#   datetime.datetime(2019, 4, 24, 9, 7),
#   0],
#  ['jing****',
#   '막판에 캡틴마블을 중심으로 여자 히어로들만 뭉쳐서 싸우는 장면이 있는데 마블회사가 페미를 신경쓴것 처럼 보인다.',
#   '10',
#   '3677',
#   '1200',
#   datetime.datetime(2019, 4, 24, 12, 54),
#   0],
#  ['이준혁(dlwn****)',
#   '<관람 전 필수사항>모든 마블시네마틱유니버스 보기 아이언맨1 부터...',
#   '10',
#   '2511',
#   '103',
#   datetime.datetime(2019, 4, 24, 10, 3),
#   0],
#  ['이재근(jkle****)',
#   '이 모든게 닥터 스트레인지의 엔드게임이었다는거..',
#   '10',
#   '2423',
#   '62',
#   datetime.datetime(2019, 4, 24, 14, 39),
#   0],
#  ['kof3****',
#   '한마디만 할게 스포아니다 화장실 갈타이밍은 도쿄 그때 가라',
#   '10',
#   '2412',
#   '59',
#   datetime.datetime(2019, 4, 26, 10, 33),
#   0],
#  ['엘지직관두번(kimt****)',
#   '스포하는 색히들 평생 저주 받아라',
#   '10',
#   '2539',
#   '195',
#   datetime.datetime(2019, 4, 24, 9, 32),
#   0],
#  ['하하하하ㅡㅡ(altj****)',
#   '히어로물 뻔하다고 여친때메 이거 안보고 영화 생일봤음 상영관1개였는데 여친 나 단두명 이었음 그 넓은 영화관에진짜 존나진지하게 헤어질까 고민중임',
#   '10',
#   '2515',
#   '422',
#   datetime.datetime(2019, 4, 24, 16, 18),
#   0],
#  ['이응이응(djju****)',
#   '마블을 대표하는 가장 상반된 두 히어로가 맞이하는 가장 서로에 가까운 결말',
#   '10',
#   '2045',
#   '40',
#   datetime.datetime(2019, 4, 24, 19, 13),
#   0],
#  ['thislove(two_****)',
#   '하워드 스타크와 하워드 포츠가 만날 때 너무 애잔했다..',
#   '10',
#   '2017',
#   '33',
#   datetime.datetime(2019, 4, 25, 3, 53),
#   0],
#  ['로그인하는놈들디짐(doyo****)',
#   '영웅들 한 곳에 모이는 씬에서 지립니다...',
#   '10',
#   '1893',
#   '28',
#   datetime.datetime(2019, 4, 24, 12, 9),
#   0],
#  ['rude****',
#   '3시간에 담은 11년 마블의 역사 인정',
#   '10',
#   '1899',
#   '34',
#   datetime.datetime(2019, 4, 24, 10, 55),
#   '관람객'],
#  ['악튜러스888(arct****)',
#   '자신만을 위해 살아온 아이언맨은 모두를 위해 희생하고 모두를 위해 희생해온 캡틴은 자신을 위해 선택했다',
#   '10',
#   '1913',
#   '49',
#   datetime.datetime(2019, 4, 25, 18, 48),
#   0],
#  ['sjh0****',
#   '그래서 아스가디언즈 오브 갤럭시는 언제 개봉인가요?ㅋㅋㅋ',
#   '10',
#   '1865',
#   '43',
#   datetime.datetime(2019, 4, 24, 11, 25),
#   0],
#  ['insilio12(ghkj****)',
#   "I'm Iron Man.",
#   '10',
#   '1883',
#   '89',
#   datetime.datetime(2019, 4, 24, 11, 16),
#   '관람객'],
#  ['Akkkkkkkkkkkkkk(kiss****)',
#   '엉덩이는 역시 미국 엉덩이!',
#   '10',
#   '1817',
#   '59',
#   datetime.datetime(2019, 4, 24, 13, 19),
#   0],
#  ['Mylove709(mylo****)',
#   '솔직히 극한직업이랑 이 영화랑 같은 표값인게 말이안됨ㅋㅋ',
#   '10',
#   '1843',
#   '130',
#   datetime.datetime(2019, 4, 24, 21, 10),
#   0],
#  ['연홍(yooo****)',
#   '해리포터 마지막 시리즈 보다 더 해 이 느낌은...',
#   '10',
#   '1738',
#   '75',
#   datetime.datetime(2019, 4, 24, 10, 37),
#   0],
#  ['닭둘기(fnvl****)',
#   '이 영화 제대로 즐길려면 마블 전작 다 보고 오셔야합니다.',
#   '10',
#   '1645',
#   '45',
#   datetime.datetime(2019, 4, 24, 12, 48),
#   '관람객'],
#  ['나날(lst9****)',
#   '조조예매하고 못일어났다..',
#   '10',
#   '1719',
#   '125',
#   datetime.datetime(2019, 4, 24, 12, 14),
#   '관람객'],
#  ['miinaedahhm(miky****)',
#   '7시 처음 상영영화로 봤어요 그냥 아무말도 안하겠습니다 제가 느낀 감정을 보는 모든분들이 느꼈으면 좋겠어요 일단 보세요 제발ㅠ',
#   '10',
#   '1680',
#   '92',
#   datetime.datetime(2019, 4, 24, 10, 39),
#   0],
#  ['Seonk(keum****)',
#   '인피니티워가 더 낫다. 근데 평생 기억에남게 될 건 엔드게임이다.',
#   '10',
#   '1606',
#   '130',
#   datetime.datetime(2019, 4, 24, 11, 0),
#   0],
#  ['눈꽃(blea****)',
#   '시간가는줄 모르고 봤지만 액션만 기대하면 절대 안됩니다. 각 캐릭터별로 스토리를 풀다보니 액션보단 드라마영화에 가깝다고 느껴지네요.. 느낌은 예전에 다크나이트를 보고 다크나이트라이즈를 본느낌?? 4가 정말 재밌긴 하...',
#   '10',
#   '1718',
#   '309',
#   datetime.datetime(2019, 4, 24, 10, 41),
#   0],
#  ['홍대똘아이(msp5****)',
#   '3,000 love you',
#   '10',
#   '1262',
#   '39',
#   datetime.datetime(2019, 4, 24, 11, 14),
#   0],
#  ['차박손(rjsd****)',
#   '진짜 마지막에 너무 먹먹햇어요... 마블팬이시라면 꼭 보셔야해요..',
#   '10',
#   '1241',
#   '35',
#   datetime.datetime(2019, 4, 24, 10, 15),
#   0],
#  ['yaku****',
#   '오랜 친구를 떠나보내는기분..공허하다...좌석에서 일어나자마자 그립다',
#   '10',
#   '1224',
#   '21',
#   datetime.datetime(2019, 4, 24, 19, 55),
#   0],
#  ['도시여우(city****)',
#   '아이언맨으로 시작해 아이언맨으로 끝나는 대장정',
#   '10',
#   '1187',
#   '40',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   '관람객'],
#  ['가닝(alst****)',
#   '마블의 시대에 살게 해주셔서 감사합니다',
#   '10',
#   '1082',
#   '28',
#   datetime.datetime(2019, 4, 24, 11, 57),
#   0],
#  ['pdga****',
#   '다음 아이언맨은 아이언맨3에나온 꼬마애구나...',
#   '10',
#   '1036',
#   '85',
#   datetime.datetime(2019, 4, 24, 11, 30),
#   '관람객'],
#  ['tlsg****',
#   '아이언맨1부터 본사람들은 알꺼에요 이영화는 그동안 본 모든걸 보상받을 수 있는 영화라는걸',
#   '10',
#   '962',
#   '21',
#   datetime.datetime(2019, 4, 24, 13, 29),
#   0],
#  ['egsiduwj(dhek****)',
#   '감히 내가 평가 할 수준의 영화가 아니다... 10점도 부족하다 별점 3000만큼 준비해줘요...ㅠㅠ',
#   '10',
#   '934',
#   '48',
#   datetime.datetime(2019, 4, 24, 11, 21),
#   0],
#  ['god7****',
#   '들쥐가 양자역학기계의 버튼을 누를 수 있는 확률 = 세상을 살릴 수 있는 확률 = 1/1400만 크...',
#   '10',
#   '902',
#   '23',
#   datetime.datetime(2019, 4, 25, 0, 55),
#   0],
#  ['Rot0(roto****)',
#   '엔드게임이라는 부제는 누가 붙혔는지는 몰라도 진짜 완벽하다',
#   '10',
#   '883',
#   '23',
#   datetime.datetime(2019, 4, 24, 13, 7),
#   '관람객'],
#  ['배신왕(terr****)',
#   '옆에 여자 입틀어막고 보더라 물론 나도 같이막고봄',
#   '10',
#   '895',
#   '37',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   0],
#  ['딩동(appl****)',
#   '쿠키없으니까 기다리지마세요',
#   '10',
#   '909',
#   '79',
#   datetime.datetime(2019, 4, 24, 11, 29),
#   '관람객'],
#  ['이제좀해볼라꼬(daew****)',
#   '어벤져스!!! 어셈블',
#   '10',
#   '855',
#   '47',
#   datetime.datetime(2019, 4, 24, 9, 7),
#   0],
#  ['캐샤(bang****)',
#   '자기밖에 몰랐던 아이언맨은 대의를 위해 희생했고 대의를 위해서만 힘쓰던 캡틴아메리카는 이제야 자신의 삶을 찾았다. 서로 매우 달랐지만 결국 닮아갔다.',
#   '10',
#   '781',
#   '23',
#   datetime.datetime(2019, 4, 26, 16, 19),
#   0],
#  ['로켓(inbu****)',
#   '전투신 미쳤어요 진짜 영화관에서 다들 소리지르고 난리남',
#   '10',
#   '926',
#   '172',
#   datetime.datetime(2019, 4, 24, 10, 11),
#   0],
#  ['싱짱(yard****)',
#   '가오갤찍는 토르.. 토르 찍는 캡틴.. 캡틴아메리카 찍는 토니..페어웰 어벤져스',
#   '10',
#   '749',
#   '15',
#   datetime.datetime(2019, 4, 24, 18, 33),
#   0],
#  ['한승민(9tmd****)',
#   '내가 마블영화에 네이버평점 이런거 안남기는데하나 확실한건 내가 마블영화보고 운건 처음이다단전에서 올라오는 그런 눈물 마치 내 11년의 만난 연인과 헤어지는데 동영상으로 옛 추억을 되돌려보는 느낌이랄까 가슴이 진정이 ...',
#   '10',
#   '743',
#   '30',
#   datetime.datetime(2019, 4, 24, 14, 41),
#   0],
#  ['공집합(gbh1****)',
#   '마블 팬이라면 보고 기분이묘하실듯',
#   '10',
#   '718',
#   '25',
#   datetime.datetime(2019, 4, 24, 10, 41),
#   0],
#  ['명택환(dal2****)',
#   '그로 인해 시작된 이 시작을 그가 마무리 지었다',
#   '10',
#   '710',
#   '25',
#   datetime.datetime(2019, 4, 24, 13, 13),
#   0],
#  ['매직아워(eilo****)',
#   '타노스... 빌런 주제에 최후까지 이토록 순교자처럼 거룩하면 어쩌잔 거냐... 아. ㅠㅠ',
#   '9',
#   '710',
#   '60',
#   datetime.datetime(2019, 4, 24, 13, 0),
#   0],
#  ['내일모래(hich****)',
#   '사실상 아이언맨4엿다',
#   '10',
#   '670',
#   '26',
#   datetime.datetime(2019, 4, 24, 19, 35),
#   0],
#  ['2d22412(c1s2****)',
#   '???? : hail... hydra...',
#   '10',
#   '675',
#   '36',
#   datetime.datetime(2019, 4, 24, 12, 39),
#   '관람객'],
#  ['wkrr****',
#   '완다개좋아3000만큼',
#   '10',
#   '660',
#   '25',
#   datetime.datetime(2019, 4, 24, 13, 9),
#   '관람객'],
#  ['이윤석(lysj****)',
#   '마지막 30분이 진짜 불태웠다....전율이....',
#   '10',
#   '659',
#   '25',
#   datetime.datetime(2019, 4, 24, 11, 12),
#   0],
#  ['32(love****)',
#   '스톤이 없는 타노스는 약할줄 알았는데 그래도 좀 쎄긴 하더라 세명을 걍 갖고놀아버리네',
#   '10',
#   '625',
#   '16',
#   datetime.datetime(2019, 4, 25, 1, 54),
#   '관람객'],
#  ['8월8일(jusn****)',
#   '난 아이언맨이다. 이거 한줄로 충분',
#   '10',
#   '620',
#   '25',
#   datetime.datetime(2019, 4, 24, 10, 43),
#   0],
#  ['wltn****',
#   '너무재미있어서 눈물이난다.',
#   '10',
#   '609',
#   '42',
#   datetime.datetime(2019, 4, 24, 9, 39),
#   0],
#  ['쑥(chdo****)',
#   '영화보고 버거킹 갔습니다...',
#   '10',
#   '516',
#   '29',
#   datetime.datetime(2019, 4, 24, 13, 4),
#   0],
#  ['이재택(godo****)',
#   'cgv하계 I 열 6 번에 앉았던 새기야 봉지과자랑 맥주가 그렇게 쳐먹고 싶었냐?? 니때메 3번 볼거 5번 본다 ㅡㅡ 영화관에서 봉지과자좀 처먹지마세요 제발……… 죽이고 싶습니다',
#   '10',
#   '514',
#   '69',
#   datetime.datetime(2019, 4, 24, 17, 36),
#   0],
#  ['hareyan(rlar****)',
#   '단독 영화였으면 8점이였겠지만 지난 10년의 시리즈의 마무리와  MCU 창립멤버들의 최고의 은퇴식으로는 10점 만점',
#   '10',
#   '464',
#   '25',
#   datetime.datetime(2019, 4, 24, 13, 16),
#   0],
#  ['민달팽이(als-****)',
#   '2명의 죽음이 인류 절반의 죽음 보다 슬픈 것 같다. . . .',
#   '10',
#   '441',
#   '28',
#   datetime.datetime(2019, 4, 25, 18, 45),
#   0],
#  ['jsm8****',
#   '3000편만 더 만들어 주세요',
#   '10',
#   '429',
#   '20',
#   datetime.datetime(2019, 4, 24, 13, 10),
#   '관람객'],
#  ['irur****',
#   '토르한테 그렇게 하다니 ㅜㅠ',
#   '10',
#   '418',
#   '10',
#   datetime.datetime(2019, 4, 24, 13, 55),
#   0],
#  ['지젤(rosy****)',
#   '대작은 대작이네요...시원섭섭하고 아쉽습니다ㅎㅎ',
#   '10',
#   '426',
#   '23',
#   datetime.datetime(2019, 4, 24, 11, 15),
#   '관람객'],
#  ['워니(guss****)',
#   '스타크...수고햇어',
#   '10',
#   '422',
#   '26',
#   datetime.datetime(2019, 4, 24, 13, 1),
#   0],
#  ['크리링(scjk****)',
#   '어벤져스에 댓글 알바가 필요할까?',
#   '10',
#   '405',
#   '33',
#   datetime.datetime(2019, 4, 24, 9, 15),
#   0],
#  ['손갓(ssh9****)',
#   '영화 보지도 않고서 본 척 하고 스포 하는 애들 극혐. 보지도 않았는데 왜 자꾸 본 척 스포하는거임 관종인가??;',
#   '10',
#   '410',
#   '40',
#   datetime.datetime(2019, 4, 24, 9, 19),
#   0],
#  ['panz****',
#   '타노스... 그정도 파워면 행성 하나 잡고 왕노릇이나 하면서 살아도 되는데 굳이 우주의 질서를 위해 싸우겠다며 시간과 돈을 써가며 사람 모으고 스톤 모은... 마지막까지 불한당들과 끝까지 의연하게 싸운 모습을 보면 ...',
#   '10',
#   '380',
#   '17',
#   datetime.datetime(2019, 4, 25, 16, 22),
#   0],
#  ['인천대딩(gurw****)',
#   '여러분 맥주가 그렇게 위험합니다',
#   '10',
#   '360',
#   '10',
#   datetime.datetime(2019, 4, 24, 19, 22),
#   0],
#  ['열정디앤비(werw****)',
#   '여러분 베댓이외에는 스포가 가득할것이니 평점은 읽지맙시다',
#   '10',
#   '372',
#   '22',
#   datetime.datetime(2019, 4, 24, 9, 26),
#   0],
#  ['유산균(hakd****)',
#   '닥터 인성을 재조명해야함ㅠㅜ',
#   '10',
#   '366',
#   '17',
#   datetime.datetime(2019, 4, 24, 15, 2),
#   0],
#  ['김민수(msms****)',
#   '영웅들도 인간이었고 삶이있었다....',
#   '10',
#   '347',
#   '8',
#   datetime.datetime(2019, 4, 25, 1, 33),
#   0],
#  ['잉잉(xax1****)',
#   '영화 시작하지마자 인생 최대의 급똥이 찾아왔지만 화장실을 가지 않아도 됐다. 시각과 청각을 제외한 모든 감각이 멎었다고 착각할 정도로 최고의 영화.',
#   '10',
#   '376',
#   '40',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   '관람객'],
#  ['ttwoGom(pion****)',
#   '세상에 스토리가 없다고 한 사람 진심인가? 설마 마블 영화를 처음으로 엔드게임부터 본거 아니겠지??단 한편에 마블의 모든 스토리를 관통했는데????',
#   '10',
#   '343',
#   '8',
#   datetime.datetime(2019, 4, 25, 11, 11),
#   0],
#  ['li zhengjie(lanp****)',
#   '그래서 로키는 어케되는데?',
#   '10',
#   '351',
#   '22',
#   datetime.datetime(2019, 4, 24, 21, 55),
#   '관람객'],
#  ['juhy****',
#   '이 영화를 보시려면 아이언맨123, 캡틴 아메리카 123, 어벤저스 123, 가디언스 오브 갤럭시 12, 토르 123, 캡틴 마블 1, 스파이더맨, 앤트맨 12,팬더,닥터스트래인지등 총 20편을 보셔야 합니다.그래야...',
#   '10',
#   '344',
#   '17',
#   datetime.datetime(2019, 4, 25, 16, 57),
#   0],
#  ['장기태(1989****)',
#   '전혀생각지못한놈이 캡틴이 된듯...',
#   '10',
#   '348',
#   '25',
#   datetime.datetime(2019, 4, 24, 13, 22),
#   0],
#  ['바른나라(kitc****)',
#   '영화 로건이 울버린역의 휴잭맨을 위한 우울한장송곡 이라면 엔드게임은 지금의 마블을 있게해준 토니 스타크역의 로버트 다우니 주니어를 위한 화려한 레퀴엠이다마블의 팬이라면 꼭 봐야할 영화',
#   '10',
#   '331',
#   '15',
#   datetime.datetime(2019, 4, 25, 0, 14),
#   '관람객'],
#  ['eluice(rnjs****)',
#   '재밌었는데 왜 개인적으론 인피니티 워가 더 재밌는것 같이 느껴질까요? 아무튼 세대교체를 위한 영화 잘 봤습니다. 다음에 나오게 될 어벤져스가 기대되네요.',
#   '10',
#   '587',
#   '273',
#   datetime.datetime(2019, 4, 24, 11, 15),
#   '관람객'],
#  ['낮잠(open****)',
#   '방광도 울고 나도 울고...',
#   '10',
#   '312',
#   '13',
#   datetime.datetime(2019, 4, 24, 15, 56),
#   0],
#  ['룰루랄라(feli****)',
#   '재밌는데 캐붕 너무 심했음 ㅠㅜ 재밌긴 재밌는데 아 햄식이 핫바디는 암묵적인 룰 아니었냐고요....',
#   '8',
#   '350',
#   '51',
#   datetime.datetime(2019, 4, 25, 1, 44),
#   '관람객'],
#  ['alice(viie****)',
#   '지난 11년간 MCU를 사랑해준 팬들에게 마치 선물과도 같은 영화.  손수건 꼭 준비하세요 ㅠㅠ',
#   '10',
#   '321',
#   '23',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   0],
#  ['자몽그레이프(cyan****)',
#   '와 상영 시간 한 시간 더 했어도 만족했을 것 같다.',
#   '10',
#   '305',
#   '11',
#   datetime.datetime(2019, 4, 24, 18, 4),
#   '관람객'],
#  ['이승빈(sleh****)',
#   '재밌는데..진짜 재밌는데 개인적으로 인피니티 워가 더 소름 돋았음..',
#   '8',
#   '461',
#   '179',
#   datetime.datetime(2019, 4, 24, 10, 38),
#   0],
#  ['김춘수(sunn****)',
#   '3시간 동안 양자터널속에 있었던 기분',
#   '10',
#   '289',
#   '9',
#   datetime.datetime(2019, 4, 24, 13, 54),
#   0],
#  ['Overmanking(konj****)',
#   '아이언맨 1 편부터 봤던 사람들은 눈물나온다',
#   '10',
#   '275',
#   '10',
#   datetime.datetime(2019, 4, 25, 6, 11),
#   0],
#  ['RobertWhittaker(aorm****)',
#   '꼭 보십시요. 마블 팬이 아니어도 표값은 합니다.',
#   '10',
#   '291',
#   '28',
#   datetime.datetime(2019, 4, 24, 9, 40),
#   0],
#  ['allnight(cute****)',
#   '하워드 포츠 당신도 분명 좋은 아버지가 되었을 거예요.',
#   '10',
#   '261',
#   '11',
#   datetime.datetime(2019, 4, 25, 22, 29),
#   0],
#  ['정영석(gkgk****)',
#   '진짜 소름이 돋음 역대급 전투씬인듯',
#   '10',
#   '243',
#   '12',
#   datetime.datetime(2019, 4, 24, 13, 7),
#   '관람객'],
#  ['쿠요미(dlck****)',
#   'I...am ironman.',
#   '10',
#   '243',
#   '13',
#   datetime.datetime(2019, 4, 24, 10, 39),
#   0],
#  ['아틀라스(tins****)',
#   '조조로 보고와서 일하고 있는데 자꾸만  생각나고... 벅차고...  뭉클해진다. 영화가 주는 최상의 행복이 이런 게 아닐까 생각한다.',
#   '10',
#   '234',
#   '12',
#   datetime.datetime(2019, 4, 24, 15, 32),
#   0],
#  ['uago****',
#   '해리포터를 떠나 보낼 때의 감정',
#   '10',
#   '229',
#   '16',
#   datetime.datetime(2019, 4, 24, 19, 57),
#   0],
#  ['innerglow(ayaa****)',
#   '아침 7시 영화 지금 엔딩 크레딧 올라가는 중.일단 모든 편을 다 보고 오시는 걸 추천. 기존 스포는 스포도 아니었음을 미리 알려드려요.화장실 한 번을 못 갔음....',
#   '10',
#   '221',
#   '10',
#   datetime.datetime(2019, 4, 24, 10, 7),
#   0],
#  ['dahe****',
#   '히드라만세에서 터졌었네요',
#   '10',
#   '210',
#   '11',
#   datetime.datetime(2019, 4, 24, 13, 11),
#   0],
#  ['jsoo****',
#   '나는 아이언맨이다...',
#   '10',
#   '208',
#   '13',
#   datetime.datetime(2019, 4, 24, 11, 17),
#   0],
#  ['sung****',
#   '어벤저스의 시작과 끝은 아이언맨이다딱 이생각 밖에 안들었음쿠키영상기다리면서 이생각이 들었음(마블영화 최초로 쿠키영상없음)',
#   '10',
#   '209',
#   '14',
#   datetime.datetime(2019, 4, 24, 13, 8),
#   0],
#  ['이자두(saga****)',
#   '미쳤습니다.. 7시 첫 영화 보고 출근하는데기분 세상 짜릿.. 보면서 두손 꼭 모으고 입을 틀어막았어요ㅠㅠㅠㅠ 어벤져스 짜릿해...',
#   '10',
#   '212',
#   '19',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   '관람객'],
#  ['올해는우리꺼(wjdd****)',
#   '"그"로 시작해서 "그"로 끝났다',
#   '10',
#   '199',
#   '13',
#   datetime.datetime(2019, 4, 24, 17, 8),
#   0],
#  ['안녕하소(cjh2****)',
#   '가디언즈 오브 갤럭시3  토르 출현 할가능성높음',
#   '10',
#   '196',
#   '12',
#   datetime.datetime(2019, 4, 24, 20, 32),
#   0],
#  ['불효자(silb****)',
#   '토니스타크는 아이언맨이 됐고 캡틴 아메리카는 스티브 로저스가 됐다.',
#   '10',
#   '188',
#   '6',
#   datetime.datetime(2019, 4, 27, 8, 5),
#   0],
#  ['앨리스(acac****)',
#   '말이 필요없으니 그냥 영화관 가서 보세요. 아 참고로 이번영화는 쿠키영상 없습니다. 대신 크레딧영상 보면 다들 찡 할거에요.',
#   '10',
#   '198',
#   '17',
#   datetime.datetime(2019, 4, 24, 11, 49),
#   0],
#  ['enough(rdxs****)',
#   '내가 본 히어로 영화중 현재까진 엔드게임이 최고 였다',
#   '9',
#   '200',
#   '25',
#   datetime.datetime(2019, 4, 24, 11, 40),
#   0],
#  ['Happy Day(mins****)',
#   '2번 보겠습니다  아듀  어벤져스',
#   '10',
#   '182',
#   '18',
#   datetime.datetime(2019, 4, 24, 9, 36),
#   0],
#  ['gh(leeg****)',
#   '1/1400만이 쥐가 버튼누를 확률이었놐ㅋㅋㅋ',
#   '10',
#   '169',
#   '7',
#   datetime.datetime(2019, 4, 26, 13, 40),
#   0],
#  ['밤고양이(anej****)',
#   "'목을 쳤어야지'  '응 목따러 왔다'",
#   '10',
#   '169',
#   '7',
#   datetime.datetime(2019, 4, 24, 13, 7),
#   0],
#  ['123x****',
#   '3000만큼 사랑해.',
#   '10',
#   '168',
#   '7',
#   datetime.datetime(2019, 4, 24, 10, 52),
#   0],
#  ['황채민(roka****)',
#   '진짜 최고의 영화다. 마블은 천재다 이 말 밖에 안 나온다. 끝나고는 벌써 3시간이나 지나있었다는게 믿기지 않았고, 그저 눈물만 났다. 마블과 11년 동안 행복했습니다. 이 시대를 즐길 수 있게 해주셔서 정말 감사합...',
#   '10',
#   '169',
#   '9',
#   datetime.datetime(2019, 4, 24, 13, 29),
#   0],
#  ['잠오는민(sksk****)',
#   '이제 뭘 기다려야 하나요..',
#   '10',
#   '164',
#   '6',
#   datetime.datetime(2019, 4, 24, 16, 14),
#   0],
#  ['hiph****',
#   '역시 걸복동 과는 다르네 캬.ㅎㅎ',
#   '10',
#   '194',
#   '38',
#   datetime.datetime(2019, 4, 24, 9, 18),
#   0],
#  ['이도연(anyl****)',
#   '토니....그동안 고생 많았어 이제 불안해하지 말고 편안한 곳에서 맛있는거 먹고 푹 쉬어',
#   '10',
#   '197',
#   '42',
#   datetime.datetime(2019, 4, 24, 13, 11),
#   '관람객'],
#  ['최진영(cjsq****)',
#   '콜라 대량 흡입금지 화장실 갈 시간이 없습니다',
#   '10',
#   '160',
#   '6',
#   datetime.datetime(2019, 4, 24, 18, 5),
#   '관람객'],
#  ['강상우(sang****)',
#   '결국 세상을 구한건 쥐 한마리인건가..?',
#   '8',
#   '171',
#   '20',
#   datetime.datetime(2019, 4, 24, 22, 46),
#   0],
#  ['스카이다이빙(into****)',
#   '아 보고나니 뭔가 가족을 떠나보낸 기분이에요',
#   '10',
#   '154',
#   '4',
#   datetime.datetime(2019, 4, 24, 17, 26),
#   '관람객'],
#  ['염민똥(rjad****)',
#   '마블 영화들 전부다 봐야지 하나하니 세세히 이해할 수 있어요.안봐놓고 지루하다 하지마십셩.',
#   '10',
#   '136',
#   '7',
#   datetime.datetime(2019, 4, 24, 13, 28),
#   0],
#  ['csw2****',
#   '아이언맨의 심장이 따뜻했다는 증거..',
#   '10',
#   '130',
#   '5',
#   datetime.datetime(2019, 4, 24, 21, 46),
#   '관람객'],
#  ['허무맨(poki****)',
#   '쿠키영상 없으니까 친필싸인 다보면 집가도됨',
#   '8',
#   '140',
#   '19',
#   datetime.datetime(2019, 4, 24, 13, 22),
#   '관람객'],
#  ['wudy(dudg****)',
#   '마지막 전투씬에서 완다가 염력을 이용해 타노스와 대치할때 전투씬말고 다른걸 보았습니다.',
#   '10',
#   '184',
#   '64',
#   datetime.datetime(2019, 4, 25, 15, 19),
#   0],
#  ['이뎨(tmdr****)',
#   '대강 예상은했지만 포탈열릴 때 지렸다',
#   '10',
#   '127',
#   '8',
#   datetime.datetime(2019, 4, 26, 17, 23),
#   '관람객'],
#  ['fsfssf(rkdc****)',
#   '온몸에 소름만 한 10번정도 돋은듯..',
#   '10',
#   '132',
#   '13',
#   datetime.datetime(2019, 4, 24, 10, 35),
#   '관람객'],
#  ['kkwa****',
#   '이제 무슨 낙으로 사냐.',
#   '10',
#   '125',
#   '7',
#   datetime.datetime(2019, 4, 24, 20, 29),
#   0],
#  ['젠틀에디(lym3****)',
#   '어벤저스 어셈블!!ㄷㄷ',
#   '10',
#   '126',
#   '8',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   0],
#  ['HIM(dlck****)',
#   '진짜 10년의 시작과 끝을 너무 멋있게 보여줬다어셈블',
#   '10',
#   '126',
#   '9',
#   datetime.datetime(2019, 4, 24, 11, 57),
#   '관람객'],
#  ['헬루(iwon****)',
#   '아이언맨4 잘보고 왔습니다.',
#   '10',
#   '128',
#   '11',
#   datetime.datetime(2019, 4, 24, 19, 55),
#   '관람객'],
#  ['손영준(ojuo****)',
#   '아이언맨 사가라 해도 과언이 아니다..',
#   '10',
#   '126',
#   '10',
#   datetime.datetime(2019, 4, 24, 10, 40),
#   '관람객'],
#  ['변태대머리(skae****)',
#   "i'm iron man으로 시작하고 끝나네ㅠㅠ",
#   '10',
#   '122',
#   '7',
#   datetime.datetime(2019, 4, 24, 13, 17),
#   0],
#  ['SJ(cha9****)',
#   '10대는 해리포였고 20대는 어벤져스였다',
#   '10',
#   '118',
#   '4',
#   datetime.datetime(2019, 4, 26, 21, 17),
#   '관람객'],
#  ['정진(bkbk****)',
#   '울었다 너무 웅장해서 두번본다',
#   '10',
#   '114',
#   '5',
#   datetime.datetime(2019, 4, 24, 14, 39),
#   0],
#  ['장미란에게장미란(gtwa****)',
#   '죽기전에 이런 영화를 또 볼수있을까? 히어로물의 장르적 한계를 엄청나게 확장시켜놓은 어벤져스 시리즈의 대미를 장식하는 최고의 명작.',
#   '10',
#   '111',
#   '3',
#   datetime.datetime(2019, 4, 25, 1, 24),
#   0],
#  ['MRAZLIM(mraz****)',
#   '아버지의 치즈버거..',
#   '10',
#   '114',
#   '8',
#   datetime.datetime(2019, 4, 24, 15, 27),
#   0],
#  ['eag(eagl****)',
#   "Ironman의 iron은 '강철` 이외에도 '끝내다, 해결하다` 의 뜻도 있듯, 토니의 아이언맨은 그저 강철수트를 입은 남자가 아닌, 해결사이자 종결자였다.",
#   '10',
#   '109',
#   '4',
#   datetime.datetime(2019, 4, 26, 3, 13),
#   0],
#  ['흙(jyou****)',
#   '보는 내내 오오거리고 재밌는대사 소리내서 따라하는 무개념20대 커플덕분에 영화가 더 재밌었네요.  어린애들보다 나대는 커플을 피해야할듯 싶음',
#   '10',
#   '116',
#   '13',
#   datetime.datetime(2019, 4, 24, 18, 34),
#   0],
#  ['kang****',
#   '쿠키영상이 없다는건 이미 알고 있었습니다. 근데도 일어날수가 없었어요.',
#   '10',
#   '108',
#   '6',
#   datetime.datetime(2019, 4, 25, 14, 41),
#   0],
#  ['narc****',
#   '11년간의 보상당일 아침에 본 사람들이 승리자다',
#   '10',
#   '114',
#   '13',
#   datetime.datetime(2019, 4, 24, 13, 9),
#   '관람객'],
#  ['솔라문스타(glor****)',
#   '마지막 싸움에서 지리고 아이언맨은 짠했다',
#   '10',
#   '108',
#   '8',
#   datetime.datetime(2019, 4, 24, 15, 26),
#   0],
#  ['이승민(skdh****)',
#   '와 미친.. 꼭보세요 강추강추!!',
#   '10',
#   '116',
#   '17',
#   datetime.datetime(2019, 4, 24, 9, 36),
#   0],
#  ['주화입마(rkdw****)',
#   '지금까지의 모든 마블 영화가 앤드게임의 마지막 순간을 위해 제작되었다는 느낌을 받음',
#   '10',
#   '106',
#   '8',
#   datetime.datetime(2019, 4, 25, 18, 12),
#   0],
#  ['BlackJin(gurw****)',
#   '진짜 재밌었어요 요즘 만족스럽게본 영화가 없었는데 어벤져스는 좋아하는만큼 기대한 그 이상으로 재미있어가지고 행복했어요ㅎㅎ!!',
#   '10',
#   '107',
#   '9',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   '관람객'],
#  ['다시돌아가야지(cano****)',
#   '토르 너무 좋아 아스가디언 나왔으면',
#   '10',
#   '102',
#   '5',
#   datetime.datetime(2019, 4, 25, 1, 23),
#   '관람객'],
#  ['Taehwan95(imai****)',
#   '어벤져스 보러 한국오신다는분ㅋㅋㅋㅋ 일본도 26일 개봉인데 어그로 ㄴㄴ',
#   '10',
#   '107',
#   '13',
#   datetime.datetime(2019, 4, 24, 9, 50),
#   0],
#  ['한서정(gjsl****)',
#   '스포할 생각도 들지않는 영화를 보고 나온 사람들끼리 그동안의 얘기를 풀고싶어지는 영화네요 10대에 해리포터였다면 제 20대는 어벤져스로 마무리지어지는 그런 영화였어요 영화가 끝나고나서 제 속이 텅빈느낌과 꽉찬느낌 2...',
#   '10',
#   '99',
#   '6',
#   datetime.datetime(2019, 4, 24, 16, 27),
#   0],
#  ['jinw****',
#   '뭔가 허무해..근데 재밌어 ㅠ',
#   '10',
#   '93',
#   '6',
#   datetime.datetime(2019, 4, 24, 13, 9),
#   '관람객'],
#  ['김동환(nanu****)',
#   '이 영화를 굳이 하나의 독립된 영화로서 평가해야 하나? 2008 아이언맨부터 시작된 마블시네마틱 유니버스의 연계 캐릭터의 서사 액션 전부가 이 엔드게임에 녹여져있다 그리고 11년간 함께해온 어벤져스 원년멤버에 대한 ...',
#   '10',
#   '90',
#   '5',
#   datetime.datetime(2019, 4, 26, 2, 18),
#   0],
#  ['srak****',
#   '누군가와 같은 시간 속에 같은 기억을 공유하며 함께 살아간다는 것은 멋진 일이라고 생각합니다.  함께 해서 즐거웠고, 함께해서 영광이었습니다. 고맙습니다. 어벤저스.',
#   '10',
#   '87',
#   '5',
#   datetime.datetime(2019, 4, 25, 7, 30),
#   '관람객'],
#  ['perspicacia(hans****)',
#   '쿠키영상은 없습니다. 본편에 쿠키라 할만한 이야기들을 다 풀어내고 완벽한 마침표를 찍습니다.',
#   '10',
#   '88',
#   '8',
#   datetime.datetime(2019, 4, 24, 10, 35),
#   0],
#  ['하하하(milb****)',
#   '로다주랑 스칼렛한테 왜이러냐 마블아...로키코인으로 깽판기원갑니다',
#   '10',
#   '91',
#   '12',
#   datetime.datetime(2019, 4, 24, 13, 15),
#   0],
#  ['황봉알(tjdd****)',
#   '마블이 현시점 최고의 제작사인듯',
#   '10',
#   '79',
#   '5',
#   datetime.datetime(2019, 4, 24, 21, 15),
#   '관람객'],
#  ['하미니(hami****)',
#   '지루하다고 하는 사람들은 마블시리즈를 다 안 본 사람들이 아닐까 싶음. 꼭!!!! 마블유니버스 영화를 다 보고 이거 보세요. 장면 하나하나 다 놓칠 수 없습니다..감동이 다를거에요 ㅠㅠ',
#   '10',
#   '84',
#   '10',
#   datetime.datetime(2019, 4, 25, 1, 22),
#   0],
#  ['태임(s200****)',
#   '아 진짜 애들 데리고 영화보러 올거면 미리 애들한테 영화관 안에서 어떻게 행동해야 하는지 가르치고 데리고 와라. 주의력결핍인 초딩놈 때문에 짜증나 죽는줄 알았다.  애가 어리면 말도 안해 딱봐도 초등학교 5학년 이상...',
#   '7',
#   '91',
#   '17',
#   datetime.datetime(2019, 4, 25, 22, 32),
#   0],
#  ['Dunk(hb12****)',
#   '아임 아이언맨. 할때 눈물나옴',
#   '10',
#   '79',
#   '6',
#   datetime.datetime(2019, 4, 24, 11, 45),
#   0],
#  ['xion****',
#   '닥터 스트레인지 양반 ! 꼴랑 찾아낸 승리하는 미래가 이거였수?  더 찾지 그랬수 .어이 캡틴  .   가정 지키고 싶다는 친구 등 떠밀고 본인은 행복한 미래?',
#   '10',
#   '169',
#   '96',
#   datetime.datetime(2019, 4, 26, 6, 16),
#   '관람객'],
#  ['이승헌(lemo****)',
#   '재미없다는 사람특징 : 지금까지 마블영화 제대로 안봤음, 그래놓고 지루하다 재미없다 운운, 그 거대한 이야기 이정도면 최고의 마무리',
#   '10',
#   '93',
#   '22',
#   datetime.datetime(2019, 4, 25, 22, 17),
#   0],
#  ['김민수(kim0****)',
#   '이 영화 때문에 SNS를 다 지웠습니다.',
#   '10',
#   '81',
#   '12',
#   datetime.datetime(2019, 4, 24, 10, 32),
#   0],
#  ['바콩(loyp****)',
#   '로키는 어디로 사라졌을까?',
#   '10',
#   '69',
#   '2',
#   datetime.datetime(2019, 4, 27, 11, 17),
#   0],
#  ['yehy****',
#   '엔드게임 한 편으로만 보자면 완성도가 떨어지지만 어벤져스 1세대의 마지막으로선 완벽했다. 토니 스티브 행복하길... 나타샤도...',
#   '8',
#   '107',
#   '41',
#   datetime.datetime(2019, 4, 24, 17, 19),
#   0],
#  ['gksw****',
#   '영화다보고 화장실갔는데 영화 내용 엄청 떠들던 분들..;내가 이미 봐서 다행이지 이기적으로 살지 맙시다',
#   '10',
#   '74',
#   '10',
#   datetime.datetime(2019, 4, 24, 17, 36),
#   0],
#  ['빈(tomu****)',
#   '솔직히 스포 당해도 큰 문제 없음... 마블 팬이었다면 그동안 어렴풋이 예상한 것들이기 때문에. 그보다는, 지금까지의 MCU 21편 모두를 정주행하고 숙지하는 것이 감동 10배 100배로 다가옴. 진짜 정주행자들만이...',
#   '9',
#   '77',
#   '13',
#   datetime.datetime(2019, 4, 25, 11, 54),
#   0],
#  ['빅슈즈몰(choi****)',
#   '스포하는 새끼 올해 출근하다 교통사고 당한다',
#   '10',
#   '145',
#   '81',
#   datetime.datetime(2019, 4, 24, 11, 44),
#   0],
#  ['우여니(sids****)',
#   '이십대중반 아가씨때부터 애둘 아줌마까지.나의 청춘에 큰 즐거움이었던 어벤져스 사랑합니다',
#   '10',
#   '68',
#   '6',
#   datetime.datetime(2019, 4, 25, 20, 1),
#   0],
#  ['JM9(a126****)',
#   '댓글 처음써봐요 어벤져스 3000만큼사랑합니다 하.. 지렸다',
#   '10',
#   '68',
#   '6',
#   datetime.datetime(2019, 4, 24, 11, 49),
#   0],
#  ['bbs7****',
#   '누군가는 액션의 분량이 성에 차지않거나 너무 드라마가 많아서 조금 지루할지도 모르겠지만  이 영화는 단순 오락 액션물이 아니고 가상의 유니버스에서 인간 내면의 갈등과 사랑, 선과 악, 웃음,가족애, 동지애를 그리는 ...',
#   '10',
#   '65',
#   '5',
#   datetime.datetime(2019, 4, 26, 14, 53),
#   0],
#  ['XRTC(bono****)',
#   '다크나이트 라이즈랑 비슷한 느낌. 마블과 SF라는 장르에 대한 오마주와 헌사로 가득하고 깔끔하게 마무리를 지은것은 놀라운 성과이지만 그를 위해서 자연스러움이 많이 희생되었다',
#   '8',
#   '80',
#   '21',
#   datetime.datetime(2019, 4, 24, 13, 54),
#   0],
#  ['구한샘(hans****)',
#   '마블영화보면서 울컥한건 처음입니다..꼭 보세요 너무 재밌습니다!',
#   '10',
#   '64',
#   '6',
#   datetime.datetime(2019, 4, 24, 12, 13),
#   '관람객'],
#  ['열심히살자(umen****)',
#   '밤새고  7시15분 첫상영보러왔는데 만석에놀랐고  사들고온 팝콘은  아침부터 보러오신분들께 감히 방해될까봐영화끝날때까지 손도 못대고 버렸지만 이영화를 관람했다는게 감사할뿐이다.영화야 뭐.. 말해뭐하겠어요.  지릴준비...',
#   '10',
#   '79',
#   '21',
#   datetime.datetime(2019, 4, 24, 10, 34),
#   0],
#  ['T11DH(jinm****)',
#   '소름돋는 장면과 눈물이나오는 장면 마지막 배우들의 자필 서명때 나오는 영웅들까지...! 완벽한 영화였습니다',
#   '10',
#   '66',
#   '10',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   0],
#  ['inja****',
#   '스포를 즈제하겠습니다. 너무 재밋다 정도는 아니지만 좋은 마무리가 아닌가 싶습니다',
#   '10',
#   '70',
#   '15',
#   datetime.datetime(2019, 4, 24, 11, 16),
#   '관람객'],
#  ['정연의(dusd****)',
#   '명작이야 닥터스트레인지가 애들 다시 돌려보낼때 진짜 울뻔',
#   '10',
#   '56',
#   '4',
#   datetime.datetime(2019, 4, 25, 19, 53),
#   '관람객'],
#  ['tmfr****',
#   '미국대장이 날라오는 외국산망치와 번개뚝배기브레이커 잡을땐 개전율과 동시에 지렸다....',
#   '8',
#   '62',
#   '10',
#   datetime.datetime(2019, 4, 24, 11, 41),
#   0],
#  ['npng(kckh****)',
#   '인피니티워가 더 낫다는 의견에는 동의하기 힘드네요 지금까지의 거의 모든 마블 시리즈 영화의 풀리지 않은 떡밥들을 회수하면서 최대한 식상하지 않게 끝맺음을 지었단 점에서 조금 더 좋은 평가를 줄 수 있을것 같습니다',
#   '10',
#   '70',
#   '18',
#   datetime.datetime(2019, 4, 24, 19, 44),
#   0],
#  ['이응(pokr****)',
#   '재밌긴한데 인피니티워가 더재밌었음',
#   '9',
#   '170',
#   '119',
#   datetime.datetime(2019, 4, 24, 11, 15),
#   '관람객'],
#  ['Shind(cys6****)',
#   '어벤져스 11년이라는 대장정의 마침표를 찍는 완벽한 마무리였다.그가 시작한 게임을 그가 끝냈다.액션씬도 마지막인 만큼 진짜 멋있고 웅장했고 스케일도 컷다.아이언맨 캡아 없는 어벤져스 생각도하기싫다ㅠㅠ그리고 타노스 당...',
#   '10',
#   '54',
#   '4',
#   datetime.datetime(2019, 4, 25, 5, 9),
#   0],
#  ['gkgkgkgkgkgkgkgkkg(gbv3****)',
#   'MCU에서 가장 뿌리깊언던 두 히어로. 지금까지 둘이 다투는 모습을 보며 서로의 이상향이 다르다 생각했지만 실은 누구보다도 서로를 이해하는 사이였다.',
#   '10',
#   '56',
#   '6',
#   datetime.datetime(2019, 4, 25, 22, 19),
#   0],
#  ['최프로(trut****)',
#   '진정한 영웅은 앤트맨구한 쥐새끼임',
#   '10',
#   '51',
#   '4',
#   datetime.datetime(2019, 4, 25, 1, 9),
#   0],
#  ['Haetpi(tjdg****)',
#   '보기전엔 기대됬지만 보고난후 허전하다',
#   '10',
#   '54',
#   '7',
#   datetime.datetime(2019, 4, 24, 17, 34),
#   0],
#  ['neon****',
#   '엄복동하과 엔드게임하고 관람료가 같다면서요?',
#   '10',
#   '50',
#   '4',
#   datetime.datetime(2019, 4, 26, 16, 25),
#   0],
#  ['JDH(ekgu****)',
#   '3시간 순삭 ..마지막 전투씬은 제작진들의 혼을 갈아 넣었다....',
#   '10',
#   '47',
#   '2',
#   datetime.datetime(2019, 4, 26, 1, 24),
#   0],
#  ['압(dlak****)',
#   '제발 재미있었으면한다 ;; 내인생에서 군대가기전 마지막 영화니깐 ..',
#   '10',
#   '58',
#   '14',
#   datetime.datetime(2019, 4, 24, 10, 4),
#   0],
#  ['free****',
#   '이시대에 태어나서 다행이다...',
#   '10',
#   '50',
#   '7',
#   datetime.datetime(2019, 4, 24, 13, 1),
#   '관람객'],
#  ['cmhok(cmho****)',
#   '어벤져스 엔드게임은 영화가 아니다',
#   '10',
#   '47',
#   '5',
#   datetime.datetime(2019, 4, 24, 21, 10),
#   0],
#  ['송이송이(song****)',
#   '이번영화 주인공은 쥐다..',
#   '10',
#   '50',
#   '8',
#   datetime.datetime(2019, 4, 24, 15, 43),
#   0],
#  ['워부워부(dndt****)',
#   '7시 30분 영화보고 바로 쓰는 후기.말잇못...히어로 영화 특유의 액션의 짜릿함은 물론이고,재미,감동,서사 모두를 잡은 완벽한 영화.깔래야 깔 곳이 없습니다.',
#   '10',
#   '53',
#   '11',
#   datetime.datetime(2019, 4, 24, 10, 52),
#   0],
#  ['형준(smar****)',
#   '내 인생에서 가장 빠른 3시간 이었다.',
#   '10',
#   '44',
#   '4',
#   datetime.datetime(2019, 4, 26, 2, 5),
#   0],
#  ['얌미(cann****)',
#   '정말정말 사랑하는 마블이지만.. 이게 최선인가 띠용하는 장면이 꽤 많았다 마지막인데 토르한테 꼭 그랬어야했어..?',
#   '8',
#   '48',
#   '8',
#   datetime.datetime(2019, 4, 27, 0, 23),
#   0],
#  ['Jwpapa(wedd****)',
#   '마블과함께한 내젊은날의 10년.. 마지막 장면 캡틴같구려',
#   '8',
#   '49',
#   '9',
#   datetime.datetime(2019, 4, 24, 15, 17),
#   0],
#  ['지오(lbso****)',
#   '타노스가 쎄긴 진짜 쎈넘이였음 최강빌런답게. 그렇게 두들겨맞고도 멀쩡히 장갑끼고 나는 필연적인 존재다 이 ㅈㄹ하는거보면',
#   '10',
#   '39',
#   '0',
#   datetime.datetime(2019, 4, 29, 12, 49),
#   0],
#  ['방구석날라리(chul****)',
#   '가장 임펙트있는 장면 나는 아이언맨이다',
#   '10',
#   '42',
#   '3',
#   datetime.datetime(2019, 4, 25, 6, 17),
#   '관람객'],
#  ['JH Park(benc****)',
#   '모든 영웅의 퇴장이 꼭 처절한 전투에서의 장렬한 전사일 필요는 없지 지금의 mcu를 만든 두 주역중 하나에게는 이게 가장 걸맞는 예우, 어울리는 퇴장이었다',
#   '10',
#   '43',
#   '4',
#   datetime.datetime(2019, 4, 25, 21, 32),
#   0],
#  ['나잡아봐라(inhy****)',
#   '아이맥스고 뭐고 다 필요없다 사람들 없는데 가서 봐라  화장실 간다고 들락날락  먹는다고 우걱우걱   뿌시럭 뿌시럭   개짜증남',
#   '9',
#   '45',
#   '6',
#   datetime.datetime(2019, 4, 25, 10, 45),
#   0],
#  ['DK(ssun****)',
#   '아스가디언즈오브갤럭시ㅋㅋㅋ',
#   '10',
#   '39',
#   '1',
#   datetime.datetime(2019, 4, 25, 3, 6),
#   0],
#  ['kiha****',
#   '모든 장면들이 다 쩔지만 진짜 중간부분에 2012 뉴욕 뽝!!!! 나오고 어벤져스 나오는 장면도 레알 소름....몇년 안된거 같은데 되게 젊어보임ㅠㅠ 엉엉 진짜 나의 10대의 마지막부터 30대까지 함께해줘서 고마워 ...',
#   '10',
#   '40',
#   '2',
#   datetime.datetime(2019, 4, 27, 19, 17),
#   0],
#  ['토깽이(pula****)',
#   '스포는 자제... 많이 울었네요ㅠㅠ',
#   '10',
#   '43',
#   '7',
#   datetime.datetime(2019, 4, 24, 14, 27),
#   '관람객'],
#  ['원동휘(ohok****)',
#   '쿠키영상없는데 사람들  안나가고 기대중 ㄷ ㄷ',
#   '10',
#   '46',
#   '10',
#   datetime.datetime(2019, 4, 24, 13, 28),
#   '관람객'],
#  ['비야내려라라(gotk****)',
#   '말도 못하고 봤음. 히어로물 보면서 눈물 날줄 몰랐다. 액션물이 아니라 한편의 드라마. 펑펑 터지는 거 기대하고 갔다가 먹먹해지고 왔다.',
#   '10',
#   '37',
#   '3',
#   datetime.datetime(2019, 4, 27, 4, 27),
#   0],
#  ['융(dbsk****)',
#   '어벤저스가 마지막이라니 ㅠㅠ여운남네요..',
#   '10',
#   '38',
#   '4',
#   datetime.datetime(2019, 4, 24, 19, 55),
#   '관람객'],
#  ['WonderBoy(schm****)',
#   '2008년 이후 모든 마블 사가와 함께 해왔다면 만점이 응당 과하지 않다. 이제껏 어벤져스만 보면 왜 모이면 솔로무비보다 항상 아쉽나 했지만 처음으로 완전체가 모여 캡틴이 어셈블을 외치기 위해 그동안 숨죽여 왔던 것...',
#   '10',
#   '36',
#   '3',
#   datetime.datetime(2019, 4, 26, 8, 7),
#   0],
#  ['건시기(bpyu****)',
#   '정말 재밌는 영화인데 먹먹합니다.. 앞으로 볼 수 없다는 것 때문에요....',
#   '10',
#   '36',
#   '3',
#   datetime.datetime(2019, 4, 24, 23, 53),
#   '관람객'],
#  ['sd54****',
#   '딱 이번년도 개봉한 한국영화의 100배쯤 잼있습니다',
#   '10',
#   '38',
#   '6',
#   datetime.datetime(2019, 4, 24, 19, 36),
#   0],
#  ['이학승(greg****)',
#   '토니와 같은 사랑을 나누고 싶은 캡틴이야 말로 영화가 우리에게 전달하고 싶은 말이 아닐까?',
#   '10',
#   '32',
#   '2',
#   datetime.datetime(2019, 4, 26, 16, 52),
#   0],
#  ['bill****',
#   '캡틴 아메리카 ..당당히 제 몫을 해냈다☆',
#   '10',
#   '33',
#   '3',
#   datetime.datetime(2019, 4, 24, 22, 19),
#   0],
#  ['ey08****',
#   '토를를 왜..? 재미있긴했는데',
#   '8',
#   '43',
#   '13',
#   datetime.datetime(2019, 4, 26, 1, 54),
#   '관람객'],
#  ['새우(taew****)',
#   '마지막 전투씬은 단연코 인생 최고 3시간동안 버릴 장면이 없다',
#   '10',
#   '30',
#   '1',
#   datetime.datetime(2019, 4, 25, 2, 15),
#   0],
#  ['블랙탄(blac****)',
#   '댓글ㅋㅋㅋ쳐보지도않고 베플되고싶어서 씹 오글거리는 댓글들 써재끼네ㅋㅋ',
#   '10',
#   '67',
#   '38',
#   datetime.datetime(2019, 4, 24, 9, 21),
#   0],
#  ['이윤선(yoon****)',
#   '마블을 보면서 울게 될 줄이야.. 너무 멋있었습니다',
#   '10',
#   '29',
#   '1',
#   datetime.datetime(2019, 4, 27, 12, 14),
#   '관람객'],
#  ['ilov****',
#   '존잼탱입니다 꼭보세요',
#   '10',
#   '40',
#   '12',
#   datetime.datetime(2019, 4, 24, 10, 7),
#   0],
#  ['불량곰탱(jinn****)',
#   '하루종일 할 수도 있어.',
#   '10',
#   '32',
#   '5',
#   datetime.datetime(2019, 4, 25, 6, 11),
#   0],
#  ['황보숙(hbs7****)',
#   '나의 토르를 돌려주세요',
#   '10',
#   '28',
#   '2',
#   datetime.datetime(2019, 4, 27, 23, 22),
#   '관람객'],
#  ['첼로인(cell****)',
#   '정말 이건 명작이다 그러나 토르는...',
#   '10',
#   '29',
#   '3',
#   datetime.datetime(2019, 4, 25, 19, 43),
#   0],
#  ['우럭매운탕(sona****)',
#   '덕분에 핫도그에 마요네즈 뿌려먹어봄',
#   '10',
#   '29',
#   '3',
#   datetime.datetime(2019, 4, 25, 7, 6),
#   0],
#  ['랄로(apri****)',
#   '아쉽다 솔직히 아쉬운 점들이 많음',
#   '8',
#   '72',
#   '46',
#   datetime.datetime(2019, 4, 24, 15, 1),
#   0],
#  ['청노루(blue****)',
#   '인류가 볼수있는 가장 화려하고 감동적인 영화',
#   '10',
#   '32',
#   '8',
#   datetime.datetime(2019, 4, 24, 19, 41),
#   0],
#  ['Damien(yoos****)',
#   '마블이니까 잘 끝낼거라 예상은 했다만 이렇게 완벽한 피날레라니. 난 과거 여행만 하다 끝나진 않겠지 했는데 역시나 마지막에 모으고 모아놨던걸 그냥 뽜아아앙 터트려 주는데 온몸에 전율이 확 오르고 진짜 내 20대를 책...',
#   '10',
#   '25',
#   '2',
#   datetime.datetime(2019, 4, 27, 23, 14),
#   0],
#  ['apxl****',
#   'mcu 특유의 영상미와 연출, 짜임새가 매우 만족스러웠다.당분간 다른 영화를 보아도 이런 감탄과 감동과 재미는 오지않을것 같다.3시간짜리 영화지만 엔딩 직전에 이제 영화 반절 본건가? 싶을 정도로 3시간의 압박은 없...',
#   '10',
#   '26',
#   '3',
#   datetime.datetime(2019, 4, 24, 16, 13),
#   0],
#  ['비버(zkqm****)',
#   '좋은 추억을 주어서 고마워요',
#   '10',
#   '27',
#   '4',
#   datetime.datetime(2019, 4, 24, 13, 7),
#   0],
#  ['중고양발(dhki****)',
#   '눈물난다 보내시싫다...',
#   '10',
#   '22',
#   '0',
#   datetime.datetime(2019, 4, 28, 22, 17),
#   '관람객'],
#  ['김동하(ehdg****)',
#   '전투씬 진짜 개소름 ...한번 더 봐야지 ㅋ',
#   '10',
#   '22',
#   '0',
#   datetime.datetime(2019, 4, 27, 23, 15),
#   0],
#  ['이주혁(wnfk****)',
#   '역사상 전무후무한 최고의 히어로 영화다',
#   '10',
#   '26',
#   '4',
#   datetime.datetime(2019, 4, 24, 19, 21),
#   0],
#  ['크로니클(zzpo****)',
#   '와칸다포에버 채드윅보스만포에버',
#   '10',
#   '21',
#   '0',
#   datetime.datetime(2020, 8, 29, 16, 55),
#   '관람객'],
#  ['U프로디테(leeu****)',
#   '완벽한 결말 이런 영화는 다시 나올 수 없을 만큼 완벽하다',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2019, 4, 26, 5, 25),
#   '관람객'],
#  ['전이안(zizh****)',
#   '당신들의 마지막 전투에 함께하게 되어 영광이였습니다.감사합니다 마블.',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2019, 4, 25, 19, 41),
#   0],
#  ['에어보이컷(duse****)',
#   '정말 감동과 대단원의 막...',
#   '10',
#   '23',
#   '2',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   0],
#  ['인생살기힘듬(tmde****)',
#   '진짜 꼭봐야합니다 평점 3000만큼 주고싶네',
#   '10',
#   '25',
#   '4',
#   datetime.datetime(2019, 4, 25, 19, 42),
#   '관람객'],
#  ['형성빈(kkh4****)',
#   'Avengers Assemble!!',
#   '10',
#   '22',
#   '2',
#   datetime.datetime(2019, 4, 25, 22, 19),
#   0],
#  ['shot(euns****)',
#   '닥터 스트레인지가 본 경우의수가 쥐가 버튼 밟을 확률임',
#   '10',
#   '23',
#   '3',
#   datetime.datetime(2019, 4, 28, 18, 48),
#   0],
#  ['BIAZO(xord****)',
#   '꼭 봐야 한다. 꼭. 꼭.',
#   '10',
#   '24',
#   '4',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   '관람객'],
#  ['내방귀16비트(ldj9****)',
#   'DC는 절대 마블 못이김',
#   '10',
#   '20',
#   '1',
#   datetime.datetime(2019, 4, 30, 9, 48),
#   0],
#  ['LilWayne(ojst****)',
#   '어벤져스를 볼수있는 시대에 태어남에 감사함을 느낄 수 있는 영화.',
#   '10',
#   '21',
#   '2',
#   datetime.datetime(2019, 4, 27, 7, 39),
#   0],
#  ['김따뚜(khj1****)',
#   '아주 오랜된 친구들을 떠나보는 마음... 3시간은 충분하지 않았다',
#   '10',
#   '21',
#   '2',
#   datetime.datetime(2019, 4, 25, 9, 49),
#   0],
#  ['rnal****',
#   '최고의 엔딩 10년을 함께 해 온 팬들을 위한 최고의 작품이라고 생각해요잎으로의 10년도 더 기다려지네요',
#   '10',
#   '24',
#   '5',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   0],
#  ['지리산작두(20bo****)',
#   '스포하는것들은 손가락을 토르도끼로   절단 하거나타노스 주먹으로 주둥이를  막아버리는 법안이 나왔으면한다',
#   '10',
#   '25',
#   '6',
#   datetime.datetime(2019, 4, 24, 14, 57),
#   0],
#  ['qndu****',
#   '어벤져스 어셈블!!',
#   '10',
#   '18',
#   '0',
#   datetime.datetime(2020, 5, 10, 13, 43),
#   '관람객'],
#  ['건빵(bigs****)',
#   '지금 다시봐도 그냥 역대급이다',
#   '10',
#   '19',
#   '1',
#   datetime.datetime(2020, 3, 3, 15, 27),
#   0],
#  ['붕붕이(hy2m****)',
#   '3시간이 1시간 같다 진짜 최고였음 근데 토르 꼭 그렇게 묘사해야만 했나ㅠ',
#   '10',
#   '19',
#   '1',
#   datetime.datetime(2019, 4, 29, 12, 39),
#   '관람객'],
#  ['rmfb****',
#   '청춘을 함께해줘서 감사합니다',
#   '10',
#   '20',
#   '2',
#   datetime.datetime(2019, 4, 27, 7, 32),
#   0],
#  ['ms2i****',
#   '아 너무 좋아여 ㅠㅠ 가슴이 벅차올라여',
#   '10',
#   '21',
#   '3',
#   datetime.datetime(2019, 4, 24, 10, 49),
#   0],
#  ['magi****',
#   '이 영화 보면서 캡틴마블 활약하는 장면에 캡틴마블 대신 전성기 토르 넣어서 생각해보세요 놀랍도록 자연스럽고 개연성 있고 인피니티 사가를 마무리하는 멋진 전개가 됩니다. 이제 왜 토르가 복수도 못하는 찌질이 돼르가 될...',
#   '9',
#   '23',
#   '5',
#   datetime.datetime(2019, 5, 4, 2, 45),
#   0],
#  ['ghkdtmdgml(anad****)',
#   '3000만큼 재밌었고 감동, 유머까지 ㅠㅜ3시간이아니라 좀 더 길었으면 하는 마음이 생깁니다♥♥',
#   '10',
#   '27',
#   '9',
#   datetime.datetime(2019, 4, 24, 12, 27),
#   '관람객'],
#  ['재키찬(bdle****)',
#   '다필요없고 캡아vs타노스 3분이 3시간러닝타임에 꽃이다. 그것만 다시보러 또간다. 가장 현실적인 액션. 캡마?넌 그냥 우주선 파괴용.',
#   '10',
#   '32',
#   '14',
#   datetime.datetime(2019, 4, 25, 9, 42),
#   0],
#  ['Leuuuny(leuu****)',
#   '엄청 나게 꿀잼은 아니었다그냥 아련한 기분.. 안녕 어벤져스',
#   '7',
#   '58',
#   '40',
#   datetime.datetime(2019, 4, 24, 13, 43),
#   0],
#  ['프렌독(frie****)',
#   '어벤져스들 전부 소집됫을때 계속소름;;;;',
#   '10',
#   '17',
#   '0',
#   datetime.datetime(2019, 6, 19, 10, 31),
#   '관람객'],
#  ['금속문화재(hj92****)',
#   '3시간동안 넋놓고 봤다...',
#   '10',
#   '18',
#   '1',
#   datetime.datetime(2019, 4, 25, 6, 11),
#   '관람객'],
#  ['미용계에서 부자(qkdt****)',
#   '영화끝나고 치즈버거 먹으러가자....',
#   '10',
#   '21',
#   '4',
#   datetime.datetime(2019, 4, 24, 13, 8),
#   0],
#  ['밀런(izun****)',
#   '타노스가 귀농을 한 후 덜구운 굽네 고추바사삭이 되엇꼬캡틴아메리카가 알고보니 하이드라인데다가 아스가르드를 차지하게 되엇읍니다.',
#   '10',
#   '25',
#   '8',
#   datetime.datetime(2019, 4, 24, 12, 20),
#   0],
#  ['낄삼(piah****)',
#   '사실 엉성한 구성에 늘어지는 장면들을 너무 많이 넣어놔서 막판 클라이막스까지 가는 길이 꽤나 험난합니다. 다만 마무리는 어찌어찌 지은 것 같네요. 6점 영화. 평점 밸런스 위해 1점 갑니다',
#   '1',
#   '28',
#   '11',
#   datetime.datetime(2019, 4, 24, 16, 2),
#   0],
#  ['OnePieceOnly(abg1****)',
#   '엔드게임 자체가 수작이었다기보단 지난 수년간 전세계 팬들을 위해 최고의 영상과 스토리로 SF계의 한 획을 그어준 마블 관계자들 모두에게 고맙다는 이야기를 전하고 싶습니다. 정말 고생 많으셨습니다. 잊지 못할 영화였습...',
#   '10',
#   '16',
#   '0',
#   datetime.datetime(2019, 4, 29, 12, 35),
#   0],
#  ['두부공자(ahwa****)',
#   '미국이 아닌 진정한 마블펜들을 위한 선물같은 영화.내 돈주고 보고 뭔가 내가 더 이득 본 느낌.한국영화가 아니라 한국영화제작사가 반드시 보고 배워야하는 영화.',
#   '10',
#   '17',
#   '1',
#   datetime.datetime(2019, 4, 27, 21, 0),
#   0],
#  ['Pentacode(rebe****)',
#   '웃고 울고 .. 넘모재밌는것',
#   '10',
#   '17',
#   '1',
#   datetime.datetime(2019, 4, 26, 2, 7),
#   '관람객'],
#  ['ipra****',
#   '극한직업보다 3000배 재미있음..',
#   '10',
#   '18',
#   '2',
#   datetime.datetime(2019, 4, 26, 0, 30),
#   '관람객'],
#  ['jun(stor****)',
#   '쥐가 세상을 구했습니다',
#   '10',
#   '18',
#   '2',
#   datetime.datetime(2019, 4, 24, 23, 29),
#   0],
#  ['드암(whgd****)',
#   '정말 재밌었고 11년의 대장정의 끝맺음으로서도 아주 좋았다 제발 스포충들은 스포좀 하지마 명대사도 하지마 그냥 아무것도 하지마 재밌다는 말이면 충분하다',
#   '10',
#   '19',
#   '3',
#   datetime.datetime(2019, 4, 24, 10, 51),
#   0],
#  ['jyj1****',
#   '마실것사서 영화관 입장하지마세요 방광터집니다',
#   '10',
#   '20',
#   '4',
#   datetime.datetime(2019, 4, 24, 17, 55),
#   '관람객'],
#  ['스트라빈스(jjhe****)',
#   '여러모로 당황스럽고 황당했다',
#   '10',
#   '21',
#   '5',
#   datetime.datetime(2019, 4, 24, 10, 37),
#   0],
#  ['미요미요(a174****)',
#   '몬가아쉽네 너무기댈했나?',
#   '8',
#   '43',
#   '27',
#   datetime.datetime(2019, 4, 24, 15, 48),
#   0],
#  ['멍뭉이(nada****)',
#   '마블 3000만큼 사랑해',
#   '10',
#   '15',
#   '0',
#   datetime.datetime(2020, 5, 9, 10, 18),
#   '관람객'],
#  ['빨간레스폴기타(asdk****)',
#   '너무 재밌었지만 마음이 허 하다...',
#   '10',
#   '15',
#   '0',
#   datetime.datetime(2019, 5, 5, 20, 45),
#   0],
#  ['Pernilla(kimb****)',
#   '4월29일 밤9시 건대입구 CGV 4층 3관 . E열 7.8 자리에 앉은 커플때문에 정말! 다리로 계속 의자건드리고 미치는줄!!! 정말 미치는줄 알았음!!! 어케 둘중에 하나도 안말리고 딱 끼리끼리 만나서 그렇게 기...',
#   '10',
#   '16',
#   '1',
#   datetime.datetime(2019, 4, 30, 9, 26),
#   0],
#  ['유한(dbsd****)',
#   '너무 감동적이고 웃기고 아쉬운마음으로 아주 재밌게 봤습니당~~!!',
#   '10',
#   '16',
#   '1',
#   datetime.datetime(2019, 4, 24, 21, 50),
#   '관람객'],
#  ['가가갉(qogh****)',
#   '3번보고 재개봉으로 또봐도 눈물 펑펑이에요',
#   '10',
#   '17',
#   '2',
#   datetime.datetime(2020, 5, 7, 17, 54),
#   '관람객'],
#  ['naca****',
#   '어벤져스다모일때 소름! 감동적이고 눈물나네요',
#   '10',
#   '17',
#   '2',
#   datetime.datetime(2019, 4, 27, 23, 15),
#   0],
#  ['dhgh****',
#   '이 이상의 걸작이 뭐가 있을까 싶을 정도로 모든 것이 완벽한 영화.',
#   '10',
#   '18',
#   '3',
#   datetime.datetime(2020, 6, 18, 17, 20),
#   '관람객'],
#  ['하늘초원(kang****)',
#   '아이언맨으로 시작해서 아이언맨으로 끝나다.정말 최고다. 꼭 보길 바란다.',
#   '10',
#   '19',
#   '4',
#   datetime.datetime(2019, 4, 25, 19, 48),
#   0],
#  ['JohntheBaptist(mwjo****)',
#   '인피니티 워가 더 재밌다',
#   '5',
#   '96',
#   '81',
#   datetime.datetime(2019, 4, 24, 11, 17),
#   0],
#  ['ma1z****',
#   '마블 시리즈 중 가장 인상깊게 본 것 같아요',
#   '10',
#   '16',
#   '2',
#   datetime.datetime(2019, 4, 24, 21, 50),
#   '관람객'],
#  ['낮은곳으로(tole****)',
#   '봤는데, 진짜 안본사람 위해서 스포하지말아요.',
#   '10',
#   '17',
#   '3',
#   datetime.datetime(2019, 4, 24, 13, 6),
#   0],
#  ['야생소녀(csh9****)',
#   '완전 러블리했다...ㅜ',
#   '10',
#   '17',
#   '3',
#   datetime.datetime(2019, 4, 24, 12, 16),
#   '관람객'],
#  ['세려(ilov****)',
#   '???: 헤일 하이드라',
#   '10',
#   '19',
#   '5',
#   datetime.datetime(2019, 4, 24, 13, 7),
#   0],
#  ['네스타(slne****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '9',
#   '13',
#   '0',
#   datetime.datetime(2020, 5, 22, 12, 39),
#   '관람객'],
#  ['영태(inos****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '9',
#   '14',
#   '1',
#   datetime.datetime(2019, 10, 12, 20, 34),
#   0],
#  ['현우(gusd****)',
#   '마블이 10년 동안 바라봐준 마블팬들에게 헌정하는 선물',
#   '10',
#   '14',
#   '1',
#   datetime.datetime(2019, 4, 27, 21, 14),
#   0],
#  ['nkw9****',
#   '내 생에 가장 짧은 3시간이였다. 3000만큼 재밌어요ㅠㅠ',
#   '10',
#   '15',
#   '2',
#   datetime.datetime(2019, 4, 24, 18, 34),
#   0],
#  ['너부리씨(este****)',
#   '3시간이 넘는 영화인데 중간에 화장실가는 사람 하나도 못봤음.. 모두가 집중해서 봤어요...',
#   '10',
#   '15',
#   '2',
#   datetime.datetime(2019, 4, 24, 16, 15),
#   0],
#  ['지수(yoon****)',
#   '하....꼭보세요 돈안아까움 진짜',
#   '10',
#   '16',
#   '3',
#   datetime.datetime(2019, 4, 24, 19, 21),
#   0],
#  ['서예찬(tjdp****)',
#   '완벽함..그이상을 보여주었다',
#   '10',
#   '17',
#   '4',
#   datetime.datetime(2019, 4, 24, 11, 57),
#   0],
#  ['유신애(liuh****)',
#   '10점도 모자랍니다.. 이대로 보내주기가 너무 아쉽고 슬픕니다.. 마블과 동시대에 태어나 이런 영화를 볼 수 있다는 것은 정말 크나큰 행운 같습니다..',
#   '10',
#   '12',
#   '0',
#   datetime.datetime(2019, 4, 28, 22, 24),
#   0],
#  ['qhfl****',
#   '오히려 두번째 볼때 눈물났다..첫번째 볼땐 정말 실감도 안났는데 두번째 볼땐 지난 세월에서의 토니 스타크가 떠올라서..”쉬어도돼” 라는 대사에서 참았던 눈물이 터졌다...아이언맨 3000만큼 사랑합니다',
#   '10',
#   '13',
#   '1',
#   datetime.datetime(2019, 5, 6, 5, 29),
#   0],
#  ['죠즈(wns3****)',
#   '한번보고두번보고 자꾸만 보고싶네',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2019, 4, 25, 19, 47),
#   0],
#  ['nice(tand****)',
#   '어벤저스중 최고!! 처음달아보는 평점',
#   '10',
#   '14',
#   '2',
#   datetime.datetime(2019, 4, 24, 21, 52),
#   0],
#  ['일장춘몽(asur****)',
#   '후반부 액션은 좋았는데 초반에 너무 지루하다.기대가 너무 컸네..',
#   '6',
#   '55',
#   '43',
#   datetime.datetime(2019, 4, 26, 2, 42),
#   0],
#  ['김주영(rlaw****)',
#   '어벤져스다운 영화였다',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2020, 6, 13, 0, 38),
#   '관람객'],
#  ['이네(inei****)',
#   '어벤져스 너무 그리울거 같아요ㅠㅜ',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 6, 19, 12, 35),
#   '관람객'],
#  ['햇살담은토끼조림(sirp****)',
#   '인생에 손꼽히는 영화입니다',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 6, 19, 12, 29),
#   '관람객'],
#  ['택신(gksw****)',
#   '3시간이 짧았던 영화!!마지막이라 너무 아쉽ㅠㅠ',
#   '10',
#   '11',
#   '0',
#   datetime.datetime(2019, 4, 30, 21, 17),
#   '관람객'],
#  ['이병욱(bwle****)',
#   '말이필요합니까',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2020, 5, 26, 22, 47),
#   '관람객'],
#  ['고구마(nntt****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2020, 5, 22, 14, 50),
#   '관람객'],
#  ['희(pphu****)',
#   '존잼이에요 스포하고 싶어 미치겟네요 ㅠㅠ 또 보러 갈거예요',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2019, 4, 24, 19, 33),
#   '관람객'],
#  ['rlar****',
#   '여운이많이남네요. 좋은영화입니다',
#   '10',
#   '12',
#   '1',
#   datetime.datetime(2019, 4, 24, 13, 8),
#   '관람객'],
#  ['hooc****',
#   '3000만큼 사랑해요~~~~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2019, 4, 25, 19, 48),
#   0],
#  ['채수빈(cotn****)',
#   '3000만큼 사랑해..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2019, 4, 24, 22, 27),
#   '관람객'],
#  ['mylo****',
#   '진짜인생영화다  온몸에 전율이 몇번 왔는지 모른다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2019, 4, 24, 21, 50),
#   '관람객'],
#  ['쑥쑥이(ball****)',
#   '즐거웠고 행복했다. 어벤져스 영원하라.',
#   '10',
#   '14',
#   '3',
#   datetime.datetime(2019, 4, 24, 10, 30),
#   '관람객'],
#  ['박준현(dywl****)',
#   '이거 뭔가 인피니티워가 임팩트가 더 컸는지 인피니티워만큼은 아니라고 생각함...',
#   '8',
#   '45',
#   '34',
#   datetime.datetime(2019, 4, 25, 0, 26),
#   0],
#  ['로미(whkg****)',
#   '역시 재미있었어요 ㅎㅎㅎㅎ',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2020, 6, 28, 18, 31),
#   '관람객'],
#  ['이정준(godo****)',
#   '3시간 짜리 러닝타임을 가진 긴영화 였는데 생각나는건 아엠 아이언맨 밖에없다...',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2019, 6, 21, 14, 12),
#   '관람객'],
#  ['창가(mall****)',
#   '마블팬이라면 꼭 봐야할 영화',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2019, 6, 19, 12, 5),
#   '관람객'],
#  ['himz****',
#   '토니스타크 살려내서 10년 더 나왔으면...',
#   '10',
#   '10',
#   '0',
#   datetime.datetime(2019, 6, 4, 1, 33),
#   '관람객'],
#  ['문기(gye1****)',
#   '잘가요 어벤져스 그동안 고생했어요',
#   '9',
#   '11',
#   '1',
#   datetime.datetime(2020, 5, 1, 19, 7),
#   '관람객'],
#  ['러브JM0423(ohyo****)',
#   "영화내내 콜라에 팝콘에 오징어까지 처묵고 세번이나 화장실 갔던 내앞에 두자녀를 둔 엄마한테 한마디 하고 싶었다.'그만 좀 처먹어라.그러니까 애들이 싸재끼지'",
#   '10',
#   '11',
#   '1',
#   datetime.datetime(2019, 4, 29, 4, 24),
#   0],
#  ['SBS(su47****)',
#   '새(smsa****) 니 인생이 노잼',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 6, 28, 17, 22),
#   0],
#  ['떡크(elan****)',
#   '흠 잡을 데 없는 완벽한 영화는 아니었지만, 흠 잡고 싶지 않을 만큼 감동적인 영화였습니다.',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 5, 19, 21, 19),
#   '관람객'],
#  ['a451****',
#   '너무 제미가 있었고 마지막 장면은 마음이 짠',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 5, 15, 7, 39),
#   '관람객'],
#  ['김민재(mjki****)',
#   '내가 본 마블영화중 최고의영화라생각한다.',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 5, 6, 6, 36),
#   0],
#  ['케빈 가넷(dlck****)',
#   '집결씬에서 지렸다 이건 10점으로 부족해',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 5, 5, 23, 59),
#   0],
#  ['문기(gye1****)',
#   '잘가요 어벤져스 그동안 고생했어요',
#   '9',
#   '10',
#   '1',
#   datetime.datetime(2020, 5, 1, 19, 7),
#   '관람객'],
#  ['당초망(joyc****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '9',
#   '10',
#   '1',
#   datetime.datetime(2019, 6, 9, 23, 59),
#   0],
#  ['닉네임없어요(wg90****)',
#   '재미 없다는 분들은 마블영화 안본거 많으신 분일듯 다 보신 분이라면 재미 없을수가 없는데 정말 지금까지 꾸준히 봐 온 마블팬들을 위한 영화였습니다.',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2019, 4, 28, 22, 20),
#   0],
#  ['주기자(mama****)',
#   '앤딩이라 먼가 액션보다 스토리 중심아쉽',
#   '8',
#   '14',
#   '5',
#   datetime.datetime(2019, 4, 30, 8, 3),
#   0],
#  ['아이스크림맨(arse****)',
#   '결말도 깔끔했고 이야기 구성도 좋았는데 이걸 3시간으로 풀어낼 이야기는 아니었음짧은 스토리를 길게 풀어내다보니 살짝 루즈해지는 구간이 3번 정도 있었음3시간짜리 영화중에 지루하지 않았던 영화는 반지의 제왕이랑 해리포...',
#   '7',
#   '15',
#   '6',
#   datetime.datetime(2019, 5, 7, 19, 51),
#   0],
#  ['습근평동지만수무강(jhwa****)',
#   '0점은없나?하..솔찍히 5점인데 어벤져스라 7점 주러왔는데 평점과장보고 0점주고싶다. 왜 이러는거임? 사실 스토리 특별한부분 없잖아? 흔한 시간여행에 팀내배신, 마무리 싸움 게다가 히어로 살아났을거라 생각하고 곧 나...',
#   '1',
#   '17',
#   '8',
#   datetime.datetime(2019, 4, 30, 12, 10),
#   0],
#  ['yeyehanhan(newh****)',
#   '캡틴 마블은 억지로 끼원 넣은 듯한 느낌. 이거 빼고는 더할 나위 없는 엔딩',
#   '9',
#   '22',
#   '13',
#   datetime.datetime(2019, 4, 26, 17, 12),
#   0],
#  ['나락(usp7****)',
#   '내가 너무 큰 기대를 한탓일까 물론 그동안의 마블 유니버스를 집대성 하기위해 상당히 고민한 흔적이 영화에서 보였는데 개인적으로 좀 과한 부분도 있는듯 했음 그래도 마블팬이라면 찡한 장면도 있고 3시간은 순삭 당했음',
#   '7',
#   '44',
#   '35',
#   datetime.datetime(2019, 4, 24, 13, 41),
#   0],
#  ['오이(jo49****)',
#   '재미는 있었으나 모든 캐릭터가 붕괴하는 모습에 화가난다',
#   '6',
#   '51',
#   '42',
#   datetime.datetime(2019, 4, 24, 14, 43),
#   0],
#  ['yyy(yyyy****)',
#   '진짜 이 영화는 21세기의 마블이라는 장르를 완벽하게 긑내는 최고의 영화입니다.',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2020, 5, 8, 17, 59),
#   0],
#  ['Dybala(ghth****)',
#   '최고더이상 무슨말이 필요할까요',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 9, 14, 22, 27),
#   '관람객'],
#  ['그림자따라걷기(fogn****)',
#   '엔드게임, 오래 기억될 명작',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 8, 19, 15, 15),
#   '관람객'],
#  ['mith****',
#   '인생영화 2번봐도 안아깝습니다',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 8, 12, 21, 24),
#   '관람객'],
#  ['강스컬(dndr****)',
#   '11년 간 즐거웠어요, 토니.',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 7, 7, 3, 7),
#   '관람객'],
#  ['pny2****',
#   '재밌었어요재밌는데재밌엇어요',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 6, 19, 10, 54),
#   '관람객'],
#  ['dodo****',
#   '나의 어벤져스 나의 아이언맨 잘가요 그동안 정말 고마웠어요ㅜㅜ',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 6, 2, 5, 19),
#   '관람객'],
#  ['루시퍼(kluc****)',
#   '재미도 있고 감동도 있고 많이 슬퍼요 ㅠㅠ',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 5, 19, 12, 36),
#   '관람객'],
#  ['ㅋㅋㅋ(lse8****)',
#   "I'm Ironman.",
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 5, 2, 22, 5),
#   '관람객'],
#  ['바둑(dfjj****)',
#   '아이언맨 그는 위대한 히어로였습니다..',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 4, 29, 12, 36),
#   0],
#  ['shal****',
#   '재미있다아',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2020, 5, 11, 17, 30),
#   '관람객'],
#  ['이윤호(tvyu****)',
#   'ㅋㅋㅋㅋ 개봉하자마자 본 인생영화인데 엔드게임 개연성 없다는 놈들은 영화 보지 마라 ㅋㅋ영화를 뭘로 보는거냐. 떡밥회수까지 완벽했는데..영화를 뭘로 보면 엔드게임이 개연성이 없다는건데',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2020, 5, 3, 9, 36),
#   0],
#  ['허원(hw40****)',
#   'vian ↓↓ 그럼 왜 봐ㅋ',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2020, 5, 2, 22, 6),
#   0],
#  ['ㅍㅍ(yeon****)',
#   '역시 마블 대박입니다 후반부 액션 대박이에영 소름돋음 웃음포인트도 있고 재밌어요',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2020, 5, 1, 15, 55),
#   '관람객'],
#  ['빡꾸(hssy****)',
#   '역시 마블이라는 말밖에  나는 아이언맨도 좋지만 캡아가 왤케 좋은지 ㅋㅋ',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 6, 10, 14, 10),
#   '관람객'],
#  ['jj(miff****)',
#   '11년 감사했어요 별점 남기고 싶어 리플 답니다',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 5, 17, 3, 53),
#   0],
#  ['저기압고기앞(smy5****)',
#   '3시간이 1시간같다 근데 너무 기대해서 아쉽더라',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 4, 24, 15, 2),
#   '관람객'],
#  ['yaj(yaj3****)',
#   "아니 재미없다고 하는건 개인취향이 다르니까 그럴  수 있는데 '유치하네 초딩들이 좋아하겠네', '유치한ㅂㅅ들이 좋아하겠네' 하는 사람들 진짜 꺼졌으면 좋겠다. 우리부모님도 이거 좋아하는데...",
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2020, 4, 15, 1, 19),
#   0],
#  ['슈퍼공돌이(hiso****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '9',
#   '10',
#   '2',
#   datetime.datetime(2020, 1, 13, 0, 56),
#   0],
#  ['싱숭생숭(rlag****)',
#   '최고의 결말. 최고의 히어로 영화.내 젊은 시절을 어벤져스와 함께할수있어 행복했다.',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2019, 4, 26, 2, 6),
#   0],
#  ['우울과몽상(tota****)',
#   '정말 감동과 슬픔이 가득한 최고의 영화였습니다.',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2019, 4, 25, 19, 47),
#   0],
#  ['hsgg****',
#   '참..마블에 마자도 모르는 사람들이 평소 잘 보지도 않다가 엔드게임만 보고 이해도 못하고 재미없다 어쩐다 불평하는 거 보면 참 안타깝다.. 그냥 님들이 동시대 영화의 큰 흐름이자 유행 중 하나를 못탄거고 그래서 못느...',
#   '10',
#   '11',
#   '3',
#   datetime.datetime(2019, 5, 6, 7, 5),
#   0],
#  ['Lukee(xpws****)',
# ...
#  ['ungiue(xiao****)',
#   '마지막이라서 아쉽지만 그동안 영화에 대한 기대감과 설레임을 만들어 준 마블에 감사인사를 하고 싶다. 판타지 액션영화이지만 언제봐도 멋있고 감동이여서 평생기억에 남을겁니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 17, 15, 51),
#   '관람객'],
#  ['피렌체(kym2****)',
#   '엄청 재미있게 봤슴 레알~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 17, 15, 46),
#   '관람객'],
#  ['제미크리(gemi****)',
#   '이보다 더 완벽한 시나리오와 스타일을 만들어낼 영화가 있을까?',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 17, 14, 43),
#   0],
#  ['빈이(bin1****)',
#   '거의 끝물에 극장가서 봤는데, 안봤으면 죽을때까지 후회할뻔 했다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 17, 3, 49),
#   0],
#  ['navycvf(indi****)',
#   '후유증이 쉽게 안사라지네',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 15, 16, 54),
#   0],
#  ['리밥ful(lch1****)',
#   '내어린시절부터 함께한 아이언맨의 완벽한퇴장...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 15, 6, 23),
#   0],
#  ['jmj1****',
#   '10년의 대장정.. 나의 청춘과 함께 행복했다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 14, 21, 35),
#   '관람객'],
#  ['seon****',
#   '역쉬~~~라는게 절로 나오는 영화였어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 13, 16, 1),
#   '관람객'],
#  ['엄형(ever****)',
#   '기성세대도 매력을 느끼는',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 13, 15, 21),
#   0],
#  ['jpudding(j_pu****)',
#   "Cap, it's Sam. Can you hear me? On you r left.",
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 13, 12, 10),
#   '관람객'],
#  ['XOXO(shin****)',
#   '재밌네요. 어벤져스가 늘 그렇듯이.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 12, 23, 20),
#   '관람객'],
#  ['성지홍(buki****)',
#   '난 아직도 자기전에 포탈씬에서 달려가는 게 생각난다.마블 3000만큼 사랑한다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 12, 22, 53),
#   0],
#  ['momo****',
#   '마블 패밀리와 팬들에게 보내는 아름다운 헌사',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 12, 14, 56),
#   '관람객'],
#  ['wwekd(adda****)',
#   '두번봐따... 사랑해 삼천만큼',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 12, 13, 41),
#   '관람객'],
#  ['Blah(scro****)',
#   '3회차까지 관람했습니다. 첨에 토니 구출되고 우리들의 자유를 포기하고 지키려고 했던건데 너는 함께지키자고 해놓고 필요할땐 없었다. (대충이랬던거같은데)뭐 이런 대사치면서 캡틴한테 화내는 장면. 로다주 연기력에 감탄....',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 12, 9, 3),
#   0],
#  ['피쓰(ilaw****)',
#   '아임 아이언맨...ㅜㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 10, 27),
#   0],
#  ['동화(wjdr****)',
#   '역시 어벤져스입니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 9, 19),
#   '관람객'],
#  ['바람같물이되장작인(tend****)',
#   '3000사랑해, 나는 아이언맨',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 6, 5),
#   '관람객'],
#  ['멋쟁이(kkuk****)',
#   '당신들이 있어서 지난 10여년간 행복했습니다.Thank you. Thor. Thank you. Cap. Thank you. Tony..',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 4, 56),
#   0],
#  ['rla9****',
#   '3000만큼사랑합니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 2, 26),
#   '관람객'],
#  ['iss2****',
#   '내 20대를 함께했다 마블 감사합니다 너무 즐거웠어요 후속도 쭉쭉 기대~~~~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 2, 3),
#   0],
#  ['숀(huma****)',
#   '두번 보면 두번 울꺼에요',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 9, 0, 30),
#   '관람객'],
#  ['이동욱(jung****)',
#   '개연성이나 이야기를 풀어가는게 2프로 아쉽긴 했지만 어벤져스의 마무리를 나름 멋지게 했다고 생각합니당^^',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 8, 22, 34),
#   0],
#  ['Robin(robi****)',
#   '감동의 피날레였어..',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 7, 23, 23),
#   '관람객'],
#  ['품위있게(deer****)',
#   '정말 감동적인 영화 입니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 7, 23, 14),
#   0],
#  ['rosebaek(h251****)',
#   '너무 슬퍼서 대성통곡했어요 ㅠ 너무 재미있었습니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 7, 22, 45),
#   '관람객'],
#  ['fajijaf(ber3****)',
#   '토니 이제 쉬어도돼...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 7, 22, 14),
#   0],
#  ['Rascal(600g****)',
#   '마지막 엔딩 크레딧 원년멤버들 사인나올때 ㅂㄹ떨리면서 울었다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 7, 21, 57),
#   0],
#  ['엘뚜뚜(sjs0****)',
#   '와 대단해요   이런영화는 없었다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 6, 20, 47),
#   0],
#  ['김영서(pure****)',
#   '영화가 더 길었음해서 전투신이 특히 더더더 길었음 좋겠다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 5, 18, 25),
#   0],
#  ['최연복(chld****)',
#   '너무 재밋엇어요 세상에 블팬나올때 소름',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 5, 14, 11),
#   '관람객'],
#  ['iridescent(jung****)',
#   '끝이란 생각에 자꾸 눈물이 났다.. 이제 모두들 행복하길',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 4, 22, 28),
#   0],
#  ['김태희(xogm****)',
#   '이거 보고 울 줄은 생각도 못 했다...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 4, 17, 35),
#   0],
#  ['J helen(here****)',
#   '어벤져스 엔드게임 와 스케일이 장난아닙니다~~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 4, 11, 14),
#   '관람객'],
#  ['crox****',
#   '아....ㅜㅜ 씨 난 3000보다 더 사랑한다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 4, 11, 12),
#   0],
#  ['지수현(sooh****)',
#   '다섯번봄.ㅋ. .ㅋ...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 4, 8, 10),
#   '관람객'],
#  ['훈자씨(venu****)',
#   '마블~ 정주행중입니다ㅎ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 23, 41),
#   '관람객'],
#  ['이연희(renk****)',
#   '아이언맨 재미있었습니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 23, 31),
#   '관람객'],
#  ['루미드(kims****)',
#   '너무 재밌습니다. 근데  이전 마블시리즈를 봐야 더 이해하기가 좋을 것같아요ㅜ ㅇ ㅜ 인피니티워, 가디언즈  다시 봤어요 ㅎ',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 22, 40),
#   '관람객'],
#  ['capboy(caps****)',
#   'I am groot...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 22, 30),
#   0],
#  ['백룡세탁(3dyg****)',
#   '여러가지 시퀀스들의 재접목! 화려하고 깔끔하다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 22, 11),
#   0],
#  ['잇힝(parr****)',
#   '시리즈의 훌륭한 마지막',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 20, 55),
#   '관람객'],
#  ['유심(youj****)',
#   '완벽한 마무리 좋았어요~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 20, 1),
#   '관람객'],
#  ['TJ(beam****)',
#   '아이언맨 3000만큼 사랑해ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 15, 46),
#   0],
#  ['은지(mini****)',
#   '완전 재밌어요 또 볼거에여ㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 14, 32),
#   '관람객'],
#  ['미노루(punx****)',
#   '마블은 사랑입니다.♡',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 13, 27),
#   '관람객'],
#  ['사발짱구(babo****)',
#   '너무 재미나게 봤어요~^^',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 11, 2),
#   '관람객'],
#  ['쿠쿠(sinm****)',
#   '마블영화는 언제나 재미있다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 10, 8),
#   '관람객'],
#  ['love****',
#   '11년의 기다림을 멋있게 마무리해주는 훌륭한영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 9, 56),
#   '관람객'],
#  ['이월이(ahni****)',
#   '증말 잼있어요 빵빵~~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 8, 37),
#   '관람객'],
#  ['Asimov(dhby****)',
#   '인생마저도 돌아보게만드는 오락영화같지않은 최고의 오락영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 8, 36),
#   0],
#  ['shhy****',
#   '10년의 여정을 함께해준 팬들에 대한 헌사와 장엄한 마무리. 다음여정도 믿어본다',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 4, 40),
#   '관람객'],
#  ['요피(o3o_****)',
#   '인피니티사가의 피날레',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 4, 1),
#   '관람객'],
#  ['heu0****',
#   '캡아와 아이언맨을 말그대로 히어로로 만들어줘서 마블이 얼마나 그들을 애정하는지 알 수 있었어요. 다른 캐릭터들도 개성넘치고 멋있습니다. 마블 캐릭터를 생생하게 연기해준 배우들과 제작진들 모두 3000만큼 사랑합니다....',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 3, 3, 53),
#   '관람객'],
#  ['해외축구부장판사(1670****)',
#   '지금까지 내인생 최고의 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 20, 59),
#   0],
#  ['장태영(jade****)',
#   'I am ironman Avengers assemble!!Proof that Tony has a heartI love you 3000 10년의 시간은 무의미하지 않았습니다...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 12, 13),
#   0],
#  ['yaee****',
#   '3000만큼 사랑해~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 11, 59),
#   '관람객'],
#  ['꽃유댕(lsy8****)',
#   '또 보고싶다는!!! 꾸르잼',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 11, 6),
#   '관람객'],
#  ['shi(shin****)',
#   '토니에게 따듯한 심장이 있다는 증거....',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 9, 38),
#   0],
#  ['JM(kjmn****)',
#   '이제는 뭐가 나올련지....',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 7, 2),
#   '관람객'],
#  ['사브리나(sabr****)',
#   '밤10시20분 영화였는데 아직도 전석 매진!하..믿기지 않는 스토리',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 3, 59),
#   0],
#  ['프리이니(free****)',
#   '10년간 쭉 봐온 팬들에 대한 선물. 이렇게 만족스러울순 없다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 3, 41),
#   0],
#  ['울락불락(ohja****)',
#   '그립다캡틴 위도우, ,',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 6, 2, 1, 27),
#   '관람객'],
#  ['우미(dnal****)',
#   '마블 3000만큼 사랑합니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 31, 14, 4),
#   '관람객'],
#  ['feateon(feat****)',
#   '9살 아이도 재밌게 봤어요~ 스파이더맨도 기대됩니다. ^^',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 31, 9, 23),
#   '관람객'],
#  ['리얼니쥬(real****)',
#   '마블시리즈 몰아보고 가서 더 몰입함 ㅠㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 31, 9, 10),
#   '관람객'],
#  ['바나나라떼(hydf****)',
#   '하..마지막 너무 슬픈듯 ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 31, 8, 16),
#   0],
#  ['홍수연(hsy3****)',
#   '손으로 입막고 오열했다,,,',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 30, 1, 37),
#   0],
#  ['zz(5p_u****)',
#   '점옥씨랑 춘녀씨랑 같이 보았읍니다. 엑션 영화는 처음이지만 재미있었던 것 같았네요.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 22, 42),
#   '관람객'],
#  ['그뤠잇터(pssh****)',
#   '재미대가리 없는 아바타 흥행기록좀 제발 깨자',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 21, 16),
#   0],
#  ['엠마(deep****)',
#   '재밌었어요 인생 까지는 아니지만 ㅋㅋ 나름 즐겁게 봄',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 20, 9),
#   '관람객'],
#  ['리용(wipp****)',
#   '넘 좋았어요. 최고여요.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 19, 50),
#   '관람객'],
#  ['KK(bkkg****)',
#   '마지막 전투신이 좀 짧아서 아쉬웠지만..',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 0, 36),
#   0],
#  ['안녕하쩨염(zzrl****)',
#   '3000만큼 감동이였다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 29, 0, 0),
#   '관람객'],
#  ['ㅇㅣㅇ(auro****)',
#   '유년시절부터 평생을 함께해온 아이언맨..당신을 3000만큼사랑합니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 28, 23, 37),
#   '관람객'],
#  ['김안석(asgg****)',
#   '21세기 동시대 최고의 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 28, 21, 14),
#   '관람객'],
#  ['titl****',
#   '진짜 눈이 호강하네 ㅠ 최고다 ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 28, 3, 20),
#   0],
#  ['찐원(jinw****)',
#   '3000만큼 사랑해와 치즈버거 감동이다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 11, 57),
#   '관람객'],
#  ['레슬링의신(zxzx****)',
#   '3번봤는데.. 질리지않더라  어벤져스 어셈블.. 그거 들으려고 4년간 기다렸던 거였구나 .. 어벤져스는 이제 떠났지만 그들의 의지는 다음페이지 히어로들이 계승하고 이어갈것이다.. 3000만큼 사랑했습니다 앞으로는 6...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 9, 51),
#   '관람객'],
#  ['딴따벨라(kiki****)',
#   '엔드게임 최고 두번 봐도 재밋네요 ^^',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 9, 47),
#   '관람객'],
#  ['진붕이(semp****)',
#   '믿고보는 마블입니당 최고최고',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 9, 43),
#   '관람객'],
#  ['현니(shgu****)',
#   '처음으로 극장에서 3번 본 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 7, 10),
#   0],
#  ['산마루(anim****)',
#   '치즈버거 주세요 ...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 3, 51),
#   '관람객'],
#  ['chwn****',
#   '자연스럽다! 어벤져스 3.4의 놀라운점은 캐릭터의 능력에 따라 역할분배를 기가막히게 잘한다는점!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 2, 55),
#   0],
#  ['곽정원(kjw4****)',
#   '이만큼 많이 운 영화는 처음임...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 27, 2, 13),
#   0],
#  ['CFP(tkdd****)',
#   '그냥 봐도 재밌지만, 이전 마블 영화들을 다 보고 엔드게임을 보길 추천함. 이전 영화들 내용을 이해하고 있어야 엔드게임이 의도하는 감동을 온전히 느낄 수 있을 것 같다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 26, 23, 13),
#   0],
#  ['The Music(wcn0****)',
#   '최근에 10년 가까이 봐왔던 드라마가 마지막시즌에 막장으로 끝나버려서... 어벤져스는 그러지 않아서 감사합니다 ㅜㅜ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 26, 1, 35),
#   '관람객'],
#  ['뚜뚜(did7****)',
#   '난 아이언맨이다 할때 진짜 눈물주룩ㅜㅜ마블 3000만큼 사랑합니다!!!!어벤져스 어셈블!!!정말 사랑합니다ㅜㅜㅜ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 26, 0, 29),
#   '관람객'],
#  ['여인의 향기(hs76****)',
#   '3000천만큼사랑해~~♡♡',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 16, 3),
#   0],
#  ['Kang17(imsm****)',
#   '"자...로키가 어디 있습니까?" "죽었잔어" "끝인가..?ㅠㅠ"',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 7, 39),
#   0],
#  ['송재민(ma88****)',
#   '말이필요없죠 미국에서또봄',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 3, 47),
#   0],
#  ['디디헤(dddy****)',
#   '잘가요 아이언맨 그동안 고마웠어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 3, 37),
#   0],
#  ['cybe****',
#   '혼자가서 봤는데 시간가는 줄 몰랐어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 3, 25),
#   '관람객'],
#  ['룽루(wjda****)',
#   '너무 재밌었어요,,기대이상입니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 3, 10),
#   '관람객'],
#  ['tjdw****',
#   '어벤져스 최고의 영화입니다!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 2, 28),
#   0],
#  ['빛나리(ross****)',
#   'Thanks, Marvel',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 2, 22),
#   0],
#  ['이소연(viui****)',
#   '진짜 강추..너무재밌어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 1, 40),
#   0],
#  ['쭈(sprt****)',
#   '진짜 최고!!  내가sf영화 보면서  울꺼라고는...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 1, 8),
#   0],
#  ['권민혜(haey****)',
#   '뒤늦게 덕후됐어요 ㅠㅜㅜ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 0, 15),
#   0],
#  ['hjk5****',
#   '굿잡 3000만큼 사랑합니당',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 25, 0, 8),
#   '관람객'],
#  ['뽕썬우린하나(kare****)',
#   '다시 보고 싶은 영화!!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 23, 46),
#   '관람객'],
#  ['정백수(jhj7****)',
#   '처음 보면 타노스 정말 나빠보이는데 두번째보면 결과를 알아섯 그런지 타노스 불쌍해보여요ㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 14, 56),
#   '관람객'],
#  ['Huang Shuqian(sook****)',
#   '3000만큼 사랑합니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 1, 43),
#   '관람객'],
#  ['성찬우(cksd****)',
#   '그냥 말이 필요없습니다ㅋㅋ  and I.. am.. Ironman',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 0, 30),
#   '관람객'],
#  ['ehgn****',
#   '마지막 한시간은 진짜...ㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 0, 23),
#   '관람객'],
#  ['임과장(yimc****)',
#   '정말 재미있게 잘 봤고  ..  다음은 파 프롬 홈 차례다!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 24, 0, 7),
#   0],
#  ['두산v6(mbc-****)',
#   '3000만큼 사랑해!어밴져스',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 23, 57),
#   0],
#  ['박무승(dumb****)',
#   '당장 이서버를 떠나라 그렇지 않으면 집에 찾아가 스톰브레이커로 때려팰거야',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 23, 50),
#   0],
#  ['쥰군찬양(sj17****)',
#   '3000만큼 사랑하구요 어벤져스 어셈블!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 23, 30),
#   0],
#  ['ehso****',
#   '이지혜 평론가님은 뭘 어떻게 영화를 보셧길래 6점을 줄수가 있나요;;',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 22, 7),
#   0],
#  ['목화(eve_****)',
#   '잘 봤어요. 볼 수 있다는 것은 정말 가치있는 것이지요.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 13, 59),
#   '관람객'],
#  ['모슬(aigu****)',
#   '마지막 인사 잘 받았습니다 고마워요 행복했어요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 5, 54),
#   0],
#  ['이창선(chan****)',
#   '나와 같이 늙어가는 영웅들과 마지막까지 함께해서 즐거웠다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 1, 40),
#   0],
#  ['마나부(pure****)',
#   '내20대를 보낸영화 재밋엇다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 1, 6),
#   0],
#  ['술여자담배침대(kikk****)',
#   '처음 봤었는데 와..눈물이 갑자기 나오더라고요 죽었던 멤버들 나올때',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 23, 0, 48),
#   '관람객'],
#  ['신재혁(asas****)',
#   '3000만큼 사랑해 마블',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 20, 14),
#   '관람객'],
#  ['jiwoni(jwyo****)',
#   '엔드게임 명대사 :난 아이언맨 이다!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 20, 11),
#   '관람객'],
#  ['eoy0****',
#   '말해 뭐할까요 .. 정주행 갈 예정입니다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 18, 49),
#   '관람객'],
#  ['jung(selv****)',
#   '흠~~잼나게봤네요~~^~~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 18, 1),
#   '관람객'],
#  ['col(colo****)',
#   "영화 재밌습니다 '♡♤☆♧",
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 18, 1),
#   0],
#  ['밝은주석(ggab****)',
#   '재미보다 아쉽고 슬픔이 더 큰 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 17, 45),
#   '관람객'],
#  ['생생우동(fire****)',
#   '아용맨...잘가요 ㅠㅠㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 17, 43),
#   0],
#  ['벼락천사(meca****)',
#   '시리즈의 처음부터 끝까지 걍~굿~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 10, 1),
#   '관람객'],
#  ['촌닭(nans****)',
#   '마블팬에겐 최고의선물',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 9, 3),
#   0],
#  ['DNA(aige****)',
#   '3000만큼 사랑해 어벤져스',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 7, 54),
#   0],
#  ['한상우(hans****)',
#   'I love you 3000',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 6, 50),
#   0],
#  ['산타페(hsmi****)',
#   '고생들 했어. 정말 끝이네... 고마웠다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 5, 48),
#   0],
#  ['무소피나는꽃(gusa****)',
#   '넌 감동이였어 ....ㅠㅠㅠㅠ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 22, 4, 52),
#   '관람객'],
#  ['별빛호야(hoya****)',
#   '최고입니다 최고~~~ 말이 필요없음',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 21, 23, 54),
#   0],
#  ['blac****',
#   'ㅜ 우리세대의 히어로가 가는구나ㅜ',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2019, 5, 21, 23, 49),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                        0  ...    6
# 0          전은호(eunh****)  ...    0
# 1            송(hiuh****)  ...    0
# 2        ubola(ubol****)  ...    0
# 3         해피사과(qord****)  ...  관람객
# 4           마즈(choi****)  ...    0
# ...                  ...  ...  ...
# 4995            sjja****  ...    0
# 4996        공백(rlae****)  ...  관람객
# 4997        경수(jing****)  ...    0
# 4998        뉴뉴(dbwl****)  ...    0
# 4999  Goretzka(junh****)  ...    0
#
# [5000 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                 nickname  ... watch_movie
# 0          전은호(eunh****)  ...           0
# 1            송(hiuh****)  ...           0
# 2        ubola(ubol****)  ...           0
# 3         해피사과(qord****)  ...         관람객
# 4           마즈(choi****)  ...           0
# ...                  ...  ...         ...
# 4995            sjja****  ...           0
# 4996        공백(rlae****)  ...         관람객
# 4997        경수(jing****)  ...           0
# 4998        뉴뉴(dbwl****)  ...           0
# 4999  Goretzka(junh****)  ...           0
#
# [5000 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
