# %% [markdown]
# <a href="https://colab.research.google.com/github/namyoon95/KIMNAMYOON_201500327/blob/main/%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91(%EB%A7%88%EB%B8%94_%EC%96%B4%EB%B0%B4%EC%A0%B8%EC%8A%A4_%EC%97%90%EC%9D%B4%EC%A7%80%EC%98%A4%EB%B8%8C%EC%9A%B8%ED%8A%B8%EB%A1%A0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=98438
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&onlyActualPointYn=Y&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 98438
total_count = 5000  ## 전체 크기=5112

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=251
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=418
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=419
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=420
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=421
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=422
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=423
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=424
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=425
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=426
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=427
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=428
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=429
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=430
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=431
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=432
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=433
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=434
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=435
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=436
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=437
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=438
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=439
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=440
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=441
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=442
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=443
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=444
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=445
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=446
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=447
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=448
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=449
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=450
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=451
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=452
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=453
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=454
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=455
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=456
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=457
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=458
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=459
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=460
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=461
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=462
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=463
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=464
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=465
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=466
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=467
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=468
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=469
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=470
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=471
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=472
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=473
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=474
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=475
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=476
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=477
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=478
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=479
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=480
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=481
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=482
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=483
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=484
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=485
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=486
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=487
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=488
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=489
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=490
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=491
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=492
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=493
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=494
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=495
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=496
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=497
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=498
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=499
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=98438&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=500

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 98438
total_count = 5000  ## 전체 크기=5112

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['유유(foxm****)',
#   '한국사람들 급해서 마지막 최고 정점을 못보고 막 나감 ㅜ 왜그래요..ㅜㅜ',
#   '10',
#   '5542',
#   '802',
#   datetime.datetime(2015, 4, 23, 1, 24),
#   0],
#  ['별이(ilu3****)',
#   '하 1편이 잘되면 2편은 망한다더니... 누가 그래 이 영화는 미쳤어',
#   '10',
#   '3450',
#   '1015',
#   datetime.datetime(2015, 4, 23, 0, 54),
#   0],
#  ['비토다츠야(outs****)',
#   '충무로에서 몇년간 조폭얘기나 끄적일때 헐리웃은 악당조차 업그레이드 된다.',
#   '9',
#   '2817',
#   '455',
#   datetime.datetime(2015, 4, 23, 10, 38),
#   0],
#  ['fbi0****',
#   '나어릴적 아빠와우뢰매보러구 줄섰는데 세월은흘러 내따내미와 어벤져스보러줄을섭니다 TT',
#   '10',
#   '2594',
#   '441',
#   datetime.datetime(2015, 4, 23, 8, 25),
#   0],
#  ['장난하냐(cgs0****)',
#   '내가 영화관에서 한국영화를 안보는 이유',
#   '10',
#   '2369',
#   '733',
#   datetime.datetime(2015, 4, 23, 2, 5),
#   0],
#  ['dbtl****',
#   '오늘 시사회다녀와서 생전처음으로 평점남깁니다. 긴말말고 걍 가서 보세요',
#   '10',
#   '2003',
#   '551',
#   datetime.datetime(2015, 4, 23, 0, 45),
#   0],
#  ['Ilpleutsurlaroute(dker****)',
#   '어벤져스 제목만 들어도 설렌다',
#   '10',
#   '1755',
#   '324',
#   datetime.datetime(2015, 4, 23, 0, 0),
#   0],
#  ['꾼쟁이(feel****)',
#   '한동안 놀림 받겠군....',
#   '9',
#   '1428',
#   '212',
#   datetime.datetime(2015, 4, 23, 11, 2),
#   '관람객'],
#  ['RHJ(pros****)',
#   '스케일은 1못지않게 컸지만 더 추가된 등장인물들과 밸런스나 영화의흐름들이 조금 실망이었습니다 조금 어수선한면들이 많았고 마지막 극의 후반까지 긴장감을 쭉 가져가는 것이 조금 부족 했습니다, 너무 한번에 많은 것을 보...',
#   '6',
#   '2067',
#   '1039',
#   datetime.datetime(2015, 4, 23, 13, 12),
#   '관람객'],
#  ['준호(june****)',
#   '전체적으로 무거워 졌지만 볼거리도 충분했고 히어로들은 능력과 개성은 잘 살려주었다.',
#   '10',
#   '1197',
#   '238',
#   datetime.datetime(2015, 4, 23, 8, 23),
#   0],
#  ['lzxe****',
#   '마지막 장면 꼭 보고 가십시오 ㅋㅋㅋ',
#   '10',
#   '1030',
#   '160',
#   datetime.datetime(2015, 4, 23, 11, 7),
#   '관람객'],
#  ['quantum(ropk****)',
#   '편집에서 약간 아쉬운 감이 있다. 한국이 생각보다 많이 나와 반갑더라.',
#   '7',
#   '972',
#   '257',
#   datetime.datetime(2015, 4, 23, 11, 26),
#   '관람객'],
#  ['hysaran(aran****)',
#   '서울ㅋㅋ서울 나오는 장면에서 웃음이 피식 나는ㅋㅋㅋㅋ',
#   '10',
#   '740',
#   '67',
#   datetime.datetime(2015, 4, 23, 19, 4),
#   '관람객'],
#  ['이승호(tmdg****)',
#   '이제 시빌워가 기대된다.극 초반에 단체로 등장할 때 소름 쫙.',
#   '9',
#   '678',
#   '96',
#   datetime.datetime(2015, 4, 23, 13, 38),
#   '관람객'],
#  ['가오나시(phj9****)',
#   '요즘 남자들도 에코백 하나씩은 들잖아요 팬티 꼭챙겨가;',
#   '10',
#   '914',
#   '357',
#   datetime.datetime(2015, 4, 23, 0, 16),
#   0],
#  ['TopEames(thsg****)',
#   '어머니 시험망했어요..',
#   '10',
#   '643',
#   '106',
#   datetime.datetime(2015, 4, 23, 7, 3),
#   0],
#  ['BIZARRE(pyb0****)',
#   '퀵실버는 역시 엑스맨의 퀵실버가 더 낫네요.',
#   '8',
#   '671',
#   '144',
#   datetime.datetime(2015, 4, 23, 15, 12),
#   '관람객'],
#  ['마운(moun****)',
#   '이건 뭐 저리 많은 캐릭터들을 어떻게 이렇게 살리는지..',
#   '10',
#   '551',
#   '81',
#   datetime.datetime(2015, 4, 23, 11, 2),
#   0],
#  ['시안테(bloo****)',
#   '남자는 등으로 말한다..마블 세계관을 조금이라도 알고 봐야 재미가 배가 되리라고 생각합니다',
#   '10',
#   '580',
#   '146',
#   datetime.datetime(2015, 4, 23, 10, 24),
#   '관람객'],
#  ['한 방에 끝내(hae1****)',
#   '한국 생각보다 구리게 나와ㅜ',
#   '7',
#   '522',
#   '143',
#   datetime.datetime(2015, 4, 23, 14, 20),
#   0],
#  ['min8****',
#   '재미있는데 서울이 무슨 시골처럼 나와서 좀 아쉽다는..',
#   '9',
#   '426',
#   '71',
#   datetime.datetime(2015, 4, 25, 8, 33),
#   '관람객'],
#  ['영감탱구(asur****)',
#   '헐크버스터 씬에서 지렸다',
#   '10',
#   '369',
#   '55',
#   datetime.datetime(2015, 4, 23, 13, 56),
#   0],
#  ['gmld****',
#   '기대 많이했는데 좀 지루했어요...',
#   '6',
#   '710',
#   '403',
#   datetime.datetime(2015, 4, 23, 12, 33),
#   '관람객'],
#  ['youm****',
#   '지루함..스토리 전게에 핵심이 미약함...',
#   '7',
#   '802',
#   '509',
#   datetime.datetime(2015, 4, 23, 13, 56),
#   '관람객'],
#  ['엉짱(w76j****)',
#   '어제아이맥스3D로 사사회더녀왔는데 3D효과도 좋고...무엇보다 유머코드도 너무웃겼네요  언능가서보시길',
#   '10',
#   '384',
#   '123',
#   datetime.datetime(2015, 4, 23, 7, 50),
#   0],
#  ['피부멘토HOONZ(hoon****)',
#   '생각보다 수현도 많이 나오고 액션장면이 많아 즐거웠습니다.',
#   '10',
#   '312',
#   '88',
#   datetime.datetime(2015, 4, 23, 14, 48),
#   '관람객'],
#  ['봉쓰(hoy4****)',
#   '기절해 기절해 기절해 기절해 기절해',
#   '10',
#   '248',
#   '51',
#   datetime.datetime(2015, 4, 23, 15, 0),
#   0],
#  ['alls****',
#   '기대는 많이하지 마세요~',
#   '8',
#   '408',
#   '212',
#   datetime.datetime(2015, 4, 23, 18, 7),
#   '관람객'],
#  ['song****',
#   '내 인생에서 어벤져스라는 영화를 볼 수있어서 정말 좋다...',
#   '10',
#   '283',
#   '89',
#   datetime.datetime(2015, 4, 23, 11, 3),
#   0],
#  ['슈퍼맨이되고싶은여자(awoo****)',
#   '액션과 볼거리는 화려한데 보는내내 지치네요..초반은 재밌게봤는데....러브라인은 왜넣은건지 모르겠고 좀 정신도 사납고 .중반에는 루즈해서 졸뻔했어요..;딱 7점짜리 영화라고생각합니다.',
#   '7',
#   '331',
#   '140',
#   datetime.datetime(2015, 4, 23, 17, 15),
#   0],
#  ['ray0****',
#   '가히 올해 최고의 작품이라 생각된다... 예상으로 1200만 명이 관람할 것이라는 추측을 해본다..',
#   '10',
#   '424',
#   '250',
#   datetime.datetime(2015, 4, 23, 1, 46),
#   0],
#  ['yuwo****',
#   '마지막 타노스 개쩜 ㅎㅎ 비젼도 졸멋',
#   '10',
#   '273',
#   '101',
#   datetime.datetime(2015, 4, 23, 12, 41),
#   '관람객'],
#  ['행쇼(gudr****)',
#   '작품성 운운하지 말자.. 어벤져스 그 자체만으로도 화려하다!',
#   '10',
#   '278',
#   '130',
#   datetime.datetime(2015, 4, 23, 5, 48),
#   0],
#  ['cdch****',
#   '생각보다 별로ㅠㅠ너무기대했나보다',
#   '7',
#   '270',
#   '141',
#   datetime.datetime(2015, 4, 23, 21, 7),
#   '관람객'],
#  ['에피쏘드(zkdl****)',
#   '기대했던만큼 역시재미있네~',
#   '10',
#   '259',
#   '133',
#   datetime.datetime(2015, 4, 23, 10, 56),
#   '관람객'],
#  ['망고개미(skwo****)',
#   'DC영화보다 마블영화가 대단한 이유는 캐릭터들의 능력 밸런스가 절묘하다는 거다..',
#   '10',
#   '155',
#   '41',
#   datetime.datetime(2015, 4, 23, 11, 58),
#   0],
#  ['이다해(love****)',
#   '난 어쩔수 없는 마블덕후인가봄ㅋㅋㅋㅋ너무재밌었어요ㅋㅋ한번더 보고싶당',
#   '10',
#   '162',
#   '59',
#   datetime.datetime(2015, 4, 23, 16, 57),
#   '관람객'],
#  ['히헛(huih****)',
#   '솔직히 지루한감이없진 않았다..아쉬워',
#   '6',
#   '167',
#   '65',
#   datetime.datetime(2015, 4, 24, 2, 29),
#   '관람객'],
#  ['유리_Kelly(love****)',
#   '어벤져스 관련영화 (아이언맨, 토르 등...) 안 보신분들이라면 비추입니다 -_-  대충 내용은 알겠지만 뭔가 영화에 몰입이 안돼ㅜㅜㅜ 하품만 30번은 하다 나온것 같네요.',
#   '6',
#   '233',
#   '132',
#   datetime.datetime(2015, 4, 23, 16, 22),
#   0],
#  ['책갈피(vajr****)',
#   '그냥 블록버스터 무비입니다. 어디서 뭘 느껴야할지 정신없이 혼란하기만 했네요.',
#   '6',
#   '224',
#   '127',
#   datetime.datetime(2015, 4, 23, 17, 16),
#   0],
#  ['kisz****',
#   '와 역시 어벤저스다...  진짜 괜히 마블이 아니네ㅋㅋ 마블 세계관을 안다면 맨마지막 보고 소름돋았을꺼임',
#   '10',
#   '125',
#   '36',
#   datetime.datetime(2015, 4, 23, 13, 55),
#   0],
#  ['momo****',
#   '토르가 좀 웃기고, 중간에 헐크하고 아이언맨 치고 박고 할 때가 제일 재밌었음. 그외엔 그닥..',
#   '8',
#   '130',
#   '41',
#   datetime.datetime(2015, 4, 23, 15, 19),
#   0],
#  ['콘기사(ocyo****)',
#   '생각보다잼없엇음기대이하',
#   '4',
#   '325',
#   '239',
#   datetime.datetime(2015, 4, 23, 14, 11),
#   '관람객'],
#  ['사이버존(obch****)',
#   '여기다 10점을 안주면 어디다 주려고 짜게 굴지 말자 10점 맞다',
#   '10',
#   '208',
#   '129',
#   datetime.datetime(2015, 4, 23, 10, 55),
#   0],
#  ['미르미르(kung****)',
#   '어벤저스2에 한국이 나온다는게 대박!',
#   '10',
#   '148',
#   '77',
#   datetime.datetime(2015, 4, 23, 13, 53),
#   '관람객'],
#  ['그리(yace****)',
#   '기대를 너무 했나보다..',
#   '7',
#   '123',
#   '54',
#   datetime.datetime(2015, 4, 24, 2, 41),
#   '관람객'],
#  ['교촌도적(eeem****)',
#   '재밋어요 ㅎㅎ 강추입니다',
#   '10',
#   '153',
#   '85',
#   datetime.datetime(2015, 4, 23, 10, 26),
#   '관람객'],
#  ['베엥글(kny7****)',
#   '영화관으로 소풍 온 옆사람 때문에  집중을 못 해서 그런가...(뭔 먹을걸 그렇게 싸왔는지...  영화 내내 먹더라..ㅠ) 1보다는 재미있지 않았지만..  싸우는 장면도  꽤 재미있었고 마블 특유의 유머도 재미있었다...',
#   '8',
#   '187',
#   '121',
#   datetime.datetime(2015, 4, 23, 9, 36),
#   '관람객'],
#  ['R_N(pqpq****)',
#   '아 진짜 스케일 커지는것 보소 ㅋㅋ자비스 어쩔껍니까 내 사랑 자비스가 앜ㅋㅋ',
#   '10',
#   '100',
#   '36',
#   datetime.datetime(2015, 4, 23, 12, 11),
#   '관람객'],
#  ['baey****',
#   '기대를 많이한건가??ㅠ',
#   '5',
#   '100',
#   '38',
#   datetime.datetime(2015, 4, 23, 23, 56),
#   '관람객'],
#  ['limd****',
#   '생각 보다 별로엿음 졸려요',
#   '5',
#   '96',
#   '35',
#   datetime.datetime(2015, 4, 25, 13, 4),
#   '관람객'],
#  ['유정만리(yski****)',
#   '뭘 더 바라는 거야? 최고구먼! 한국의 너저분한 영화보다  만배는  낫다.',
#   '10',
#   '126',
#   '65',
#   datetime.datetime(2015, 4, 23, 15, 6),
#   0],
#  ['수면중(iris****)',
#   '기대하고 보면 뭔가 2% 부족함을 느끼고아무생각없이보면 볼거리 가득한 sf영화임',
#   '8',
#   '84',
#   '25',
#   datetime.datetime(2015, 4, 23, 21, 27),
#   '관람객'],
#  ['제네시스(mogo****)',
#   '지루하다는애들  전투씬만보고 스토리  전개는 신경 안쓰냐???  수준 답답하다',
#   '10',
#   '339',
#   '282',
#   datetime.datetime(2015, 4, 23, 10, 55),
#   0],
#  ['zhen****',
#   '스케일은 매우 웅대하나,상대적으로 스토리 찌임새가 정신없이 구성되어 있어내용을 좀더 간결하게 했으면 좋았겠다는 의견임',
#   '6',
#   '70',
#   '14',
#   datetime.datetime(2015, 4, 24, 18, 11),
#   '관람객'],
#  ['tlsg****',
#   '재밌음. 볼거리많고 서울이 디게 오묘하게 나옴ㅋㅋ',
#   '8',
#   '98',
#   '42',
#   datetime.datetime(2015, 4, 23, 12, 48),
#   '관람객'],
#  ['나르샤(inev****)',
#   '시사회 가서 봤지만, 영화관 가서 또 보고 싶은 영화..',
#   '10',
#   '98',
#   '47',
#   datetime.datetime(2015, 4, 23, 8, 29),
#   0],
#  ['sogi****',
#   '스토리는 기대하지마라. 그냥 눈요기만 한다고 보면 된다. 난 마지막까지 보고 입에서 절로 욕이 나왔다. 내가 타락한건지 동심을 잃은건지도 모르겠으나.. 진짜 유치하고 단순한 작품이었다',
#   '4',
#   '169',
#   '119',
#   datetime.datetime(2015, 4, 23, 16, 52),
#   0],
#  ['마래모해(cute****)',
#   '소문난 잔치에 먹을게 없다.딱 이거네요ㅠㅠ큰기대마시고 그냥 보세요.솔직히 전편보다 못해요ㅎㅎ지루함도 있고 액션도 그다지...분노의질주가 훨씬 나았음!',
#   '6',
#   '129',
#   '81',
#   datetime.datetime(2015, 4, 23, 15, 5),
#   0],
#  ['yook****',
#   '그냥 보셈 난 9번더볼꺼임',
#   '10',
#   '104',
#   '59',
#   datetime.datetime(2015, 4, 23, 10, 55),
#   0],
#  ['핑크오리(indr****)',
#   '1시간30분은 지루했고 마지막 30분정도 몰입했어요하품 다섯번넘게한듯..',
#   '5',
#   '106',
#   '61',
#   datetime.datetime(2015, 4, 23, 17, 12),
#   0],
#  ['승쨩(skhj****)',
#   '재밌지만 대단하다고 할 정도는 아니고3편을 위한 중간다리 역할을 하는 정도?울트론을 비록해서 인물들 설정이 심하게너프먹은건 정말 아쉽다',
#   '9',
#   '63',
#   '20',
#   datetime.datetime(2015, 4, 23, 18, 20),
#   '관람객'],
#  ['plys****',
#   '그냥 재밌어~ 울트론이 너무 약한거 같긴 하지만~ 타노스 개기대되네~ㅋㅋㅋ',
#   '10',
#   '60',
#   '20',
#   datetime.datetime(2015, 4, 23, 16, 47),
#   0],
#  ['LOVEEW(dkdl****)',
#   '미쳤다. 이건 무조건 N차 찍어야 된다. 전작보다 별로라는 기자들 설레발에 겁 먹었는데 그 기사 쓴 기자 혼구녕을...! 멤버들과의 사이도 두터워졌고 내용 또한 알차고 마무리까지 완벽하다! 내 사랑 어벤져스!',
#   '10',
#   '89',
#   '51',
#   datetime.datetime(2015, 4, 23, 10, 27),
#   0],
#  ['love****',
#   '구글에 어벤저스 관련 비평가들 글에 제일 많은 평가가 첫째, 놀랄정도로 스토리 연계성이 부족하다 둘째, 엄청난 실망이다 이런이야기가 쏟아지고 있는데.. 평점등록 알바가 얼마나 무서운지 이 댓글라인이 보여주고 있군.',
#   '1',
#   '79',
#   '43',
#   datetime.datetime(2015, 4, 25, 16, 22),
#   0],
#  ['tois****',
#   '1편보다못해요 역시헐크는짱',
#   '8',
#   '57',
#   '22',
#   datetime.datetime(2015, 4, 23, 20, 41),
#   '관람객'],
#  ['joyf****',
#   '뭐, 긴말안한다. 사람마다 다르겟지만 보험용팬티 한장 정도는 챙겨가도 나쁠거 없다. 그리고 영화보기전에 물 너무 마시거나 영화도중에 콜라 너무 들이키면 보험용을 진짜 써야될지도 모르니까 조심들해라.',
#   '10',
#   '117',
#   '82',
#   datetime.datetime(2015, 4, 23, 6, 31),
#   0],
#  ['청결깔끔(soot****)',
#   '지루하고 놀라울게 없었음.',
#   '1',
#   '87',
#   '54',
#   datetime.datetime(2015, 4, 24, 1, 46),
#   0],
#  ['엄성(tjdd****)',
#   '극장가서꼭보세여개꿀잼임',
#   '10',
#   '80',
#   '48',
#   datetime.datetime(2015, 4, 23, 10, 26),
#   '관람객'],
#  ['namb****',
#   '스토리는억지스럽고 무조건 때려부순다 어벤져스팬아니면 보지말것',
#   '1',
#   '47',
#   '16',
#   datetime.datetime(2015, 5, 1, 9, 48),
#   0],
#  ['Shizuku(gack****)',
#   '원작을 많이 꼬아 놓았지만, 그럭 저럭 볼만했음. 마지막이 보너스 영상에서 나오는 그놈이 빨리 보고 싶음.',
#   '9',
#   '39',
#   '9',
#   datetime.datetime(2015, 4, 23, 16, 54),
#   0],
#  ['성재(zksd****)',
#   '액션은 역시나네요...!!',
#   '10',
#   '47',
#   '17',
#   datetime.datetime(2015, 4, 23, 13, 38),
#   '관람객'],
#  ['라라(bbo6****)',
#   '잘 나가는 과자로만 만들어진 종합선물세트.  현실엔 없는데 어벤져스엔 있다~',
#   '10',
#   '39',
#   '11',
#   datetime.datetime(2015, 4, 23, 12, 49),
#   0],
#  ['annnne(idea****)',
#   '액션이며 스토리 기대치 못하다 분위기 어둡게 하는데 하나도 안어울림',
#   '5',
#   '43',
#   '16',
#   datetime.datetime(2015, 4, 23, 14, 9),
#   0],
#  ['블루(0001****)',
#   '기대가 너무 컷나봅니다.영화보다 졸기까지...',
#   '5',
#   '46',
#   '20',
#   datetime.datetime(2015, 4, 24, 17, 50),
#   '관람객'],
#  ['Jack(mg14****)',
#   '진짜 재밌게 봤다 ㅋㅋ어떻게 재밌는지 설명하고 싶은데ㅅ설명할라면 스포일러...ㅋㅋㅋ',
#   '9',
#   '64',
#   '38',
#   datetime.datetime(2015, 4, 23, 12, 38),
#   '관람객'],
#  ['이팔청춘(acts****)',
#   '본격 마블 덕후 양산 영화',
#   '10',
#   '40',
#   '16',
#   datetime.datetime(2015, 4, 23, 18, 47),
#   '관람객'],
#  ['라이토(slvj****)',
#   '핵노잼;;;뭐냐 이거;;;',
#   '1',
#   '46',
#   '22',
#   datetime.datetime(2015, 5, 2, 1, 2),
#   '관람객'],
#  ['hoes****',
#   '이 영화의 진정한 끝은 쿠키영상에 있지',
#   '10',
#   '24',
#   '1',
#   datetime.datetime(2015, 4, 23, 18, 45),
#   0],
#  ['Allday(alld****)',
#   '스토리가 산만하게 흘러가다가 마지막에 분위기잡고 최후의결전 그 뒤 끝냄. 개연성은 있지만 재미는 부족한 시나리오',
#   '7',
#   '38',
#   '15',
#   datetime.datetime(2015, 4, 23, 17, 10),
#   0],
#  ['tbwn****',
#   '역시. 그냥 보세요. 최소 본전은 건집니다',
#   '10',
#   '42',
#   '19',
#   datetime.datetime(2015, 4, 23, 13, 0),
#   0],
#  ['stor****',
#   '많이 기다렸던 영화인데 기대만큼 그리 재밋지는 않았음 ㅠㅠ',
#   '9',
#   '42',
#   '20',
#   datetime.datetime(2015, 4, 23, 14, 16),
#   '관람객'],
#  ['heli****',
#   '서울 왜 그따구로 나왔냐 참....판자촌 사이에 둥둥섬 빼고는 베트남인줄 알았다 차라리 부산 광안대교 센텀 마린시티에서  찍어도 그것보다  멋지게 나왔을듯 서울이  어벤져스2 망쳤음',
#   '5',
#   '44',
#   '22',
#   datetime.datetime(2015, 4, 23, 14, 20),
#   0],
#  ['구레기(tkda****)',
#   '하....초딩만화영화보는줄',
#   '1',
#   '64',
#   '42',
#   datetime.datetime(2015, 4, 26, 22, 27),
#   '관람객'],
#  ['heon****',
#   '액션씬보다 대화씬이 많아서 좀 지루했어요 전편이 더 재있는 듯',
#   '6',
#   '34',
#   '13',
#   datetime.datetime(2015, 4, 24, 0, 5),
#   0],
#  ['배성재(nice****)',
#   '솔직히 재미없었다. 스토리가 너무 산으로감ㅡㅡ',
#   '1',
#   '30',
#   '10',
#   datetime.datetime(2015, 4, 27, 15, 25),
#   '관람객'],
#  ['jadu****',
#   '기다리고 기다리던 어벤져스2 3편 나올 듯 기대됩니다',
#   '10',
#   '30',
#   '10',
#   datetime.datetime(2015, 4, 23, 18, 49),
#   '관람객'],
#  ['yang****',
#   '지루함의끝을달린다이건뭐냐',
#   '1',
#   '46',
#   '26',
#   datetime.datetime(2015, 4, 27, 2, 31),
#   '관람객'],
#  ['전홍미(riri****)',
#   '아직은 못봣다 손 ...',
#   '10',
#   '48',
#   '28',
#   datetime.datetime(2015, 4, 23, 11, 0),
#   0],
#  ['하이텔(bigd****)',
#   '대박이다 무조건 봐라 아이맥스로 꼭!!',
#   '10',
#   '50',
#   '30',
#   datetime.datetime(2015, 4, 23, 10, 59),
#   0],
#  ['웅이(hunt****)',
#   '재미 없어요,,,,1편을 기대했다면 무조건 실망해요,,,',
#   '1',
#   '30',
#   '11',
#   datetime.datetime(2015, 5, 2, 17, 14),
#   '관람객'],
#  ['단추두개(robo****)',
#   '그냥 저냥 볼만하지만 중간이 너무 루즈함.',
#   '6',
#   '36',
#   '17',
#   datetime.datetime(2015, 4, 24, 0, 8),
#   0],
#  ['감쟈링(hari****)',
#   '진짜 영상이랑 스토리랑 모두 다 유치해서 보는 내내 한숨밖에 안나왔어요  한국은 왜그렇게 낙후된모습으로 표현됬는지',
#   '1',
#   '37',
#   '18',
#   datetime.datetime(2015, 5, 2, 8, 32),
#   0],
#  ['yaga****',
#   '기대해서 그런가...  지루함...',
#   '1',
#   '37',
#   '18',
#   datetime.datetime(2015, 4, 27, 8, 5),
#   '관람객'],
#  ['Binna(bbbb****)',
#   '생각보다 기대 이하 전편이 더 재미있음',
#   '9',
#   '25',
#   '7',
#   datetime.datetime(2015, 4, 24, 0, 5),
#   '관람객'],
#  ['레몬트리(lbj6****)',
#   '시사회보고왔는데스케일이다름',
#   '10',
#   '32',
#   '14',
#   datetime.datetime(2015, 4, 23, 8, 24),
#   0],
#  ['민국대한우리(meso****)',
#   '전 별로네여. 기대만큼은 아니에여',
#   '1',
#   '33',
#   '15',
#   datetime.datetime(2015, 4, 24, 23, 37),
#   '관람객'],
#  ['netr****',
#   '눈못땔정도로멍하게봤내요대박..짱짱!!',
#   '10',
#   '33',
#   '15',
#   datetime.datetime(2015, 4, 24, 2, 7),
#   '관람객'],
#  ['xete****',
#   '후 ...장면이야 당연히 멋있지만스토리 등등 미약해',
#   '1',
#   '34',
#   '16',
#   datetime.datetime(2015, 4, 27, 17, 38),
#   '관람객'],
#  ['buddt(rera****)',
#   '기대를 너무 많이했나봐요....지금까지 마블영화중 최악이에요 ㅠㅠ',
#   '1',
#   '49',
#   '31',
#   datetime.datetime(2015, 4, 25, 22, 55),
#   '관람객'],
#  ['roko****',
#   '평점 7점정도의영화같아요 .. 3D로봤는데 1에비하면 너무재미없었어요 별1준건 별점깎아서 평점 평균 7점정도로 되었으면 하는마음에 1줍니다 ..',
#   '1',
#   '69',
#   '51',
#   datetime.datetime(2015, 4, 24, 6, 30),
#   0],
#  ['영화쟁이(foma****)',
#   '딴거 몰겠고 헐크 폭주하고 베로니카랑 맞짱 뜰때가 최고였음 밤새고 조조로 봐서 그런가 유머코드도 피식정도고 스토리도 잘안들어온다 3디로 봤지만 그래비티 보다 효과 별로 돌출이 별로 없어서 그런지 스케일과 세계관은 인...',
#   '8',
#   '23',
#   '6',
#   datetime.datetime(2015, 4, 23, 13, 1),
#   0],
#  ['세계(dhwo****)',
#   '엔드게임을 보고 다시봐야되는 영화',
#   '10',
#   '16',
#   '0',
#   datetime.datetime(2019, 4, 24, 17, 56),
#   0],
#  ['druc****',
#   '큰기대를 가지고봤다. 전작에비해 전체적으로 어두운 분위기이기는하지만 중간중간의 유머코드는 여전하고 액션씬은 기대를 충족시켜줬다. 아쉬운부분이 없다곤 할 수 없지만 액션씬만으로도 충분한 수작.',
#   '10',
#   '23',
#   '7',
#   datetime.datetime(2015, 4, 23, 11, 46),
#   0],
#  ['블루(tont****)',
#   '마블영화 라면 아오 정말대박이다.',
#   '10',
#   '25',
#   '9',
#   datetime.datetime(2015, 4, 23, 14, 50),
#   0],
#  ['kwli****',
#   '진짜재미없음. 지루함의 극치였음.',
#   '1',
#   '32',
#   '16',
#   datetime.datetime(2015, 4, 26, 22, 50),
#   0],
#  ['dark****',
#   '두시간반이라는 긴시간이 무색할정도로 엄청난 흡입력이 있는 영화입니다. 스토리는 다소 밋밋하지만 최첨단 액션으로 모두를 커버한다!!',
#   '10',
#   '41',
#   '25',
#   datetime.datetime(2015, 4, 23, 14, 3),
#   '관람객'],
#  ['pakc****',
#   '3년동안 발전한게 없는 기술 수트 전투력... 그리고 산만한 스토리',
#   '1',
#   '85',
#   '69',
#   datetime.datetime(2015, 4, 24, 9, 28),
#   0],
#  ['먹뽀미(dbsd****)',
#   '완전 재밋음ㅋㅋㅋ ㅋ그리고 끝나고 마지막까지 보세요 나가지마시고',
#   '10',
#   '22',
#   '7',
#   datetime.datetime(2015, 4, 23, 13, 36),
#   0],
#  ['ttoma(wop9****)',
#   '김수현이 생각보다 안정적으로 잘해서 뿌듯했음.. 대신 서울은 참 특색없이 나옴..ㅋㅋ',
#   '7',
#   '17',
#   '3',
#   datetime.datetime(2015, 4, 24, 16, 21),
#   0],
#  ['허접(tlsg****)',
#   '졸면서봣다 보지마라진짜비추다 돈아깝다..하..',
#   '1',
#   '20',
#   '6',
#   datetime.datetime(2015, 5, 6, 1, 18),
#   0],
#  ['cyh(ggal****)',
#   '기대가 컸었는데 실망만 하고 왔음',
#   '1',
#   '22',
#   '8',
#   datetime.datetime(2015, 4, 29, 0, 25),
#   0],
#  ['유진(nine****)',
#   '평점에 스포쓰는 관종들 참ㅋ 한가지만 말하면 어벤져스2처럼 기대를 한몸에받는 영화들은 기대감이 너무 큰탓에 보고나면 허탈함과 실망감도 들기 마련인데 감독이 한국촬영한 탓인지 몰라도 비빔밥 먹듯 영화를 잘 비볐다는것ㅎ...',
#   '10',
#   '29',
#   '15',
#   datetime.datetime(2015, 4, 23, 12, 45),
#   0],
#  ['아밍(luna****)',
#   '아이언맨이 정말 사고뭉치임',
#   '8',
#   '15',
#   '2',
#   datetime.datetime(2015, 4, 24, 2, 5),
#   0],
#  ['빠삐코(rmfp****)',
#   '개봉 첫회 3d로보고 왔는데요 굳이 3d로 볼필요는 없고 아이맥스 추천드립니다 그리고 생각없이 때리고부수고 스트레스 확풀리네요 ㅎ 헐크버스터 나오는 장면이 지립니다 ㅎ',
#   '10',
#   '21',
#   '8',
#   datetime.datetime(2015, 4, 23, 12, 51),
#   0],
#  ['돈돈(barl****)',
#   '졸잼짱잼!!!!ㅋㅋㅋ',
#   '10',
#   '29',
#   '16',
#   datetime.datetime(2015, 4, 23, 12, 17),
#   '관람객'],
#  ['락사마(ckr3****)',
#   '서울은 배경이 왜이렇게 촌스럽지 중국이나 일본 배경은 괜찮던데 한국 촬영신은 디워 느낌 나더라',
#   '8',
#   '12',
#   '0',
#   datetime.datetime(2015, 4, 24, 18, 13),
#   0],
#  ['MCF토끼(lgm0****)',
#   '킬링타임용으로도 시간이아깝고 돈이아까웠다 졸렸다',
#   '1',
#   '13',
#   '1',
#   datetime.datetime(2015, 5, 6, 10, 26),
#   0],
#  ['hube****',
#   '기대를 너무많이했나봐요',
#   '5',
#   '13',
#   '1',
#   datetime.datetime(2015, 4, 29, 1, 14),
#   '관람객'],
#  ['melo****',
#   '방금 3d아이맥스로 봤는데 16000원 휴지통에 버린기분 아이언맨시리즈 엑스맨시리즈 다 재미있었는데 이건 뭐 2시간내내 졸면서 봤다 휴지조각이랑 싸우나',
#   '1',
#   '14',
#   '2',
#   datetime.datetime(2015, 5, 7, 3, 6),
#   0],
#  ['율뉼률(cyr0****)',
#   '기절해라 기절해라 기절해라 기절해라 sorry',
#   '10',
#   '15',
#   '3',
#   datetime.datetime(2015, 4, 24, 9, 51),
#   0],
#  ['bqbq****',
#   '서울에서의 장면은 합성이 너무 티가 나는 군요ㅠ마치 90년대 영화처럼 ㅠㅠㅠ하지만 긴장하면서 잘 봤어요 영웅들!',
#   '8',
#   '15',
#   '3',
#   datetime.datetime(2015, 4, 24, 1, 56),
#   '관람객'],
#  ['작은별(skag****)',
#   '자신이 이영화를 보다 초중반쯤 살짝 졸렸거나 졸았다.. 공감 누르시기 바랍니다',
#   '1',
#   '17',
#   '5',
#   datetime.datetime(2015, 5, 13, 17, 46),
#   0],
#  ['nine(case****)',
#   '쿠키는 1절이 끝이니 사람들 조금 빠지면 일어나세요 ㅋㅋㅋ',
#   '10',
#   '17',
#   '5',
#   datetime.datetime(2015, 4, 23, 19, 56),
#   '관람객'],
#  ['XiDCZD(floc****)',
#   '돈이 아깝지 않은 화려한 액션신',
#   '10',
#   '17',
#   '5',
#   datetime.datetime(2015, 4, 23, 14, 47),
#   0],
#  ['ysan****',
#   '이야기가 늘어진다. 황당한 설정과 기존 능력과 전혀 다른 모습으로 이야기를 이해할수 없는 경지로 비틀어간다. 마블의 억지 짜깁기가 몇발자국 못가 한계에 다다른듯~',
#   '1',
#   '18',
#   '6',
#   datetime.datetime(2015, 5, 8, 14, 11),
#   0],
#  ['파란색(tlad****)',
#   '차라리 만화책을 보세요',
#   '1',
#   '19',
#   '7',
#   datetime.datetime(2015, 5, 6, 20, 44),
#   '관람객'],
#  ['정영주(ssim****)',
#   '알바들 제발 그만 좀 해 솔직히 이번 편 졸작이잖아 1편에 비해 넘 완성도 떨어져요. 악당도 무슨 이렇게 약할 수가 없어',
#   '1',
#   '22',
#   '10',
#   datetime.datetime(2015, 4, 30, 8, 21),
#   0],
#  ['dlsh****',
#   '1편에 비하면 졸립다 12세가 보기엔 내용 넘 어려운듯 성인이 보기엔 넘 만화같고 중간 부분 넘 지루해서 잠깐 졸았다는 ㅋㅋ',
#   '1',
#   '23',
#   '11',
#   datetime.datetime(2015, 4, 29, 7, 50),
#   0],
#  ['펠리시아(susa****)',
#   '한마디로 압축하면 관객의 기대를 완전 말아먹은거같음 ㅜㅠ전편은 레알 꿀잼이었는데 이건 뭐 웃기지도 않는 유치개그+난잡한 전투씬에 부실한스토리+매력도 없는 신캐릭터 끼얹은 실망작..이래놓고 막판에 대놓고 속편예고질.....',
#   '1',
#   '24',
#   '12',
#   datetime.datetime(2015, 4, 26, 16, 54),
#   0],
#  ['우량엄마(79pi****)',
#   '개봉일 첫시간예매해서봤습니다. 개취이겠지만1편이 몇배 재밌습니다. 왠만해서는 평이한내용도 집중해서보는편인데...너무 내용도없이산만해서 지루했어요 하품계속...유치하기까지한장면도 몇몇있구요;;그냥 dvd로보세요ㅠ 3d...',
#   '1',
#   '24',
#   '12',
#   datetime.datetime(2015, 4, 24, 23, 31),
#   0],
#  ['Muse(dfd6****)',
#   '닥치고 마블은 위대하다.',
#   '10',
#   '24',
#   '12',
#   datetime.datetime(2015, 4, 23, 14, 51),
#   0],
#  ['로그(hqu4****)',
#   '덕후가 아니라면 돈주고 볼 필요없는 영화. 아니면 덕후거나 히어로를 좋아하는 동심이 있거나.',
#   '1',
#   '25',
#   '13',
#   datetime.datetime(2015, 4, 26, 21, 50),
#   0],
#  ['착한호빗님(jhtn****)',
#   '그냥 할말없음 볼거리가 매우많음 생각보다 서울 오래나와서 좋았고',
#   '10',
#   '26',
#   '14',
#   datetime.datetime(2015, 4, 23, 13, 27),
#   '관람객'],
#  ['USANA(kako****)',
#   '어벤져스 1 이 훨씬 낫다..정말 실망이다... 정말 기대했는데...졸리기 까지 할 정도...어벤져스 1 로 끝냈어야 했다....',
#   '1',
#   '28',
#   '16',
#   datetime.datetime(2015, 4, 24, 23, 26),
#   '관람객'],
#  ['형안(na91****)',
#   '도대체 이딴 영화가 왜 재밌다는건지 모르겠다 세상 사람들 전부 그냥 뇌가 없는건가 재미도 감동도 여운도 교훈도 맘는것도 아무것도 없는 희대의 졸작 그냥 어린이용 만화 딱 그 수준임 너무 기대하고 봐서 그런가 킬링타임...',
#   '1',
#   '31',
#   '19',
#   datetime.datetime(2015, 5, 7, 9, 1),
#   '관람객'],
#  ['판타스틱싱어(coco****)',
#   '재료는 더 화려해졌는데 더 재미없는 속편은 감독의 연출 실패로 보인다. 다시 보고 또 봐도 변함없다. 초반부터 어벤져스의 액션신을 보여주지만 난잡하기만 하고 새로운 캐릭터들의 등장은 전개만 느려지게 만들고 가장 중요...',
#   '5',
#   '11',
#   '0',
#   datetime.datetime(2018, 6, 3, 3, 43),
#   0],
#  ['찡맘(ppou****)',
#   '잘 잤어요.  한국 골목 중국같았어요.',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2015, 5, 6, 9, 7),
#   '관람객'],
#  ['ywjy****',
#   '오늘 보다고 지루해서 죽을 뻔 했는데 네이버 평점은 초딩만 참여한건지 왜케높은 거냐....',
#   '1',
#   '14',
#   '3',
#   datetime.datetime(2015, 5, 5, 22, 8),
#   0],
#  ['카니자(puha****)',
#   '우와~ 정도는 아니고 그냥저냥 볼만한영화.보는내내 뭔가가 영화가 조잡한느낌?스토리가 매끄럽지못하고액션도 깔끔하다긴보단 정신없는느낌이 많이드네요.솔직히 10점은 나올수없는 영화같네요.',
#   '7',
#   '15',
#   '4',
#   datetime.datetime(2015, 4, 24, 15, 2),
#   '관람객'],
#  ['Pohem(didi****)',
#   '왜케 허접..해졌지?',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2015, 5, 1, 14, 16),
#   0],
#  ['rudw****',
#   '졸았음 너무지루함 돈만많이쓴듯',
#   '1',
#   '16',
#   '5',
#   datetime.datetime(2015, 4, 28, 16, 58),
#   '관람객'],
#  ['han9****',
#   '어벤져스 울트론같은 영화 많이 개봉해주세요',
#   '10',
#   '16',
#   '5',
#   datetime.datetime(2015, 4, 24, 19, 12),
#   '관람객'],
#  ['반니(silv****)',
#   '최악의 마블 영화 졸림 집가서 잘거임',
#   '1',
#   '17',
#   '6',
#   datetime.datetime(2015, 5, 5, 21, 27),
#   '관람객'],
#  ['이준영(bomb****)',
#   '1편보다잼슬거라고기대햇는데 좀 떨어짐 어지러움이 심함',
#   '1',
#   '17',
#   '6',
#   datetime.datetime(2015, 5, 1, 10, 26),
#   0],
#  ['이래기(hyuk****)',
#   '노잼..졸앗음..보지마삼',
#   '1',
#   '19',
#   '8',
#   datetime.datetime(2015, 5, 9, 9, 20),
#   '관람객'],
#  ['우투(lees****)',
#   '눈요기만큼은 확실히 보장한다. 3d도 돈이 아깝다. 1점짜린 아니다만 현재 평점 8점짜리도 아니다. 평점좀 낮추자',
#   '1',
#   '19',
#   '8',
#   datetime.datetime(2015, 4, 29, 1, 21),
#   0],
#  ['dnsd****',
#   '내용이 없고, 의미도 없는  졸속 영화',
#   '1',
#   '29',
#   '18',
#   datetime.datetime(2015, 4, 25, 20, 31),
#   '관람객'],
#  ['때마다(dail****)',
#   '초딩들 현혹시키기엔 최고의 작품이네요ㅎㅎ',
#   '7',
#   '10',
#   '0',
#   datetime.datetime(2015, 4, 30, 22, 20),
#   '관람객'],
#  ['스카이(seve****)',
#   '기자,평론가가6,91이라니  믿을사람없군 ~~요  시간과돈이 정말 아까운  영화입니다 개인의 취향이 아닌 듯  관객이 나갈때는  이유가 있겠죠  다시는  조스웨던감독 영화 안봐요',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2015, 5, 6, 12, 10),
#   0],
#  ['suno****',
#   '기대에 못미치는영화~~',
#   '1',
#   '11',
#   '1',
#   datetime.datetime(2015, 5, 5, 17, 31),
#   '관람객'],
#  ['아타락시아(hots****)',
#   '경제효과2조라며며칠동안차량통제하자던인간들어디갔냐? 리서치센터조사결과경제유발효과따위계상조차되지않는수준이란다. 반대로며칠간길막아서낭비된금액이백억대. 국민혈세로제작비27억지원. 얼빠진마블종자들때문에호갱님된대한민국. ㅉㅉ~...',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2015, 9, 19, 15, 36),
#   0],
#  ['미리내(ca00****)',
#   'CG는 최고봉 스토리는 최악',
#   '1',
#   '12',
#   '2',
#   datetime.datetime(2015, 5, 28, 17, 16),
#   '관람객'],
#  ['chul****',
#   '영화의 다양성이 없애는 나쁜영화 빨리 영화 내려야 그리고 별로 재미없다',
#   '1',
#   '13',
#   '3',
#   datetime.datetime(2015, 5, 7, 9, 15),
#   0],
#  ['주솝(kjmw****)',
#   '솔직히  평점 10점 주신 분들 낚으려고 이러는 거 아닌가 생각까지 했다. 제 2의 클레멘타인;;;급',
#   '1',
#   '13',
#   '3',
#   datetime.datetime(2015, 5, 5, 11, 17),
#   0],
#  ['정원이(newj****)',
#   '재밌기는 한데 성인이 보기에늠 좀 지루한 감이 있네여~~~ 스토리는 대충 짐작이 가는 내용입니다~~ 지루하진 않지만~~ 루즈한 감이 있네요~~ 시간 때우기에는 좋네요',
#   '8',
#   '13',
#   '3',
#   datetime.datetime(2015, 4, 29, 20, 58),
#   '관람객'],
#  ['소히(sop0****)',
#   '그냥 미친거지..헐크랑 아이언맨 싸울때 방광컨트롤 잘해라.',
#   '10',
#   '13',
#   '3',
#   datetime.datetime(2015, 4, 24, 13, 3),
#   0],
#  ['커러들임(ww50****)',
#   '관광효과 3200억이라던 서울시... 정작 영화속엔 꾸진데만 나오고 호구가 따로 없었음.',
#   '1',
#   '14',
#   '4',
#   datetime.datetime(2015, 5, 19, 17, 20),
#   0],
#  ['영창(kong****)',
#   '에효 잠유발 영화.... 한국 나와서 반갑긴 하더라만',
#   '1',
#   '14',
#   '4',
#   datetime.datetime(2015, 5, 6, 11, 37),
#   0],
#  ['장화신은고양이(lim9****)',
#   '완전 지루하고 재미없어요..애들은 왜또 영화보면서 시끄러운지..부모들은 관리안하고 뭐하는건지...몰입도 하나도 안되고..꽝이네요!!!',
#   '1',
#   '15',
#   '5',
#   datetime.datetime(2015, 5, 9, 16, 58),
#   '관람객'],
#  ['정연우(4720****)',
#   '스토리가 없고 이건 내 인생 최악의 영화다. 10점 주는 알바가 많은 거 같네. 시간 날리고 돈 날리고.',
#   '1',
#   '15',
#   '5',
#   datetime.datetime(2015, 5, 6, 6, 7),
#   0],
#  ['hyeseo513(513g****)',
#   '어벤져스 분노의질주 차이나타운 장수상회 다봤는데 어벤져스가 제일 재미없다..',
#   '1',
#   '15',
#   '5',
#   datetime.datetime(2015, 5, 5, 23, 55),
#   0],
#  ['높은하늘(sink****)',
#   '넘 많은 주인공들...약간 산만했음.매니아층 아니면 내용 이해 못 할수도 있음.사전 공부하고 가야됨.',
#   '8',
#   '15',
#   '5',
#   datetime.datetime(2015, 4, 24, 19, 27),
#   '관람객'],
#  ['sjet****',
#   '5백만돌파라니 기가 막힙니다.. 5월1일 가보니, 어벤져스2/차이나타운/위험한상견례2.. 이렇게  3작품만 상영하던데 어벤져스로 상영관 5개를 채워버렸고   차이나타운은 청소년 불가라 어벤져스로 선택을 강요하는 분위...',
#   '1',
#   '16',
#   '6',
#   datetime.datetime(2015, 5, 2, 10, 18),
#   0],
#  ['로벤루니(pict****)',
#   '정말 기대 이하 입니다  실망',
#   '1',
#   '16',
#   '6',
#   datetime.datetime(2015, 4, 29, 11, 23),
#   '관람객'],
#  ['하빈habeen(habe****)',
#   '할말잃음 만화한권 읽는게 나아요',
#   '1',
#   '17',
#   '7',
#   datetime.datetime(2015, 5, 2, 19, 40),
#   '관람객'],
#  ['별을위해(roba****)',
#   '스토리 괜히 꼬아서 시간만 끄는 별로인 2',
#   '1',
#   '20',
#   '10',
#   datetime.datetime(2015, 4, 26, 17, 34),
#   '관람객'],
#  ['svck****',
#   '어벤져스1보고 흥분됫고 캡아2보고 기대햇다가이거보고 음 ....',
#   '1',
#   '22',
#   '12',
#   datetime.datetime(2015, 4, 25, 3, 44),
#   0],
#  ['존시나(bven****)',
#   '이래서 우리나라영화안봄',
#   '10',
#   '22',
#   '12',
#   datetime.datetime(2015, 4, 24, 14, 28),
#   0],
#  ['지야(rhem****)',
#   '재밌게 봤어요 어벤져스 짱',
#   '10',
#   '24',
#   '14',
#   datetime.datetime(2015, 4, 23, 20, 16),
#   '관람객'],
#  ['김익명(unde****)',
#   '전작만큼의 임팩트는 없었지만 그래도 눈은 즐거움',
#   '9',
#   '32',
#   '22',
#   datetime.datetime(2015, 4, 23, 16, 40),
#   '관람객'],
#  ['반찬(raul****)',
#   '엔드게임 보고 다시 보니까 그땐 별 생각없던 내용들이 다 중요한 내용이었네ㅋ 토니가 예언한게 맞았음',
#   '10',
#   '9',
#   '0',
#   datetime.datetime(2019, 4, 27, 20, 48),
#   0],
#  ['임기동(frid****)',
#   '울트론이 굉장히 아쉬웠던 영화',
#   '7',
#   '9',
#   '0',
#   datetime.datetime(2018, 5, 29, 5, 44),
#   0],
#  ['구운마늘(kjjo****)',
#   '유머가 가끔 안 먹힐때도 있긴 하지만, 다소 무거워진 것도 사실이지만, 화려하고 끊임없는 액션과 각 캐릭터에 대한 적절한 어필 시간(?) 배분, 전 작품들과의  연결로 점차 골격을 갖춰가는 세계관 등이 다른 단점을 ...',
#   '9',
#   '9',
#   '0',
#   datetime.datetime(2015, 4, 24, 9, 56),
#   0],
#  ['신의심판(leek****)',
#   '보다가 졸았다 너무 유치했고..',
#   '1',
#   '10',
#   '1',
#   datetime.datetime(2015, 5, 2, 2, 37),
#   0],
#  ['R_VD(haye****)',
#   '마블은 미쳤다!!!!',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2015, 4, 24, 9, 42),
#   0],
#  ['NC라인(kang****)',
#   '오늘 보고옴 완전 굿ㅋㅋㅋㅋ',
#   '10',
#   '10',
#   '1',
#   datetime.datetime(2015, 4, 23, 20, 17),
#   0],
#  ['소군(kth9****)',
#   '재미없었음 레알로다가...',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2018, 5, 24, 10, 33),
#   0],
#  ['raji****',
#   '줄거리 핵노잼 1탄이 더 나은듯',
#   '1',
#   '11',
#   '2',
#   datetime.datetime(2015, 6, 10, 20, 10),
#   '관람객'],
#  ['베오울프(azum****)',
#   'ㅋㅋㅋ 급해서 나가긴 머가 급해서나감? 재미가 없어서 더이상 볼필요가 없으니 나가는거지',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2015, 5, 9, 8, 55),
#   0],
#  ['dhfkddl(mina****)',
#   '이젠 뉴스 낚시질에 낚이다니..',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2015, 5, 5, 23, 57),
#   0],
#  ['c537****',
#   '스토리 전개 지겹네요 이런 영화에 10점은 아니네요 옆사람 잡니다 5점 짜리 영화랍니다',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2015, 5, 5, 23, 36),
#   0],
#  ['해피기프트드러머(gtr2****)',
#   '재미없어서 졸았던 영화',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2015, 5, 4, 11, 56),
#   '관람객'],
#  ['NoMark(kara****)',
#   '다량의 물적 투자에 비해.. 연약한 스토리와 연계성 볼거리가 생각보다 아쉬움으로 남네요... CG빼면.. 남는게 없는듯... 기대가 커서인지 실망도 크네요..',
#   '1',
#   '13',
#   '4',
#   datetime.datetime(2015, 4, 26, 20, 24),
#   0],
#  ['Dexter(jera****)',
#   '재미있어요 한국씬 많내요',
#   '10',
#   '13',
#   '4',
#   datetime.datetime(2015, 4, 24, 11, 53),
#   '관람객'],
#  ['dbzl****',
#   '...그냥 아이언맨만..',
#   '1',
#   '14',
#   '5',
#   datetime.datetime(2015, 4, 29, 9, 48),
#   0],
#  ['뭐요네즈(rlar****)',
#   '당분간 다른 영화는 내리시는게 좋을듯...상영관이 아깝네요',
#   '10',
#   '14',
#   '5',
#   datetime.datetime(2015, 4, 23, 12, 15),
#   0],
#  ['jung****',
#   '그저 때리부순 기억말고는  없다',
#   '1',
#   '15',
#   '6',
#   datetime.datetime(2015, 5, 4, 18, 3),
#   0],
#  ['게장(rpwk****)',
#   '뭔내용인지 모르겠슴 `',
#   '1',
#   '15',
#   '6',
#   datetime.datetime(2015, 4, 30, 22, 1),
#   0],
#  ['이승진(celt****)',
#   '과거 회상신이 너무 많고 환각 상태 너무 자주 나와서 짜증남.. 드라마와 이전편들 안보면 내용 이해 어려움. 저는 1점 드립니다.. 졸려 죽을번..',
#   '1',
#   '15',
#   '6',
#   datetime.datetime(2015, 4, 27, 12, 28),
#   0],
#  ['SoulN웅이(oo30****)',
#   '수현 생각보다 많이나오네요 ㅎㅎ  개그요소가 많이 줄었네요. 바른말 캡틴~!!',
#   '9',
#   '15',
#   '6',
#   datetime.datetime(2015, 4, 23, 14, 54),
#   0],
#  ['무면허라이더(kidk****)',
#   '액션이 정말 너무 화려해서 일반적인 스토리는 좀 지루한감이 없지않지만 그래도 액션이!! 액션이!! 헐크vs헐크버스터가 정말 압권이네요',
#   '9',
#   '15',
#   '6',
#   datetime.datetime(2015, 4, 23, 12, 15),
#   0],
#  ['환영(kkt0****)',
#   '스토리 개떡 그래픽도 개떡 이',
#   '1',
#   '16',
#   '7',
#   datetime.datetime(2015, 5, 1, 8, 33),
#   0],
#  ['윤준용(bric****)',
#   '정말 재밌게 보긴 했지만 점점 식상해지는 쿨한 개그들',
#   '7',
#   '16',
#   '7',
#   datetime.datetime(2015, 4, 24, 15, 33),
#   '관람객'],
#  ['깡순이(jmjm****)',
#   '개잼없슴 실망 만퍼센트!',
#   '1',
#   '17',
#   '8',
#   datetime.datetime(2015, 5, 2, 1, 41),
#   '관람객'],
#  ['몰라(ysj_****)',
#   '매우 유치하다 어른이 볼 영화가 아님',
#   '1',
#   '18',
#   '9',
#   datetime.datetime(2015, 4, 28, 12, 58),
#   '관람객'],
#  ['HelenScarlet(gile****)',
#   '그저그랫어요....',
#   '5',
#   '18',
#   '9',
#   datetime.datetime(2015, 4, 24, 14, 39),
#   '관람객'],
#  ['추약사(choo****)',
#   '이거도 아니고 저거도 아니고..작정하고 만든 상업영화',
#   '5',
#   '22',
#   '13',
#   datetime.datetime(2015, 4, 24, 14, 24),
#   '관람객'],
#  ['료미(qhem****)',
#   '지금 막보고 왔습니다 . 정말 기대 많이 했는데 기대이상이다 ! 영화가 끝나도 아직도 잊을수가 없습니다 .영화 내리기전 꼭한번 더볼껍니다 꼭!꼭 보시길 강추!!!강추!!!!이게 재미없으면 사람이 아니다!!!ㅋㅋ',
#   '10',
#   '23',
#   '14',
#   datetime.datetime(2015, 4, 23, 18, 18),
#   0],
#  ['박도현(prrk****)',
#   '어벤저스2 핵잼 1보다 재밌는듯',
#   '10',
#   '26',
#   '17',
#   datetime.datetime(2015, 4, 23, 20, 18),
#   '관람객'],
#  ['ㅎㄴ(ttim****)',
#   '처음 볼땐 잘 몰랐는데 의외로 떡밥투성이;;;',
#   '9',
#   '8',
#   '0',
#   datetime.datetime(2019, 6, 15, 19, 41),
#   0],
#  ['김따뚜(khj1****)',
#   '와씨 지금OCN으로다시봤는데 끝에토르,캡틴, 토니의 대화가....이런 떡밥이.. 진짜 마블의 떡밥회수는 기가막힘다시 모든 마블영화22편 정주행갑니다',
#   '10',
#   '8',
#   '0',
#   datetime.datetime(2019, 4, 28, 15, 7),
#   0],
#  ['총(7851****)',
#   '그럭저럭임 1편이랑 다를게없음',
#   '7',
#   '8',
#   '0',
#   datetime.datetime(2015, 4, 29, 19, 54),
#   '관람객'],
#  ['쥐뽕(invu****)',
#   '지루한감이 있어서 처음에는 지루했는데 중간부분부터확 살아나서 잼나게봤음',
#   '6',
#   '8',
#   '0',
#   datetime.datetime(2015, 4, 29, 0, 52),
#   '관람객'],
#  ['짐새(tpfu****)',
#   '다시 보니까 캡틴 마지막에 하려던 대사가 어셈블인가보네..',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 5, 4, 1, 1),
#   0],
#  ['trac****',
#   '여전히 화려하고 시원하지만 기대감을 충족시켜주진 못한다',
#   '6',
#   '9',
#   '1',
#   datetime.datetime(2018, 5, 3, 0, 12),
#   0],
#  ['좀 웃어봐(sgh3****)',
#   '어벤져스3 이후로 복습차 다시 보는 중인데, 이 영화도 스토리랑 액션도 나름 괜찮다. 다만, 울트론이 너무 약하게 나온 것 같아서 아쉬울뿐..말만 많고. 난이도를 더 올려주면 좋았을텐데.',
#   '8',
#   '9',
#   '1',
#   datetime.datetime(2018, 4, 29, 21, 20),
#   0],
#  ['노코멘또(sjss****)',
#   '이런건 좀 지겹고 지루하네',
#   '1',
#   '9',
#   '1',
#   datetime.datetime(2015, 12, 14, 23, 34),
#   0],
#  ['설리반(taki****)',
#   '쉴드에서 일하던 남자 애 나오길래 버키 반즈도 나오나 쿠키 지나고 크래딧 지날 때까지 기다렸는데... 이건 두번보고 세번 보고 네번 보셈.',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2015, 4, 23, 19, 36),
#   0],
#  ['빨대로만든부채(337g****)',
#   '졸려죽는줄 알았음.헉.',
#   '1',
#   '10',
#   '2',
#   datetime.datetime(2015, 4, 29, 17, 11),
#   0],
#  ['몰러(haha****)',
#   '한국씬 생각보다 한국스럽지 않게 나와서 보기 좋았다 떡뽁이 간판만 좀 오글거리고 ㅋㅋ 헐크버스터랑 헐크 싸울때 와 개 감동~',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2015, 4, 23, 18, 47),
#   0],
#  ['봄이(8844****)',
#   '극장 점령 너무한거 아니냐 !!! 자다왔습니다..만화에 추억없는 분들은 보지마시길 ㅜㅜ',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2015, 5, 6, 1, 8),
#   0],
#  ['gard****',
#   '존니유치함. . .ㅇ.',
#   '1',
#   '11',
#   '3',
#   datetime.datetime(2015, 5, 5, 14, 44),
#   0],
#  ['hong****',
#   '내용이 조금은 어수선 하기는 하지만 액션신은 볼만했습니다.',
#   '8',
#   '11',
#   '3',
#   datetime.datetime(2015, 4, 25, 7, 34),
#   '관람객'],
#  ['MIE(ravi****)',
#   '영화관에서 영화보다가 졸기는 처음. 서울에서 촬영했다는거 하나만으로 흥행거품이 심하다.',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2015, 5, 8, 23, 55),
#   0],
#  ['낙화유수(vick****)',
#   '가족끼리 영화 보러 갔는데 극장에 이 영화가 많이 걸려있고 시간이 맞아서 보게 됐다. 시리즈물을 전혀 안보고 배경지식 없이 봤더니 무슨 내용인지 알기 어려웠다. 가족 모두 잠만 잤다ㅠㅠ',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2015, 5, 7, 23, 58),
#   0],
#  ['stre****',
#   '할인받아 만원에 둘이서 봣습니다 1000원이면 볼만한듯 귀천도애 이후 극장에서 도중에 나간적은 첨입이다',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2015, 5, 7, 21, 40),
#   0],
#  ['여행(sukm****)',
#   '아놔~ 알바들...평점보소....',
#   '1',
#   '12',
#   '4',
#   datetime.datetime(2015, 5, 4, 17, 31),
#   0],
#  ['오늘(flpd****)',
#   '전작에 비해 내용이 좀 어두워진 느낌에, 기대가 컸던 탓인지 크게 만족스럽진 않다. 서울 장면 역시 한국이라는 나라를 드러내기엔 시간도, 특색도 모자랐다. 하지만 지루할 틈 없는 어벤져스의 활약과 마블 유니버스의 이...',
#   '8',
#   '12',
#   '4',
#   datetime.datetime(2015, 4, 23, 22, 31),
#   0],
#  ['이쑥맹(heze****)',
#   '예고편으로만은 결코 이영화를 예상 할수없다.',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2015, 4, 23, 20, 14),
#   0],
#  ['wwwr****',
#   '볼거리 풍부!! 이거 하나로도 돈을 쓰기 아깝지 않은 영화',
#   '10',
#   '12',
#   '4',
#   datetime.datetime(2015, 4, 23, 12, 45),
#   0],
#  ['카사오(fort****)',
#   '너무 지루함.. 재미없습니다..',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2015, 5, 18, 17, 35),
#   '관람객'],
#  ['푸르딩딩(hyej****)',
#   '평점이 너무 높네ㅠㅠ 난 보다 중간에 잠듦.... 싸울때만 깨고 ㅠㅠ 내용이 너무 난잡하고 싸우는씬만 재밌음.. 나머진 그닥 .. 1은 재밌게 봤는데 2는 정말 많이 실망 ㅠㅜ 너무 유치했음....',
#   '1',
#   '13',
#   '5',
#   datetime.datetime(2015, 4, 28, 0, 54),
#   0],
#  ['붉은달(abcd****)',
#   '재미있었음 특히 헐크 랑 아이언맨 싸울때 크..',
#   '10',
#   '13',
#   '5',
#   datetime.datetime(2015, 4, 23, 20, 12),
#   '관람객'],
#  ['뢰(whd3****)',
#   '역시 어벤져스는배신을하지않아',
#   '10',
#   '13',
#   '5',
#   datetime.datetime(2015, 4, 23, 16, 36),
#   '관람객'],
#  ['souj****',
#   '진짜 잼잇냐 어디가 잼잇다는거여',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2015, 5, 7, 5, 40),
#   0],
#  ['세상의모든것들(sm64****)',
#   '고작 서울시 나온다고 보는새1끼들 노이해 ㅉㅉ',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2015, 5, 6, 21, 35),
#   0],
#  ['작은 별 통신(dkfl****)',
#   '보다가잠들었어요..',
#   '1',
#   '14',
#   '6',
#   datetime.datetime(2015, 4, 25, 17, 7),
#   0],
#  ['emfm****',
#   '큰기대를 안하는게 오히려 좋은감상이 될수있는 영화...너무 짧게나온게 스토리진행에 방해된다고 느낌..차라리 1시간더늘리는게 좋았을영화임',
#   '6',
#   '14',
#   '6',
#   datetime.datetime(2015, 4, 23, 21, 36),
#   '관람객'],
#  ['탱자탱자(yunm****)',
#   '너무 잘자서 내용을 모르겠네요....',
#   '1',
#   '15',
#   '7',
#   datetime.datetime(2015, 4, 27, 13, 7),
#   0],
#  ['janu(in_m****)',
#   '이번은 킬링타임용~인듯^^',
#   '6',
#   '15',
#   '7',
#   datetime.datetime(2015, 4, 25, 10, 26),
#   '관람객'],
#  ['밥통모바일(sons****)',
#   '오늘 오전9시 건대에서 봄 순식간에 영화종료',
#   '10',
#   '16',
#   '8',
#   datetime.datetime(2015, 4, 23, 20, 18),
#   0],
#  ['K2J(k2g2****)',
#   '울트론 귀는 당나귀귀!!!',
#   '10',
#   '16',
#   '8',
#   datetime.datetime(2015, 4, 23, 12, 16),
#   '관람객'],
#  ['너를위해만들었어(nghy****)',
#   '말이 필요 없다....',
#   '10',
#   '16',
#   '8',
#   datetime.datetime(2015, 4, 23, 10, 51),
#   0],
#  ['봉구(hoya****)',
#   '10살미만이시라면 보세요~좋아하는 사람과 좋아하는 영화보러 왔는데너무 정신없고 산만하기만 하네요',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2015, 5, 2, 22, 11),
#   '관람객'],
#  ['규바히(rjsd****)',
#   '뻔한 스토리 잠올뻔 ㅋㅋㅋ',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2015, 4, 25, 0, 37),
#   0],
#  ['asdf(rqat****)',
#   '소문난 잔치에 먹을 것 없다. 너무 재미없었음',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2015, 4, 24, 0, 11),
#   0],
#  ['긍정의힘(csh3****)',
#   '재밌네요~시간 가는줄 몰랐음',
#   '10',
#   '20',
#   '12',
#   datetime.datetime(2015, 4, 23, 18, 20),
#   '관람객'],
#  ['Lee(bonv****)',
#   '엔드게임보고나서 OCN에서 해주길래 다시 보니 몇년전에 보고 슥 지나갔던 부분들이 뭔가 퍼즐맞춰지는 듯한 기분이랄까요. 1편보단 확실히 떡밥 많이 뿌리네요.',
#   '8',
#   '7',
#   '0',
#   datetime.datetime(2019, 5, 4, 1, 7),
#   0],
#  ['jabe(qwqw****)',
#   '이영화가 잘못한거 3개때문에 3점 뺀다1.옆동네에선 총알을 가지고 놀던 애가 여기선 총맞아 죽음2.브루스 배너와 블랙위도우의 어올리지도않는 연애3.감히 우리 울느님을 중2병걸린 비브라늄성애자 깡통 로봇으로 만들어? ...',
#   '7',
#   '7',
#   '0',
#   datetime.datetime(2018, 3, 4, 18, 27),
#   0],
#  ['psal****',
#   '악당이 컨셉은 최고였으나 싱겁게 끝난 느낌주인공이 많아 스토리가 산만한 느낌',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2015, 4, 29, 20, 42),
#   '관람객'],
#  ['하얀나라(hyun****)',
#   '정신이 없고 내용이 없더요.... 아들하고 즐거운 시간을 보냈더요',
#   '7',
#   '8',
#   '1',
#   datetime.datetime(2015, 4, 28, 7, 57),
#   '관람객'],
#  ['HyoS(geon****)',
#   '억지감동 한국영화보단 나은듯',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2018, 2, 21, 18, 49),
#   0],
#  ['허정무(aste****)',
#   '어벤져스 핵노잼 무슨 내용인지 모르겠다.',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2015, 5, 5, 14, 25),
#   0],
#  ['다람쥐(jins****)',
#   '커다란 상상에 좀 못미치는...',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2015, 5, 5, 14, 12),
#   0],
#  ['Planetarium(seao****)',
#   '한국이 나올 이유가 전혀 없었던 영화',
#   '7',
#   '10',
#   '3',
#   datetime.datetime(2019, 4, 24, 16, 38),
#   0],
#  ['surge55(stom****)',
#   '수준높은 파워레인저. 머리에서 빔 쏠 때 유치함의  극치를 보여주었다.',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2015, 5, 14, 9, 8),
#   0],
#  ['일체유심조(kor2****)',
#   'CG 라든지영상은 잘 만든 작품이나  손발이 오그라드는 유치함. 가벼운  미국 만화가 원작이라 그럴지도. 스토리라든지 진지한 영화를 좋아하는 어른에게는  맞지 않을듯합니다. 7.5정도가 적당. 단순히 부수는 잘만든 ...',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2015, 5, 6, 19, 12),
#   0],
#  ['고릴라(alvi****)',
#   '조금 별로였습니다. 앞으로 잘해주세요.',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2015, 5, 1, 20, 57),
#   0],
#  ['난201이다(toug****)',
#   '게이버 수준 봐라 ㅉㅉㅉㅉ',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2015, 5, 1, 1, 34),
#   0],
#  ['요구기(gang****)',
#   '마블이 미쳤다 ㅋㅋ 아니 고맙다 이런 영화를 볼 수 있게 해준 마블 ㅋㅋ 너무 잼있게 봤네 ㅋㅋ 어벤저스 에이지오브울트론을 즐기려면 지금까지 나온 마블영화 챙겨보길 권함..',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 24, 14, 28),
#   0],
#  ['qudw****',
#   '너무 재미있다 다음이 너무너무 기대된다. 계속 후속작 봐야해서 오래 살아야 겠다는 생각이 든다.',
#   '9',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 24, 10, 47),
#   0],
#  ['봄언니(xown****)',
#   '실수를 만회하고 싶으니깐 아주 잘 만든 만화영화를 보며 훌쩍훌쩍 ㅜ헐크....ㅠ',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 23, 20, 16),
#   0],
#  ['ping****',
#   '예고편은 껌입니다 직접 보세요 팝콘먹을 정신따위 없습니다 진짜 짱짱어벤져스',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 23, 19, 21),
#   0],
#  ['ㅇㅇㅋ(kth2****)',
#   '역시나 옳은 선택이였습니다 ㅋ',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 23, 19, 6),
#   0],
#  ['쵸파(rlag****)',
#   '영화관 마블충 극혐 인피니트스톤이고 히든영상이고 뭐만나오면 나왓다고 아는척오지네 ㄷㄷ',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2015, 4, 23, 13, 35),
#   0],
#  ['alas****',
#   '매번 똑같은 미국의 영웅주의 히어로물(내용이 밑도 끝도 없음. ),,팀원의 반대에도  캡틴은 소수의 희생을 용납하지 않으며, 한두명의 영웅이 죽지만  일반인의 희생없이 적을 물리친다. 그러나 결국 새로운 악당이 나타...',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 13, 17, 5),
#   0],
#  ['rgyn****',
#   '지루 스토리 없는 완전실망 ㅠ',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 10, 12, 46),
#   '관람객'],
#  ['감사사랑(puri****)',
#   '길고 지루하네요 강비추',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 7, 21, 38),
#   0],
#  ['골드맨(1293****)',
#   '그냥 진심 씹노잼이었다 폼만 잡다 끝나네',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 7, 21, 0),
#   0],
#  ['Ronaldo(jyh6****)',
#   '억지작렬 개연성 제로 다 때려부수기식 스토리구성,수현 발연기,3류코미디급 유머가 이루어낸 마블의 블록버스터급 파워레인져',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 5, 0, 3),
#   0],
#  ['sang****',
#   '친구가 스포함....',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 4, 11, 40),
#   0],
#  ['번트홈런(dada****)',
#   '스타크가 싸지른 똥에 엄한 시민들만 허우적대다가 똥을 닦아내자 아무런 일 없다는듯 영웅되는..  하지만 사방에 묻은 똥들.. 이해되지도 이해하고싶지도 않은 스토리',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 2, 18, 52),
#   0],
#  ['kkqoqo(flyh****)',
#   '노잼 할말도없다.. 진심이다',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 2, 16, 47),
#   0],
#  ['Alue(wjsw****)',
#   '하?! 도데체 왜 이런 영화가 성화인지 납득이 안 갑니다. 개연성 없는 스토리에 액션신은 무의미하게 변모하고, 유아층을 대상으로 하는게 아닌지 의심스러운 이상한 전개입니다. 한국 촬영은 무슨 제 3국으로 표현되고, ...',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2015, 5, 2, 8, 15),
#   0],
#  ['gmy2****',
#   '스케일은 컸다 .스칼렛 요한슨은 이뻤다 .',
#   '6',
#   '11',
#   '4',
#   datetime.datetime(2015, 4, 29, 19, 58),
#   0],
#  ['떡냠냠꼬기냠냠(bana****)',
#   '심오한 작품이였어요. 여태까지 단순히 웃고떠들던 시리즈들과는 다르게 진지했네요',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2015, 4, 23, 19, 51),
#   '관람객'],
#  ['bloo****',
#   '죨 재미없음.. 보다가 잤음..',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2015, 5, 5, 23, 41),
#   0],
#  ['멸치볶음(noma****)',
#   '히어로들이 악당과 싸우는 동안에 난 졸음과 싸웠어...',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2015, 5, 5, 11, 13),
#   0],
#  ['헤븐즈(yiys****)',
#   '스토리 최악 각 캐릭터성 일부 최악 뜬금 진행 뭐야 이거',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2015, 5, 1, 17, 49),
#   '관람객'],
#  ['suhyeon(suhy****)',
#   '나오자마자 또 보고싶어지는 상반기 최고의영화!!',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2015, 4, 25, 7, 10),
#   '관람객'],
#  ['돈한푼만(7tra****)',
#   '믿힌놈들아 마블에서 알바쓰면 워너브라더스도 알바 쓰겠넼ㅋ늬들이 좋아하는 알바쓰는 장수상회나 보세욬',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2015, 4, 24, 13, 36),
#   0],
#  ['길(kait****)',
#   '그냥 말 다 필요없고 예매하십쇼',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2015, 4, 23, 20, 16),
#   0],
#  ['daek****',
#   '좋은 재료로 평범한 음식을 만든 감독을 내칩시다!!!!',
#   '6',
#   '12',
#   '5',
#   datetime.datetime(2015, 4, 23, 18, 2),
#   0],
#  ['kdm7****',
#   '구로 CGV 조조보고 왔습니다. 정말 꿀잼잼잼!  1편보다 액션 훨씬 화려합니다. 서울신도 비중있고 좋구요, 이전 시사회 평론가 리뷰가 너무 깍아내리려 쓴거 아닌가 합니다. 액션영화는 액션으로 평해야죠. 헐크와 헐크...',
#   '9',
#   '12',
#   '5',
#   datetime.datetime(2015, 4, 23, 13, 57),
#   0],
#  ['두발(tttc****)',
#   '솔직히별로였음 .. 어벤져스는 캐릭터가많은게 장점이작단점인데 패싸움만하고 울트론은오ㅔ케약한지 ㅉㅉ',
#   '6',
#   '13',
#   '6',
#   datetime.datetime(2015, 4, 23, 17, 43),
#   0],
#  ['청운의꿈(soja****)',
#   '이렇게 지루한 액션은 처음이다. 사공이 많으면 배가 산으로 간다는 속담이 틀린게 아니군.',
#   '1',
#   '15',
#   '8',
#   datetime.datetime(2015, 4, 27, 11, 56),
#   0],
#  ['유천독재(kill****)',
#   '평론가 미쳤냐? 그리고 여기 재미없다는 사람들이 재밌게 본 영화가궁금하네 개인적으로 1편은 좀 유치했는데 2편은 액션. 동료들의 유대감. 스토리. 그리고 어벤져스라는 팀이 더욱 돋보였다. 대박임 ㅋㅋ 심오한 스토리라...',
#   '10',
#   '15',
#   '8',
#   datetime.datetime(2015, 4, 24, 9, 57),
#   0],
#  ['시유(nrzr****)',
#   '음량이 너무 커서 불쾌할정도로 내내 귀가 아팠어요. 개연성도 없고 산만하고.. 지루해서 잠들기까지 했네요ㅠㅠ 하도 주변에서 어벤져스 어벤져스 하길래 기대하고 봤는데도.',
#   '1',
#   '16',
#   '9',
#   datetime.datetime(2015, 4, 25, 16, 41),
#   0],
#  ['VICIOUS(ohmn****)',
#   '이건 뭐.. 전작 빌미로 깎아 내리려고 눈을 씻고 봐도 깔 데가 없네',
#   '10',
#   '17',
#   '10',
#   datetime.datetime(2015, 4, 23, 19, 40),
#   0],
#  ['와황(gbwl****)',
#   '1탄에 비해 진짜 한 4배는 재밌어진듯',
#   '10',
#   '33',
#   '26',
#   datetime.datetime(2015, 4, 23, 15, 22),
#   0],
#  ['yana****',
#   '무난하다고 본다...',
#   '7',
#   '6',
#   '0',
#   datetime.datetime(2019, 9, 16, 10, 17),
#   0],
#  ['쿵쿵뿜뿜(love****)',
#   '1보다 못하지만 cg는 대박',
#   '8',
#   '6',
#   '0',
#   datetime.datetime(2019, 8, 24, 23, 6),
#   0],
#  ['망고(sks9****)',
#   '완전재밌는데? 엔드게임보고 오니 대박...',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 5, 6, 13, 43),
#   0],
#  ['김혜승(gptm****)',
#   '엔드게임보고 이거 다시보면 떡밥 회수 대박입니다 ㅜㅠ역시 어벤져스 꿀잼ㅂ',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 5, 2, 23, 28),
#   0],
#  ['반달고양이(rkdt****)',
#   '와 엔드게임 보고 다시보니까 더 재밌네마지막 캡틴아메리카나오는 장면에서 다시 소름ㅋㅋ',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 28, 15, 21),
#   0],
#  ['오르막길(dncj****)',
#   '외국인 사이에 껴서 그런가 수현 표정이나 말투 연기가 너무 어색해보임...',
#   '9',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 28, 14, 12),
#   0],
#  ['ahj9****',
#   '토니스타크 : 울트론군단을 만들어 타노스와 싸울 준비를 해둿어야됫다.캡틴 : 놉.',
#   '10',
#   '6',
#   '0',
#   datetime.datetime(2019, 4, 26, 21, 41),
#   0],
#  ['fabulous(oasi****)',
#   '설정도 빈틈이 많고 쿠키도 시리즈 중 가장 못하다.',
#   '7',
#   '7',
#   '1',
#   datetime.datetime(2019, 10, 31, 13, 6),
#   0],
#  ['재(jin5****)',
#   '수현은 뭐지? 왜 갑자기 어벤져스 인 척하며 나타나는건지... "왜 우릴(어벤져스) 죽이려하지?" 이 대사 왜 치는거임?',
#   '6',
#   '7',
#   '1',
#   datetime.datetime(2019, 4, 28, 21, 13),
#   0],
#  ['차칸남자(mien****)',
#   '빛 좋은 개살구같은 영화! 중간 중간 지루함을 이겨내면 화려한 액션신을 볼수있음',
#   '5',
#   '7',
#   '1',
#   datetime.datetime(2018, 6, 12, 16, 41),
#   0],
#  ['크세(zmtp****)',
#   '후반부빼면  갠적으로 그닥이었음',
#   '2',
#   '7',
#   '1',
#   datetime.datetime(2018, 5, 20, 11, 56),
#   0],
#  ['건배(rrat****)',
#   '진심 핵노잼... 이걸 보고 왜 열광하는지 모르겠음',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2015, 12, 26, 11, 4),
#   0],
#  ['JYL(meme****)',
#   '기대이하.. 한국홍보는 개뿔',
#   '1',
#   '7',
#   '1',
#   datetime.datetime(2015, 5, 2, 2, 10),
#   0],
#  ['리리라(zse7****)',
#   '마지막 교회 전투에서 스파이더맨만 있었으면 영화사 길이 남을 명장면이었을듯... 지렸다',
#   '10',
#   '7',
#   '1',
#   datetime.datetime(2015, 4, 26, 6, 12),
#   0],
#  ['blac****',
#   '퀵실버가 여기서 안 죽었더라면, 타노스가 손놀림 하기 전에 장갑 벗길 수 있었을 텐데.. 아이언맨 안 죽어도 됐었을텐데..',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2019, 5, 19, 22, 24),
#   0],
#  ['tar(tarc****)',
#   '역시 어벤 감독은 루소가 갑',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2019, 4, 14, 0, 53),
#   0],
#  ['호랑이 파워(wpwn****)',
#   '전 편보다는 별로지만 나쁘지는 않았다. 하지만 마블의 몇 안되는 실패작.',
#   '7',
#   '8',
#   '2',
#   datetime.datetime(2018, 6, 14, 1, 53),
#   0],
#  ['희동이(skcw****)',
#   '평점 7점 대가 적당한듯 1편은 잼있었는데',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2015, 5, 14, 9, 38),
#   0],
#  ['HOUND(sean****)',
#   '울트론이 너무 약하게 나와...',
#   '1',
#   '8',
#   '2',
#   datetime.datetime(2015, 5, 5, 13, 43),
#   0],
#  ['꿈을준비중(rlaq****)',
#   '감독이 여러 사회문제데 대한 비판과, 인간과 영웅 사이의 갈등에 대한 개개인의 고통을 그리려 초반에 많은 노력을 기울었으나, 액션신만 기대하고 온 수준 낮은 관객들이 초반에 전부 실망할까 걱정되는... 그래도 솔직히...',
#   '9',
#   '8',
#   '2',
#   datetime.datetime(2015, 4, 23, 19, 29),
#   0],
#  ['cacao(duat****)',
#   '진짜 재미없음 돈아깝다',
#   '1',
#   '9',
#   '3',
#   datetime.datetime(2015, 5, 13, 18, 59),
#   0],
#  ['xdiv****',
#   '재미커녕 짜증  갈수록 짜증 .... 그만좀 했으면 하는 바램',
#   '1',
#   '9',
#   '3',
#   datetime.datetime(2015, 5, 13, 2, 5),
#   0],
#  ['미녀주얼(rnrw****)',
#   '으 기대 이하엿어요  영웅들이 많은데 2시반30분동안 스토리짜기엔 벅찬듯ㅜㅜㅜ 후회대고 돈아까워요',
#   '1',
#   '9',
#   '3',
#   datetime.datetime(2015, 5, 7, 14, 3),
#   0],
#  ['퐁퐁가족(abbe****)',
#   '졸다깨다 자다깨다 30분전에 뛰쳐나감. 마블의엄청난매니아를 위한 서비스영화. 스토리의 전달력,개연성따윈 개나줘버려. 아들도 졸고 남편은궁시렁. 포켓몬극장판 보는게 낫지.',
#   '1',
#   '9',
#   '3',
#   datetime.datetime(2015, 5, 7, 13, 49),
#   0],
#  ['shzm****',
#   '마블거품임. 솔직히 시리즈물 이런거 없이 단독으로 나온 영화였으면 8점도 못받았을 영화',
#   '1',
#   '9',
#   '3',
#   datetime.datetime(2015, 4, 30, 21, 21),
#   0],
#  ['데굴이다(1tjw****)',
#   '졸린데도 심야로 봤는데 점점 눈떠지는 클래스 영화',
#   '9',
#   '9',
#   '3',
#   datetime.datetime(2015, 4, 24, 11, 54),
#   0],
#  ['hsto****',
#   '엄청재밋게봄 왜케 기자들한테 까이는지모르겟네',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2015, 4, 24, 11, 50),
#   0],
#  ['신기남(xbff****)',
#   '액션씬 후덜덜하게 잘만들었네나타샤의 헐크꼬시기 OO시하다',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2015, 4, 23, 19, 41),
#   0],
#  ['하일미믹(hail****)',
#   '어벤져스2는 다른 마블 영화까지 전부 보고가야 100% 뽑아낼 수 있는 영화입니다. 달랑 아이언맨1하고 어벤져스1 봐놓고 보면서 이해 안 된다. 어렵다. 하는 분들은... 쩝. 후속 영화란 개념이 괜히 있는 게 아니...',
#   '10',
#   '9',
#   '3',
#   datetime.datetime(2015, 4, 23, 15, 19),
#   0],
#  ['전우진(dsky****)',
#   '핵노잼줄거리 없이 싸우다가 끝남서울시가 22억지원한게 한심',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 9, 9, 21, 7),
#   0],
#  ['멍멍(sure****)',
#   '쓰레기. 이게 1000만 영화에 평점 8.27이라니 미쳤네 미쳤어',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 27, 17, 5),
#   0],
#  ['back****',
#   '이게 재밋다면 한국수준이 바닥인걸 인정한 영화',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 9, 12, 40),
#   0],
#  ['깍두기(noma****)',
#   '이거 평점이 왜 그럼? 8점? 말도 안되네 이거 볼꺼면 그냥 기부하세요',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 9, 8, 41),
#   0],
#  ['리피로스(hotr****)',
#   '아이언맨 1 빼고 다 그지같은 내용',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 8, 0, 44),
#   0],
#  ['세봉(rudt****)',
#   '내가 뭘 본거지. . 같이 간 동반자여 또 한번 미안',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 5, 16, 16),
#   '관람객'],
#  ['정리와추론(heyp****)',
#   '보다 잠들었음 핵노잼 ㅜㅜ',
#   '1',
#   '10',
#   '4',
#   datetime.datetime(2015, 5, 5, 5, 46),
#   0],
#  ['juju****',
#   '감동.꿀재미 다잡음.  최고다진심',
#   '10',
#   '10',
#   '4',
#   datetime.datetime(2015, 4, 24, 18, 41),
#   0],
#  ['나스키(qhtj****)',
#   '매드맥스 분노의질주 보고 이거 보니까 어벤져스 오징어되버렷내 ;;; 한국나오는거부터  망작이야',
#   '1',
#   '11',
#   '5',
#   datetime.datetime(2015, 5, 15, 10, 44),
#   0],
#  ['아리별(twin****)',
#   '진짜너무재밋어요ㅠㅠㅠ어벤져스사랑해요',
#   '10',
#   '11',
#   '5',
#   datetime.datetime(2015, 4, 24, 1, 49),
#   '관람객'],
#  ['라라랑(oitp****)',
#   '기대많이했는데 역시는역시에여 또볼겁니다',
#   '10',
#   '12',
#   '6',
#   datetime.datetime(2015, 4, 23, 19, 36),
#   '관람객'],
#  ['sksk****',
#   '내용이 1점만큼 쓰레기는 아니지만 전체 평점 좀 낮춰야한다. 내가 마블팬이지만 내용개거지임. 한국도대체 왜 배경으로쓴거니. 영화보는내내 웃겨서 영화에 몰입방해됨. 내용만 괜찮으면 3번볼생각도 있었는데 돈아까움.',
#   '1',
#   '14',
#   '8',
#   datetime.datetime(2015, 5, 4, 18, 5),
#   '관람객'],
#  ['YaphetS(yaph****)',
#   '핵노잼잠와죽을뻔햇다',
#   '1',
#   '14',
#   '8',
#   datetime.datetime(2015, 4, 29, 19, 26),
#   '관람객'],
#  ['페이커(apxk****)',
#   '전체적으로 전작보다는 스케일이 커진 느낌?어벤져스들 위기와 그걸 극복하는 과정 그리고 수많은 복선들이 잘 어우러져 있다',
#   '9',
#   '14',
#   '8',
#   datetime.datetime(2015, 4, 23, 12, 22),
#   '관람객'],
#  ['뜨꾸(dhgh****)',
#   '별로재미없네요 ㅎㅎ..',
#   '1',
#   '17',
#   '11',
#   datetime.datetime(2015, 4, 25, 13, 11),
#   '관람객'],
#  ['보리(euni****)',
#   '그냥 그래요 그냥 그래요',
#   '1',
#   '22',
#   '16',
#   datetime.datetime(2015, 4, 26, 2, 6),
#   '관람객'],
#  ['김형준(rosh****)',
#   '울트론 너무 쉽게 발린것 같아 아쉽....',
#   '8',
#   '5',
#   '0',
#   datetime.datetime(2019, 9, 19, 6, 52),
#   0],
#  ['mooon(dbst****)',
#   '어벤져스 어셈블!!!!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2019, 4, 20, 9, 7),
#   0],
#  ['엔비(ksh8****)',
#   '중2병 걸린 울트론과 히어로들의 대결!아이언맨은 이사태를 어떻게 책임져야하는지,..',
#   '7',
#   '5',
#   '0',
#   datetime.datetime(2018, 5, 22, 22, 22),
#   0],
#  ['ll(rhfl****)',
#   '볼만하고 후회없습니다. 재미써요!!!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 10, 23, 20, 16),
#   '관람객'],
#  ['작은기니(andt****)',
#   '이런 히어로물에서 복잡한 스토리나 개연성 보다 볼거리 캐릭터의 매력이 가장 중요한 것이라 생각합니다. 애초에 어벤져스가 다른 세계관인물을 짜깁어 놓은건데 예기가 딱딱 맞아들면 이상한 거죠',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2015, 4, 24, 18, 49),
#   '관람객'],
#  ['SPRING(bomb****)',
#   '쉴틈없는 액션과 볼거리는 만점!!하지만 특유의 위트는 약했던 편.팀의 모토와 존재이유에 대한 분명하고 비유적인 대사는 좋았으나 전개가 점점 단순해지는듯..더 탄탄한 스토리와 결속력이 있어야할듯. 또 무지막지하고 뜬금...',
#   '9',
#   '5',
#   '0',
#   datetime.datetime(2015, 4, 24, 16, 39),
#   '관람객'],
#  ['950427(a12e****)',
#   '어벤져스 시리즈중 가장 낮은 완성도라 생각되는... 울트론은 원작처럼 이때까진 비전과 비슷하게 우호적이였다 적이되는 루트가 더 어땟나싶은...',
#   '6',
#   '6',
#   '1',
#   datetime.datetime(2019, 9, 8, 3, 30),
#   0],
#  ['바카요코하마(grea****)',
#   '캡틴 방패에 위치추적기좀 달아주셍. 던져놓고 못찾을까봐 걱정됨',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 8, 15, 21, 37),
#   0],
#  ['사랑돼지(love****)',
#   '음....그닥 별로임',
#   '5',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 12, 20, 39),
#   0],
#  ['컴맹(your****)',
#   '어벤져스1에 비해 중구난방인 느낌. 헐크가 항상 극중 몰입을 깬다. 이제 제발 돌아오지마',
#   '6',
#   '6',
#   '1',
#   datetime.datetime(2018, 5, 6, 17, 53),
#   0],
#  ['acti****',
#   '"I will do it myself." - Thanos',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 26, 0, 22),
#   0],
#  ['공듀(grun****)',
#   '액션은 좋았지만 이것을 뒷받침 해주지 못하는 스토리',
#   '6',
#   '6',
#   '1',
#   datetime.datetime(2018, 4, 9, 22, 15),
#   0],
#  ['까만태양(supd****)',
#   '깔라고 맘먹으면 무슨영화든 못까겠냐만 영화를 보면서 즐겁고 보고나서도 후회없는 영화라는 말은 할 수 있음.',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2015, 4, 30, 15, 32),
#   '관람객'],
#  ['dlgm****',
#   '최근나온 분노의질주나 킹스맨보다는 느슨함이 있었지만, 그래도 마블은 마블이고 어벤져스니까 무조건. 봐줘야만 하는 그런 영화ㅎㅎ 새로운 영웅들과 다음편이 또 기대됨',
#   '8',
#   '6',
#   '1',
#   datetime.datetime(2015, 4, 28, 18, 58),
#   '관람객'],
#  ['ㅇㅇㅇ(answ****)',
#   '헐크va아이언맨 싸움 굿',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2015, 4, 25, 20, 59),
#   '관람객'],
#  ['효루(alfk****)',
#   '나한텐 마냥 그냥 좋은 영화ㅋ',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2015, 4, 25, 15, 18),
#   '관람객'],
#  ['c987****',
#   '넘재미없고 아이는 재미있어하는것같음',
#   '1',
#   '7',
#   '2',
#   datetime.datetime(2015, 5, 5, 18, 5),
#   '관람객'],
#  ['lykl****',
#   '굿굿  아이언맨 너무 멋있어요',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2015, 4, 25, 4, 1),
#   '관람객'],
#  ['aimme(less****)',
#   '약간 유치하고 소재가 이제 슬슬 부족해 보이지만 개그코드도 많이 넣고 노력한티가 잇어서 웃으며 재밌게 볼만함',
#   '8',
#   '7',
#   '2',
#   datetime.datetime(2015, 4, 25, 2, 56),
#   '관람객'],
#  ['체리소녀(pink****)',
#   '헐크 서비스신 많아서 좋았어요..!! 헐크 사랑해요',
#   '10',
#   '7',
#   '2',
#   datetime.datetime(2015, 4, 24, 2, 9),
#   '관람객'],
#  ['강동엽(rkdd****)',
#   '아쉬움이 남는 화려한 액션',
#   '6',
#   '7',
#   '2',
#   datetime.datetime(2015, 4, 23, 20, 40),
#   '관람객'],
#  ['Mac(mac_****)',
#   'bbbb올해 최고의 영화',
#   '9',
#   '7',
#   '2',
#   datetime.datetime(2015, 4, 23, 20, 28),
#   '관람객'],
#  ['뿡뿡빵(apoc****)',
#   '내용도 꽤 충실하고 캐릭터 하나하나 비중있음 재밌음ㅋㅋ',
#   '9',
#   '7',
#   '2',
# ...
#   datetime.datetime(2015, 4, 25, 7, 56),
#   0],
#  ['Soul쥐(hanj****)',
#   '로키가 원흉이고 마지막에 죽는다!!',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 7, 53),
#   0],
#  ['joon(joon****)',
#   '그런데 퀵실버의 능력을 표현한건  엑스맨이 갑인것같다',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 7, 39),
#   0],
#  ['카리츠(iskf****)',
#   '코믹스 스토리대로 안가는 게 맘에 듬..이대로 가면 캡아가 안죽을지도 몰라!보기전에 관람평이 굉장히 안 좋아서 약간 실망했으나 원래 마블 팬이었다면 즐겁게 관람하고 만족감도 느낄 수 있을 그 정도 수준은 됨.알고보면...',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 5, 23),
#   0],
#  ['s(kkum****)',
#   '아이맥스로 4째줄 정중앙에서봤는데 기대를 저버리지 않았다.',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 4, 57),
#   0],
#  ['myak****',
#   '마블의 코믹함과 극중 배우들의 맡은 역과 호흡이 정말 볼만했으나 내용이 너무 기억에 남지를 않을만큼 이펙트가 없었는거 같다. 소문난 잔치에 먹을께 없는 느낌이랄까?',
#   '7',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 3, 8),
#   0],
#  ['dope****',
#   '1은 2를 기대하게 만들고 2는 3를 기대하게 만든다. 타노스 쿠키나올때 몇몇 남성분들 으아아 !! 하는 소리 들을수 있다. 마블 팬으로써 꾸준히 이 장편 드라마같은 긴 얘기들을 보고 기다릴수 있는것에 감사하다!',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 2, 47),
#   0],
#  ['김혜린(khr5****)',
#   '어벤져스 1편과는 다르게 휴머니즘과 히어로들의 각 개성,내면?모두 다 잘 살려냈고,마블 특유의 유머코드가 중간중간 빵빵 터지면서 생각지도 못했던 흥미로운 스토리들이 너무나 많았다. 좀 더 비중있게 다뤄진 호크아이,...',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 2, 38),
#   0],
#  ['김경석(dkff****)',
#   '울트론이 생각보다 너무 약해 긴장감이 조금 적었던 부분이 아쉬움. 허나 1편에비해 업그래이드된 영상미, 유머 등등 여러모로 괜찮은 작품이다. 올해 최고의 영화가 될 것 같다.',
#   '8',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 25, 2, 4),
#   0],
#  ['cogsci(keok****)',
#   '어벤져스 1 보다 낫다 ..',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 20, 9),
#   0],
#  ['하늘나뭇잎(hong****)',
#   '뭘 기대하고 보느냐에 따라서 다르겠지만 액션을 원했다면 강추',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 19, 57),
#   0],
#  ['모테레간미노(gohi****)',
#   '의떤 신선함도 없으며 그저 첨부터 끝까지 부수기만 한다. 아... 의미없다...',
#   '5',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 16, 1),
#   0],
#  ['jh17****',
#   '저 4D로 18,000원 내고 봤는데요 그냥 2D로 봐도 나쁘지 않을 것 같아요돈 아깝지않고 더 재밌게 보실 수 있을거에요',
#   '7',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 14, 35),
#   0],
#  ['인기만점(kaca****)',
#   '조금 어수하긴했지만 유머있고 재미있게봤습니다ㅋ 토르망치 어벤져스멤버들이 돌아가면서 들때 웃겼네ㅋㅋ',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 9, 53),
#   0],
#  ['정yo한(wjdd****)',
#   '내가 딱 바라던 스토리, 그 이상진정한 마블팬이라면 다른사람들이 지루하게 느꼈던 그장면들이 새로워서 좋았고 진지해서 좋았을것,1편보다 훨씬 더 많이 웃었다 감독이 1편의 느낌을 못내서 이리만들었겠냐 스칼렛 위치?개쩔...',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 8, 42),
#   0],
#  ['노비츠키(dulc****)',
#   '이번 가장 쩔었던건 다른 히어로도 아닌 자비스였다. 수퍼맨인줄. 매번 목소리만 출연하던 폴 베타니가 cg지만 영화에 얼굴을 드러낸건 반가웠지!!',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 4, 50),
#   0],
#  ['하늘을날자(99gu****)',
#   '서울배경 노래방간판에 움찔하고 고가도로 너무 좁아 없어 보여서 확장공사 시키고 싶고 한국의 수도인데 할렘가 인줄 알았음...우리나라는 아직 도시가 안이쁜듯. 내용은 굿!!!',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 24, 3, 32),
#   0],
#  ['뚜곰01(nab0****)',
#   '이건 뭐 엄청나네요 새로나온 스칼렛위치와 퀵실버 그리고 비전이 참 신선하게 느껴지네요 그런데 헐크 팬으로서 헐크가 비중이 너무 작은건 좀 아쉽네요.... 그래도 절대 실망시키지 않는 마블 영화 다음 작도 기대되네요',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 23, 7),
#   0],
#  ['OrOiU(teer****)',
#   '솔직히 레알 진짜 꿀잼임',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 21, 11),
#   0],
#  ['yyhz****',
#   '딱 기대만큼만 재미있었다 하지만 또보고싶다',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 20, 24),
#   0],
#  ['단풍(yung****)',
#   '마르지 않는 샘물, 매력적인 스칼렛위치',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 20, 14),
#   0],
#  ['GoodSoul(timb****)',
#   '이 보다 더한 오락활극을 원하는것은 사치다.후반부  어벤져스들 뭉쳐서 싸우는 장면은 이 영화의 백미....',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 19, 41),
#   0],
#  ['엠케이(mkma****)',
#   '마지막 엔딩크레딧,,.. 어벤져스3 편이 기다려진다...!!!',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 19, 35),
#   0],
#  ['ADERA(ader****)',
#   '냉정을 찾고 이성적인 평가 6점. 1탄보단 노잼.',
#   '6',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 16, 12),
#   0],
#  ['콕(zhd0****)',
#   '너무 어두웠음 개봉 첫날 팬심으로 조조 달려가 봤는데 내가 마블 시리즈 보다가 잠시 졸다니...수현 이뻤고 서울 배경은 떡볶이 간판만 기억에 남아있지만 액션씬이 멋있어서 울나라에서 저런 대단한 장면을 찍다니 약간 뿌...',
#   '5',
#   '4',
#   '1',
#   datetime.datetime(2015, 4, 23, 13, 15),
#   0],
#  ['김도현(ewq5****)',
#   '에이지 오브 울트론은 뭔가 임팩트없고 1편에 비해 기대만큼은 아니었다는 평이 당시에는 많았으나 엔드게임까지 나열하면서 많은 탄탄대로의 설정들을 여기서 꽤 많이 풀어뒀다 시빌워 보다도 더 미래에 영향이 컸던 영화',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2019, 8, 4, 2, 58),
#   0],
#  ['sson****',
#   '2편은 보고 또 봐도 매장면들이 기억에 안남. 처음본 느낌',
#   '6',
#   '5',
#   '2',
#   datetime.datetime(2019, 4, 29, 1, 49),
#   0],
#  ['원지후(pete****)',
#   '울트론도 알고보면 깊이 있는 빌런이라는 것을 모르고 그 강함에만 집착하는 관객들의 좁은 눈이 안쓰럽다.',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2018, 4, 24, 17, 25),
#   0],
#  ['jar9****',
#   '..? 평점이 왜 이리 높담 마블 팬이지만 어벤2는 정말...;;',
#   '6',
#   '5',
#   '2',
#   datetime.datetime(2017, 9, 23, 15, 43),
#   0],
#  ['기억8987(ciot****)',
#   '정말 별 한개도 아까운 영화다....그 많은 돈 때려넣어서 이렇게 지루하게 만드는 것도 참 대단하다.',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 9, 21, 0, 19),
#   0],
#  ['미란다꺼커(veni****)',
#   '너무 지루하다 뭐 하러 여기에 돈 지원했냐',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 9, 16, 1, 1),
#   0],
#  ['0ops****',
#   '아 진짜 쓰레기..한국 씬들 씨쥐 개 그지같고 내용이 전반적으로 너무 그지같음 그리고 너무 말도 안됨.논리도 안맞고 무슨 주인공들이 완젼 무적임..      적어도 활쏘는 넘이랑 걔들은 인간인데',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 7, 2, 15, 53),
#   0],
#  ['루미너스(shsh****)',
#   '배경이 여기저기 갔다가 엄청 헷갈린다',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 6, 11, 10, 29),
#   0],
#  ['cxcxlsls(wwc5****)',
#   '처음으로 영화를보면서 잠들었다',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 6, 7, 15, 13),
#   0],
#  ['암사자(namp****)',
#   '영웅물은 배트맨 미만 쓰레기',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 6, 7, 2, 39),
#   0],
#  ['hellowooju(hell****)',
#   '이게  잼있다니 지루해죽겠다 지금 CGV드림플러스극장에서 언제끝나하고 씀',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 5, 5, 20, 41),
#   0],
#  ['gkwl****',
#   '별로... 원래 히어로물을 별로 안좋아해서그런가 지루햇음',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 5, 5, 4, 10),
#   0],
#  ['망아지야(rlat****)',
#   '인간적으로 별점이 너무높다 7.5정도가 적당하다고 본다',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 5, 2, 2, 9),
#   0],
#  ['gnlf****',
#   "It ain't funny  핵노잼",
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 5, 1, 21, 35),
#   0],
#  ['라이더(2fas****)',
#   '20년넘는 무비라이프 사상 2번째로  중간에 나온영화..축하합니다.',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 5, 1, 10, 16),
#   0],
#  ['파란달빛(ufoi****)',
#   '그저 그러함..소문난 잔치에 먹을 거 없다더만...',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 30, 21, 59),
#   0],
#  ['디오게네스(rodm****)',
#   '뭔가 구성도는 1보다 퇴보했고 마블영화는 고질적으로 악당이빈약한데 영화에서 울트론도 역시는 역시였다. 3에서 타노스를 기대하겠음 3는 더잼있을듯하다',
#   '1',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 28, 12, 12),
#   0],
#  ['ggls****',
#   '한국이 너무 후진국처럼나옴',
#   '5',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 25, 13, 8),
#   0],
#  ['chlq****',
#   '너무 기대했나보다 스토리 라인이 너무 지루함',
#   '6',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 25, 9, 59),
#   0],
#  ['박형빈(mjc0****)',
#   '역시 어벤져스다. 무슨 말이 필요할까. 이번에 한국에서 촬영해서 인지 더 정감이 간다. 마블이 전해주는 엄청난 액션을 몸소느껴보길 강력추천한다. 코믹한 장면도 생각외로 많아 웃음도 선사할것이다',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 25, 4, 31),
#   0],
#  ['ejmi****',
#   '뭐가 재미가없다는거지..?? 오락은오락영화일뿐이지,,시간가는줄모르게봤음..3편4편 기대됨..그냥미친영화..ㅎㅎ',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 18, 40),
#   0],
#  ['패피(taeg****)',
#   '명불허전 마블!!!!',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 10, 11),
#   0],
#  ['lesg****',
#   '와...졸음이 싹 달아나는 영화. 그냥 대박!!!',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 9, 57),
#   0],
#  ['처루(delt****)',
#   '역시 기다린 보람이 있네 중간 중간 살짝 지루할 수 있으나 전체적으로 말이 필요없네 2015년 현재 최고의 영화',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 9, 45),
#   0],
#  ['연아의커피(isuz****)',
#   '서울시에서 제작비 30억 지원해준거.. 헛돈 썼네요.',
#   '6',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 1, 18),
#   0],
#  ['yhk0****',
#   '생각보다 훨 재미없네. 기존의 영화들보다 구성에서 너무 늘어져.  많은 분들이 기다리던 서울 씬은 있어도 그만 없어도 그만일만큼 비중이 너무 적어 아쉬움. 비디오 영화용이 적정.',
#   '7',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 24, 0, 7),
#   0],
#  ['거성(ohmr****)',
#   '마블짬뽕스는 역시 좀 정신이 x 그래도 캐릭터 하나하나 무게감을 실어줘서 좋았다. 근데 왠지 어벤져스2가 아니라 아이언맨4를 본 것 같은  이 느낌은 뭐지?',
#   '8',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 23, 22, 31),
#   0],
#  ['후루룩쩝(kukk****)',
#   '진수성찬도 때때로 먹어야 맛나지 영화내내 맛난 음식을 들이미니 끝날때 쯤은 아예 앉아서 보는것 마저 고역이다',
#   '5',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 23, 21, 58),
#   0],
#  ['coolest guy(syru****)',
#   "예상 외 엄청난 비중을 차지하는 수현(헬렌  조),  '아마데우스 조'  시네마틱 유니버스에선 어케  등장 할까? ㅋㅋ  마블 제작 영환 닥치고 봐야한다.  하나의 거대한 시리즈를 놓치지 말자.",
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 23, 20, 34),
#   0],
#  ['join****',
#   '마블 시리즈 마니아면 무척 좋아할 것이고 그렇지 않은 분들에겐 다소 지루해 할지도 모르겠다. 다소 어두워진 분위기에 누구나 갖고 있는 트라우마에 대한 혼란과 고뇌도 엮여낼 줄도 아는 이 영화는 꽤 산만한 전개임에도 ...',
#   '9',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 23, 20, 9),
#   0],
#  ['리치(1009****)',
#   '놀라운 완성도에 눈이 즐거운 영화입니다. 서울장면  저는 상당히 흥미롭던데요??? 분량이 중요하겠지만 영화 핵심적인 부분에 등장하는 서울  도심이 새로웠습니다.  재미는 보장합니다 ^^',
#   '9',
#   '5',
#   '2',
#   datetime.datetime(2015, 4, 23, 19, 47),
#   0],
#  ['ekrs****',
#   '한마디로초딩영화...',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 7, 2, 14, 44),
#   0],
#  ['한중의왕(port****)',
#   '이딴게 천만관객??? 노잼이다. 1점주기에도  아깝다.',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 6, 18, 8, 29),
#   0],
#  ['모노(meso****)',
#   '진심으로 별점8점대는 아니다',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 6, 4, 20, 51),
#   0],
#  ['rlaw****',
#   '3개 주려햇으나 평점이 높아서 1점줌.내가 아직 20대 중반인데도 왤케 유치해서 못봐주겟는지. 스토리도 너무 뻔하고 급한상황에 헐크 러브라인 못봐주겟고 싸움 중간에 아이언맨 개그치는것도 개유치ㅠ 쌍둥이 여자가 어벤져...',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 15, 16, 5),
#   0],
#  ['gml1****',
#   '지금 이점수 너무 높다 ㅋㅋ 기억나는건 질레트, 아우디, 삼성 ㅋㅋㅋ',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 15, 10, 43),
#   0],
#  ['wjdt****',
#   '조잡하게 때거지로 나와서 부시기만 하고 잔해만 남긴영화',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 14, 19, 44),
#   0],
#  ['박서방(ok79****)',
#   '그래픽 티가 팍팍 나네.. 분노의 질주랑 너무 비교 되잖어',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 13, 2, 4),
#   0],
#  ['오주형(oh62****)',
#   '퀵실버죽이다니 나빳다',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 8, 14, 40),
#   0],
#  ['데니스(cvov****)',
#   '가볍게 즐기면 모르겠는데',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 6, 17, 30),
#   0],
#  ['토린이(ming****)',
#   '극장에서 영화보다 졸린적은 처음인듯~',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 6, 17, 28),
#   0],
#  ['천하제일(chun****)',
#   '이런 쓰레기 영화가 평점 높다는 자체가 얼마나 미개한 문화수준인지..안타깝다..헐리우드 같은 미개 영화 수준이 통하는게 한심..',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 6, 13, 13),
#   0],
#  ['지킬하드(dall****)',
#   'CG 는 화려합니다~ 만, 정말 재미없었습니다.1편의~ 반도 못따라오는~ 스토리~ 보시면 돈아깝다 생각 하실거예요 ㅎ~ 이영환~6점이 적당하다고 봅니다.',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 5, 19, 25),
#   0],
#  ['쿠킹호일(spgs****)',
#   '돈아깝다ㅇㄱㄹㅇ, ㄹㅇㅍㅌ',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 5, 15, 57),
#   0],
#  ['진영이는내꺼(one8****)',
#   '그리고어벤져스재미없어요그냥서울만나오고끝인데요',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 5, 13, 20),
#   0],
#  ['네이벌(hine****)',
#   '딱히 1편보다 재미없음 그냥 싸우기만함',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 4, 16, 22),
#   0],
#  ['rebk****',
#   '졸다가 팝콘 쏟았다.. 최악이었다.',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 3, 23, 49),
#   0],
#  ['Tei(toef****)',
#   '어벤져스관련시리즈 다봤지만 개인적으로는 이번이 최악이던데.. 왜이렇게평점이높은건지..',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 2, 23, 7),
#   0],
#  ['corr****',
#   '아 진짜 기대 엄청했는데, 지루한부분이 너무 많아.',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 2, 11, 28),
#   0],
#  ['savi****',
#   '할말이없다....ㅠ',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 2, 2, 23),
#   0],
#  ['둥굴레(gong****)',
#   '스토리 엉망, 쌩뚱맞네 정말..',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 5, 1, 20, 40),
#   0],
#  ['shin****',
#   '말이 필요없이 쓰레기였다. 한국에서 촬영했다고 평점 높이는거 보소',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 30, 11, 7),
#   0],
#  ['이승호(plok****)',
#   '평점 너무 높아서 조절하려고 1드립니다.솔직히 너무 많은 캐릭터 때문에 개개인 액션씬 너무 정신사나워 보였고 너무 많은 떡밥 때문에 내용집중하기가 너무 어려웠어요...그래도 쿠키영상 안본건 좀 후회되네요ㅠ',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 27, 15, 11),
#   0],
#  ['zard****',
#   '워 월 흥분하지말고 워 워',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 26, 20, 42),
#   0],
#  ['최정민(ssam****)',
#   '평점 7.9점 조절용입니다',
#   '1',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 26, 18, 51),
#   0],
#  ['연(gomg****)',
#   '솔직히 재미없었따.그동안  마블영화가 흔한 건, 주변스토리와 세계관을 몰라도그 자체 영화만으로도 영화 한편의 스토리를 이해하고 재밌게 웃을 수 있었다.어벤저스2는 세계관 모르니 정말 재미없더라.',
#   '3',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 25, 10, 13),
#   0],
#  ['ㅇㅇ(ksyy****)',
#   '그냥슈퍼히어로영화 7 점이 적당함',
#   '7',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 23, 18, 4),
#   0],
#  ['jame****',
#   '걍 잼잼 인피니티잼 타노스 크리딧 베이베',
#   '10',
#   '6',
#   '3',
#   datetime.datetime(2015, 4, 23, 10, 57),
#   0],
#  ['김지원(hatb****)',
#   '국뽕들  한국 나온다고 싱글벙글 하더니 헬조센 보고 엉엉 ㅋㅋㅋㅋ',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 31, 21, 55),
#   0],
#  ['한화V2(csl1****)',
#   '노잼이다 진심이게 뭐냐',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 30, 13, 15),
#   0],
#  ['민트초콜릿(yile****)',
#   '개인적으로 너무재미없어서 보다가중간에나왔어요나랑코드가안맞는건지.. 돈아까워ㅠㅠ',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 19, 12, 15),
#   0],
#  ['하늘이짱(salt****)',
#   '기대보다 너무 지루하다',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 17, 21, 3),
#   0],
#  ['조자(maen****)',
#   '노잼....돈아까워',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 17, 12, 40),
#   0],
#  ['kimb****',
#   '매드맥스 보고 오신분은 느끼실 겁니다 이정도 배우로 이정도 재미밖에 초딩들이나 오타쿠들 좋다고 환호 지르던데 저는 아이언버스터 헐크 액션장면밖에 남는게 없네요 어벤져스1이나 아이언맨3에 비하면 개망작',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 15, 12, 46),
#   0],
#  ['슈마갤(getg****)',
#   '평점 너무 높다..1편보다 영..',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 11, 18, 44),
#   0],
#  ['나이트(aszx****)',
#   '기대했던것 보다 별로임',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 9, 8, 29),
#   0],
#  ['tini****',
#   '그냥 어벤져스라는 이름뿐.... 실망이네요',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 4, 15, 3),
#   0],
#  ['흐아(rhdn****)',
#   '재미없어요ㅋㅋㅋㅋ 진짜 지금 개거품낀 영화임',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 4, 14, 56),
#   0],
#  ['sadf54(sltk****)',
#   '액션초딩영화.. 두시간동안 시간버리다온기분. 꼭보세요~ 나만돈버리기 아까움',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 2, 23, 7),
#   0],
#  ['4v49****',
#   '별내용도. 반전도없는 초딩용.',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 2, 11, 4),
#   0],
#  ['범돌범돌(jung****)',
#   '시리즈 최악의 작품. 뜬금없는 환영의 샘장면에선 진짜 실소가..',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 2, 10, 33),
#   0],
#  ['아롱이(kar9****)',
#   '이걸영화라고?기대엄청했는데재미없고 결국 나중에는평화네요',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 1, 19, 29),
#   0],
#  ['혈산객(jkby****)',
#   '중학생급도 안될 딱 초딩용 마블 어벤져스2 에이지 오브 울트론에 다 낚인 8일간 430만 ㅎㅎ 진짜 한국사람들만 한순간에 바보되고 이미 관람한 430만 관객이 다 헐리웃 봉 된 느낌...',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 1, 14, 21),
#   0],
#  ['썹썹(jere****)',
#   '돈주고 보기엔 좀 아깝고 한국나와서 기대했는데 별로네요.',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 5, 1, 14, 12),
#   0],
#  ['달이(luna****)',
#   '3점은 되는데 평점이 너무 높아 1점 줍니다. 저 영화 많이 보는데... 손에 꼽을 정도로 정말 최. 악입니다.',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 30, 23, 12),
#   0],
#  ['12345(ckdr****)',
#   '초딩들 싸그리 10점주네',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 29, 18, 43),
#   0],
#  ['나나좋아(vmvm****)',
#   '핵노잼  같이간 초딩들은  재미졌라했것만   난 상영중에 잤다능     처음과 끝만봤다',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 29, 18, 6),
#   0],
#  ['연듀(jyj6****)',
#   '정말 이런 평점 안남기는데 아무리 생각해도 이 영화는 그냥.. 미국 대빵 크게 나오고 한국은 뒷골목만 보여주고 이거 보여주려고 울 나라는 그렇게 돈을 썻냐ㅠㅠ스토리도 개똥같았다 어벤져스 실망왕실망그냥 영화보고 나니 ...',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 29, 1, 58),
#   0],
#  ['아기별(119d****)',
#   '올해들어ㅠ 최고로 재미없어요 지루하고 진짜 잡탕같은 느낌 ㅠ진짜 기대안하고 갔는데 기대이하이하실망',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 29, 1, 51),
#   0],
#  ['cbw0****',
#   '분노의 질주 봐라 차라리 그게 더 재밌는듯',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 28, 20, 4),
#   0],
#  ['김은서(dmst****)',
#   '개재미어뵤어짖에서잠이나잘걸',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 28, 18, 3),
#   0],
#  ['김용선(king****)',
#   '기대했던것보다실망많이지루해요',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 28, 0, 32),
#   0],
#  ['태일(tai2****)',
#   '벌써 기억안남... 무슨 내용이었지?',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 27, 17, 40),
#   0],
#  ['hyun****',
#   '한국흥보도 개뿔,, 흥보수익은 커녕 적자 나겠거만, 글고 개연성도 딱히 없고,,, 내생각엔 잘된 영화는 아닌것 같다.이건 걍 내개인적인 의견이니 태클거실분은 딴대가서 거셈.괜히 태클시비걸지말고',
#   '1',
#   '7',
#   '4',
#   datetime.datetime(2015, 4, 27, 14, 41),
#   0],
#  ['왕자가아닌한아이(sysh****)',
#   '이게 영화냐? ..디워 보는 거 같다..',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2015, 5, 17, 14, 11),
#   0],
#  ['rhs1****',
#   '잘잤습니다..나도 모르게 잠이 들더라구요.. 마치 자장가듣는 아이처럼...',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2015, 5, 11, 14, 24),
#   0],
#  ['아젤(crcr****)',
#   '초딩용 영화에 개똥같은 철학을 입히려는 무리수',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2015, 5, 9, 16, 12),
#   0],
#  ['큰곰부(west****)',
#   '무슨 만화영화 본 느낌...황당무계..돈이 아깝네..',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2015, 5, 7, 16, 23),
#   0],
#  ['스톰(kmye****)',
#   '정말 제작비와 출연배우들이 아까운 망작이었다. 마블코믹스 시리즈는 전부 챙겨서 봤지만, 어벤져스1과 비교해도 정말 형편없는 빈약한 스토리와 진부한 대사, 전혀 개연성 없는 전개... 솔직히 평정 1점도 아깝다. 관람...',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2015, 5, 5, 4, 44),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                      0  ...    6
# 0         유유(foxm****)  ...    0
# 1         별이(ilu3****)  ...    0
# 2      비토다츠야(outs****)  ...    0
# 3             fbi0****  ...    0
# 4       장난하냐(cgs0****)  ...    0
# ...                ...  ...  ...
# 4995      디엠(piou****)  ...  관람객
# 4996    잿빛분노(tnis****)  ...    0
# 4997  하이웨이스타(rr12****)  ...  관람객
# 4998  컴온굿리액션(cico****)  ...    0
# 4999      스신(soss****)  ...    0
#
# [5000 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#               nickname  ... watch_movie
# 0         유유(foxm****)  ...           0
# 1         별이(ilu3****)  ...           0
# 2      비토다츠야(outs****)  ...           0
# 3             fbi0****  ...           0
# 4       장난하냐(cgs0****)  ...           0
# ...                ...  ...         ...
# 4995      디엠(piou****)  ...         관람객
# 4996    잿빛분노(tnis****)  ...           0
# 4997  하이웨이스타(rr12****)  ...         관람객
# 4998  컴온굿리액션(cico****)  ...           0
# 4999      스신(soss****)  ...           0
#
# [5000 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
